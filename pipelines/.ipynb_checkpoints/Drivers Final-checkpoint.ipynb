# %% [markdown]
# ## Importing the Required Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import csv
import matplotlib as mp
import matplotlib.pyplot as plt
import mysql.connector as mysql
from sqlalchemy import create_engine

# %%
engine = create_engine('mysql+pymysql://root:Visionamd@23@localhost/montgomery')

# %% [markdown]
# ## Reading Data into Variable Named Data From the CSV File

# %%
data = pd.read_csv("Drivers_Data_20240404.csv")
# Out:
# /var/folders/_t/d0zkt0395w39b1mpx92kjmrw0000gn/T/ipykernel_55901/1262171991.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("Drivers_Data_20240404.csv")

# %%
# Checking the input data which was imported from the csv into the data variable

# %%
data.head()
# Out:
#   Report Number Local Case Number                Agency Name  \
# 0   MCP3040003N         190026050   Montgomery County Police
# 1    EJ78850038         230034791  Gaithersburg Police Depar
# 2   MCP2009002G         230034583   Montgomery County Police
# 3   MCP3201004C         230035036   Montgomery County Police
# 4   MCP23290028         230035152   Montgomery County Police
#
#         ACRS Report Type         Crash Date/Time        Route Type  \
# 0  Property Damage Crash  05/31/2019 03:00:00 PM               NaN
# 1  Property Damage Crash  07/21/2023 05:59:00 PM  Maryland (State)
# 2  Property Damage Crash  07/20/2023 03:10:00 PM  Maryland (State)
# 3  Property Damage Crash  07/23/2023 12:10:00 PM            County
# 4  Property Damage Crash  07/24/2023 06:10:00 AM            County
#
#                 Road Name Cross-Street Type  Cross-Street Name  \
# 0                     NaN               NaN                NaN
# 1            FREDERICK RD           Unknown    WATKINS MILL RD
# 2             GEORGIA AVE  Maryland (State)         NORBECK RD
# 3         CRYSTAL ROCK DR            County  WATERS LANDING DR
# 4  MONTGOMERY VILLAGE AVE            County       CENTERWAY RD
#
#              Off-Road Description  ... Speed Limit Driverless Vehicle  \
# 0  PARKING LOT OF 3215 SPARTAN RD  ...          15                 No
# 1                             NaN  ...          40                 No
# 2                             NaN  ...          35                 No
# 3                             NaN  ...          40                 No
# 4                             NaN  ...          35                 No
#
#   Parked Vehicle Vehicle Year Vehicle Make Vehicle Model Equipment Problems  \
# 0             No         2004        HONDA            TK            UNKNOWN
# 1             No         2011          GMC            TK          NO MISUSE
# 2             No         2019         FORD          F150          NO MISUSE
# 3             No         2016          KIA            SW          NO MISUSE
# 4             No         2016         TOYT            TK          NO MISUSE
#
#     Latitude  Longitude                     Location
# 0  39.150044 -77.063089  (39.15004368, -77.06308884)
# 1  39.159264 -77.219025   (39.1592635, -77.21902483)
# 2  39.109535 -77.075806  (39.10953506, -77.07580619)
# 3  39.190149 -77.266766  (39.19014917, -77.26676583)
# 4  39.172558 -77.203745  (39.17255801, -77.20374546)
#
# [5 rows x 43 columns]

# %% [markdown]
# ## Creating Relational Database Connection MYSQL

# %%
# Establishing connection
connection = mysql.connect(
            host='localhost',
            user='root',
            password='Visionamd@23',
            database='montgomery'
)

if connection.is_connected():
    print("Connected to MySQL database")
# Out:
# Connected to MySQL database

# %%
connection

# %%
mycursor = connection.cursor()

# %% [markdown]
# ## Relational Database Queries / DML Statements / DDL Statements

# %%
# Sql Statement for creation of table

# %%
querycreate = '''CREATE TABLE IF NOT EXISTS drivers_final(
   report_number text,
   local_case_number text,
   agency_name text,
   acrs_report_type text,
   crash_date_time text,
   route_type text,
   road_name text,
   cross_street_type text,
   cross_street_name text,
   off_road_description text,
   municipality text,
   related_non_motorist text,
   collision_type text,
   weather text,
   surface_condition text,
   light text,
   traffic_control text,
   driver_substance_abuse text,
   non_motorist_substance_abuse text,
   person_id text,
   driver_at_fault text,
   injury_severity text,
   circumstance text,
   driver_distracted_by text,
   drivers_license_state text,
   vehicle_id text,
   vehicle_damage_extent text,
   vehicle_first_impact_location text,
   vehicle_second_impact_location text,
   vehicle_body_type text,
   vehicle_movement text,
   vehicle_continuing_dir text,
   vehicle_going_dir text,
   speed_limit text,
   driverless_vehicle text,
   parked_vehicle text,
   vehicle_year text,
   vehicle_make text,
   vehicle_model text,
   equipment_problems text,
   latitude text,
   longitude text,
   location text
                )'''

# %%
mycursor.execute(querycreate) # executing/creating a table
connection.commit() # Commit the transaction

# %% [markdown]
# ## Checking the Tables in the Database

# %%
mycursor.execute("SHOW TABLES")
tables = mycursor.fetchall()

# Print table names
for table in tables:
    print(table[0])
# Out:
# drivers
# drivers1
# drivers_final

# %%
# Check Description of the drivers table
querydescribe="DESCRIBE drivers_final"

# %%
mycursor.execute(querydescribe)

# %%
columns=mycursor.fetchall()
for column in columns:
    print(column[0], "-", column[1])
# Out:
# report_number - text
# local_case_number - text
# agency_name - text
# acrs_report_type - text
# crash_date_time - text
# route_type - text
# road_name - text
# cross_street_type - text
# cross_street_name - text
# off_road_description - text
# municipality - text
# related_non_motorist - text
# collision_type - text
# weather - text
# surface_condition - text
# light - text
# traffic_control - text
# driver_substance_abuse - text
# non_motorist_substance_abuse - text
# person_id - text
# driver_at_fault - text
# injury_severity - text
# circumstance - text
# driver_distracted_by - text
# drivers_license_state - text
# vehicle_id - text
# vehicle_damage_extent - text
# vehicle_first_impact_location - text
# vehicle_second_impact_location - text
# vehicle_body_type - text
# vehicle_movement - text
# vehicle_continuing_dir - text
# vehicle_going_dir - text
# speed_limit - text
# driverless_vehicle - text
# parked_vehicle - text
# vehicle_year - text
# vehicle_make - text
# vehicle_model - text
# equipment_problems - text
# latitude - text
# longitude - text
# location - text

# %%
# Sql Statement for inserting data into the table

# %%
queryinsert = '''INSERT INTO drivers_final (
    report_number,
    local_case_number,
    agency_name,
    acrs_report_type,
    crash_date_time,
    route_type,
    road_name,
    cross_street_type,
    cross_street_name,
    off_road_description,
    municipality,
    related_non_motorist,
    collision_type,
    weather,
    surface_condition,
    light,
    traffic_control,
    driver_substance_abuse,
    non_motorist_substance_abuse,
    person_id,
    driver_at_fault,
    injury_severity,
    circumstance,
    driver_distracted_by,
    drivers_license_state,
    vehicle_id,
    vehicle_damage_extent,
    vehicle_first_impact_location,
    vehicle_second_impact_location,
    vehicle_body_type,
    vehicle_movement,
    vehicle_continuing_dir,
    vehicle_going_dir,
    speed_limit,
    driverless_vehicle,
    parked_vehicle,
    vehicle_year,
    vehicle_make,
    vehicle_model,
    equipment_problems,
    latitude,
    longitude,
    location
) VALUES ( %s,%s,%s,%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)'''

# %%
df=data

# %%
print(df.dtypes)
# Out:
# Report Number                      object
# Local Case Number                  object
# Agency Name                        object
# ACRS Report Type                   object
# Crash Date/Time                    object
# Route Type                         object
# Road Name                          object
# Cross-Street Type                  object
# Cross-Street Name                  object
# Off-Road Description               object
# Municipality                       object
# Related Non-Motorist               object
# Collision Type                     object
# Weather                            object
# Surface Condition                  object
# Light                              object
# Traffic Control                    object
# Driver Substance Abuse             object
# Non-Motorist Substance Abuse       object
# Person ID                          object
# Driver At Fault                    object
# Injury Severity                    object
# Circumstance                       object
# Driver Distracted By               object
# Drivers License State              object
# Vehicle ID                         object
# Vehicle Damage Extent              object
# Vehicle First Impact Location      object
# Vehicle Second Impact Location     object
# Vehicle Body Type                  object
# Vehicle Movement                   object
# Vehicle Continuing Dir             object
# Vehicle Going Dir                  object
# Speed Limit                         int64
# Driverless Vehicle                 object
# Parked Vehicle                     object
# Vehicle Year                        int64
# Vehicle Make                       object
# Vehicle Model                      object
# Equipment Problems                 object
# Latitude                          float64
# Longitude                         float64
# Location                           object
# dtype: object

# %% [markdown]
# ## Filling Empty spaces with Missing

# %%
df_filled = data.fillna("Missing")

# %%
df_filled
# Out:
#        Report Number Local Case Number                Agency Name  \
# 0        MCP3040003N         190026050   Montgomery County Police
# 1         EJ78850038         230034791  Gaithersburg Police Depar
# 2        MCP2009002G         230034583   Montgomery County Police
# 3        MCP3201004C         230035036   Montgomery County Police
# 4        MCP23290028         230035152   Montgomery County Police
# ...              ...               ...                        ...
# 172100    DM8338000C          16010228  Takoma Park Police Depart
# 172101   MCP1182001S         170519976   Montgomery County Police
# 172102   MCP1453008X         200046217   Montgomery County Police
# 172103   MCP2568000M         190056701   Montgomery County Police
# 172104   MCP1048000P          15003337   Montgomery County Police
#
#              ACRS Report Type         Crash Date/Time        Route Type  \
# 0       Property Damage Crash  05/31/2019 03:00:00 PM           Missing
# 1       Property Damage Crash  07/21/2023 05:59:00 PM  Maryland (State)
# 2       Property Damage Crash  07/20/2023 03:10:00 PM  Maryland (State)
# 3       Property Damage Crash  07/23/2023 12:10:00 PM            County
# 4       Property Damage Crash  07/24/2023 06:10:00 AM            County
# ...                       ...                     ...               ...
# 172100  Property Damage Crash  01/03/2016 10:01:00 AM      Municipality
# 172101  Property Damage Crash  07/19/2017 02:22:00 PM            County
# 172102  Property Damage Crash  11/23/2020 07:37:00 AM  Maryland (State)
# 172103  Property Damage Crash  11/23/2019 11:23:00 PM            County
# 172104  Property Damage Crash  01/21/2015 09:02:00 AM  Maryland (State)
#
#                        Road Name Cross-Street Type  \
# 0                        Missing           Missing
# 1                   FREDERICK RD           Unknown
# 2                    GEORGIA AVE  Maryland (State)
# 3                CRYSTAL ROCK DR            County
# 4         MONTGOMERY VILLAGE AVE            County
# ...                          ...               ...
# 172100  NEW HAMPSHIRE SERVICE LA      Municipality
# 172101                  CEDAR LA  Maryland (State)
# 172102                  RIDGE RD           Unknown
# 172103            SHADY GROVE RD              Ramp
# 172104              FREDERICK RD      Municipality
#
#                             Cross-Street Name            Off-Road Description  \
# 0                                     Missing  PARKING LOT OF 3215 SPARTAN RD
# 1                             WATKINS MILL RD                         Missing
# 2                                  NORBECK RD                         Missing
# 3                           WATERS LANDING DR                         Missing
# 4                                CENTERWAY RD                         Missing
# ...                                       ...                             ...
# 172100                     PRINCE GEORGES AVE                         Missing
# 172101                      OLD GEORGETOWN RD                         Missing
# 172102                     LITTLE SENECA PKWY                         Missing
# 172103  RAMP 9 FR IS 370 EB TO SHADY GROVE RD                         Missing
# 172104                              W GUDE DR                         Missing
#
#         ... Speed Limit Driverless Vehicle Parked Vehicle Vehicle Year  \
# 0       ...          15                 No             No         2004
# 1       ...          40                 No             No         2011
# 2       ...          35                 No             No         2019
# 3       ...          40                 No             No         2016
# 4       ...          35                 No             No         2016
# ...     ...         ...                ...            ...          ...
# 172100  ...          25                 No             No         2016
# 172101  ...          35                 No             No         2008
# 172102  ...          40                 No             No         2008
# 172103  ...          35                 No             No         2018
# 172104  ...          35                 No             No         2011
#
#        Vehicle Make Vehicle Model Equipment Problems   Latitude  Longitude  \
# 0             HONDA            TK            UNKNOWN  39.150044 -77.063089
# 1               GMC            TK          NO MISUSE  39.159264 -77.219025
# 2              FORD          F150          NO MISUSE  39.109535 -77.075806
# 3               KIA            SW          NO MISUSE  39.190149 -77.266766
# 4              TOYT            TK          NO MISUSE  39.172558 -77.203745
# ...             ...           ...                ...        ...        ...
# 172100         FORD      EXPLORER          NO MISUSE  38.972560 -76.997466
# 172101       NISSAN        ALTIMA          NO MISUSE  39.004640 -77.108502
# 172102    CHEVROLET       EXPRESS          NO MISUSE  39.228963 -77.236757
# 172103         FORD   TRANSIT VAN          NO MISUSE  39.120440 -77.180047
# 172104        HONDA           CRV            Missing  39.106847 -77.158380
#
#                            Location
# 0       (39.15004368, -77.06308884)
# 1        (39.1592635, -77.21902483)
# 2       (39.10953506, -77.07580619)
# 3       (39.19014917, -77.26676583)
# 4       (39.17255801, -77.20374546)
# ...                             ...
# 172100  (38.97255976, -76.99746609)
# 172101     (39.00464, -77.10850167)
# 172102  (39.22896333, -77.23675667)
# 172103  (39.12043995, -77.18004738)
# 172104     (39.10684667, -77.15838)
#
# [172105 rows x 43 columns]

# %%
# replacing all the values as strings in the data columns
df_filled.astype(str)
# Out:
#        Report Number Local Case Number                Agency Name  \
# 0        MCP3040003N         190026050   Montgomery County Police
# 1         EJ78850038         230034791  Gaithersburg Police Depar
# 2        MCP2009002G         230034583   Montgomery County Police
# 3        MCP3201004C         230035036   Montgomery County Police
# 4        MCP23290028         230035152   Montgomery County Police
# ...              ...               ...                        ...
# 172100    DM8338000C          16010228  Takoma Park Police Depart
# 172101   MCP1182001S         170519976   Montgomery County Police
# 172102   MCP1453008X         200046217   Montgomery County Police
# 172103   MCP2568000M         190056701   Montgomery County Police
# 172104   MCP1048000P          15003337   Montgomery County Police
#
#              ACRS Report Type         Crash Date/Time        Route Type  \
# 0       Property Damage Crash  05/31/2019 03:00:00 PM           Missing
# 1       Property Damage Crash  07/21/2023 05:59:00 PM  Maryland (State)
# 2       Property Damage Crash  07/20/2023 03:10:00 PM  Maryland (State)
# 3       Property Damage Crash  07/23/2023 12:10:00 PM            County
# 4       Property Damage Crash  07/24/2023 06:10:00 AM            County
# ...                       ...                     ...               ...
# 172100  Property Damage Crash  01/03/2016 10:01:00 AM      Municipality
# 172101  Property Damage Crash  07/19/2017 02:22:00 PM            County
# 172102  Property Damage Crash  11/23/2020 07:37:00 AM  Maryland (State)
# 172103  Property Damage Crash  11/23/2019 11:23:00 PM            County
# 172104  Property Damage Crash  01/21/2015 09:02:00 AM  Maryland (State)
#
#                        Road Name Cross-Street Type  \
# 0                        Missing           Missing
# 1                   FREDERICK RD           Unknown
# 2                    GEORGIA AVE  Maryland (State)
# 3                CRYSTAL ROCK DR            County
# 4         MONTGOMERY VILLAGE AVE            County
# ...                          ...               ...
# 172100  NEW HAMPSHIRE SERVICE LA      Municipality
# 172101                  CEDAR LA  Maryland (State)
# 172102                  RIDGE RD           Unknown
# 172103            SHADY GROVE RD              Ramp
# 172104              FREDERICK RD      Municipality
#
#                             Cross-Street Name            Off-Road Description  \
# 0                                     Missing  PARKING LOT OF 3215 SPARTAN RD
# 1                             WATKINS MILL RD                         Missing
# 2                                  NORBECK RD                         Missing
# 3                           WATERS LANDING DR                         Missing
# 4                                CENTERWAY RD                         Missing
# ...                                       ...                             ...
# 172100                     PRINCE GEORGES AVE                         Missing
# 172101                      OLD GEORGETOWN RD                         Missing
# 172102                     LITTLE SENECA PKWY                         Missing
# 172103  RAMP 9 FR IS 370 EB TO SHADY GROVE RD                         Missing
# 172104                              W GUDE DR                         Missing
#
#         ... Speed Limit Driverless Vehicle Parked Vehicle Vehicle Year  \
# 0       ...          15                 No             No         2004
# 1       ...          40                 No             No         2011
# 2       ...          35                 No             No         2019
# 3       ...          40                 No             No         2016
# 4       ...          35                 No             No         2016
# ...     ...         ...                ...            ...          ...
# 172100  ...          25                 No             No         2016
# 172101  ...          35                 No             No         2008
# 172102  ...          40                 No             No         2008
# 172103  ...          35                 No             No         2018
# 172104  ...          35                 No             No         2011
#
#        Vehicle Make Vehicle Model Equipment Problems     Latitude  \
# 0             HONDA            TK            UNKNOWN  39.15004368
# 1               GMC            TK          NO MISUSE   39.1592635
# 2              FORD          F150          NO MISUSE  39.10953506
# 3               KIA            SW          NO MISUSE  39.19014917
# 4              TOYT            TK          NO MISUSE  39.17255801
# ...             ...           ...                ...          ...
# 172100         FORD      EXPLORER          NO MISUSE  38.97255976
# 172101       NISSAN        ALTIMA          NO MISUSE     39.00464
# 172102    CHEVROLET       EXPRESS          NO MISUSE  39.22896333
# 172103         FORD   TRANSIT VAN          NO MISUSE  39.12043995
# 172104        HONDA           CRV            Missing  39.10684667
#
#            Longitude                     Location
# 0       -77.06308884  (39.15004368, -77.06308884)
# 1       -77.21902483   (39.1592635, -77.21902483)
# 2       -77.07580619  (39.10953506, -77.07580619)
# 3       -77.26676583  (39.19014917, -77.26676583)
# 4       -77.20374546  (39.17255801, -77.20374546)
# ...              ...                          ...
# 172100  -76.99746609  (38.97255976, -76.99746609)
# 172101  -77.10850167     (39.00464, -77.10850167)
# 172102  -77.23675667  (39.22896333, -77.23675667)
# 172103  -77.18004738  (39.12043995, -77.18004738)
# 172104     -77.15838     (39.10684667, -77.15838)
#
# [172105 rows x 43 columns]

# %%
# Defining a variable to use as input counter

# %%
in_rec_cnt = 0

# %%
for index, row in df_filled.iterrows():
    mycursor.execute(queryinsert, tuple(row))
    in_rec_cnt += 1

# %%
connection.commit()

# %%
print("Number of records inserted into table:", in_rec_cnt)
# Out:
# Number of records inserted into table: 172105

# %%
mycursor.execute("SELECT COUNT(*) FROM drivers_final")
mycursor.fetchone()[0]
# Out:
# 172105

# %%
querydropcol = '''ALTER TABLE drivers_final
DROP COLUMN Latitude,
DROP COLUMN Longitude,
DROP COLUMN Location'''

# %%
mycursor.execute(querydropcol)

# %%
connection.commit()

# %%
# Execute the DESCRIBE query
mycursor.execute("DESCRIBE drivers_final")

# Fetch and print the column information
columns = mycursor.fetchall()
for column in columns:
    print(column)
# Out:
# ('report_number', 'text', 'YES', '', None, '')
# ('local_case_number', 'text', 'YES', '', None, '')
# ('agency_name', 'text', 'YES', '', None, '')
# ('acrs_report_type', 'text', 'YES', '', None, '')
# ('crash_date_time', 'text', 'YES', '', None, '')
# ('route_type', 'text', 'YES', '', None, '')
# ('road_name', 'text', 'YES', '', None, '')
# ('cross_street_type', 'text', 'YES', '', None, '')
# ('cross_street_name', 'text', 'YES', '', None, '')
# ('off_road_description', 'text', 'YES', '', None, '')
# ('municipality', 'text', 'YES', '', None, '')
# ('related_non_motorist', 'text', 'YES', '', None, '')
# ('collision_type', 'text', 'YES', '', None, '')
# ('weather', 'text', 'YES', '', None, '')
# ('surface_condition', 'text', 'YES', '', None, '')
# ('light', 'text', 'YES', '', None, '')
# ('traffic_control', 'text', 'YES', '', None, '')
# ('driver_substance_abuse', 'text', 'YES', '', None, '')
# ('non_motorist_substance_abuse', 'text', 'YES', '', None, '')
# ('person_id', 'text', 'YES', '', None, '')
# ('driver_at_fault', 'text', 'YES', '', None, '')
# ('injury_severity', 'text', 'YES', '', None, '')
# ('circumstance', 'text', 'YES', '', None, '')
# ('driver_distracted_by', 'text', 'YES', '', None, '')
# ('drivers_license_state', 'text', 'YES', '', None, '')
# ('vehicle_id', 'text', 'YES', '', None, '')
# ('vehicle_damage_extent', 'text', 'YES', '', None, '')
# ('vehicle_first_impact_location', 'text', 'YES', '', None, '')
# ('vehicle_second_impact_location', 'text', 'YES', '', None, '')
# ('vehicle_body_type', 'text', 'YES', '', None, '')
# ('vehicle_movement', 'text', 'YES', '', None, '')
# ('vehicle_continuing_dir', 'text', 'YES', '', None, '')
# ('vehicle_going_dir', 'text', 'YES', '', None, '')
# ('speed_limit', 'text', 'YES', '', None, '')
# ('driverless_vehicle', 'text', 'YES', '', None, '')
# ('parked_vehicle', 'text', 'YES', '', None, '')
# ('vehicle_year', 'text', 'YES', '', None, '')
# ('vehicle_make', 'text', 'YES', '', None, '')
# ('vehicle_model', 'text', 'YES', '', None, '')
# ('equipment_problems', 'text', 'YES', '', None, '')

# %%
# Sql Statement for Visualisation of data inserted into the table

# %%
queryshowtab = "SELECT * FROM drivers_final;"

# %%
mycursor.execute(queryshowtab)
mycursor.fetchall()
# Out:
# [('MCP3040003N',
#   '190026050',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '05/31/2019 03:00:00 PM',
#   'Missing',
#   'Missing',
#   'Missing',
#   'Missing',
#   'PARKING LOT OF 3215 SPARTAN RD',
#   'Missing',
#   'Missing',
#   'OTHER',
#   'CLEAR',
#   'Missing',
#   'DAYLIGHT',
#   'Missing',
#   'UNKNOWN',
#   'Missing',
#   'DE2A24CD-7919-4F8D-BABF-5B75CE12D21E',
#   'Yes',
#   'NO APPARENT INJURY',
#   'Missing',
#   'UNKNOWN',
#   'Missing',
#   '165AD539-A8C8-4004-AF73-B7DCAAA8B3CC',
#   'SUPERFICIAL',
#   'ONE OCLOCK',
#   'ONE OCLOCK',
#   'PASSENGER CAR',
#   'PARKING',
#   'North',
#   'North',
#   '15',
#   'No',
#   'No',
#   '2004',
#   'HONDA',
#   'TK',
#   'UNKNOWN'),
#  ('EJ78850038',
#   '230034791',
#   'Gaithersburg Police Depar',
#   'Property Damage Crash',
#   '07/21/2023 05:59:00 PM',
#   'Maryland (State)',
#   'FREDERICK RD',
#   'Unknown',
#   'WATKINS MILL RD',
#   'Missing',
#   'Missing',
#   'Missing',
#   'STRAIGHT MOVEMENT ANGLE',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'TRAFFIC SIGNAL',
#   'NONE DETECTED',
#   'Missing',
#   'E7058A8E-4F18-4D2A-954E-04A099CFED12',
#   'No',
#   'NO APPARENT INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'MD',
#   '1C3C3E2F-9A23-4ED0-9BB3-B6C370D99C37',
#   'DISABLING',
#   'THREE OCLOCK',
#   'TWO OCLOCK',
#   'PASSENGER CAR',
#   'MAKING LEFT TURN',
#   'East',
#   'South',
#   '40',
#   'No',
#   'No',
#   '2011',
#   'GMC',
#   'TK',
#   'NO MISUSE'),
#  ('MCP2009002G',
#   '230034583',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '07/20/2023 03:10:00 PM',
#   'Maryland (State)',
#   'GEORGIA AVE',
#   'Maryland (State)',
#   'NORBECK RD',
#   'Missing',
#   'Missing',
#   'Missing',
#   'STRAIGHT MOVEMENT ANGLE',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'TRAFFIC SIGNAL',
#   'NONE DETECTED',
#   'Missing',
#   '2B404D6D-8DB5-4CB6-9E71-9F1B8D0A8925',
#   'Yes',
#   'NO APPARENT INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'MD',
#   '0483CE47-E0FC-4BCA-BAB0-B7541820FEE6',
#   'FUNCTIONAL',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   'PICKUP TRUCK',
#   'ACCELERATING',
#   'North',
#   'North',
#   '35',
#   'No',
#   'No',
#   '2019',
#   'FORD',
#   'F150',
#   'NO MISUSE'),
#  ('MCP3201004C',
#   '230035036',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '07/23/2023 12:10:00 PM',
#   'County',
#   'CRYSTAL ROCK DR',
#   'County',
#   'WATERS LANDING DR',
#   'Missing',
#   'Missing',
#   'Missing',
#   'STRAIGHT MOVEMENT ANGLE',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'NO CONTROLS',
#   'NONE DETECTED',
#   'Missing',
#   '637D8107-0381-4B8D-848A-B4A93B4D53CE',
#   'Yes',
#   'NO APPARENT INJURY',
#   'Missing',
#   'LOOKED BUT DID NOT SEE',
#   'MD',
#   '4406AA84-07F8-45F4-88A2-09AD89AC9AAF',
#   'FUNCTIONAL',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   'PASSENGER CAR',
#   'STARTING FROM LANE',
#   'East',
#   'East',
#   '40',
#   'No',
#   'No',
#   '2016',
#   'KIA',
#   'SW',
#   'NO MISUSE'),
#  ('MCP23290028',
#   '230035152',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '07/24/2023 06:10:00 AM',
#   'County',
#   'MONTGOMERY VILLAGE AVE',
#   'County',
#   'CENTERWAY RD',
#   'Missing',
#   'Missing',
#   'Missing',
#   'HEAD ON LEFT TURN',
#   'CLOUDY',
#   'DRY',
#   'DAYLIGHT',
#   'TRAFFIC SIGNAL',
#   'NONE DETECTED',
#   'Missing',
#   '52F904CB-822C-4D8D-9457-0D66B99AD407',
#   'Yes',
#   'NO APPARENT INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'CA',
#   '148FAA0F-4EBB-43E8-9339-BBED3F245751',
#   'FUNCTIONAL',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   '(SPORT) UTILITY VEHICLE',
#   'MAKING LEFT TURN',
#   'West',
#   'North',
#   '35',
#   'No',
#   'No',
#   '2016',
#   'TOYT',
#   'TK',
#   'NO MISUSE'),
#  ('MCP295200DV',
#   '230032956',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '11/07/2023 07:40:00 AM',
#   'County',
#   'WAYNE AVE',
#   'County',
#   'ALLEY',
#   'Missing',
#   'Missing',
#   'Missing',
#   'SAME DIR REAR END',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'NO CONTROLS',
#   'NONE DETECTED',
#   'Missing',
#   '800B57CA-3277-4DC5-8C8D-457AF042F683',
#   'No',
#   'NO APPARENT INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'MD',
#   'E9504EBF-592D-4E6D-B28E-07B8773E2530',
#   'FUNCTIONAL',
#   'SIX OCLOCK',
#   'SIX OCLOCK',
#   'TRANSIT BUS',
#   'STOPPED IN TRAFFIC LANE',
#   'East',
#   'East',
#   '30',
#   'No',
#   'No',
#   '2016',
#   'GILL',
#   'BUS',
#   'NO MISUSE'),
#  ('MCP33510013',
#   '230033282',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '12/07/2023 08:28:00 PM',
#   'Maryland (State)',
#   'COLESVILLE RD',
#   'US (State)',
#   'COLESVILLE RD',
#   'Missing',
#   'Missing',
#   'Missing',
#   'SAME DIR REAR END',
#   'CLEAR',
#   'DRY',
#   'DUSK',
#   'NO CONTROLS',
#   'NONE DETECTED',
#   'Missing',
#   '3F9D8C7E-6F06-45DC-8250-E30A8ACC5F2A',
#   'Yes',
#   'NO APPARENT INJURY',
#   'ANIMAL, N/A',
#   'NOT DISTRACTED',
#   'MD',
#   '870FF895-E20E-41E0-BE96-CC7D86335B37',
#   'DISABLING',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   '(SPORT) UTILITY VEHICLE',
#   'SLOWING OR STOPPING',
#   'South',
#   'South',
#   '25',
#   'No',
#   'No',
#   '2014',
#   'SUBA',
#   'SW',
#   'NO MISUSE'),
#  ('EJ7869003F',
#   '230032124',
#   'Gaithersburg Police Depar',
#   'Injury Crash',
#   '05/07/2023 11:25:00 PM',
#   'Maryland (State)',
#   'CLOPPER RD',
#   'Unknown',
#   'STRUC #15093 GREAT SENECA CREEK',
#   'Missing',
#   'Missing',
#   'Missing',
#   'SINGLE VEHICLE',
#   'CLEAR',
#   'DRY',
#   'DARK -- UNKNOWN LIGHTING',
#   'NO CONTROLS',
#   'ALCOHOL PRESENT',
#   'Missing',
#   '6247C8F6-297F-4E71-B653-B69CBB22804E',
#   'Yes',
#   'SUSPECTED MINOR INJURY',
#   'Missing',
#   'UNKNOWN',
#   'MD',
#   '5D60FF00-F6AB-4774-9A87-6D7C62856972',
#   'DESTROYED',
#   'TWELVE OCLOCK',
#   'FOUR OCLOCK',
#   'PASSENGER CAR',
#   'MOVING CONSTANT SPEED',
#   'North',
#   'North',
#   '35',
#   'No',
#   'No',
#   '2013',
#   'BMW',
#   '328I',
#   'UNKNOWN'),
#  ('MCP3244002K',
#   '230034697',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '07/21/2023 07:14:00 AM',
#   'US (State)',
#   'GEORGIA AVE',
#   'Unknown',
#   'NW EASTERN AVE (DC MAINT)',
#   'Missing',
#   'Missing',
#   'Missing',
#   'SAME DIR REAR END',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'TRAFFIC SIGNAL',
#   'UNKNOWN',
#   'Missing',
#   '41DDE59B-58B1-4A00-8A0E-4C4B9CD7B6E1',
#   'Yes',
#   'NO APPARENT INJURY',
#   'Missing',
#   'UNKNOWN',
#   'Missing',
#   '1B98988B-1BBC-4ED4-955B-C48617170157',
#   'Missing',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   'PASSENGER CAR',
#   'STARTING FROM LANE',
#   'South',
#   'South',
#   '35',
#   'No',
#   'No',
#   '2020',
#   'HYUNDAI',
#   'ELENTRA',
#   'UNKNOWN'),
#  ('MCP2863002V',
#   '230034445',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '07/19/2023 07:00:00 PM',
#   'Maryland (State)',
#   'WOODFIELD RD',
#   'County',
#   'MIDCOUNTY HWY',
#   'Missing',
#   'Missing',
#   'Missing',
#   'SAME DIR REAR END',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'OTHER',
#   'NONE DETECTED',
#   'Missing',
#   'D3E6DAAE-9C30-4FC6-B791-4B21F2B35246',
#   'Yes',
#   'NO APPARENT INJURY',
#   'Missing',
#   'INATTENTIVE OR LOST IN THOUGHT',
#   'MD',
#   'ED90B6F6-216F-4C97-BD23-B12D8F2124C9',
#   'SUPERFICIAL',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   '(SPORT) UTILITY VEHICLE',
#   'SLOWING OR STOPPING',
#   'North',
#   'North',
#   '30',
#   'No',
#   'No',
#   '2022',
#   'VOLK',
#   'UT',
#   'NO MISUSE'),
#  ('MCP2456007L',
#   '230034690',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '07/20/2023 05:00:00 PM',
#   'County',
#   'OLD COLUMBIA PIKE',
#   'County',
#   'BRIGGS CHANEY RD',
#   'Missing',
#   'Missing',
#   'Missing',
#   'SAME DIR REAR END',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'TRAFFIC SIGNAL',
#   'NONE DETECTED',
#   'Missing',
#   'AFE3019A-E804-41D6-BECF-822275F1FEA7',
#   'No',
#   'NO APPARENT INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'MD',
#   '96DD6BD8-B88A-41C8-AC5B-7F19B12431D0',
#   'FUNCTIONAL',
#   'SIX OCLOCK',
#   'SIX OCLOCK',
#   'VAN',
#   'STOPPED IN TRAFFIC LANE',
#   'West',
#   'North',
#   '35',
#   'No',
#   'No',
#   '2013',
#   'FORD',
#   'E350',
#   'NO MISUSE'),
#  ('MCP2009002G',
#   '230034583',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '07/20/2023 03:10:00 PM',
#   'Maryland (State)',
#   'GEORGIA AVE',
#   'Maryland (State)',
#   'NORBECK RD',
#   'Missing',
#   'Missing',
#   'Missing',
#   'STRAIGHT MOVEMENT ANGLE',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'TRAFFIC SIGNAL',
#   'NONE DETECTED',
#   'Missing',
#   '175152ED-D7D4-4570-9FB4-F8D73B4F3437',
#   'No',
#   'NO APPARENT INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'MD',
#   '8AC1AAF7-17E6-437C-86CD-AD0F5C1A1749',
#   'DISABLING',
#   'FOUR OCLOCK',
#   'FIVE OCLOCK',
#   'PASSENGER CAR',
#   'ACCELERATING',
#   'East',
#   'East',
#   '35',
#   'No',
#   'No',
#   '2017',
#   'FORD',
#   'FUSION',
#   'Missing'),
#  ('MCP9365001V',
#   '230030221',
#   'Montgomery County Police',
#   'Injury Crash',
#   '06/24/2023 12:39:00 PM',
#   'Maryland (State)',
#   'SANDY SPRING RD',
#   'County',
#   'DINO DR',
#   'Missing',
#   'Missing',
#   'BICYCLIST',
#   'SAME DIR REAR END',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'Missing',
#   'NONE DETECTED',
#   'NONE DETECTED',
#   '6593C76A-AF80-4C4A-A44B-6AE3837159C0',
#   'No',
#   'NO APPARENT INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'MD',
#   '500A519E-9193-4C07-8C41-033E3DF20D08',
#   'FUNCTIONAL',
#   'SIX OCLOCK',
#   'SIX OCLOCK',
#   'PASSENGER CAR',
#   'STOPPED IN TRAFFIC LANE',
#   'East',
#   'East',
#   '50',
#   'No',
#   'No',
#   '2008',
#   'HONDA',
#   'CIVIC',
#   'NO MISUSE'),
#  ('EJ78860034',
#   '230034298',
#   'Gaithersburg Police Depar',
#   'Property Damage Crash',
#   '06/19/2023 10:19:00 PM',
#   'Missing',
#   'Missing',
#   'Missing',
#   'Missing',
#   'LIBERTY GAS STATION LOCATED AT 623 S. FREDERICK AVENUE, GAITHERSBURG, MD 20877',
#   'Missing',
#   'Missing',
#   'SAME DIR REAR END',
#   'CLEAR',
#   'Missing',
#   'DARK LIGHTS ON',
#   'Missing',
#   'Missing',
#   'Missing',
#   'F8C59941-49D6-4741-AB50-A9316E2CB36C',
#   'Unknown',
#   'NO APPARENT INJURY',
#   'Missing',
#   'UNKNOWN',
#   'MD',
#   '5CD98587-8A06-4A6A-B585-1631923C12B4',
#   'FUNCTIONAL',
#   'UNKNOWN',
#   'UNKNOWN',
#   'PASSENGER CAR',
#   'BACKING',
#   'South',
#   'South',
#   '0',
#   'No',
#   'No',
#   '2012',
#   'HONDA',
#   'ACCORD COUPE',
#   'Missing'),
#  ('MCP2927004G',
#   '230032852',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '10/07/2023 03:26:00 PM',
#   'County',
#   'FOREST GLEN RD',
#   'County',
#   'DAMERON DR',
#   'Missing',
#   'Missing',
#   'Missing',
#   'SAME DIR REAR END',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'TRAFFIC SIGNAL',
#   'NONE DETECTED',
#   'Missing',
#   '39CF6083-CB08-474F-A53E-20B9B6CA8314',
#   'Yes',
#   'NO APPARENT INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'MD',
#   '030C6EB6-F848-4E69-AC75-E85FD58BE285',
#   'FUNCTIONAL',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   'PASSENGER CAR',
#   'SLOWING OR STOPPING',
#   'West',
#   'West',
#   '25',
#   'No',
#   'No',
#   '2016',
#   'HONDA',
#   '4S',
#   'NO MISUSE'),
#  ('MCP2270001V',
#   '230033962',
#   'Montgomery County Police',
#   'Injury Crash',
#   '07/17/2023 08:50:00 AM',
#   'Maryland (State)',
#   'WISCONSIN AVE',
#   'Other Public Roadway',
#   'SOMERSET TERRACE',
#   'Missing',
#   'Missing',
#   'Missing',
#   'HEAD ON LEFT TURN',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'TRAFFIC SIGNAL',
#   'NONE DETECTED',
#   'Missing',
#   'EB063DCF-D48C-4706-8F0B-E69D7150F840',
#   'Yes',
#   'NO APPARENT INJURY',
#   'Missing',
#   'LOOKED BUT DID NOT SEE',
#   'MD',
#   '3476A508-746E-4E4B-9209-099CE5BC23B3',
#   'DISABLING',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   'PASSENGER CAR',
#   'MAKING LEFT TURN',
#   'East',
#   'South',
#   '35',
#   'No',
#   'No',
#   '2011',
#   'TOYOTA',
#   'CAMRY',
#   'NO MISUSE'),
#  ('MCP3360000L',
#   '230046354',
#   'Montgomery County Police',
#   'Injury Crash',
#   '07/25/2023 10:12:00 AM',
#   'County',
#   'WATKINS MILL RD',
#   'County',
#   'STEDWICK RD',
#   'Missing',
#   'Missing',
#   'BICYCLIST',
#   'SINGLE VEHICLE',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'TRAFFIC SIGNAL',
#   'UNKNOWN',
#   'Missing',
#   '31EF564E-B954-460B-8D06-AD0FA078A6F7',
#   'Yes',
#   'NO APPARENT INJURY',
#   'Missing',
#   'UNKNOWN',
#   'Missing',
#   'DF9118CC-3545-4FEB-9D3C-09A4BFF40F2F',
#   'UNKNOWN',
#   'UNKNOWN',
#   'UNKNOWN',
#   'PASSENGER CAR',
#   'MAKING RIGHT TURN',
#   'East',
#   'North',
#   '35',
#   'No',
#   'No',
#   '2020',
#   'TOYOTA',
#   'CAMRY',
#   'UNKNOWN'),
#  ('MCP2948006B',
#   '230034678',
#   'Montgomery County Police',
#   'Injury Crash',
#   '07/21/2023 01:15:00 AM',
#   'County',
#   'KENDALL ST',
#   'County',
#   'NEWTON ST',
#   'Missing',
#   'Missing',
#   'Missing',
#   'HEAD ON',
#   'CLEAR',
#   'Missing',
#   'DARK -- UNKNOWN LIGHTING',
#   'Missing',
#   'UNKNOWN',
#   'Missing',
#   '9D7CBFF7-30BA-408C-8CC9-4B927BEA1100',
#   'Yes',
#   'SUSPECTED MINOR INJURY',
#   'Missing',
#   'UNKNOWN',
#   'MD',
#   '246FD5B0-708D-47CF-B060-CAA40AD720C1',
#   'DISABLING',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   'PASSENGER CAR',
#   'MOVING CONSTANT SPEED',
#   'South',
#   'South',
#   '25',
#   'No',
#   'No',
#   '2015',
#   'VOLKSWAGON',
#   'PASSAT',
#   'NO MISUSE'),
#  ('MCP22030073',
#   '230034143',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '07/18/2023 08:45:00 AM',
#   'Missing',
#   'Missing',
#   'Missing',
#   'Missing',
#   'PARKING LOT OF 2405 REEDIE DR (DUNKIN DONUTS)',
#   'Missing',
#   'Missing',
#   'ANGLE MEETS LEFT HEAD ON',
#   'CLEAR',
#   'Missing',
#   'DAYLIGHT',
#   'NO CONTROLS',
#   'UNKNOWN',
#   'Missing',
#   '1A9CDB9B-0DD9-4B32-A7A9-7FCAB3D5A76D',
#   'Yes',
#   'NO APPARENT INJURY',
#   'Missing',
#   'UNKNOWN',
#   'Missing',
#   '5313B100-EED5-48F7-911A-585EA9462E61',
#   'UNKNOWN',
#   'SIX OCLOCK',
#   'SIX OCLOCK',
#   '(SPORT) UTILITY VEHICLE',
#   'BACKING',
#   'East',
#   'East',
#   '15',
#   'No',
#   'No',
#   '2010',
#   'VOLKSWAGON',
#   'TIGUAN',
#   'UNKNOWN'),
#  ('MCP2723007B',
#   '230035094',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '07/23/2023 06:00:00 PM',
#   'Maryland (State)',
#   'GEORGIA AVE',
#   'County',
#   'GLENALLAN AVE',
#   'Missing',
#   'Missing',
#   'Missing',
#   'SAME DIR REAR END',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'TRAFFIC SIGNAL',
#   'UNKNOWN',
#   'Missing',
#   'AA8FE01A-FC0B-4ADA-818E-DA48C4A5791A',
#   'No',
#   'NO APPARENT INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'Missing',
#   'E55BBE34-E50A-4C1C-9091-8AF96A21C03D',
#   'UNKNOWN',
#   'SIX OCLOCK',
#   'SIX OCLOCK',
#   'PICKUP TRUCK',
#   'SLOWING OR STOPPING',
#   'North',
#   'North',
#   '35',
#   'No',
#   'No',
#   '2018',
#   'DODGE',
#   'RAM 2500',
#   'UNKNOWN'),
#  ('MCP32070038',
#   '230034789',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '07/21/2023 05:05:00 PM',
#   'Maryland (State)',
#   'NEW HAMPSHIRE AVE',
#   'Unknown',
#   'MICHELSON RD',
#   'Missing',
#   'Missing',
#   'Missing',
#   'SINGLE VEHICLE',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'TRAFFIC SIGNAL',
#   'NONE DETECTED',
#   'Missing',
#   '4AE1BD23-1853-4AFA-BC0C-DEB54854B18D',
#   'Yes',
#   'NO APPARENT INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'MD',
#   'C2006EBE-E4DE-4BE4-9C10-BA76C1F2ABAA',
#   'DISABLING',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   'PASSENGER CAR',
#   'MAKING LEFT TURN',
#   'East',
#   'East',
#   '40',
#   'No',
#   'No',
#   '2018',
#   'HYUNDAI',
#   'SONATA',
#   'NO MISUSE'),
#  ('MCP3086009C',
#   '230034046',
#   'Montgomery County Police',
#   'Injury Crash',
#   '07/17/2023 05:10:00 PM',
#   'County',
#   'MUNCASTER RD',
#   'County',
#   'WILD FLOWER CT',
#   'Missing',
#   'Missing',
#   'Missing',
#   'OPPOSITE DIRECTION SIDESWIPE',
#   'CLOUDY',
#   'DRY',
#   'DAYLIGHT',
#   'NO CONTROLS',
#   'NONE DETECTED',
#   'Missing',
#   '273895A3-78AC-4FD5-AB8E-D4077E9220D7',
#   'No',
#   'NO APPARENT INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'MD',
#   '3C2754E5-774E-4401-8912-E81270C258C2',
#   'DISABLING',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   '(SPORT) UTILITY VEHICLE',
#   'MOVING CONSTANT SPEED',
#   'North',
#   'North',
#   '30',
#   'No',
#   'No',
#   '2008',
#   'NISSAN',
#   'ROGUE',
#   'NO MISUSE'),
#  ('MCP2361002M',
#   '230046471',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '07/27/2023 03:41:00 PM',
#   'Maryland (State)',
#   'MONTGOMERY VILLAGE AVE',
#   'County',
#   'LOST KNIFE RD',
#   'Missing',
#   'Missing',
#   'Missing',
#   'STRAIGHT MOVEMENT ANGLE',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'TRAFFIC SIGNAL',
#   'NONE DETECTED',
#   'Missing',
#   'C78CA90F-4188-41F1-B737-6165311C6F5D',
#   'No',
#   'NO APPARENT INJURY',
#   'Missing',
#   'UNKNOWN',
#   'MD',
#   '05AB7DD3-1F60-4C71-AE7F-9D5B57DC904D',
#   'FUNCTIONAL',
#   'NINE OCLOCK',
#   'NINE OCLOCK',
#   'PASSENGER CAR',
#   'ACCELERATING',
#   'West',
#   'West',
#   '35',
#   'No',
#   'No',
#   '2007',
#   'LEXUS',
#   '4D',
#   'NO MISUSE'),
#  ('MCP3126004Q',
#   '230035266',
#   'Montgomery County Police',
#   'Injury Crash',
#   '07/24/2023 04:45:00 PM',
#   'Maryland (State)',
#   'RIDGE RD',
#   'County',
#   'HAWKES RD',
#   'Missing',
#   'Missing',
#   'Missing',
#   'STRAIGHT MOVEMENT ANGLE',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'NO CONTROLS',
#   'NONE DETECTED',
#   'Missing',
#   '0C3BE5BE-F7E0-49CB-AAA3-24B4E03F40E0',
#   'Yes',
#   'SUSPECTED SERIOUS INJURY',
#   'Missing',
#   'LOOKED BUT DID NOT SEE',
#   'MD',
#   '38ECE958-F4E3-423C-9BC3-DEC1BC440A04',
#   'DESTROYED',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   'MOTORCYCLE',
#   'MOVING CONSTANT SPEED',
#   'North',
#   'North',
#   '40',
#   'No',
#   'No',
#   '2005',
#   'YAMAHA',
#   'MC',
#   'NO MISUSE'),
#  ('MCP12050099',
#   '230034759',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '07/21/2023 02:30:00 PM',
#   'County',
#   'STONEYBROOK DR',
#   'County',
#   'LA DUKE DR',
#   'Missing',
#   'Missing',
#   'Missing',
#   'SAME DIRECTION RIGHT TURN',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'NO CONTROLS',
#   'NONE DETECTED',
#   'Missing',
#   '01AA896E-906A-4BCC-89B4-5A558CE5F1EE',
#   'Yes',
#   'NO APPARENT INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'MD',
#   'C4AF5D21-9BBF-493B-9D5E-2F116FECE473',
#   'DISABLING',
#   'ONE OCLOCK',
#   'ONE OCLOCK',
#   'PASSENGER CAR',
#   'MOVING CONSTANT SPEED',
#   'North',
#   'North',
#   '25',
#   'No',
#   'No',
#   '2014',
#   'HONDA',
#   'CRZ',
#   'NO MISUSE'),
#  ('MCP26740046',
#   '230034929',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '07/22/2023 03:39:00 PM',
#   'County',
#   'LEWIS DR',
#   'Maryland (State)',
#   'RIDGE RD',
#   'Missing',
#   'Missing',
#   'Missing',
#   'SAME DIRECTION RIGHT TURN',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'STOP SIGN',
#   'NONE DETECTED',
#   'Missing',
#   '43D3A6D8-35BB-4031-B053-56D1B1E19E06',
#   'Yes',
#   'NO APPARENT INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'MD',
#   'B43131C9-25C3-4543-9E3C-D2EA5A3588ED',
#   'FUNCTIONAL',
#   'TEN OCLOCK',
#   'TEN OCLOCK',
#   'PASSENGER CAR',
#   'MAKING RIGHT TURN',
#   'West',
#   'South',
#   '25',
#   'No',
#   'No',
#   '2013',
#   'HYUNDAI',
#   'SONATA',
#   'NO MISUSE'),
#  ('MCP31090086',
#   '230034491',
#   'Montgomery County Police',
#   'Injury Crash',
#   '07/20/2023 07:30:00 AM',
#   'US (State)',
#   'COLESVILLE RD',
#   'County',
#   'LANARK WAY',
#   'Missing',
#   'Missing',
#   'Missing',
#   'SAME DIR REAR END',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'TRAFFIC SIGNAL',
#   'UNKNOWN',
#   'Missing',
#   '234D4A7C-C639-4006-B9B8-9E372AC352EB',
#   'No',
#   'NO APPARENT INJURY',
#   'Missing',
#   'UNKNOWN',
#   'Missing',
#   '58B0BFDD-4954-460D-95E5-9F947B7DD54E',
#   'UNKNOWN',
#   'UNKNOWN',
#   'UNKNOWN',
#   'UNKNOWN',
#   'UNKNOWN',
#   'South',
#   'South',
#   '35',
#   'No',
#   'No',
#   '0',
#   'UNKNOWN',
#   'UNKNOWN',
#   'UNKNOWN'),
#  ('MCP2846008X',
#   '230034260',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '07/17/2023 10:45:00 AM',
#   'County',
#   'SELFRIDGE RD',
#   'County',
#   'RANDOLPH RD',
#   'Missing',
#   'Missing',
#   'Missing',
#   'OTHER',
#   'CLEAR',
#   'DRY',
#   'DARK LIGHTS ON',
#   'TRAFFIC SIGNAL',
#   'UNKNOWN',
#   'Missing',
#   '9ACC5A7E-47A1-438F-BF0E-40B0A8632055',
#   'Yes',
#   'NO APPARENT INJURY',
#   'Missing',
#   'INATTENTIVE OR LOST IN THOUGHT',
#   'MD',
#   '8B61B8E0-5473-4C78-A654-6029684ABD03',
#   'SUPERFICIAL',
#   'SEVEN OCLOCK',
#   'SEVEN OCLOCK',
#   'PASSENGER CAR',
#   'MOVING CONSTANT SPEED',
#   'East',
#   'East',
#   '35',
#   'No',
#   'No',
#   '2003',
#   'FORD',
#   'TK',
#   'NO MISUSE'),
#  ('MCP32900026',
#   '230033569',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '07/14/2023 02:22:00 PM',
#   'Maryland (State)',
#   'GEORGIA AVE',
#   'Maryland (State)',
#   'FOREST GLEN RD',
#   'Missing',
#   'Missing',
#   'Missing',
#   'SAME DIR REAR END',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'Missing',
#   'NONE DETECTED',
#   'Missing',
#   '42394778-78CC-4A0D-82E0-BC0A7950299F',
#   'Unknown',
#   'NO APPARENT INJURY',
#   'Missing',
#   'UNKNOWN',
#   'MD',
#   'D7C5FA89-92AA-4A92-8F9D-9F4A5DFD5ECF',
#   'FUNCTIONAL',
#   'SIX OCLOCK',
#   'SIX OCLOCK',
#   'PASSENGER CAR',
#   'CHANGING LANES',
#   'North',
#   'North',
#   '35',
#   'No',
#   'No',
#   '2013',
#   'INFI',
#   '4S',
#   'Missing'),
#  ('MCP2534004S',
#   '230046104',
#   'Montgomery County Police',
#   'Injury Crash',
#   '07/26/2023 12:57:00 AM',
#   'Maryland (State)',
#   'GEORGIA AVE',
#   'County',
#   'BLUERIDGE AVE',
#   'Missing',
#   'Missing',
#   'Missing',
#   'STRAIGHT MOVEMENT ANGLE',
#   'CLEAR',
#   'DRY',
#   'DARK LIGHTS ON',
#   'FLASHING TRAFFIC SIGNAL',
#   'NONE DETECTED',
#   'Missing',
#   'FA53E592-CA1D-47FF-A254-5029847D7039',
#   'Yes',
#   'SUSPECTED MINOR INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'MD',
#   'E7BDDF09-C796-4C2F-8350-455FB2C66053',
#   'DISABLING',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   'PASSENGER CAR',
#   'MOVING CONSTANT SPEED',
#   'East',
#   'East',
#   '25',
#   'No',
#   'No',
#   '2020',
#   'HYUNDAI',
#   'ELANTRA',
#   'NO MISUSE'),
#  ('MCP2974004N',
#   '230034511',
#   'Montgomery County Police',
#   'Injury Crash',
#   '07/20/2023 09:25:00 AM',
#   'Maryland (State)',
#   'SANDY SPRING RD',
#   'US (State)',
#   'COLUMBIA PIKE',
#   'Missing',
#   'Missing',
#   'Missing',
#   'SAME DIR REAR END',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'NO CONTROLS',
#   'NONE DETECTED',
#   'Missing',
#   '846FFDA1-4DDA-4ED5-9BDF-BB55450E121C',
#   'Yes',
#   'SUSPECTED MINOR INJURY',
#   'ANIMAL, BACKUP DUE TO NON-RECURRING INCIDENT',
#   'OTHER DISTRACTION',
#   'MD',
#   'DDF969AD-15DE-4076-8881-D6AD5359CF76',
#   'DISABLING',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   'PASSENGER CAR',
#   'MOVING CONSTANT SPEED',
#   'West',
#   'West',
#   '35',
#   'No',
#   'No',
#   '2014',
#   'NISSAN',
#   'PATHFINDER',
#   'NO MISUSE'),
#  ('EJ78850038',
#   '230034791',
#   'Gaithersburg Police Depar',
#   'Property Damage Crash',
#   '07/21/2023 05:59:00 PM',
#   'Maryland (State)',
#   'FREDERICK RD',
#   'Unknown',
#   'WATKINS MILL RD',
#   'Missing',
#   'Missing',
#   'Missing',
#   'STRAIGHT MOVEMENT ANGLE',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'TRAFFIC SIGNAL',
#   'NONE DETECTED',
#   'Missing',
#   'C649EC6C-F5C4-4B0C-89FE-5F44AF95D47A',
#   'Yes',
#   'NO APPARENT INJURY',
#   'Missing',
#   'UNKNOWN',
#   'MD',
#   'BD5AF939-61D2-498C-97B3-6E274946D45E',
#   'DISABLING',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   'PASSENGER CAR',
#   'MOVING CONSTANT SPEED',
#   'North',
#   'North',
#   '40',
#   'No',
#   'No',
#   '2011',
#   'BMW',
#   '4S',
#   'NO MISUSE'),
#  ('MCP302600BC',
#   '230034734',
#   'Montgomery County Police',
#   'Injury Crash',
#   '07/21/2023 11:53:00 AM',
#   'Maryland (State)',
#   'RIVER RD',
#   'County',
#   'BROOKSIDE DR',
#   'Missing',
#   'Missing',
#   'Missing',
#   'ANGLE MEETS LEFT TURN',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'TRAFFIC SIGNAL',
#   'NONE DETECTED',
#   'Missing',
#   '7B09A8FA-5B59-4EBE-87BA-69946D68484F',
#   'No',
#   'POSSIBLE INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'MD',
#   '14CC9C84-6033-4E19-97BC-F431D4857981',
#   'DISABLING',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   'PASSENGER CAR',
#   'MOVING CONSTANT SPEED',
#   'North',
#   'West',
#   '35',
#   'No',
#   'No',
#   '2012',
#   'MAZDA',
#   'A5',
#   'NO MISUSE'),
#  ('MCP3199005D',
#   '230035027',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '07/23/2023 03:30:00 AM',
#   'County',
#   'LONGMEAD CROSSING DR',
#   'County',
#   'WIMBLEDON DR',
#   'Missing',
#   'Missing',
#   'Missing',
#   'STRAIGHT MOVEMENT ANGLE',
#   'CLEAR',
#   'DRY',
#   'DARK -- UNKNOWN LIGHTING',
#   'NO CONTROLS',
#   'NONE DETECTED',
#   'Missing',
#   'CB184542-732D-4161-8237-DF1011DC0E91',
#   'Yes',
#   'NO APPARENT INJURY',
#   'Missing',
#   'UNKNOWN',
#   'MD',
#   '1E57F291-3131-4913-894D-47BB8FF549B7',
#   'FUNCTIONAL',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   '(SPORT) UTILITY VEHICLE',
#   'MOVING CONSTANT SPEED',
#   'West',
#   'West',
#   '25',
#   'No',
#   'No',
#   '2015',
#   'TOYTA',
#   '4RUNNER',
#   'UNKNOWN'),
#  ('MCP913000G5',
#   '230034860',
#   'Montgomery County Police',
#   'Injury Crash',
#   '07/22/2023 06:28:00 AM',
#   'US (State)',
#   'COLESVILLE RD',
#   'County',
#   'SOUTHWOOD AVE',
#   'Missing',
#   'Missing',
#   'Missing',
#   'SAME DIR REAR END',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'NO CONTROLS',
#   'NONE DETECTED',
#   'Missing',
#   '4A13A249-6C2E-483F-A6F6-5D632824950B',
#   'Yes',
#   'SUSPECTED MINOR INJURY',
#   'Missing',
#   'LOOKED BUT DID NOT SEE',
#   'MD',
#   '44F12629-A05B-4219-A9A3-68DE29298A35',
#   'DISABLING',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   'PASSENGER CAR',
#   'MOVING CONSTANT SPEED',
#   'South',
#   'South',
#   '40',
#   'No',
#   'No',
#   '2017',
#   'TOYOTA',
#   'PRIUS',
#   'Missing'),
#  ('MCP289200F0',
#   '230034624',
#   'Montgomery County Police',
#   'Injury Crash',
#   '07/20/2023 06:01:00 PM',
#   'County',
#   'THAYER AVE',
#   'County',
#   'FENTON ST',
#   'Missing',
#   'Missing',
#   'PEDESTRIAN',
#   'SINGLE VEHICLE',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'NO CONTROLS',
#   'NONE DETECTED',
#   'NONE DETECTED',
#   'C483C378-DA60-4181-8262-93532F7C204C',
#   'No',
#   'NO APPARENT INJURY',
#   'Missing',
#   'LOOKED BUT DID NOT SEE',
#   'MD',
#   '9842BB30-57CC-429E-B01E-B972820EC38A',
#   'NO DAMAGE',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   'PASSENGER CAR',
#   'SLOWING OR STOPPING',
#   'West',
#   'West',
#   '25',
#   'No',
#   'No',
#   '2014',
#   'SUBARU',
#   'SU',
#   'NO MISUSE'),
#  ('MCP3201004C',
#   '230035036',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '07/23/2023 12:10:00 PM',
#   'County',
#   'CRYSTAL ROCK DR',
#   'County',
#   'WATERS LANDING DR',
#   'Missing',
#   'Missing',
#   'Missing',
#   'STRAIGHT MOVEMENT ANGLE',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'NO CONTROLS',
#   'NONE DETECTED',
#   'Missing',
#   'E12D8A6E-3D29-4DDB-BCA8-6817E1C6D8A8',
#   'No',
#   'NO APPARENT INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'MD',
#   'F0AB309A-5B0C-4F22-8AA6-EFEC8B07AFA9',
#   'FUNCTIONAL',
#   'FOUR OCLOCK',
#   'FOUR OCLOCK',
#   'PASSENGER CAR',
#   'MOVING CONSTANT SPEED',
#   'South',
#   'South',
#   '40',
#   'No',
#   'No',
#   '2008',
#   'TOYT',
#   '4S',
#   'NO MISUSE'),
#  ('MCP23560036',
#   '230034771',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '07/21/2023 03:50:00 PM',
#   'County',
#   'SHADY GROVE RD',
#   'Other Public Roadway',
#   'CORPORATE BLVD',
#   'Missing',
#   'Missing',
#   'Missing',
#   'HEAD ON LEFT TURN',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'TRAFFIC SIGNAL',
#   'NONE DETECTED',
#   'Missing',
#   '1F871B3B-232D-4D86-B04A-47BA198E19A9',
#   'No',
#   'NO APPARENT INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'MD',
#   '388E36EA-3728-4FEE-9BE3-BCD0F43DBB5F',
#   'DISABLING',
#   'ELEVEN OCLOCK',
#   'ELEVEN OCLOCK',
#   'PASSENGER CAR',
#   'MOVING CONSTANT SPEED',
#   'North',
#   'North',
#   '40',
#   'No',
#   'No',
#   '2019',
#   'ACUR',
#   '1LX',
#   'NO MISUSE'),
#  ('MCP2974004N',
#   '230034511',
#   'Montgomery County Police',
#   'Injury Crash',
#   '07/20/2023 09:25:00 AM',
#   'Maryland (State)',
#   'SANDY SPRING RD',
#   'US (State)',
#   'COLUMBIA PIKE',
#   'Missing',
#   'Missing',
#   'Missing',
#   'SAME DIR REAR END',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'NO CONTROLS',
#   'NONE DETECTED',
#   'Missing',
#   '25D19276-AE66-41D2-8050-DF297CBC69AB',
#   'No',
#   'POSSIBLE INJURY',
#   'ANIMAL, BACKUP DUE TO NON-RECURRING INCIDENT',
#   'NOT DISTRACTED',
#   'MD',
#   'D96164B9-3497-46D9-8DC9-442EC79297F0',
#   'DISABLING',
#   'SIX OCLOCK',
#   'SIX OCLOCK',
#   'PASSENGER CAR',
#   'STOPPED IN TRAFFIC LANE',
#   'West',
#   'West',
#   '35',
#   'No',
#   'No',
#   '2010',
#   'TOYOTA',
#   'COROLLA',
#   'NO MISUSE'),
#  ('MCP27800077',
#   '230033432',
#   'Montgomery County Police',
#   'Injury Crash',
#   '07/13/2023 06:25:00 PM',
#   'Maryland (State)',
#   'FREDERICK RD',
#   'County',
#   'SHAKESPEARE BLVD',
#   'Missing',
#   'Missing',
#   'Missing',
#   'STRAIGHT MOVEMENT ANGLE',
#   'CLOUDY',
#   'DRY',
#   'DAYLIGHT',
#   'TRAFFIC SIGNAL',
#   'NONE DETECTED',
#   'Missing',
#   '8F6FD4BE-18BA-49C3-8B04-5EC5818CAA39',
#   'No',
#   'POSSIBLE INJURY',
#   'Missing',
#   'LOOKED BUT DID NOT SEE',
#   'MD',
#   '6B3D1862-DBB4-4AD8-BF30-E4F72DF8EC0E',
#   'FUNCTIONAL',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   'PASSENGER CAR',
#   'MOVING CONSTANT SPEED',
#   'South',
#   'South',
#   '35',
#   'No',
#   'No',
#   '2008',
#   'BMW',
#   '328I',
#   'NO MISUSE'),
#  ('MCP3279002C',
#   '230033406',
#   'Montgomery County Police',
#   'Injury Crash',
#   '04/07/2023 03:55:00 PM',
#   'Missing',
#   'Missing',
#   'Missing',
#   'Missing',
#   'AT THE EXIT OF THE PARKING LOT OF THE GLENMONT SHOPPING CENTER THAT LEADS TO NORTHBOUND GEORGIA AVE',
#   'Missing',
#   'Missing',
#   'SAME DIR REAR END',
#   'CLEAR',
#   'Missing',
#   'DAYLIGHT',
#   'Missing',
#   'NONE DETECTED',
#   'Missing',
#   '7C4BC7B1-5D7E-4E70-A258-C992E71DB083',
#   'No',
#   'NO APPARENT INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'MD',
#   'DEF59B10-A221-4D0D-A4A3-7B2367F11032',
#   'SUPERFICIAL',
#   'SIX OCLOCK',
#   'SIX OCLOCK',
#   'PASSENGER CAR',
#   'STOPPED IN TRAFFIC LANE',
#   'West',
#   'West',
#   '0',
#   'No',
#   'No',
#   '2022',
#   'KIA',
#   'FORTE',
#   'Missing'),
#  ('EJ78850036',
#   '230034585',
#   'Gaithersburg Police Depar',
#   'Property Damage Crash',
#   '07/20/2023 02:48:00 PM',
#   'Municipality',
#   'FIRSTFIELD RD',
#   'Municipality',
#   'QUINCE ORCHARD BLVD',
#   'Missing',
#   'GAITHERSBURG',
#   'Missing',
#   'STRAIGHT MOVEMENT ANGLE',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'STOP SIGN',
#   'NONE DETECTED',
#   'Missing',
#   'B5B85B55-FD98-4D52-85C0-4A8E3CE53EA0',
#   'No',
#   'NO APPARENT INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'MD',
#   'CE2FAD86-0755-4B83-8518-2E872994E098',
#   'FUNCTIONAL',
#   'NINE OCLOCK',
#   'NINE OCLOCK',
#   'PASSENGER CAR',
#   'MOVING CONSTANT SPEED',
#   'West',
#   'West',
#   '30',
#   'No',
#   'No',
#   '2019',
#   'HYUN',
#   'SD',
#   'NO MISUSE'),
#  ('MCP2846008W',
#   '230034231',
#   'Montgomery County Police',
#   'Injury Crash',
#   '07/18/2023 04:20:00 PM',
#   'Maryland (State)',
#   'VEIRS MILL RD',
#   'Unknown',
#   'ENT TO WHEATON PLAZA',
#   'Missing',
#   'Missing',
#   'Missing',
#   'HEAD ON LEFT TURN',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'TRAFFIC SIGNAL',
#   'NONE DETECTED',
#   'Missing',
#   '1ABD97CF-9619-4AFA-B193-570506BCE6AF',
#   'Yes',
#   'POSSIBLE INJURY',
#   'Missing',
#   'INATTENTIVE OR LOST IN THOUGHT',
#   'MD',
#   '696647A2-DF17-4DDD-9078-1008033E61FE',
#   'DISABLING',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   'PASSENGER CAR',
#   'MAKING LEFT TURN',
#   'South',
#   'West',
#   '35',
#   'No',
#   'No',
#   '2014',
#   'HYUN',
#   '4D',
#   'NO MISUSE'),
#  ('MCP3160004S',
#   '230034385',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '07/18/2023 02:10:00 PM',
#   'Maryland (State)',
#   'CONNECTICUT AVE',
#   'Maryland (State)',
#   'BRADLEY LA',
#   'Missing',
#   'Missing',
#   'Missing',
#   'SAME DIRECTION SIDESWIPE',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'NO CONTROLS',
#   'NONE DETECTED',
#   'Missing',
#   '736B22E3-A910-4922-BF36-39380253EA8D',
#   'Yes',
#   'NO APPARENT INJURY',
#   'Missing',
#   'LOOKED BUT DID NOT SEE',
#   'DC',
#   'B75AE6C7-E768-49ED-92B7-FD81B7A6762E',
#   'SUPERFICIAL',
#   'EIGHT OCLOCK',
#   'EIGHT OCLOCK',
#   'PASSENGER CAR',
#   'MOVING CONSTANT SPEED',
#   'South',
#   'South',
#   '30',
#   'No',
#   'No',
#   '2008',
#   'HONDA',
#   'CIVIC',
#   'NO MISUSE'),
#  ('MCP26740046',
#   '230034929',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '07/22/2023 03:39:00 PM',
#   'County',
#   'LEWIS DR',
#   'Maryland (State)',
#   'RIDGE RD',
#   'Missing',
#   'Missing',
#   'Missing',
#   'SAME DIRECTION RIGHT TURN',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'STOP SIGN',
#   'NONE DETECTED',
#   'Missing',
#   'E4D26EE3-DF56-49A0-822C-BED608044A40',
#   'No',
#   'NO APPARENT INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'VA',
#   '9DAA4E0D-B778-4C46-8687-C8587C3973BC',
#   'NO DAMAGE',
#   'FOUR OCLOCK',
#   'FOUR OCLOCK',
#   'TRUCK TRACTOR',
#   'MAKING RIGHT TURN',
#   'West',
#   'South',
#   '25',
#   'No',
#   'No',
#   '2017',
#   'FREIGHT',
#   'TRACTOR',
#   'NO MISUSE'),
#  ('MCP3168005S',
#   '230034457',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '07/19/2023 08:05:00 PM',
#   'Missing',
#   'Missing',
#   'Missing',
#   'Missing',
#   'IN THE DRIVEWAY LOT OF 7700 TUCKERMAN LANE',
#   'Missing',
#   'Missing',
#   'SINGLE VEHICLE',
#   'CLEAR',
#   'Missing',
#   'DAYLIGHT',
#   'NO CONTROLS',
#   'NONE DETECTED',
#   'Missing',
#   '7D431B22-0542-4FD3-9B08-16A1B5FB2BE7',
#   'Yes',
#   'NO APPARENT INJURY',
#   'Missing',
#   'LOOKED BUT DID NOT SEE',
#   'MD',
#   '4BDE08BA-5693-42AD-AEEA-05642C63E0B6',
#   'FUNCTIONAL',
#   'SIX OCLOCK',
#   'SIX OCLOCK',
#   'POLICE VEHICLE/EMERGENCY',
#   'BACKING',
#   'North',
#   'North',
#   '5',
#   'No',
#   'No',
#   '2014',
#   'CHEVROLET',
#   'SUBURBAN',
#   'NO MISUSE'),
#  ('MCP3367000X',
#   '230035086',
#   'Montgomery County Police',
#   'Injury Crash',
#   '07/23/2023 05:03:00 PM',
#   'Maryland (State)',
#   'NEW HAMPSHIRE AVE',
#   'County',
#   'CRESTHAVEN DR',
#   'Missing',
#   'Missing',
#   'Missing',
#   'SAME DIRECTION SIDESWIPE',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'NO CONTROLS',
#   'Missing',
#   'Missing',
#   'A8AFAF60-CB06-4628-8CCE-7832B5126016',
#   'No',
#   'POSSIBLE INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'MD',
#   'A8195420-62B8-4293-A4E7-8D4BD196DBB5',
#   'DISABLING',
#   'TWO OCLOCK',
#   'TWO OCLOCK',
#   'PASSENGER CAR',
#   'MOVING CONSTANT SPEED',
#   'South',
#   'South',
#   '35',
#   'No',
#   'No',
#   '2018',
#   'TOYOTA',
#   'COROLLA',
#   'NO MISUSE'),
#  ('MCP9419004F',
#   '23003437',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '07/19/2023 12:19:00 PM',
#   'County',
#   'CRABBS BRANCH WAY',
#   'County',
#   'REDLAND RD',
#   'Missing',
#   'Missing',
#   'Missing',
#   'SINGLE VEHICLE',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'NO CONTROLS',
#   'NONE DETECTED',
#   'Missing',
#   'D2335072-EEB8-4C8A-B6E7-77C542D2C5DE',
#   'Yes',
#   'NO APPARENT INJURY',
#   'Missing',
#   'USING OTHER DEVICE CONTROLS INTEGRAL TO VEHICLE',
#   'MD',
#   'BB574474-261F-4E34-BEC6-A49501B7BFFD',
#   'DISABLING',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   '(SPORT) UTILITY VEHICLE',
#   'MOVING CONSTANT SPEED',
#   'North',
#   'North',
#   '40',
#   'No',
#   'No',
#   '2011',
#   'TOYOTA',
#   'RAV 4',
#   'NO MISUSE'),
#  ('MCP91180042',
#   '230035007',
#   'Montgomery County Police',
#   'Injury Crash',
#   '07/23/2023 05:41:00 AM',
#   'Maryland (State)',
#   'VEIRS MILL RD',
#   'Maryland (State)',
#   'CONNECTICUT AVE',
#   'Missing',
#   'Missing',
#   'Missing',
#   'SINGLE VEHICLE',
#   'CLEAR',
#   'DRY',
#   'DARK LIGHTS ON',
#   'NO CONTROLS',
#   'NONE DETECTED',
#   'Missing',
#   '9311006E-C45B-45C5-8AE1-B335CAF951DC',
#   'Yes',
#   'POSSIBLE INJURY',
#   'Missing',
#   'UNKNOWN',
#   'MD',
#   'CA52DB8A-B51C-4EC7-A589-DA898D823D94',
#   'DISABLING',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   'PASSENGER CAR',
#   'MOVING CONSTANT SPEED',
#   'East',
#   'East',
#   '40',
#   'No',
#   'No',
#   '2018',
#   'HONDA',
#   'ACCORD',
#   'NO MISUSE'),
#  ('MCP23780010',
#   '23003801',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '07/16/2023 12:15:00 AM',
#   'Maryland (State)',
#   'WISCONSIN AVE',
#   'Maryland (State)',
#   'OLD GEORGETOWN RD',
#   'Missing',
#   'Missing',
#   'Missing',
#   'SAME DIRECTION RIGHT TURN',
#   'RAINING',
#   'WET',
#   'DARK LIGHTS ON',
#   'TRAFFIC SIGNAL',
#   'UNKNOWN',
#   'Missing',
#   'C61ECDF8-023C-4225-901F-A015DE1B8C19',
#   'Yes',
#   'NO APPARENT INJURY',
#   'Missing',
#   'UNKNOWN',
#   'Missing',
#   '9931A56B-8580-443D-9DFC-456907BB1375',
#   'UNKNOWN',
#   'FOUR OCLOCK',
#   'FOUR OCLOCK',
#   'Missing',
#   'CHANGING LANES',
#   'South',
#   'South',
#   '25',
#   'No',
#   'No',
#   '0',
#   'UNKNOWN',
#   'UNKNOWN',
#   'UNKNOWN'),
#  ('MCP3161005H',
#   '230046478',
#   'Montgomery County Police',
#   'Injury Crash',
#   '07/27/2023 04:14:00 PM',
#   'Maryland (State)',
#   'BRADLEY LA',
#   'Municipality',
#   'WEST AVE',
#   'Missing',
#   'CHEVY CHASE #4',
#   'Missing',
#   'SAME DIR REAR END',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'NO CONTROLS',
#   'NONE DETECTED',
#   'Missing',
#   '000ADE30-D0A0-44D8-9BA8-468F078E448F',
#   'Yes',
#   'NO APPARENT INJURY',
#   'Missing',
#   'UNKNOWN',
#   'DC',
#   'BDAE8581-C26B-4A79-98C9-1AFA6463FC58',
#   'DISABLING',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   'PASSENGER CAR',
#   'SLOWING OR STOPPING',
#   'West',
#   'West',
#   '25',
#   'No',
#   'No',
#   '2012',
#   'HYUNDAI',
#   'SONATA',
#   'NO MISUSE'),
#  ('DM8476004Z',
#   '230034950',
#   'Takoma Park Police Depart',
#   'Property Damage Crash',
#   '07/22/2023 05:10:00 PM',
#   'Maryland (State)',
#   'NEW HAMPSHIRE AVE',
#   'Municipality',
#   'HOLTON LA',
#   'Missing',
#   'TAKOMA PARK',
#   'Missing',
#   'SAME DIRECTION RIGHT TURN',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'Missing',
#   'Missing',
#   'Missing',
#   '756F0530-92CA-4ACF-B3B8-05D610DB535D',
#   'Yes',
#   'NO APPARENT INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'MD',
#   'BEDF2CF7-093D-4FFA-A3CB-24EE5A820F64',
#   'SUPERFICIAL',
#   'ONE OCLOCK',
#   'ONE OCLOCK',
#   'PASSENGER CAR',
#   'MOVING CONSTANT SPEED',
#   'South',
#   'South',
#   '35',
#   'No',
#   'No',
#   '2021',
#   'TOYOTA',
#   'CAMRY',
#   'Missing'),
#  ('EJ78940034',
#   '230033698',
#   'Gaithersburg Police Depar',
#   'Property Damage Crash',
#   '07/15/2023 10:47:00 AM',
#   'Municipality',
#   'W DEER PARK RD',
#   'Municipality',
#   'CEDAR AVE',
#   'Missing',
#   'GAITHERSBURG',
#   'Missing',
#   'SAME DIR REAR END',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'NO CONTROLS',
#   'NONE DETECTED',
#   'Missing',
#   '34D09525-20CD-4D3F-BED6-258B7F9F64A0',
#   'Yes',
#   'NO APPARENT INJURY',
#   'Missing',
#   'LOOKED BUT DID NOT SEE',
#   'MD',
#   '3862A9ED-63F1-49CA-8E1A-00B0F2FA7B78',
#   'DISABLING',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   'PASSENGER CAR',
#   'SLOWING OR STOPPING',
#   'West',
#   'West',
#   '25',
#   'No',
#   'No',
#   '1996',
#   'TOYT',
#   'SD',
#   'NO MISUSE'),
#  ('MCP32610017',
#   '230034668',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '07/20/2023 11:40:00 PM',
#   'Maryland (State)',
#   'MUNCASTER MILL RD',
#   'County',
#   'SHADY GROVE RD',
#   'Missing',
#   'Missing',
#   'Missing',
#   'OTHER',
#   'Missing',
#   'DRY',
#   'DARK LIGHTS ON',
#   'TRAFFIC SIGNAL',
#   'Missing',
#   'Missing',
#   'E611A3F8-5F7D-465B-8DE0-3814027998F1',
#   'No',
#   'NO APPARENT INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'MD',
#   '1A592482-AF1F-49CE-8554-77EF7C55966B',
#   'SUPERFICIAL',
#   'ELEVEN OCLOCK',
#   'ELEVEN OCLOCK',
#   'PASSENGER CAR',
#   'MAKING RIGHT TURN',
#   'South',
#   'East',
#   '45',
#   'No',
#   'No',
#   '2023',
#   'TOYT',
#   'CP',
#   'NO MISUSE'),
#  ('MCP3271003K',
#   '230034443',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '07/19/2023 12:13:00 PM',
#   'County',
#   'ARLINGTON RD',
#   'Maryland (State)',
#   'BRADLEY BLVD',
#   'Missing',
#   'Missing',
#   'Missing',
#   'SAME DIRECTION SIDESWIPE',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'Missing',
#   'Missing',
#   'Missing',
#   '557FC46D-DB8A-4E39-8814-E90755ACF146',
#   'Yes',
#   'NO APPARENT INJURY',
#   'Missing',
#   'LOOKED BUT DID NOT SEE',
#   'MD',
#   '467B8804-67FE-435E-BD0F-AADEA1AD0B3E',
#   'SUPERFICIAL',
#   'TEN OCLOCK',
#   'TEN OCLOCK',
#   'PASSENGER CAR',
#   'CHANGING LANES',
#   'North',
#   'North',
#   '35',
#   'No',
#   'No',
#   '2009',
#   'INFINITY',
#   'FX35',
#   'Missing'),
#  ('MCP2846008X',
#   '230034260',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '07/17/2023 10:45:00 AM',
#   'County',
#   'SELFRIDGE RD',
#   'County',
#   'RANDOLPH RD',
#   'Missing',
#   'Missing',
#   'Missing',
#   'OTHER',
#   'CLEAR',
#   'DRY',
#   'DARK LIGHTS ON',
#   'TRAFFIC SIGNAL',
#   'UNKNOWN',
#   'Missing',
#   'B0773ABA-8BB4-4C2F-A35F-224C1C889F71',
#   'No',
#   'NO APPARENT INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'MD',
#   '4303CA98-7852-466F-8FF6-1FFE1DBBA06B',
#   'SUPERFICIAL',
#   'ONE OCLOCK',
#   'ONE OCLOCK',
#   'PASSENGER CAR',
#   'MOVING CONSTANT SPEED',
#   'North',
#   'North',
#   '25',
#   'No',
#   'No',
#   '2016',
#   'TOYT',
#   'COROLLA',
#   'NO MISUSE'),
#  ('EJ78860034',
#   '230034298',
#   'Gaithersburg Police Depar',
#   'Property Damage Crash',
#   '06/19/2023 10:19:00 PM',
#   'Missing',
#   'Missing',
#   'Missing',
#   'Missing',
#   'LIBERTY GAS STATION LOCATED AT 623 S. FREDERICK AVENUE, GAITHERSBURG, MD 20877',
#   'Missing',
#   'Missing',
#   'SAME DIR REAR END',
#   'CLEAR',
#   'Missing',
#   'DARK LIGHTS ON',
#   'Missing',
#   'Missing',
#   'Missing',
#   '51891D7E-11CF-4C21-BC3E-E8FD5B94F46B',
#   'Unknown',
#   'NO APPARENT INJURY',
#   'Missing',
#   'UNKNOWN',
#   'MD',
#   '3B3E5A33-BD4A-436B-8A0B-4BF64AC1110C',
#   'FUNCTIONAL',
#   'UNKNOWN',
#   'UNKNOWN',
#   'PASSENGER CAR',
#   'PARKED',
#   'Missing',
#   'Missing',
#   '0',
#   'No',
#   'Yes',
#   '2009',
#   'HYUNDAI',
#   'SONATA',
#   'Missing'),
#  ('MCP2534004S',
#   '230046104',
#   'Montgomery County Police',
#   'Injury Crash',
#   '07/26/2023 12:57:00 AM',
#   'Maryland (State)',
#   'GEORGIA AVE',
#   'County',
#   'BLUERIDGE AVE',
#   'Missing',
#   'Missing',
#   'Missing',
#   'STRAIGHT MOVEMENT ANGLE',
#   'CLEAR',
#   'DRY',
#   'DARK LIGHTS ON',
#   'FLASHING TRAFFIC SIGNAL',
#   'NONE DETECTED',
#   'Missing',
#   '95EE8452-0658-49FA-992D-B7092E65B30B',
#   'No',
#   'SUSPECTED MINOR INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'DC',
#   'B6E2CB60-1CFE-44BE-A02C-1DDA2A321959',
#   'DISABLING',
#   'NINE OCLOCK',
#   'NINE OCLOCK',
#   'PASSENGER CAR',
#   'MOVING CONSTANT SPEED',
#   'North',
#   'North',
#   '25',
#   'No',
#   'No',
#   '2017',
#   'NISSAN',
#   'ALTIMA',
#   'NO MISUSE'),
#  ('MCP23290028',
#   '230035152',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '07/24/2023 06:10:00 AM',
#   'County',
#   'MONTGOMERY VILLAGE AVE',
#   'County',
#   'CENTERWAY RD',
#   'Missing',
#   'Missing',
#   'Missing',
#   'HEAD ON LEFT TURN',
#   'CLOUDY',
#   'DRY',
#   'DAYLIGHT',
#   'TRAFFIC SIGNAL',
#   'Missing',
#   'Missing',
#   '1253E33A-3066-4A92-B12A-8A401FDCCD53',
#   'No',
#   'NO APPARENT INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'MD',
#   '5190ED55-F7F5-47BE-836D-B15B8ECDB0C7',
#   'DISABLING',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   '(SPORT) UTILITY VEHICLE',
#   'MOVING CONSTANT SPEED',
#   'South',
#   'South',
#   '35',
#   'No',
#   'No',
#   '2021',
#   'TOYT',
#   'UT',
#   'Missing'),
#  ('MCP3319001Z',
#   '230034551',
#   'Montgomery County Police',
#   'Injury Crash',
#   '07/20/2023 12:53:00 PM',
#   'US (State)',
#   'GEORGIA AVE',
#   'County',
#   '13TH ST',
#   'Missing',
#   'Missing',
#   'Missing',
#   'HEAD ON LEFT TURN',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'Missing',
#   'Missing',
#   'Missing',
#   'E20CC1C2-184B-46B2-BCB6-535765F199A1',
#   'Yes',
#   'NO APPARENT INJURY',
#   'Missing',
#   'LOOKED BUT DID NOT SEE',
#   'MD',
#   '55AE962E-931A-461A-8666-4C58FB60C1DE',
#   'SUPERFICIAL',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   'PASSENGER CAR',
#   'MAKING U TURN',
#   'North',
#   'South',
#   '30',
#   'No',
#   'No',
#   '2019',
#   'NISSAN',
#   'VERSA',
#   'NO MISUSE'),
#  ('MCP30660028',
#   '230034802',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '07/21/2023 06:29:00 PM',
#   'Maryland (State)',
#   'ROCKVILLE PIKE',
#   'County',
#   'JONES BRIDGE RD',
#   'Missing',
#   'Missing',
#   'Missing',
#   'SAME DIRECTION RIGHT TURN',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'TRAFFIC SIGNAL',
#   'Missing',
#   'Missing',
#   'A228C76E-A3F6-4D38-A399-2E4F2CA70B45',
#   'Yes',
#   'NO APPARENT INJURY',
#   'Missing',
#   'UNKNOWN',
#   'MD',
#   'B9B85295-19E1-473A-9F18-11B68B37EAF4',
#   'UNKNOWN',
#   'FOUR OCLOCK',
#   'ONE OCLOCK',
#   'PASSENGER CAR',
#   'MAKING RIGHT TURN',
#   'East',
#   'East',
#   '35',
#   'No',
#   'No',
#   '2006',
#   'TOYT',
#   'PRIUS',
#   'UNKNOWN'),
#  ('MCP21810053',
#   '230024379',
#   'Montgomery County Police',
#   'Fatal Crash',
#   '05/21/2023 03:04:00 PM',
#   'County',
#   'AIRPARK RD',
#   'Maryland (State)',
#   'MUNCASTER MILL RD',
#   'Missing',
#   'Missing',
#   'Missing',
#   'SINGLE VEHICLE',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'Missing',
#   'ALCOHOL PRESENT',
#   'Missing',
#   '96BB793C-F010-4C11-9EA0-7F2FD7A10F43',
#   'Yes',
#   'FATAL INJURY',
#   'Missing',
#   'UNKNOWN',
#   'MD',
#   '5BC2F6B5-0078-448A-82EC-BB27D5315222',
#   'DISABLING',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   'MOTORCYCLE',
#   'MOVING CONSTANT SPEED',
#   'South',
#   'South',
#   '50',
#   'No',
#   'No',
#   '2010',
#   'HARLEY DAVIDSON',
#   'FLSTN SOFTAIL DELUXE',
#   'NO MISUSE'),
#  ('DD56700006',
#   '230034851',
#   'Rockville Police Departme',
#   'Injury Crash',
#   '07/22/2023 04:07:00 AM',
#   'Maryland (State)',
#   'ROCKVILLE PIKE',
#   'Municipality',
#   'W EDMONSTON DR',
#   'Missing',
#   'ROCKVILLE',
#   'Missing',
#   'STRAIGHT MOVEMENT ANGLE',
#   'Missing',
#   'DRY',
#   'DARK LIGHTS ON',
#   'TRAFFIC SIGNAL',
#   'NONE DETECTED',
#   'Missing',
#   'D1EE308D-774D-4C5A-AB6E-5D47B5E5903F',
#   'No',
#   'SUSPECTED MINOR INJURY',
#   'Missing',
#   'UNKNOWN',
#   'MD',
#   '6F25173A-5C69-4FF8-985C-F46A2704F622',
#   'DISABLING',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   'PASSENGER CAR',
#   'MOVING CONSTANT SPEED',
#   'South',
#   'South',
#   '40',
#   'No',
#   'No',
#   '2005',
#   'VOLVO',
#   'SD',
#   'NO MISUSE'),
#  ('MCP25520068',
#   '230046091',
#   'Montgomery County Police',
#   'Injury Crash',
#   '07/25/2023 09:57:00 PM',
#   'Maryland (State)',
#   'FREDERICK RD',
#   'Municipality',
#   'RIDGEMONT AVE',
#   'Missing',
#   'ROCKVILLE',
#   'Missing',
#   'HEAD ON LEFT TURN',
#   'CLEAR',
#   'WET',
#   'DARK LIGHTS ON',
#   'TRAFFIC SIGNAL',
#   'Missing',
#   'Missing',
#   '8A8B77A3-BCF7-4E4E-9A47-43615CF38838',
#   'No',
#   'SUSPECTED MINOR INJURY',
#   'RAIN, SNOW, WET',
#   'NOT DISTRACTED',
#   'MD',
#   '0B66087B-1391-4AEF-8541-6A80024C6FF5',
#   'DISABLING',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   'PASSENGER CAR',
#   'MOVING CONSTANT SPEED',
#   'South',
#   'South',
#   '35',
#   'No',
#   'No',
#   '2017',
#   'NISSAN',
#   'ROUGE',
#   'Missing'),
#  ('MCP32900027',
#   '230034915',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '07/22/2023 02:05:00 PM',
#   'Maryland (State)',
#   'GEORGIA AVE',
#   'Ramp',
#   'RAMP 3 FR IS 495 EB TO MD 97 NB',
#   'Missing',
#   'Missing',
#   'Missing',
#   'SAME DIR REAR END',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'NO CONTROLS',
#   'Missing',
#   'Missing',
#   'CDE4F40D-F88E-458D-9F31-1D26D12E73F5',
#   'Yes',
#   'NO APPARENT INJURY',
#   'Missing',
#   'UNKNOWN',
#   'Missing',
#   '204116A8-5DDF-43C3-9713-9A5EDFE04F29',
#   'UNKNOWN',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   'PASSENGER CAR',
#   'SLOWING OR STOPPING',
#   'North',
#   'North',
#   '35',
#   'No',
#   'No',
#   '2009',
#   'CHRYSLERER',
#   '200',
#   'UNKNOWN'),
#  ('DD56480024',
#   '230046146',
#   'Rockville Police Departme',
#   'Property Damage Crash',
#   '07/26/2023 09:15:00 AM',
#   'Missing',
#   'Missing',
#   'Missing',
#   'Missing',
#   '1700 ROCKVILLE PIKE PARKING LOT',
#   'Missing',
#   'Missing',
#   'OTHER',
#   'CLEAR',
#   'Missing',
#   'DAYLIGHT',
#   'Missing',
#   'NONE DETECTED',
#   'Missing',
#   '1C351519-85B8-4521-8787-66AC3D192A1B',
#   'No',
#   'NO APPARENT INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'DC',
#   'C9C18C93-A8E7-4363-8B3E-0831EBA91883',
#   'SUPERFICIAL',
#   'ELEVEN OCLOCK',
#   'ELEVEN OCLOCK',
#   'PASSENGER CAR',
#   'Missing',
#   'Unknown',
#   'Unknown',
#   '5',
#   'No',
#   'No',
#   '2021',
#   'FORD',
#   'EXPLORER',
#   'NO MISUSE'),
#  ('DD5652003G',
#   '230034756',
#   'Rockville Police Departme',
#   'Injury Crash',
#   '07/21/2023 02:26:00 PM',
#   'Maryland (State)',
#   'NORBECK RD',
#   'Municipality',
#   'AVERY RD',
#   'Missing',
#   'ROCKVILLE',
#   'Missing',
#   'SAME DIR REAR END',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'TRAFFIC SIGNAL',
#   'NONE DETECTED',
#   'Missing',
#   'F7E34A4E-6CF8-4EAF-9FE0-BEECB625BFA4',
#   'No',
#   'NO APPARENT INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'MD',
#   '78F2D10D-AC69-4125-A929-C2AB8469F4A5',
#   'SUPERFICIAL',
#   'SIX OCLOCK',
#   'SIX OCLOCK',
#   'PASSENGER CAR',
#   'SLOWING OR STOPPING',
#   'West',
#   'West',
#   '50',
#   'No',
#   'No',
#   '2018',
#   'HOND',
#   'TK',
#   'NO MISUSE'),
#  ('MCP302600BB',
#   '230034313',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '07/19/2023 07:30:00 AM',
#   'Maryland (State)',
#   'ROCKLEDGE BLVD',
#   'Unknown',
#   'BEGIN BRIDGE',
#   'Missing',
#   'Missing',
#   'Missing',
#   'SAME DIR BOTH LEFT TURN',
#   'RAINING',
#   'WET',
#   'DAYLIGHT',
#   'TRAFFIC SIGNAL',
#   'NONE DETECTED',
#   'Missing',
#   '678719DA-509B-49D3-8D27-E534CC70C48A',
#   'No',
#   'NO APPARENT INJURY',
#   'N/A, WET',
#   'NOT DISTRACTED',
#   'MD',
#   '311B186A-62E5-4C15-8223-A81593E17876',
#   'FUNCTIONAL',
#   'TEN OCLOCK',
#   'TEN OCLOCK',
#   'PASSENGER CAR',
#   'MAKING LEFT TURN',
#   'South',
#   'South',
#   '35',
#   'No',
#   'No',
#   '2007',
#   'GMC',
#   'VAN',
#   'NO MISUSE'),
#  ('MCP2844006F',
#   '230026866',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '04/06/2023 08:45:00 PM',
#   'Missing',
#   'Missing',
#   'Missing',
#   'Missing',
#   'PARKING LOT  OF 11502 ELKIN STREET  SILVER SPRING, MD 20902',
#   'Missing',
#   'Missing',
#   'OTHER',
#   'CLEAR',
#   'Missing',
#   'DARK LIGHTS ON',
#   'NO CONTROLS',
#   'NONE DETECTED',
#   'Missing',
#   '39AAE306-E3FA-4111-A1EA-2D370964CADF',
#   'No',
#   'NO APPARENT INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'MD',
#   'FDC830C1-E363-48FA-A3D4-82AA1C4822C3',
#   'SUPERFICIAL',
#   'THREE OCLOCK',
#   'THREE OCLOCK',
#   'POLICE VEHICLE/NON EMERGENCY',
#   'PARKED',
#   'Missing',
#   'Missing',
#   '0',
#   'No',
#   'Yes',
#   '2013',
#   'FORD',
#   'EXPLORER',
#   'NO MISUSE'),
#  ('MCP2723007B',
#   '230035094',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '07/23/2023 06:00:00 PM',
#   'Maryland (State)',
#   'GEORGIA AVE',
#   'County',
#   'GLENALLAN AVE',
#   'Missing',
#   'Missing',
#   'Missing',
#   'SAME DIR REAR END',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'TRAFFIC SIGNAL',
#   'NONE DETECTED',
#   'Missing',
#   '53B2C601-D627-4826-A304-4F9717A14BEC',
#   'No',
#   'NO APPARENT INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'MD',
#   '13195596-4FDB-4C69-A8D5-A436747715BF',
#   'FUNCTIONAL',
#   'SIX OCLOCK',
#   'SIX OCLOCK',
#   'PASSENGER CAR',
#   'SLOWING OR STOPPING',
#   'North',
#   'North',
#   '35',
#   'No',
#   'No',
#   '2019',
#   'TOYOTA',
#   'RAV4',
#   'NO MISUSE'),
#  ('MCP27880036',
#   '230033819',
#   'Montgomery County Police',
#   'Injury Crash',
#   '07/16/2023 04:15:00 AM',
#   'Maryland (State)',
# ...
#   'Missing',
#   'NOT DISTRACTED',
#   'MD',
#   'DC12C6F1-4CB2-43A4-854C-F928BC44B5C9',
#   'DISABLING',
#   'ONE OCLOCK',
#   'ONE OCLOCK',
#   'PASSENGER CAR',
#   'MOVING CONSTANT SPEED',
#   'East',
#   'East',
#   '35',
#   'No',
#   'No',
#   '2015',
#   'HONDA',
#   'SD',
#   'NO MISUSE'),
#  ('MCP31740046',
#   '230047574',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '03/08/2023 07:53:00 AM',
#   'Maryland (State)',
#   'QUINCE ORCHARD RD',
#   'Ramp',
#   'RAMP 3 FR MD 124 EB TO IS 270 NB',
#   'Missing',
#   'Missing',
#   'Missing',
#   'SAME DIR REAR END',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'NO CONTROLS',
#   'NONE DETECTED',
#   'Missing',
#   'C06D7B22-E982-40FB-9162-388D585EECE6',
#   'No',
#   'NO APPARENT INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'MD',
#   '132D52BF-1373-4C37-B284-2C9329202CA2',
#   'DISABLING',
#   'SIX OCLOCK',
#   'SIX OCLOCK',
#   'PASSENGER CAR',
#   'SLOWING OR STOPPING',
#   'West',
#   'West',
#   '35',
#   'No',
#   'No',
#   '2022',
#   'NISS',
#   'HB',
#   'Missing'),
#  ('MCP3010008J',
#   '230047941',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '05/08/2023 11:17:00 AM',
#   'County',
#   'KENILWORTH AVE',
#   'County',
#   'MONTROSE AVE',
#   'Missing',
#   'Missing',
#   'Missing',
#   'SINGLE VEHICLE',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'STOP SIGN',
#   'Missing',
#   'Missing',
#   '7246127C-7CEE-4A48-889D-E34AF75AF00E',
#   'Yes',
#   'NO APPARENT INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'MD',
#   '6684DE0D-860F-4F9E-98C2-49B4925FBA4A',
#   'FUNCTIONAL',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   'OTHER LIGHT TRUCKS (10,000LBS (4,536KG) OR LESS)',
#   'MAKING RIGHT TURN',
#   'South',
#   'East',
#   '25',
#   'No',
#   'No',
#   '2019',
#   'INTL',
#   'TK',
#   'NO MISUSE'),
#  ('EJ78950045',
#   '230048218',
#   'Gaithersburg Police Depar',
#   'Property Damage Crash',
#   '07/08/2023 01:00:00 PM',
#   'Maryland (State)',
#   'FREDERICK RD',
#   'Municipality',
#   'WATKINS MILL RD',
#   'Missing',
#   'GAITHERSBURG',
#   'Missing',
#   'SAME DIR REAR END',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'TRAFFIC SIGNAL',
#   'NONE DETECTED',
#   'Missing',
#   'A40BF5F9-8BB8-4EB8-8330-48944E732324',
#   'Yes',
#   'NO APPARENT INJURY',
#   'Missing',
#   'UNKNOWN',
#   'MD',
#   '32496B01-7050-4F88-8EB2-FB85A685C19A',
#   'DISABLING',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   'VAN',
#   'SLOWING OR STOPPING',
#   'North',
#   'North',
#   '35',
#   'No',
#   'No',
#   '2019',
#   'RAM',
#   'PROMASTER',
#   'NO MISUSE'),
#  ('MCP2844006L',
#   '230048454',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '08/08/2023 06:40:00 PM',
#   'Maryland (State)',
#   'GEORGIA AVE',
#   'County',
#   'WINDHAM LA',
#   'Missing',
#   'Missing',
#   'Missing',
#   'SAME DIRECTION LEFT TURN',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'NO CONTROLS',
#   'Missing',
#   'Missing',
#   'F1B61D81-504F-4D88-B787-A8019815016B',
#   'No',
#   'NO APPARENT INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'MD',
#   '6D918C4E-1AA6-4395-AC53-EECF1770AF3E',
#   'FUNCTIONAL',
#   'TWO OCLOCK',
#   'TWO OCLOCK',
#   'PASSENGER CAR',
#   'MOVING CONSTANT SPEED',
#   'North',
#   'North',
#   '25',
#   'No',
#   'No',
#   '2017',
#   'ACUR',
#   'ILX',
#   'NO MISUSE'),
#  ('MCP26560072',
#   '230048773',
#   'Montgomery County Police',
#   'Injury Crash',
#   '10/08/2023 03:50:00 PM',
#   'Maryland (State)',
#   'CLOPPER RD',
#   'County',
#   'WARING STATION RD',
#   'Missing',
#   'Missing',
#   'Missing',
#   'SAME DIR REAR END',
#   'Missing',
#   'DRY',
#   'DAYLIGHT',
#   'Missing',
#   'Missing',
#   'Missing',
#   '3721CC38-C4BE-4E41-A451-756896E66CD1',
#   'No',
#   'POSSIBLE INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'MD',
#   '4D622EB4-BC7D-4AA4-BCD3-DE812BFBA2F7',
#   'SUPERFICIAL',
#   'SIX OCLOCK',
#   'SIX OCLOCK',
#   'PASSENGER CAR',
#   'SLOWING OR STOPPING',
#   'West',
#   'West',
#   '40',
#   'No',
#   'No',
#   '2014',
#   'TOYOTA',
#   'PRIUS',
#   'NO MISUSE'),
#  ('MCP3053006J',
#   '230028673',
#   'Montgomery County Police',
#   'Injury Crash',
#   '06/14/2023 07:25:00 PM',
#   'Missing',
#   'Missing',
#   'Missing',
#   'Missing',
#   '11160 VEIRS MILL RD PARKING LOT OF LA FITNESS',
#   'Missing',
#   'PEDESTRIAN',
#   'OTHER',
#   'Missing',
#   'Missing',
#   'DAYLIGHT',
#   'NO CONTROLS',
#   'UNKNOWN',
#   'Missing',
#   '75D0140F-113D-4ACF-A2C9-48AD76C08290',
#   'Unknown',
#   'NO APPARENT INJURY',
#   'Missing',
#   'UNKNOWN',
#   'MD',
#   '74F6F087-1CC5-4ADC-87DC-F488F3371F69',
#   'NO DAMAGE',
#   'UNKNOWN',
#   'UNKNOWN',
#   'PASSENGER CAR',
#   'BACKING',
#   'Unknown',
#   'Unknown',
#   '15',
#   'No',
#   'No',
#   '2013',
#   'CHRY',
#   '4D',
#   'UNKNOWN'),
#  ('MCP3145003Q',
#   '230048067',
#   'Montgomery County Police',
#   'Injury Crash',
#   '06/08/2023 11:45:00 AM',
#   'US (State)',
#   'COLUMBIA PIKE',
#   'County',
#   'BURNT MILLS AVE',
#   'Missing',
#   'Missing',
#   'Missing',
#   'HEAD ON LEFT TURN',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'TRAFFIC SIGNAL',
#   'NONE DETECTED',
#   'Missing',
#   '5B254701-6F8C-44F3-99F2-C6B4CC64AC2D',
#   'Yes',
#   'SUSPECTED MINOR INJURY',
#   'Missing',
#   'INATTENTIVE OR LOST IN THOUGHT',
#   'MD',
#   'C3D810F2-6335-49F4-91A4-31E6A588A2B3',
#   'DESTROYED',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   'PASSENGER CAR',
#   'MOVING CONSTANT SPEED',
#   'South',
#   'South',
#   '35',
#   'No',
#   'No',
#   '2014',
#   'INFINITY',
#   'Q50',
#   'NO MISUSE'),
#  ('MCP3264003X',
#   '230047128',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '07/31/2023 01:35:00 PM',
#   'US (State)',
#   'GEORGIA AVE',
#   'County',
#   'THAYER AVE',
#   'Missing',
#   'Missing',
#   'Missing',
#   'STRAIGHT MOVEMENT ANGLE',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'TRAFFIC SIGNAL',
#   'NONE DETECTED',
#   'Missing',
#   'E1441ABD-6155-425B-877E-01EE3F9036F2',
#   'No',
#   'NO APPARENT INJURY',
#   'Missing',
#   'LOOKED BUT DID NOT SEE',
#   'MD',
#   '7E3DB017-4249-4D55-A558-7E3458B3086A',
#   'DISABLING',
#   'FOUR OCLOCK',
#   'FOUR OCLOCK',
#   'PASSENGER CAR',
#   'MAKING LEFT TURN',
#   'East',
#   'South',
#   '35',
#   'No',
#   'No',
#   '2018',
#   'HONDA',
#   'ACCORD',
#   'NO MISUSE'),
#  ('MCP3276002R',
#   '230047889',
#   'Montgomery County Police',
#   'Injury Crash',
#   '04/08/2023 11:30:00 PM',
#   'Maryland (State)',
#   'UNIVERSITY BLVD E',
#   'County',
#   'BUCKINGHAM DR',
#   'Missing',
#   'Missing',
#   'PEDESTRIAN',
#   'OTHER',
#   'CLEAR',
#   'DRY',
#   'DARK LIGHTS ON',
#   'NO CONTROLS',
#   'UNKNOWN',
#   'UNKNOWN',
#   '2280DB12-CB20-4C9C-B7C8-9B9DA570AD21',
#   'Unknown',
#   'NO APPARENT INJURY',
#   'Missing',
#   'UNKNOWN',
#   'Missing',
#   '1413BDF3-6CF6-4F96-A670-B820457680E6',
#   'SUPERFICIAL',
#   'UNDERSIDE',
#   'UNDERSIDE',
#   'Missing',
#   'UNKNOWN',
#   'Unknown',
#   'West',
#   '35',
#   'No',
#   'No',
#   '0',
#   'UNKNOWN',
#   'UNKNOWN',
#   'UNKNOWN'),
#  ('EJ7871006H',
#   '230047877',
#   'Gaithersburg Police Depar',
#   'Injury Crash',
#   '04/08/2023 10:46:00 PM',
#   'Maryland (State)',
#   'CLOPPER RD',
#   'Unknown',
#   'SPUR FR MD 124',
#   'Missing',
#   'Missing',
#   'Missing',
#   'HEAD ON LEFT TURN',
#   'CLEAR',
#   'DRY',
#   'DARK LIGHTS ON',
#   'TRAFFIC SIGNAL',
#   'NONE DETECTED',
#   'Missing',
#   'EBBA51F6-9311-4C5F-91F0-9AE45D887A65',
#   'Yes',
#   'POSSIBLE INJURY',
#   'Missing',
#   'LOOKED BUT DID NOT SEE',
#   'MD',
#   '1588A4F6-8DE9-4970-923D-6B5C5D2E2A78',
#   'DISABLING',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   'PASSENGER CAR',
#   'MOVING CONSTANT SPEED',
#   'North',
#   'North',
#   '35',
#   'No',
#   'No',
#   '2015',
#   'MAZDA',
#   'CX-5',
#   'NO MISUSE'),
#  ('MCP2108001K',
#   '230035003',
#   'Montgomery County Police',
#   'Injury Crash',
#   '07/23/2023 03:20:00 AM',
#   'Maryland (State)',
#   'ROCKVILLE PIKE',
#   'Unknown',
#   'HUBBARD DR',
#   'Missing',
#   'Missing',
#   'Missing',
#   'SINGLE VEHICLE',
#   'CLEAR',
#   'DRY',
#   'DARK LIGHTS ON',
#   'NO CONTROLS',
#   'ALCOHOL CONTRIBUTED',
#   'Missing',
#   '232049D0-3552-4CE3-9D08-202613513BF6',
#   'Yes',
#   'POSSIBLE INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'MD',
#   '0A2F8E0C-2639-43EA-93F8-DAC4512D4360',
#   'DESTROYED',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   'PASSENGER CAR',
#   'MOVING CONSTANT SPEED',
#   'North',
#   'North',
#   '35',
#   'No',
#   'No',
#   '2011',
#   'HYUN',
#   'SONATA',
#   'NO MISUSE'),
#  ('EJ7885003C',
#   '230048435',
#   'Gaithersburg Police Depar',
#   'Property Damage Crash',
#   '08/08/2023 05:02:00 PM',
#   'Maryland (State)',
#   'FREDERICK RD',
#   'Municipality',
#   'MONTGOMERY AVE',
#   'Missing',
#   'GAITHERSBURG',
#   'Missing',
#   'OTHER',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'NO CONTROLS',
#   'NONE DETECTED',
#   'Missing',
#   '59E71B34-F8E8-4266-8A79-3EAB31BE5038',
#   'No',
#   'NO APPARENT INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'MD',
#   'E2A99241-FCBC-4DE2-AA34-EF56CC16883C',
#   'FUNCTIONAL',
#   'FOUR OCLOCK',
#   'FOUR OCLOCK',
#   'PASSENGER CAR',
#   'PARKED',
#   'Missing',
#   'Missing',
#   '10',
#   'No',
#   'Yes',
#   '2019',
#   'HYUN',
#   'UT',
#   'Missing'),
#  ('EJ78520086',
#   '230047002',
#   'Gaithersburg Police Depar',
#   'Property Damage Crash',
#   '07/28/2023 04:18:00 PM',
#   'Maryland (State)',
#   'FREDERICK RD',
#   'Municipality',
#   'PERRY PKWY',
#   'Missing',
#   'GAITHERSBURG',
#   'Missing',
#   'SAME DIRECTION SIDESWIPE',
#   'Missing',
#   'DRY',
#   'DAYLIGHT',
#   'TRAFFIC SIGNAL',
#   'NONE DETECTED',
#   'Missing',
#   '5B03221E-8C8C-461F-AEAA-3C0FFA698646',
#   'No',
#   'NO APPARENT INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'MD',
#   'D160EA9B-C64C-4746-8785-06D40FC90B00',
#   'FUNCTIONAL',
#   'TEN OCLOCK',
#   'TEN OCLOCK',
#   'PASSENGER CAR',
#   'STARTING FROM LANE',
#   'South',
#   'South',
#   '40',
#   'No',
#   'No',
#   '2008',
#   'LEXUS',
#   'LS',
#   'Missing'),
#  ('MCP3145003Q',
#   '230048067',
#   'Montgomery County Police',
#   'Injury Crash',
#   '06/08/2023 11:45:00 AM',
#   'US (State)',
#   'COLUMBIA PIKE',
#   'County',
#   'BURNT MILLS AVE',
#   'Missing',
#   'Missing',
#   'Missing',
#   'HEAD ON LEFT TURN',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'TRAFFIC SIGNAL',
#   'NONE DETECTED',
#   'Missing',
#   '86CCEC46-EE60-4FE4-94EA-19A35BD9588C',
#   'No',
#   'SUSPECTED MINOR INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'MD',
#   'A07D99F4-EFDC-4B3E-AF8F-DE7E12034DE2',
#   'DESTROYED',
#   'ONE OCLOCK',
#   'ONE OCLOCK',
#   'PASSENGER CAR',
#   'MAKING LEFT TURN',
#   'West',
#   'North',
#   '35',
#   'No',
#   'No',
#   '2020',
#   'HONDA',
#   'ACCORD',
#   'NO MISUSE'),
#  ('MCP31230062',
#   '230048058',
#   'Montgomery County Police',
#   'Injury Crash',
#   '06/08/2023 09:43:00 AM',
#   'Maryland (State)',
#   'W MONTGOMERY AVE',
#   'County',
#   'SHADY GROVE RD',
#   'Missing',
#   'Missing',
#   'Missing',
#   'STRAIGHT MOVEMENT ANGLE',
#   'CLOUDY',
#   'DRY',
#   'DAYLIGHT',
#   'TRAFFIC SIGNAL',
#   'Missing',
#   'Missing',
#   'DCAE0AFE-8D7C-4AA9-AD56-E20DABA95A71',
#   'No',
#   'POSSIBLE INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'MD',
#   '1C397132-2561-4293-AAFA-F4656AE755A9',
#   'DISABLING',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   'PASSENGER CAR',
#   'MOVING CONSTANT SPEED',
#   'North',
#   'North',
#   '40',
#   'No',
#   'No',
#   '2019',
#   'ACURA',
#   'TLX',
#   'NO MISUSE'),
#  ('EJ78520085',
#   '230046713',
#   'Gaithersburg Police Depar',
#   'Property Damage Crash',
#   '07/28/2023 07:48:00 PM',
#   'County',
#   'SAM EIG HWY',
#   'Ramp',
#   'RAMP 1 FR IS 270 NB TO IS 370 WB',
#   'Missing',
#   'Missing',
#   'Missing',
#   'SINGLE VEHICLE',
#   'Missing',
#   'WET',
#   'DAYLIGHT',
#   'Missing',
#   'NONE DETECTED',
#   'Missing',
#   '1CDEC89B-DAC5-4DED-A658-E0AB9159D2F1',
#   'Yes',
#   'NO APPARENT INJURY',
#   'Missing',
#   'UNKNOWN',
#   'MD',
#   '3888CA89-A1C0-41EB-80BD-BB28B787DDB5',
#   'FUNCTIONAL',
#   'ELEVEN OCLOCK',
#   'TEN OCLOCK',
#   'PASSENGER CAR',
#   'MOVING CONSTANT SPEED',
#   'West',
#   'West',
#   '55',
#   'No',
#   'No',
#   '2019',
#   'TOYOTA',
#   'COROLLA',
#   'Missing'),
#  ('MCP24270007',
#   '230048384',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '08/08/2023 12:15:00 PM',
#   'Maryland (State)',
#   'GEORGIA AVE',
#   'US (State)',
#   'COLESVILLE RD',
#   'Missing',
#   'Missing',
#   'Missing',
#   'SAME DIRECTION SIDESWIPE',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'Missing',
#   'Missing',
#   'Missing',
#   '34375210-CE55-46E7-AAE5-DC660B6B080B',
#   'Yes',
#   'NO APPARENT INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'Missing',
#   '65DF9891-C659-46D6-9A2D-D1CC05B238D8',
#   'Missing',
#   'TWO OCLOCK',
#   'TWO OCLOCK',
#   'Missing',
#   'MOVING CONSTANT SPEED',
#   'North',
#   'North',
#   '35',
#   'No',
#   'No',
#   '0',
#   'UNKNOWN',
#   'UNKNOWN',
#   'Missing'),
#  ('MCP3053006P',
#   '230047672',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '03/08/2023 05:56:00 PM',
#   'Missing',
#   'Missing',
#   'Missing',
#   'Missing',
#   '11406 GEORGIA AVE SUITE D 7-11 PARKING LOT',
#   'Missing',
#   'Missing',
#   'OTHER',
#   'RAINING',
#   'Missing',
#   'Missing',
#   'NO CONTROLS',
#   'Missing',
#   'Missing',
#   'CD134B66-E9B6-4695-B8DF-B929A208C2AD',
#   'Yes',
#   'NO APPARENT INJURY',
#   'N/A, WET',
#   'INATTENTIVE OR LOST IN THOUGHT',
#   'MD',
#   '3E9108F0-DF5E-4796-8F78-C2E075DB5675',
#   'FUNCTIONAL',
#   'SIX OCLOCK',
#   'SIX OCLOCK',
#   'PASSENGER CAR',
#   'BACKING',
#   'Unknown',
#   'Unknown',
#   '5',
#   'No',
#   'No',
#   '2014',
#   'FORD',
#   'FUSION',
#   'Missing'),
#  ('EJ7885003B',
#   '230035068',
#   'Gaithersburg Police Depar',
#   'Property Damage Crash',
#   '07/23/2023 03:42:00 PM',
#   'Maryland (State)',
#   'FREDERICK RD',
#   'Maryland (State)',
#   'MONTGOMERY VILLAGE AVE',
#   'Missing',
#   'Missing',
#   'Missing',
#   'STRAIGHT MOVEMENT ANGLE',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'TRAFFIC SIGNAL',
#   'NONE DETECTED',
#   'Missing',
#   '35874B2C-653A-425F-987C-03CF4D4538E3',
#   'Yes',
#   'NO APPARENT INJURY',
#   'Missing',
#   'UNKNOWN',
#   'MD',
#   'DAD431C5-4BF7-4395-AABD-78BE22B91E26',
#   'DISABLING',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   'PASSENGER CAR',
#   'MOVING CONSTANT SPEED',
#   'North',
#   'North',
#   '30',
#   'No',
#   'No',
#   '2008',
#   'ACURA',
#   '4D',
#   'NO MISUSE'),
#  ('MCP3339002B',
#   '230047135',
#   'Montgomery County Police',
#   'Injury Crash',
#   '07/31/2023 02:24:00 PM',
#   'Maryland (State)',
#   'GEORGIA AVE',
#   'County',
#   'MAY ST',
#   'Missing',
#   'Missing',
#   'Missing',
#   'SAME DIR REAR END',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'TRAFFIC SIGNAL',
#   'NONE DETECTED',
#   'Missing',
#   '5227DE3E-1574-449A-9895-B970C6636BFE',
#   'Yes',
#   'NO APPARENT INJURY',
#   'Missing',
#   'LOOKED BUT DID NOT SEE',
#   'MD',
#   '23EAABAE-149B-41D0-852D-7FD64B7823D4',
#   'DISABLING',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   'CARGO VAN/LIGHT TRUCK 2 AXLES (OVER 10,000LBS (4,536 KG))',
#   'MOVING CONSTANT SPEED',
#   'South',
#   'South',
#   '35',
#   'No',
#   'No',
#   '2005',
#   'FREIGHT',
#   'TRUCK',
#   'NO MISUSE'),
#  ('MCP33740013',
#   '230047805',
#   'Montgomery County Police',
#   'Injury Crash',
#   '04/08/2023 02:55:00 PM',
#   'Missing',
#   'Missing',
#   'Missing',
#   'Missing',
#   'PARKING LOT ENTRANCE RANDOLPH RD/  LAUDERDALE DR.',
#   'Missing',
#   'Missing',
#   'STRAIGHT MOVEMENT ANGLE',
#   'CLEAR',
#   'Missing',
#   'DAYLIGHT',
#   'NO CONTROLS',
#   'NONE DETECTED',
#   'Missing',
#   '0A7A26DD-9D09-46CE-93DE-38E7EABBB6C6',
#   'Yes',
#   'NO APPARENT INJURY',
#   'Missing',
#   'OTHER CELLULAR PHONE RELATED',
#   'MD',
#   '3673FD60-7403-45E0-BAE3-8EC71EF2546D',
#   'SUPERFICIAL',
#   'TWELVE OCLOCK',
#   'TWELVE OCLOCK',
#   'PASSENGER CAR',
#   'MOVING CONSTANT SPEED',
#   'Unknown',
#   'Unknown',
#   '10',
#   'No',
#   'No',
#   '2016',
#   'TOYOTA',
#   '4S',
#   'NO MISUSE'),
#  ('MCP33740013',
#   '230047805',
#   'Montgomery County Police',
#   'Injury Crash',
#   '04/08/2023 02:55:00 PM',
#   'Missing',
#   'Missing',
#   'Missing',
#   'Missing',
#   'PARKING LOT ENTRANCE RANDOLPH RD/  LAUDERDALE DR.',
#   'Missing',
#   'Missing',
#   'STRAIGHT MOVEMENT ANGLE',
#   'CLEAR',
#   'Missing',
#   'DAYLIGHT',
#   'NO CONTROLS',
#   'NONE DETECTED',
#   'Missing',
#   '7D5B4DD2-2B31-4F73-8023-6D7503671C44',
#   'No',
#   'SUSPECTED MINOR INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'MD',
#   '6C902AD8-9CF2-4917-AF9A-395865223926',
#   'FUNCTIONAL',
#   'NINE OCLOCK',
#   'NINE OCLOCK',
#   'PASSENGER CAR',
#   'MAKING RIGHT TURN',
#   'Unknown',
#   'Unknown',
#   '10',
#   'No',
#   'No',
#   '2009',
#   'ACURA',
#   'SD',
#   'NO MISUSE'),
#  ('MCP3351001C',
#   '230047962',
#   'Montgomery County Police',
#   'Property Damage Crash',
#   '05/08/2023 01:34:00 PM',
#   'Maryland (State)',
#   'PINEY BRANCH RD',
#   'County',
#   'BARRON ST',
#   'Missing',
#   'Missing',
#   'Missing',
#   'SAME DIRECTION RIGHT TURN',
#   'CLEAR',
#   'DRY',
#   'DAYLIGHT',
#   'TRAFFIC SIGNAL',
#   'NONE DETECTED',
#   'Missing',
#   'FA32ECC9-7A5C-4CC4-B6E9-0BDA3E203162',
#   'No',
#   'NO APPARENT INJURY',
#   'Missing',
#   'NOT DISTRACTED',
#   'MD',
#   'F857AEB9-35C2-4100-B8E1-551A34F6DE4D',
#   'FUNCTIONAL',
#   'FOUR OCLOCK',
#   'FOUR OCLOCK',
#   'PASSENGER CAR',
#   'MAKING RIGHT TURN',
#   'East',
#   'East',
#   '35',
#   'No',
#   'No',
#   '2021',
#   'TOYOTA',
#   'CAMRY',
#   'NO MISUSE'),
#  ...]

# %%
## Creating a SQl frame to read and edit data from the database

# %%
sql_frame = pd.read_sql(queryshowtab, connection)
# Out:
# /var/folders/_t/d0zkt0395w39b1mpx92kjmrw0000gn/T/ipykernel_55901/1443624990.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sql_frame = pd.read_sql(queryshowtab, connection)

# %%
sql_frame.head()
# Out:
#   report_number local_case_number                agency_name  \
# 0   MCP3040003N         190026050   Montgomery County Police
# 1    EJ78850038         230034791  Gaithersburg Police Depar
# 2   MCP2009002G         230034583   Montgomery County Police
# 3   MCP3201004C         230035036   Montgomery County Police
# 4   MCP23290028         230035152   Montgomery County Police
#
#         acrs_report_type         crash_date_time        route_type  \
# 0  Property Damage Crash  05/31/2019 03:00:00 PM           Missing
# 1  Property Damage Crash  07/21/2023 05:59:00 PM  Maryland (State)
# 2  Property Damage Crash  07/20/2023 03:10:00 PM  Maryland (State)
# 3  Property Damage Crash  07/23/2023 12:10:00 PM            County
# 4  Property Damage Crash  07/24/2023 06:10:00 AM            County
#
#                 road_name cross_street_type  cross_street_name  \
# 0                 Missing           Missing            Missing
# 1            FREDERICK RD           Unknown    WATKINS MILL RD
# 2             GEORGIA AVE  Maryland (State)         NORBECK RD
# 3         CRYSTAL ROCK DR            County  WATERS LANDING DR
# 4  MONTGOMERY VILLAGE AVE            County       CENTERWAY RD
#
#              off_road_description  ...    vehicle_movement  \
# 0  PARKING LOT OF 3215 SPARTAN RD  ...             PARKING
# 1                         Missing  ...    MAKING LEFT TURN
# 2                         Missing  ...        ACCELERATING
# 3                         Missing  ...  STARTING FROM LANE
# 4                         Missing  ...    MAKING LEFT TURN
#
#   vehicle_continuing_dir vehicle_going_dir speed_limit driverless_vehicle  \
# 0                  North             North          15                 No
# 1                   East             South          40                 No
# 2                  North             North          35                 No
# 3                   East              East          40                 No
# 4                   West             North          35                 No
#
#   parked_vehicle vehicle_year vehicle_make vehicle_model equipment_problems
# 0             No         2004        HONDA            TK            UNKNOWN
# 1             No         2011          GMC            TK          NO MISUSE
# 2             No         2019         FORD          F150          NO MISUSE
# 3             No         2016          KIA            SW          NO MISUSE
# 4             No         2016         TOYT            TK          NO MISUSE
#
# [5 rows x 40 columns]

# %% [markdown]
# ## Checking for duplicate records in the data.

# %%
dup_rows = sql_frame.duplicated()
print("Number of duplicate rows:", dup_rows.sum())
# Out:
# Number of duplicate rows: 0

# %%
# There are no duplicates present in the data, if any, can drop using "sql_frame = sql_frame.drop_duplicates()" Command.

# %%
## Check for Missing Values

# %%
sql_frame.isnull().sum()
# Out:
# report_number                     0
# local_case_number                 0
# agency_name                       0
# acrs_report_type                  0
# crash_date_time                   0
# route_type                        0
# road_name                         0
# cross_street_type                 0
# cross_street_name                 0
# off_road_description              0
# municipality                      0
# related_non_motorist              0
# collision_type                    0
# weather                           0
# surface_condition                 0
# light                             0
# traffic_control                   0
# driver_substance_abuse            0
# non_motorist_substance_abuse      0
# person_id                         0
# driver_at_fault                   0
# injury_severity                   0
# circumstance                      0
# driver_distracted_by              0
# drivers_license_state             0
# vehicle_id                        0
# vehicle_damage_extent             0
# vehicle_first_impact_location     0
# vehicle_second_impact_location    0
# vehicle_body_type                 0
# vehicle_movement                  0
# vehicle_continuing_dir            0
# vehicle_going_dir                 0
# speed_limit                       0
# driverless_vehicle                0
# parked_vehicle                    0
# vehicle_year                      0
# vehicle_make                      0
# vehicle_model                     0
# equipment_problems                0
# dtype: int64

# %%
# Since we've substituted 'NaN' with 'Missing', we'll now look for instances of 'Missing' in every column.

# %%
# To check where "Missing" values occur in each column.
miss_mask = sql_frame.eq('Missing')

# Checking which columns have at least one "Missing" value.
col_miss = miss_mask.any()

# Extract the individual column names where "Missing" values appear.
col_miss_values = col_miss[col_miss].index.tolist()

# Print all the columns with "Missing" values.
print("Columns with 'Missing' values:", col_miss_values)
# Out:
# Columns with 'Missing' values: ['route_type', 'road_name', 'cross_street_type', 'cross_street_name', 'off_road_description', 'municipality', 'related_non_motorist', 'collision_type', 'weather', 'surface_condition', 'light', 'traffic_control', 'driver_substance_abuse', 'non_motorist_substance_abuse', 'circumstance', 'drivers_license_state', 'vehicle_damage_extent', 'vehicle_first_impact_location', 'vehicle_second_impact_location', 'vehicle_body_type', 'vehicle_movement', 'vehicle_continuing_dir', 'vehicle_going_dir', 'vehicle_make', 'vehicle_model', 'equipment_problems']

# %%
# To count for the number of missing values in the above given columns.

# %%
# Iterate through columns with missing values
for column in col_miss_values:
    # Get unique values and their counts
    uni_val_cnts = sql_frame[column].value_counts() 
    # Print column name
    print("Column:", column)
    # Print unique values and their counts
    print(uni_val_cnts)
    print()
# Out:
# Column: route_type
# route_type
# Maryland (State)        77074
# County                  55568
# Missing                 16973
# Municipality             9379
# US (State)               7567
# Interstate (State)       3149
# Other Public Roadway     1129
# Government                627
# Ramp                      579
# Service Road               40
# Unknown                    20
# Name: count, dtype: int64
#
# Column: road_name
# road_name
# Missing              15937
# GEORGIA AVE          10861
# NEW HAMPSHIRE AVE     6832
# FREDERICK RD          5768
# ROCKVILLE PIKE        4839
#                      ...
# WESLEY RD                1
# ORDWAY DR                1
# MANCHESTER PL            1
# STRATTON DR              1
# HARVEST SCENE CT         1
# Name: count, Length: 3804, dtype: int64
#
# Column: cross_street_type
# cross_street_type
# County                  85535
# Maryland (State)        24274
# Municipality            19160
# Missing                 17006
# Unknown                 12999
# Ramp                     5915
# Other Public Roadway     3800
# US (State)               1473
# Government               1177
# Interstate (State)        675
# Service Road               91
# Name: count, dtype: int64
#
# Column: cross_street_name
# cross_street_name
# Missing                    15951
# GEORGIA AVE                 2106
# CONNECTICUT AVE             1594
# FREDERICK RD                1544
# NEW HAMPSHIRE AVE           1315
#                            ...
# DEERHURST LANE                 1
# GAYWOODS CT                    1
# BRIGGS CHANEY RD (BACK)        1
# BELL BLUFF CT                  1
# SPRINGFIELD RD                 1
# Name: count, Length: 6698, dtype: int64
#
# Column: off_road_description
# off_road_description
# Missing                                                                156170
# PARKING LOT                                                               132
# PARKING LOT OF 11160 VEIRS MILL RD                                         15
# PARKING LOT OF 10901 WESTLAKE DR                                           13
# PARKING LOT OF 1283 SEVEN LOCKS RD                                         12
#                                                                         ...
# DRIVEWAY OF 8220 KERRY RD                                                   1
# Parking lot of 13701 Georgia Ave                                            1
# PARKING LOT IN FRONT OF 12905 FALLING WATER CIRCLE                          1
# Parking Lot 15100blk. Avery Rd.                                             1
# 4461 WILLARD AVENUE, CHEVY CHASE, MD 20815.\nIN THE REAR PAKING LOT         1
# Name: count, Length: 11303, dtype: int64
#
# Column: municipality
# municipality
# Missing                152979
# ROCKVILLE                9320
# GAITHERSBURG             6437
# TAKOMA PARK              1685
# KENSINGTON                413
# CHEVY CHASE #4            325
# CHEVY CHASE #3            156
# FRIENDSHIP HEIGHTS        133
# POOLESVILLE               108
# CHEVY CHASE VIEW           93
# CHEVY CHASE VILLAGE        87
# CHEVY CHASE #5             74
# SOMERSET                   53
# GARRETT PARK               53
# WASHINGTON GROVE           41
# NORTH CHEVY CHASE          34
# GLEN ECHO                  33
# MATINS ADDITION            28
# LAYTONSVILLE               25
# BROOKEVILLE                16
# DRUMMOND                   12
# Name: count, dtype: int64
#
# Column: related_non_motorist
# related_non_motorist
# Missing                         166642
# PEDESTRIAN                        3880
# BICYCLIST                         1169
# OTHER                              246
# OTHER CONVEYANCE                    84
# MACHINE OPERATOR/RIDER              39
# OTHER PEDALCYCLIST                  26
# OTHER, PEDESTRIAN                    9
# BICYCLIST, OTHER                     4
# BICYCLIST, PEDESTRIAN                3
# OTHER, OTHER CONVEYANCE              1
# OTHER CONVEYANCE, PEDESTRIAN         1
# IN ANIMAL-DRAWN VEH                  1
# Name: count, dtype: int64
#
# Column: collision_type
# collision_type
# SAME DIR REAR END               55755
# STRAIGHT MOVEMENT ANGLE         30340
# OTHER                           19030
# SAME DIRECTION SIDESWIPE        16226
# SINGLE VEHICLE                  15869
# HEAD ON LEFT TURN               12926
# SAME DIRECTION RIGHT TURN        3832
# HEAD ON                          3786
# SAME DIRECTION LEFT TURN         3715
# OPPOSITE DIRECTION SIDESWIPE     2883
# ANGLE MEETS LEFT TURN            2033
# ANGLE MEETS RIGHT TURN           1204
# SAME DIR REND LEFT TURN           743
# SAME DIR REND RIGHT TURN          720
# SAME DIR BOTH LEFT TURN           719
# UNKNOWN                           717
# ANGLE MEETS LEFT HEAD ON          700
# Missing                           585
# OPPOSITE DIR BOTH LEFT TURN       322
# Name: count, dtype: int64
#
# Column: weather
# weather
# CLEAR                       116774
# RAINING                      20608
# CLOUDY                       17294
# Missing                      13354
# SNOW                          1444
# UNKNOWN                        692
# FOGGY                          676
# WINTRY MIX                     391
# OTHER                          370
# SLEET                          218
# SEVERE WINDS                   154
# BLOWING SNOW                   115
# BLOWING SAND, SOIL, DIRT        15
# Name: count, dtype: int64
#
# Column: surface_condition
# surface_condition
# DRY                       120569
# WET                        28426
# Missing                    20118
# ICE                         1058
# SNOW                         938
# UNKNOWN                      509
# SLUSH                        204
# OTHER                        164
# MUD, DIRT, GRAVEL             46
# WATER(STANDING/MOVING)        41
# OIL                           28
# SAND                           4
# Name: count, dtype: int64
#
# Column: light
# light
# DAYLIGHT                    116140
# DARK LIGHTS ON               39549
# DARK NO LIGHTS                4967
# DUSK                          3935
# DAWN                          3472
# DARK -- UNKNOWN LIGHTING      1579
# Missing                       1445
# UNKNOWN                        676
# OTHER                          342
# Name: count, dtype: int64
#
# Column: traffic_control
# traffic_control
# NO CONTROLS                68626
# TRAFFIC SIGNAL             58892
# Missing                    25469
# STOP SIGN                  12488
# FLASHING TRAFFIC SIGNAL     2132
# OTHER                       1991
# YIELD SIGN                  1727
# UNKNOWN                      284
# PERSON                       282
# WARNING SIGN                 154
# RAILWAY CROSSING DEVICE       44
# SCHOOL ZONE SIGN DEVICE       16
# Name: count, dtype: int64
#
# Column: driver_substance_abuse
# driver_substance_abuse
# NONE DETECTED                 122532
# Missing                        31324
# UNKNOWN                        11993
# ALCOHOL PRESENT                 4084
# ALCOHOL CONTRIBUTED             1435
# ILLEGAL DRUG PRESENT             258
# MEDICATION PRESENT               117
# ILLEGAL DRUG CONTRIBUTED         102
# COMBINED SUBSTANCE PRESENT        92
# MEDICATION CONTRIBUTED            64
# OTHER                             58
# COMBINATION CONTRIBUTED           46
# Name: count, dtype: int64
#
# Column: non_motorist_substance_abuse
# non_motorist_substance_abuse
# Missing                                 167788
# NONE DETECTED                             3861
# UNKNOWN                                    229
# ALCOHOL PRESENT                            145
# ALCOHOL CONTRIBUTED                         39
# N/A, NONE DETECTED                          24
# ILLEGAL DRUG PRESENT                         4
# MEDICATION PRESENT                           4
# ILLEGAL DRUG CONTRIBUTED                     2
# NONE DETECTED, UNKNOWN                       2
# COMBINATION CONTRIBUTED                      2
# ALCOHOL CONTRIBUTED, ALCOHOL PRESENT         1
# OTHER                                        1
# COMBINED SUBSTANCE PRESENT                   1
# N/A, UNKNOWN                                 1
# ALCOHOL PRESENT, NONE DETECTED               1
# Name: count, dtype: int64
#
# Column: circumstance
# circumstance
# Missing                                                                                    140746
# RAIN, SNOW, WET                                                                             12172
# N/A, WET                                                                                     9084
# N/A, RAIN, SNOW                                                                              1177
# SLEET, HAIL, FREEZ. RAIN, WET                                                                1065
#                                                                                             ...
# BLOWING SAND, SOIL, DIRT, V EXHAUST SYSTEM|R OTHER ROAD, V WIPERS|W OTHER ENVIRONMENTAL         1
# BACKUP DUE TO REGULAR CONGESTION, ICY OR SNOW-COVERED, RAIN, SNOW                               1
# ROAD UNDER CONSTRUCTION/MAINTENANCE, V WIPERS|W OTHER ENVIRONMENTAL                             1
# DEBRIS OR OBSTRUCTION, SEVERE CROSSWINDS, WET                                                   1
# SLEET, HAIL, FREEZ. RAIN, WET, WORN, TRAVEL-POLISHED SURFACE                                    1
# Name: count, Length: 199, dtype: int64
#
# Column: drivers_license_state
# drivers_license_state
# MD         142845
# Missing      9950
# DC           5127
# VA           5039
# XX           1792
#             ...
# FM              1
# NS              1
# MP              1
# SK              1
# NT              1
# Name: count, Length: 75, dtype: int64
#
# Column: vehicle_damage_extent
# vehicle_damage_extent
# DISABLING      62354
# FUNCTIONAL     44989
# SUPERFICIAL    43870
# DESTROYED       7610
# UNKNOWN         6619
# NO DAMAGE       6245
# Missing          316
# OTHER            102
# Name: count, dtype: int64
#
# Column: vehicle_first_impact_location
# vehicle_first_impact_location
# TWELVE OCLOCK    68021
# SIX OCLOCK       34273
# ONE OCLOCK       16196
# ELEVEN OCLOCK    13772
# TWO OCLOCK        6238
# TEN OCLOCK        6191
# SEVEN OCLOCK      4279
# FOUR OCLOCK       4126
# FIVE OCLOCK       4063
# EIGHT OCLOCK      3700
# THREE OCLOCK      3379
# NINE OCLOCK       3358
# UNKNOWN           3081
# UNDERSIDE          524
# NON-COLLISION      394
# ROOF TOP           354
# Missing            156
# Name: count, dtype: int64
#
# Column: vehicle_second_impact_location
# vehicle_second_impact_location
# TWELVE OCLOCK    67762
# SIX OCLOCK       33922
# ONE OCLOCK       15865
# ELEVEN OCLOCK    13438
# TWO OCLOCK        6476
# TEN OCLOCK        6314
# SEVEN OCLOCK      4224
# FOUR OCLOCK       4173
# FIVE OCLOCK       4021
# EIGHT OCLOCK      3808
# THREE OCLOCK      3660
# NINE OCLOCK       3547
# UNKNOWN           3070
# UNDERSIDE          650
# ROOF TOP           543
# NON-COLLISION      376
# Missing            256
# Name: count, dtype: int64
#
# Column: vehicle_body_type
# vehicle_body_type
# PASSENGER CAR                                                119102
# (SPORT) UTILITY VEHICLE                                       15991
# PICKUP TRUCK                                                   6786
# VAN                                                            4957
# TRANSIT BUS                                                    3642
# SCHOOL BUS                                                     2975
# Missing                                                        2649
# POLICE VEHICLE/NON EMERGENCY                                   2116
# OTHER LIGHT TRUCKS (10,000LBS (4,536KG) OR LESS)               1909
# CARGO VAN/LIGHT TRUCK 2 AXLES (OVER 10,000LBS (4,536 KG))      1858
# OTHER                                                          1539
# POLICE VEHICLE/EMERGENCY                                       1498
# MEDIUM/HEAVY TRUCKS 3 AXLES (OVER 10,000LBS (4,536KG))         1469
# UNKNOWN                                                        1061
# MOTORCYCLE                                                      889
# STATION WAGON                                                   692
# TRUCK TRACTOR                                                   500
# AMBULANCE/EMERGENCY                                             466
# FIRE VEHICLE/EMERGENCY                                          438
# OTHER BUS                                                       418
# FIRE VEHICLE/NON EMERGENCY                                      296
# RECREATIONAL VEHICLE                                            197
# AMBULANCE/NON EMERGENCY                                         185
# SNOWMOBILE                                                      123
# ALL TERRAIN VEHICLE (ATV)                                       119
# MOPED                                                            87
# AUTOCYCLE                                                        41
# LOW SPEED VEHICLE                                                34
# CROSS COUNTRY BUS                                                31
# FARM VEHICLE                                                     21
# LIMOUSINE                                                        16
# Name: count, dtype: int64
#
# Column: vehicle_movement
# vehicle_movement
# MOVING CONSTANT SPEED      67233
# SLOWING OR STOPPING        24452
# STOPPED IN TRAFFIC LANE    18399
# MAKING LEFT TURN           16611
# ACCELERATING                9659
# BACKING                     5783
# MAKING RIGHT TURN           5414
# CHANGING LANES              4682
# STARTING FROM LANE          4507
# UNKNOWN                     2821
# PARKED                      2689
# PARKING                     1933
# STARTING FROM PARKED        1894
# MAKING U TURN               1225
# PASSING                      954
# OTHER                        898
# ENTERING TRAFFIC LANE        819
# SKIDDING                     690
# NEGOTIATING A CURVE          545
# Missing                      386
# RIGHT TURN ON RED            267
# LEAVING TRAFFIC LANE         207
# DRIVERLESS MOVING VEH.        37
# Name: count, dtype: int64
#
# Column: vehicle_continuing_dir
# vehicle_continuing_dir
# North      46845
# South      45951
# East       36096
# West       34866
# Unknown     5658
# Missing     2689
# Name: count, dtype: int64
#
# Column: vehicle_going_dir
# vehicle_going_dir
# North      47645
# South      46682
# East       35296
# West       34764
# Unknown     5029
# Missing     2689
# Name: count, dtype: int64
#
# Column: vehicle_make
# vehicle_make
# TOYOTA        23171
# HONDA         18870
# FORD          17138
# TOYT           8840
# NISSAN         8525
#               ...
# FORDD             1
# LEIKE             1
# TAO               1
# VOLKSWGONA        1
# HYUNUDAI          1
# Name: count, Length: 1876, dtype: int64
#
# Column: vehicle_model
# vehicle_model
# 4S                     13748
# TK                     10978
# CAMRY                   6146
# CIVIC                   5571
# ACCORD                  5559
#                        ...
# ALTIMA SD                  1
# CRAWLER LOADER 755K        1
# ROMERO                     1
# GX37X                      1
# RENAGADE                   1
# Name: count, Length: 6687, dtype: int64
#
# Column: equipment_problems
# equipment_problems
# NO MISUSE              123464
# Missing                 34141
# UNKNOWN                 14148
# AIR BAG FAILED            174
# OTHER                     112
# BELT(S) MISUSED            34
# BELTS/ANCHORS BROKE        12
# STRAP/TETHER LOOSE          8
# FACING WRONG WAY            6
# NOT STREPPED RIGHT          4
# SIZE/TYPE IMPROPER          2
# Name: count, dtype: int64

# %%
# Observing the Output for the each columns with the level of missing values and decision to keep or drop or replace the values

# %% [markdown]
# vehicle_damage_extent- 316 Missing and unknow "keep as is"
#
# vehicle_first_impact_location - "Drop"
#
# vehicle_second_impact_location - "Drop"
#
# vehicle_body_type - "keep as is"
#
# vehicle_movement - 386 fill with "Mode"
#
# vehicle_continuing_dir - "Drop"
#
# vehicle_going_dir - "Drop"
#
# vehicle_make - "keep as is"
#
# vehicle_model - "keep as is"
#
# equipment_problems - "keep as is"
#
# For route_type - 16973 missing values and 20 unknown, which can be replaced by the "Mode"
#
# For road_name - 15937 missing values can be filled with "Mode" or "keep as is"
#
# For cross_street_type - 17006 missing values which can be replaced  with "Mode" or "keep as is"
#
# For cross_street_name - 15951 missing values which can be replaced by the "Mode"
#
# For off_road_description - "Drop"
#
# For municipality - "Drop"
#
# For related_non_motorist - "Drop"
#
# For collision_type - 585 missing values which can be replaced by "Mode"
#
# For weather - 13354 missing values- "keep as is"
#
# For surface_condition - 20118 missing values- "keep as is"
#
# For light - 1445 missing values "keep as is"
#
# traffic_control - 25469 Missing - "Mode"/"Drop"
#
# driver_substance_abuse - 31324 Missing
#
# non_motorist_substance_abuse - "Drop"
#
# circumstance - "Drop"
#
# drivers_license_state - 9950 "keep as is"

# %% [markdown]
# ## Dropping columns with less importance

# %%
col_to_drop = ['circumstance', 'non_motorist_substance_abuse', 'related_non_motorist','municipality','off_road_description','vehicle_first_impact_location','vehicle_second_impact_location','vehicle_continuing_dir','vehicle_going_dir']
sql_frame.drop(columns=col_to_drop, inplace=True)

# %%
sql_frame.head()
# Out:
#   report_number local_case_number                agency_name  \
# 0   MCP3040003N         190026050   Montgomery County Police
# 1    EJ78850038         230034791  Gaithersburg Police Depar
# 2   MCP2009002G         230034583   Montgomery County Police
# 3   MCP3201004C         230035036   Montgomery County Police
# 4   MCP23290028         230035152   Montgomery County Police
#
#         acrs_report_type         crash_date_time        route_type  \
# 0  Property Damage Crash  05/31/2019 03:00:00 PM           Missing
# 1  Property Damage Crash  07/21/2023 05:59:00 PM  Maryland (State)
# 2  Property Damage Crash  07/20/2023 03:10:00 PM  Maryland (State)
# 3  Property Damage Crash  07/23/2023 12:10:00 PM            County
# 4  Property Damage Crash  07/24/2023 06:10:00 AM            County
#
#                 road_name cross_street_type  cross_street_name  \
# 0                 Missing           Missing            Missing
# 1            FREDERICK RD           Unknown    WATKINS MILL RD
# 2             GEORGIA AVE  Maryland (State)         NORBECK RD
# 3         CRYSTAL ROCK DR            County  WATERS LANDING DR
# 4  MONTGOMERY VILLAGE AVE            County       CENTERWAY RD
#
#             collision_type  ... vehicle_damage_extent  \
# 0                    OTHER  ...           SUPERFICIAL
# 1  STRAIGHT MOVEMENT ANGLE  ...             DISABLING
# 2  STRAIGHT MOVEMENT ANGLE  ...            FUNCTIONAL
# 3  STRAIGHT MOVEMENT ANGLE  ...            FUNCTIONAL
# 4        HEAD ON LEFT TURN  ...            FUNCTIONAL
#
#          vehicle_body_type    vehicle_movement speed_limit driverless_vehicle  \
# 0            PASSENGER CAR             PARKING          15                 No
# 1            PASSENGER CAR    MAKING LEFT TURN          40                 No
# 2             PICKUP TRUCK        ACCELERATING          35                 No
# 3            PASSENGER CAR  STARTING FROM LANE          40                 No
# 4  (SPORT) UTILITY VEHICLE    MAKING LEFT TURN          35                 No
#
#   parked_vehicle vehicle_year vehicle_make vehicle_model equipment_problems
# 0             No         2004        HONDA            TK            UNKNOWN
# 1             No         2011          GMC            TK          NO MISUSE
# 2             No         2019         FORD          F150          NO MISUSE
# 3             No         2016          KIA            SW          NO MISUSE
# 4             No         2016         TOYT            TK          NO MISUSE
#
# [5 rows x 31 columns]

# %%
# Checking number of rows and columns after dropping the columns.

# %%
num_rows, num_columns = sql_frame.shape
print("Number of rows:", num_rows)
print("Number of columns:", num_columns)
# Out:
# Number of rows: 172105
# Number of columns: 31

# %%
# Transforming the values with missing in the colums as required.

# %%
#Replacing Missing with mode
sql_frame['vehicle_movement'] = sql_frame['vehicle_movement'].replace('Missing', sql_frame['vehicle_movement'].mode()[0])
sql_frame['route_type'] = sql_frame['route_type'].replace('Missing', sql_frame['route_type'].mode()[0])
sql_frame['road_name'] = sql_frame['road_name'].replace('Missing', sql_frame['road_name'].mode()[0])
sql_frame['cross_street_type'] = sql_frame['cross_street_type'].replace('Missing', sql_frame['cross_street_type'].mode()[0])
sql_frame['cross_street_name'] = sql_frame['cross_street_name'].replace('Missing', sql_frame['cross_street_name'].mode()[0])
sql_frame['collision_type'] = sql_frame['collision_type'].replace('Missing', sql_frame['collision_type'].mode()[0])

# %%
sql_frame.head()
# Out:
#   report_number local_case_number                agency_name  \
# 0   MCP3040003N         190026050   Montgomery County Police
# 1    EJ78850038         230034791  Gaithersburg Police Depar
# 2   MCP2009002G         230034583   Montgomery County Police
# 3   MCP3201004C         230035036   Montgomery County Police
# 4   MCP23290028         230035152   Montgomery County Police
#
#         acrs_report_type         crash_date_time        route_type  \
# 0  Property Damage Crash  05/31/2019 03:00:00 PM  Maryland (State)
# 1  Property Damage Crash  07/21/2023 05:59:00 PM  Maryland (State)
# 2  Property Damage Crash  07/20/2023 03:10:00 PM  Maryland (State)
# 3  Property Damage Crash  07/23/2023 12:10:00 PM            County
# 4  Property Damage Crash  07/24/2023 06:10:00 AM            County
#
#                 road_name cross_street_type  cross_street_name  \
# 0                 Missing            County            Missing
# 1            FREDERICK RD           Unknown    WATKINS MILL RD
# 2             GEORGIA AVE  Maryland (State)         NORBECK RD
# 3         CRYSTAL ROCK DR            County  WATERS LANDING DR
# 4  MONTGOMERY VILLAGE AVE            County       CENTERWAY RD
#
#             collision_type  ... vehicle_damage_extent  \
# 0                    OTHER  ...           SUPERFICIAL
# 1  STRAIGHT MOVEMENT ANGLE  ...             DISABLING
# 2  STRAIGHT MOVEMENT ANGLE  ...            FUNCTIONAL
# 3  STRAIGHT MOVEMENT ANGLE  ...            FUNCTIONAL
# 4        HEAD ON LEFT TURN  ...            FUNCTIONAL
#
#          vehicle_body_type    vehicle_movement speed_limit driverless_vehicle  \
# 0            PASSENGER CAR             PARKING          15                 No
# 1            PASSENGER CAR    MAKING LEFT TURN          40                 No
# 2             PICKUP TRUCK        ACCELERATING          35                 No
# 3            PASSENGER CAR  STARTING FROM LANE          40                 No
# 4  (SPORT) UTILITY VEHICLE    MAKING LEFT TURN          35                 No
#
#   parked_vehicle vehicle_year vehicle_make vehicle_model equipment_problems
# 0             No         2004        HONDA            TK            UNKNOWN
# 1             No         2011          GMC            TK          NO MISUSE
# 2             No         2019         FORD          F150          NO MISUSE
# 3             No         2016          KIA            SW          NO MISUSE
# 4             No         2016         TOYT            TK          NO MISUSE
#
# [5 rows x 31 columns]

# %%
# Count the number of columns containing 'Missing'
missing_columns_count = 0
missing_columns = []

for column in sql_frame.columns:
    if (sql_frame[column] == 'Missing').any():
        missing_count = (sql_frame[column] == 'Missing').sum()
        if missing_count > 0:
            missing_columns_count += 1
            missing_columns.append((column, missing_count))

print("Total number of columns with 'Missing' values:", missing_columns_count)
print("Columns with count of 'Missing' values:")
for column_name, count in missing_columns:
    print(f"{column_name}: {count}")
# Out:
# Total number of columns with 'Missing' values: 13
# Columns with count of 'Missing' values:
# road_name: 15937
# cross_street_name: 15951
# weather: 13354
# surface_condition: 20118
# light: 1445
# traffic_control: 25469
# driver_substance_abuse: 31324
# drivers_license_state: 9950
# vehicle_damage_extent: 316
# vehicle_body_type: 2649
# vehicle_make: 24
# vehicle_model: 66
# equipment_problems: 34141

# %%
final_transformed_frame=sql_frame

# %%
new_df = sql_frame.head(5000)
filename = "drivers_final.json"
new_df .to_json(filename, orient='records')

# %%
# Creating output file after commiting all the required transformation.
filename = "drivers.json"
final_transformed_frame.to_json(filename, orient='records')

# %% [markdown]
# ## Mongo DB Connection

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://x23236108:aasim123@montgomerycluster.tzxvtsd.mongodb.net/?retryWrites=true&w=majority&appName=montgomerycluster"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

try:
    #client.admin.command('ping')
    client.montgomery.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
# checkig server status

# %%
try:
    server_status = client.montgomery.command('serverStatus')
    print("Server is up and running.")
except Exception as e:
    print("Error:", e)
# Out:
# Server is up and running.

# %%
# check databases.

# %%
databases = client.list_database_names()
print("Databases:")
for db_obj in databases:
    print(db_obj)
# Out:
# Databases:
# montgomery
# montgomery_reverse
# admin
# local

# %%
# checking all collections in mongo db

# %%
database_name = "montgomery"
collections = client[database_name].list_collection_names()
print("\nCollections in", database_name, ":")
for col in collections:
    print(col)
# Out:
# Collections in montgomery :
# drivers
# non_motorists
# non_motorists_dataset
# incidents

# %%
### Create database named montgomery and collection named driver

# %%
db = client["montgomery"]

# %%
database = 'montgomery'
dblist = client.list_database_names()
if database in dblist:
  print(f"The database {database} exists.")
  colList = db.list_collection_names()
  collection_name = 'drivers'
  if collection_name in colList:
      print(f"The collection { collection_name} exists.")
  else:
      print(f"The collection { collection_name } does NOT exists.")
      collection = db[ collection_name ]
else:
  print(f"The database {database} does not exists.")
  db = client[database]
# Out:
# The database montgomery exists.
# The collection drivers exists.

# %%
collections = client[database_name].list_collection_names()
print("\nCollections in", database_name, ":")
for col in collections:
    print(col)
# Out:
# Collections in montgomery :
# drivers
# non_motorists
# non_motorists_dataset
# incidents

# %% [markdown]
# ## Loading JSON file onto incidents collection of montgomery database

# %%
# Select database and collection
db = client['montgomery']
collections=db["drivers"]

# Get the total number of documents in the collection
total_records = collection.count_documents({})
print("Total number of records in the collection:", total_records)
# Out:
# Total number of records in the collection: 20000

# %%
## Loading JSON file

# %%
import json
filename = "drivers_final.json"
with open(filename, 'r') as file:
    data = json.load(file)

# %%
# Insert documents into collection

# %%
collection = db[collection_name]
collection.insert_many(data)
print("JSON data successfully loaded into MongoDB collection 'drivers_dupe' in database 'montgomery'.")
total_records = collection.count_documents({})
print("Total number of records in the collection:", total_records)
# Out:
# JSON data successfully loaded into MongoDB collection 'drivers_dupe' in database 'montgomery'.
# Total number of records in the collection: 20000

# %% [markdown]
# ## Reading data for final analysis/visualization from MongoDB

# %%
db = client["montgomery"]
collection = db["drivers"]
cursor = collection.find({})
mongo_frame = pd.DataFrame(list(cursor))

# %%
mongo_frame.head()
# Out:
#                         _id report_number local_case_number  \
# 0  6626c0ba1f8fc9ed713784b8   MCP3040003N         190026050
# 1  6626c0ba1f8fc9ed713784b9    EJ78850038         230034791
# 2  6626c0ba1f8fc9ed713784ba   MCP2009002G         230034583
# 3  6626c0ba1f8fc9ed713784bb   MCP3201004C         230035036
# 4  6626c0ba1f8fc9ed713784bc   MCP23290028         230035152
#
#                  agency_name       acrs_report_type         crash_date_time  \
# 0   Montgomery County Police  Property Damage Crash  05/31/2019 03:00:00 PM
# 1  Gaithersburg Police Depar  Property Damage Crash  07/21/2023 05:59:00 PM
# 2   Montgomery County Police  Property Damage Crash  07/20/2023 03:10:00 PM
# 3   Montgomery County Police  Property Damage Crash  07/23/2023 12:10:00 PM
# 4   Montgomery County Police  Property Damage Crash  07/24/2023 06:10:00 AM
#
#          route_type               road_name cross_street_type  \
# 0  Maryland (State)                 Missing            County
# 1  Maryland (State)            FREDERICK RD           Unknown
# 2  Maryland (State)             GEORGIA AVE  Maryland (State)
# 3            County         CRYSTAL ROCK DR            County
# 4            County  MONTGOMERY VILLAGE AVE            County
#
#    cross_street_name  ... vehicle_damage_extent        vehicle_body_type  \
# 0            Missing  ...           SUPERFICIAL            PASSENGER CAR
# 1    WATKINS MILL RD  ...             DISABLING            PASSENGER CAR
# 2         NORBECK RD  ...            FUNCTIONAL             PICKUP TRUCK
# 3  WATERS LANDING DR  ...            FUNCTIONAL            PASSENGER CAR
# 4       CENTERWAY RD  ...            FUNCTIONAL  (SPORT) UTILITY VEHICLE
#
#      vehicle_movement speed_limit driverless_vehicle parked_vehicle  \
# 0             PARKING          15                 No             No
# 1    MAKING LEFT TURN          40                 No             No
# 2        ACCELERATING          35                 No             No
# 3  STARTING FROM LANE          40                 No             No
# 4    MAKING LEFT TURN          35                 No             No
#
#   vehicle_year vehicle_make vehicle_model equipment_problems
# 0         2004        HONDA            TK            UNKNOWN
# 1         2011          GMC            TK          NO MISUSE
# 2         2019         FORD          F150          NO MISUSE
# 3         2016          KIA            SW          NO MISUSE
# 4         2016         TOYT            TK          NO MISUSE
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Visualising The data with individual columns.

# %%
plt.hist(data=mongo_frame,x='Driver_At_Fault', bins=8, color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Driver_At_Fault')
plt.ylabel('Frequency')

# Show plot
plt.show()

# %% [markdown]
# ## Visualisation of Crashes by Agency Names

# %%
# Distribution of crashes by agency name
plt.figure(figsize=(10, 6))
sns.countplot(x='agency_name', data=mongo_frame)
plt.xticks(rotation=45)
plt.title('Crashes by Agency Name')
plt.show()

# %% [markdown]
# ## Visualisation of Crash Frequency by Road Name and Cross Street Name.

# %%
# Set the figure size
plt.figure(figsize=(12, 6))

# Plot for Crash frequency by road name
plt.subplot(1, 2, 1)
sns.countplot(y='road_name', data=mongo_frame, order=mongo_frame['road_name'].value_counts().index[:10])
plt.title('Crash Frequency by Road Name (Top 10)')
plt.xlabel('Frequency')
plt.ylabel('Road Name')

# Plot for Crash frequency by cross street name
plt.subplot(1, 2, 2)
sns.countplot(y='cross_street_name', data=mongo_frame, order=mongo_frame['cross_street_name'].value_counts().index[:10])
plt.title('Crash Frequency by Cross Street Name (Top 10)')
plt.xlabel('Frequency')
plt.ylabel('Cross Street Name')

# Adjust layout
plt.tight_layout()

# Show the plots
plt.show()

# %% [markdown]
# ## Visualisation of Crashes over the years.

# %%
# Time series analysis: Distribution of crashes over years
mongo_frame['crash_date_time'] = pd.to_datetime(mongo_frame['crash_date_time'])
mongo_frame['year'] = mongo_frame['crash_date_time'].dt.year
plt.figure(figsize=(10, 6))
sns.countplot(x='year', data=mongo_frame)
plt.title('Crashes Over Years')
plt.show()
# Out:
# /var/folders/_t/d0zkt0395w39b1mpx92kjmrw0000gn/T/ipykernel_55901/3068349968.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   mongo_frame['crash_date_time'] = pd.to_datetime(mongo_frame['crash_date_time'])

# %% [markdown]
# ## Visualisation of Crashes by ACRS Report Type

# %%
# Calculate the counts for each ACRS report type
acrs_counts = mongo_frame['acrs_report_type'].value_counts()

# Plotting the pie chart
plt.figure(figsize=(8, 8))
plt.pie(acrs_counts, labels=acrs_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Crashes by ACRS Report Type')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

# Show the plot
plt.show()

# %% [markdown]
# ## Visualisation of Driver with Injury Severity.

# %%
# Set the figure size
plt.figure(figsize=(10, 6))

# Plot for Driver with Injury Severity
sns.countplot(y='injury_severity', data=mongo_frame, order=mongo_frame['injury_severity'].value_counts().index)
plt.title('Driver with Injury Severity')
plt.xlabel('Frequency')
plt.ylabel('Injury Severity')

# Show the plot
plt.show()

# %% [markdown]
# ## Visualisation of Driver Substance Abuse

# %%
# Driver Substance Abuse Distribution
plt.figure(figsize=(8, 8))
mongo_frame['driver_substance_abuse'].value_counts().plot(kind='pie',autopct='%1.1f%%')
plt.title('Proportion of Driver Substance Abuse')
plt.ylabel('')
plt.legend(bbox_to_anchor=(2, 0.5), loc="center left")
plt.tight_layout()
plt.show()
# Out:
# /var/folders/_t/d0zkt0395w39b1mpx92kjmrw0000gn/T/ipykernel_55901/1304532602.py:7: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()
