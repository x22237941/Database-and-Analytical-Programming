# %% [markdown]
# ### Import Required Librariers

# %%
import numpy as np
import pandas as pd
import matplotlib as mp
import matplotlib.pyplot as plt
import seaborn as sns
import csv
import mysql.connector as mysql
from sqlalchemy import create_engine

# %% [markdown]
# ### Creating MySQL Engine

# %%
engine = create_engine('mysql+pymysql://root:sana123@localhost/montgomery')

# %% [markdown]
# ### File to feed

# %%
data=pd.read_csv("Incidents_Data_20240404.csv")

# %% [markdown]
# ### Establishing MySQL database connection

# %%
def connect_to_mysql():
    try:
        # MySQL database connection parameters
        host = 'localhost'
        user = 'root'
        password = 'sana123'
        database = 'montgomery'

        # Establish connection
        connection = mysql.connect(
            host=host,
            user=user,
            password=password,
            database=database
        )

        if connection.is_connected():
            print("Connected to MySQL database")
            return connection
    except mysql.connector.Error as e:
        print("Error connecting to MySQL database:", e)

# %%
conn = connect_to_mysql()
conn
# Out:
# Connected to MySQL database

# %% [markdown]
# ### DDL & DML Queries - Relational DB Reading & Writing Operations

# %%
create_table='''CREATE TABLE IF NOT EXISTS incident_dupe (
                report_number TEXT,
                local_case_number TEXT,
                agency_name TEXT,
                acrs_report_type TEXT,
                crash_date_time TEXT,
                hit_run TEXT,
                route_type TEXT,
                mile_point TEXT,
                mile_point_direction TEXT,
                lane_direction TEXT,
                lane_number TEXT,
                lane_type TEXT,
                number_of_lanes TEXT,
                direction TEXT,
                distance TEXT,
                distance_unit TEXT,
                road_grade TEXT,
                non_traffic TEXT,
                road_name TEXT,
                cross_street_type TEXT,
                cross_street_name TEXT,
                off_road_description TEXT,
                municipality TEXT,
                related_non_motorist TEXT,
                at_fault TEXT,
                collision_type TEXT,
                weather TEXT,
                surface_condition TEXT,
                light TEXT,
                traffic_control TEXT,
                driver_substance_abuse TEXT,
                non_motorist_substance_abuse TEXT,
                first_harmful_event TEXT,
                second_harmful_event TEXT,
                fixed_object_struck TEXT,
                junction TEXT,
                intersection_type TEXT,
                intersection_area TEXT,
                road_alignment TEXT,
                road_condition TEXT,
                road_division TEXT,
                latitude TEXT,
                longitude TEXT,
                location TEXT
                )'''

# %%
show_table="show tables"

# %%
insert_data='''INSERT INTO incident_dupe (report_number, local_case_number, agency_name, acrs_report_type, crash_date_time, hit_run, route_type, mile_point, mile_point_direction, lane_direction, lane_number,lane_type, number_of_lanes, direction, distance, distance_unit, road_grade, non_traffic, road_name, cross_street_type, cross_street_name, off_road_description, municipality, related_non_motorist, at_fault, collision_type, weather, surface_condition, light, traffic_control, driver_substance_abuse, non_motorist_substance_abuse, first_harmful_event, second_harmful_event, fixed_object_struck, junction, intersection_type, intersection_area, road_alignment, road_condition, road_division,latitude,longitude,location) VALUES ( %s,%s,%s,%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s,
# %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)'''

# %%
drop_columns='''ALTER TABLE incident_dupe
DROP COLUMN Latitude,
DROP COLUMN Longitude,
DROP COLUMN Location'''

# %%
select_query="select * from incident_dupe"

# %% [markdown]
# ### Establishing a cursor

# %%
cursor = conn.cursor()

# %%
cursor.execute(show_table) # gives all the tables in the database
tables = cursor.fetchall()
# Print table names
for table in tables:
    print(table[0])
# Out:
# drivers
# drivers_dupe
# non_motorists

# %%
cursor.execute(create_table) # executing/creating a table
conn.commit() # Commit the transaction

# %%
cursor.execute(show_table) # gives all the tables in the database
tables = cursor.fetchall()
# Print table names
for table in tables:
    print(table[0])
# Out:
# drivers
# drivers_dupe
# incident_dupe
# non_motorists

# %%
# Execute the query to get column information
cursor.execute("DESCRIBE incident_dupe")

# %%
# Fetch all the rows
columns = cursor.fetchall()
# Print column names and data types
for column in columns:
    print(column[0], "-", column[1])
# Out:
# report_number - text
# local_case_number - text
# agency_name - text
# acrs_report_type - text
# crash_date_time - text
# hit_run - text
# route_type - text
# mile_point - text
# mile_point_direction - text
# lane_direction - text
# lane_number - text
# lane_type - text
# number_of_lanes - text
# direction - text
# distance - text
# distance_unit - text
# road_grade - text
# non_traffic - text
# road_name - text
# cross_street_type - text
# cross_street_name - text
# off_road_description - text
# municipality - text
# related_non_motorist - text
# at_fault - text
# collision_type - text
# weather - text
# surface_condition - text
# light - text
# traffic_control - text
# driver_substance_abuse - text
# non_motorist_substance_abuse - text
# first_harmful_event - text
# second_harmful_event - text
# fixed_object_struck - text
# junction - text
# intersection_type - text
# intersection_area - text
# road_alignment - text
# road_condition - text
# road_division - text
# latitude - text
# longitude - text
# location - text

# %%
cursor.close()
# Out:
# True

# %%
data.head()
# Out:
#   Report Number Local Case Number                Agency Name  \
# 0   MCP2686006F         230031339   Montgomery County Police
# 1   MCP3230004G         230031335   Montgomery County Police
# 2   MCP12600013         230031067   Montgomery County Police
# 3    DD55750030         230031365  Rockville Police Departme
# 4   MCP3010008B         230034141   Montgomery County Police
#
#         ACRS Report Type         Crash Date/Time Hit/Run  \
# 0  Property Damage Crash  06/30/2023 10:55:00 PM      No
# 1  Property Damage Crash  06/30/2023 08:00:00 PM      No
# 2           Injury Crash  06/29/2023 11:53:00 AM      No
# 3  Property Damage Crash  07/01/2023 01:48:00 AM     Yes
# 4  Property Damage Crash  07/01/2023 12:52:00 PM      No
#
#              Route Type  Mile Point Mile Point Direction Lane Direction  ...  \
# 0                   NaN         NaN                  NaN            NaN  ...
# 1                County        1.42                 West          North  ...
# 2      Maryland (State)       11.26                North          North  ...
# 3          Municipality        0.07                North          North  ...
# 4  Other Public Roadway        0.00                 West           West  ...
#
#    Fixed Oject Struck          Junction      Intersection Type  \
# 0               OTHER               NaN                    NaN
# 1                 NaN      INTERSECTION  FOUR-WAY INTERSECTION
# 2                CURB  NON INTERSECTION                    NaN
# 3  LIGHT SUPPORT POLE             OTHER  FOUR-WAY INTERSECTION
# 4                 NaN               NaN                    NaN
#
#   Intersection Area  Road Alignment Road Condition  \
# 0               NaN             NaN            NaN
# 1               NaN        STRAIGHT     NO DEFECTS
# 2      INTERSECTION        STRAIGHT     NO DEFECTS
# 3             OTHER        STRAIGHT     NO DEFECTS
# 4               NaN        STRAIGHT     NO DEFECTS
#
#                                       Road Division   Latitude  Longitude  \
# 0                                               NaN  39.244280 -77.335827
# 1  TWO-WAY, DIVIDED, UNPROTECTED PAINTED MIN 4 FEET  39.092024 -77.070570
# 2  TWO-WAY, DIVIDED, UNPROTECTED PAINTED MIN 4 FEET  39.277424 -77.324644
# 3                              TWO-WAY, NOT DIVIDED  39.074974 -77.113130
# 4                              TWO-WAY, NOT DIVIDED  39.026492 -77.148288
#
#                       Location
# 0  (39.24428009, -77.33582666)
# 1   (39.09202433, -77.0705695)
# 2  (39.27742352, -77.32464379)
# 3   (39.07497432, -77.1131297)
# 4  (39.02649167, -77.14828833)
#
# [5 rows x 44 columns]

# %% [markdown]
# The dataframe as seen above has "NaN" values which cannot be inserted into the tables created in MySQL DB

# %% [markdown]
# Thus we need to replace those Nan Values with any string like missing/unknown for instance i.e. time being

# %% [markdown]
# ### Creating a copy of original dataframe

# %%
df=data

# %%
print(df.dtypes)
# Out:
# Report Number                    object
# Local Case Number                object
# Agency Name                      object
# ACRS Report Type                 object
# Crash Date/Time                  object
# Hit/Run                          object
# Route Type                       object
# Mile Point                      float64
# Mile Point Direction             object
# Lane Direction                   object
# Lane Number                       int64
# Lane Type                        object
# Number of Lanes                   int64
# Direction                        object
# Distance                        float64
# Distance Unit                    object
# Road Grade                       object
# NonTraffic                       object
# Road Name                        object
# Cross-Street Type                object
# Cross-Street Name                object
# Off-Road Description             object
# Municipality                     object
# Related Non-Motorist             object
# At Fault                         object
# Collision Type                   object
# Weather                          object
# Surface Condition                object
# Light                            object
# Traffic Control                  object
# Driver Substance Abuse           object
# Non-Motorist Substance Abuse     object
# First Harmful Event              object
# Second Harmful Event             object
# Fixed Oject Struck               object
# Junction                         object
# Intersection Type                object
# Intersection Area                object
# Road Alignment                   object
# Road Condition                   object
# Road Division                    object
# Latitude                        float64
# Longitude                       float64
# Location                         object
# dtype: object

# %%
df_filled = df.fillna("Missing")

# %%
df_filled.head()
# Out:
#   Report Number Local Case Number                Agency Name  \
# 0   MCP2686006F         230031339   Montgomery County Police
# 1   MCP3230004G         230031335   Montgomery County Police
# 2   MCP12600013         230031067   Montgomery County Police
# 3    DD55750030         230031365  Rockville Police Departme
# 4   MCP3010008B         230034141   Montgomery County Police
#
#         ACRS Report Type         Crash Date/Time Hit/Run  \
# 0  Property Damage Crash  06/30/2023 10:55:00 PM      No
# 1  Property Damage Crash  06/30/2023 08:00:00 PM      No
# 2           Injury Crash  06/29/2023 11:53:00 AM      No
# 3  Property Damage Crash  07/01/2023 01:48:00 AM     Yes
# 4  Property Damage Crash  07/01/2023 12:52:00 PM      No
#
#              Route Type Mile Point Mile Point Direction Lane Direction  ...  \
# 0               Missing    Missing              Missing        Missing  ...
# 1                County       1.42                 West          North  ...
# 2      Maryland (State)      11.26                North          North  ...
# 3          Municipality       0.07                North          North  ...
# 4  Other Public Roadway        0.0                 West           West  ...
#
#    Fixed Oject Struck          Junction      Intersection Type  \
# 0               OTHER           Missing                Missing
# 1             Missing      INTERSECTION  FOUR-WAY INTERSECTION
# 2                CURB  NON INTERSECTION                Missing
# 3  LIGHT SUPPORT POLE             OTHER  FOUR-WAY INTERSECTION
# 4             Missing           Missing                Missing
#
#   Intersection Area Road Alignment Road Condition  \
# 0           Missing        Missing        Missing
# 1           Missing       STRAIGHT     NO DEFECTS
# 2      INTERSECTION       STRAIGHT     NO DEFECTS
# 3             OTHER       STRAIGHT     NO DEFECTS
# 4           Missing       STRAIGHT     NO DEFECTS
#
#                                       Road Division   Latitude  Longitude  \
# 0                                           Missing  39.244280 -77.335827
# 1  TWO-WAY, DIVIDED, UNPROTECTED PAINTED MIN 4 FEET  39.092024 -77.070570
# 2  TWO-WAY, DIVIDED, UNPROTECTED PAINTED MIN 4 FEET  39.277424 -77.324644
# 3                              TWO-WAY, NOT DIVIDED  39.074974 -77.113130
# 4                              TWO-WAY, NOT DIVIDED  39.026492 -77.148288
#
#                       Location
# 0  (39.24428009, -77.33582666)
# 1   (39.09202433, -77.0705695)
# 2  (39.27742352, -77.32464379)
# 3   (39.07497432, -77.1131297)
# 4  (39.02649167, -77.14828833)
#
# [5 rows x 44 columns]

# %% [markdown]
# ### Writing the dataframe to MySQL Table

# %%
inserted_records_count = 0

# %%
cursor = conn.cursor()

# %%
for index, row in df_filled.iterrows():
    cursor.execute(insert_data, tuple(row))
    inserted_records_count += 1

# %%
conn.commit()

# %%
print("Number of records inserted into table:", inserted_records_count)
# Out:
# Number of records inserted into table: 97458

# %%
# Execute SELECT COUNT(*) query
cursor.execute("SELECT COUNT(*) FROM incident_dupe")

# %%
# Fetch the result
count = cursor.fetchone()[0]
print("Number of records in 'incident_dupe' table:", count)
# Out:
# Number of records in 'incident_dupe' table: 97458

# %%
cursor.close()
# Out:
# True

# %% [markdown]
# ### Reading MySQL table to dataframe

# %%
cursor = conn.cursor()

# %%
cursor.execute(drop_columns)

# %%
conn.commit()

# %%
# Execute the DESCRIBE query
cursor.execute("DESCRIBE incident_dupe")

# Fetch and print the column information
columns = cursor.fetchall()
for column in columns:
        print(column)
# Out:
# ('report_number', 'text', 'YES', '', None, '')
# ('local_case_number', 'text', 'YES', '', None, '')
# ('agency_name', 'text', 'YES', '', None, '')
# ('acrs_report_type', 'text', 'YES', '', None, '')
# ('crash_date_time', 'text', 'YES', '', None, '')
# ('hit_run', 'text', 'YES', '', None, '')
# ('route_type', 'text', 'YES', '', None, '')
# ('mile_point', 'text', 'YES', '', None, '')
# ('mile_point_direction', 'text', 'YES', '', None, '')
# ('lane_direction', 'text', 'YES', '', None, '')
# ('lane_number', 'text', 'YES', '', None, '')
# ('lane_type', 'text', 'YES', '', None, '')
# ('number_of_lanes', 'text', 'YES', '', None, '')
# ('direction', 'text', 'YES', '', None, '')
# ('distance', 'text', 'YES', '', None, '')
# ('distance_unit', 'text', 'YES', '', None, '')
# ('road_grade', 'text', 'YES', '', None, '')
# ('non_traffic', 'text', 'YES', '', None, '')
# ('road_name', 'text', 'YES', '', None, '')
# ('cross_street_type', 'text', 'YES', '', None, '')
# ('cross_street_name', 'text', 'YES', '', None, '')
# ('off_road_description', 'text', 'YES', '', None, '')
# ('municipality', 'text', 'YES', '', None, '')
# ('related_non_motorist', 'text', 'YES', '', None, '')
# ('at_fault', 'text', 'YES', '', None, '')
# ('collision_type', 'text', 'YES', '', None, '')
# ('weather', 'text', 'YES', '', None, '')
# ('surface_condition', 'text', 'YES', '', None, '')
# ('light', 'text', 'YES', '', None, '')
# ('traffic_control', 'text', 'YES', '', None, '')
# ('driver_substance_abuse', 'text', 'YES', '', None, '')
# ('non_motorist_substance_abuse', 'text', 'YES', '', None, '')
# ('first_harmful_event', 'text', 'YES', '', None, '')
# ('second_harmful_event', 'text', 'YES', '', None, '')
# ('fixed_object_struck', 'text', 'YES', '', None, '')
# ('junction', 'text', 'YES', '', None, '')
# ('intersection_type', 'text', 'YES', '', None, '')
# ('intersection_area', 'text', 'YES', '', None, '')
# ('road_alignment', 'text', 'YES', '', None, '')
# ('road_condition', 'text', 'YES', '', None, '')
# ('road_division', 'text', 'YES', '', None, '')

# %%
read_data = "select * from incident_dupe"

# %%
sql_frame = pd.read_sql(read_data, conn)
# Out:
# C:\Users\SANA JALGAONKAR\AppData\Local\Temp\ipykernel_1292\3075156522.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sql_frame = pd.read_sql(read_data, conn)

# %%
sql_frame.head()
# Out:
#   report_number local_case_number                agency_name  \
# 0   MCP2686006F         230031339   Montgomery County Police
# 1   MCP3230004G         230031335   Montgomery County Police
# 2   MCP12600013         230031067   Montgomery County Police
# 3    DD55750030         230031365  Rockville Police Departme
# 4   MCP3010008B         230034141   Montgomery County Police
#
#         acrs_report_type         crash_date_time hit_run  \
# 0  Property Damage Crash  06/30/2023 10:55:00 PM      No
# 1  Property Damage Crash  06/30/2023 08:00:00 PM      No
# 2           Injury Crash  06/29/2023 11:53:00 AM      No
# 3  Property Damage Crash  07/01/2023 01:48:00 AM     Yes
# 4  Property Damage Crash  07/01/2023 12:52:00 PM      No
#
#              route_type mile_point mile_point_direction lane_direction  ...  \
# 0               Missing    Missing              Missing        Missing  ...
# 1                County       1.42                 West          North  ...
# 2      Maryland (State)      11.26                North          North  ...
# 3          Municipality       0.07                North          North  ...
# 4  Other Public Roadway        0.0                 West           West  ...
#
#   non_motorist_substance_abuse first_harmful_event second_harmful_event  \
# 0                      Missing        FIXED OBJECT              Missing
# 1                      Missing       OTHER VEHICLE              Missing
# 2                      Missing        FIXED OBJECT         FIXED OBJECT
# 3                      Missing      PARKED VEHICLE         FIXED OBJECT
# 4                      Missing      PARKED VEHICLE              Missing
#
#   fixed_object_struck          junction      intersection_type  \
# 0               OTHER           Missing                Missing
# 1             Missing      INTERSECTION  FOUR-WAY INTERSECTION
# 2                CURB  NON INTERSECTION                Missing
# 3  LIGHT SUPPORT POLE             OTHER  FOUR-WAY INTERSECTION
# 4             Missing           Missing                Missing
#
#   intersection_area road_alignment road_condition  \
# 0           Missing        Missing        Missing
# 1           Missing       STRAIGHT     NO DEFECTS
# 2      INTERSECTION       STRAIGHT     NO DEFECTS
# 3             OTHER       STRAIGHT     NO DEFECTS
# 4           Missing       STRAIGHT     NO DEFECTS
#
#                                       road_division
# 0                                           Missing
# 1  TWO-WAY, DIVIDED, UNPROTECTED PAINTED MIN 4 FEET
# 2  TWO-WAY, DIVIDED, UNPROTECTED PAINTED MIN 4 FEET
# 3                              TWO-WAY, NOT DIVIDED
# 4                              TWO-WAY, NOT DIVIDED
#
# [5 rows x 41 columns]

# %% [markdown]
# ### Checking for duplicate records

# %%
duplicate_rows = sql_frame.duplicated()
print("Number of duplicate rows:", duplicate_rows.sum())
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# There are no Duplicate records in the data

# %% [markdown]
# ### If there were any duplicate records I would have dropped it using below

# %% [markdown]
# sql_frame = sql_frame.drop_duplicates()

# %% [markdown]
# ### Checking Missing Values

# %%
sql_frame.isnull().sum()
# Out:
# report_number                   0
# local_case_number               0
# agency_name                     0
# acrs_report_type                0
# crash_date_time                 0
# hit_run                         0
# route_type                      0
# mile_point                      0
# mile_point_direction            0
# lane_direction                  0
# lane_number                     0
# lane_type                       0
# number_of_lanes                 0
# direction                       0
# distance                        0
# distance_unit                   0
# road_grade                      0
# non_traffic                     0
# road_name                       0
# cross_street_type               0
# cross_street_name               0
# off_road_description            0
# municipality                    0
# related_non_motorist            0
# at_fault                        0
# collision_type                  0
# weather                         0
# surface_condition               0
# light                           0
# traffic_control                 0
# driver_substance_abuse          0
# non_motorist_substance_abuse    0
# first_harmful_event             0
# second_harmful_event            0
# fixed_object_struck             0
# junction                        0
# intersection_type               0
# intersection_area               0
# road_alignment                  0
# road_condition                  0
# road_division                   0
# dtype: int64

# %% [markdown]
# As we have replaced 'NaN' has been replaced with 'Missing' we'll search for 'Missing' present in each column.

# %% [markdown]
# ### Where all Missing values are present?

# %%
# Check where "Missing" values occur in each column
missing_mask = sql_frame.eq('Missing')

# Check which columns have at least one "Missing" value
columns_with_missing = missing_mask.any()

# Extract the column names where "Missing" values occur
columns_with_missing_values = columns_with_missing[columns_with_missing].index.tolist()

# Print the columns with "Missing" values
print("Columns with 'Missing' values:", columns_with_missing_values)
# Out:
# Columns with 'Missing' values: ['hit_run', 'route_type', 'mile_point', 'mile_point_direction', 'lane_direction', 'lane_type', 'direction', 'distance', 'distance_unit', 'road_grade', 'road_name', 'cross_street_type', 'cross_street_name', 'off_road_description', 'municipality', 'related_non_motorist', 'collision_type', 'weather', 'surface_condition', 'light', 'traffic_control', 'driver_substance_abuse', 'non_motorist_substance_abuse', 'first_harmful_event', 'second_harmful_event', 'fixed_object_struck', 'junction', 'intersection_type', 'intersection_area', 'road_alignment', 'road_condition', 'road_division']

# %% [markdown]
# These are all the columns where 'Missing' value is found....get the count of 'Missing' value in each of the above columns

# %%
# Iterate through columns with missing values
for column in columns_with_missing_values:
    # Get unique values and their counts
    unique_values_counts = sql_frame[column].value_counts() 
    # Print column name
    print("Column:", column)
    # Print unique values and their counts
    print(unique_values_counts)
    print()
# Out:
# Column: hit_run
# hit_run
# No         79476
# Yes        17980
# Missing        2
# Name: count, dtype: int64
#
# Column: route_type
# route_type
# Maryland (State)        39119
# County                  32674
# Missing                 12995
# Municipality             5777
# US (State)               3732
# Interstate (State)       1647
# Other Public Roadway      707
# Government                414
# Ramp                      357
# Service Road               22
# Unknown                    14
# Name: count, dtype: int64
#
# Column: mile_point
# mile_point
# Missing    12338
# 0.0         7317
# 0.17         487
# 0.18         460
# 0.21         451
#            ...
# 8.32           1
# 2.293          1
# 6.3            1
# 8.79           1
# 0.365          1
# Name: count, Length: 2123, dtype: int64
#
# Column: mile_point_direction
# mile_point_direction
# North      43609
# East       25743
# Missing    12991
# South       8525
# West        6589
# Unknown        1
# Name: count, dtype: int64
#
# Column: lane_direction
# lane_direction
# North      25902
# South      23975
# East       17733
# West       16771
# Missing    12327
# Unknown      750
# Name: count, dtype: int64
#
# Column: lane_type
# lane_type
# Missing                 87945
# LEFT TURN LANE           3182
# RIGHT TURN LANE          1700
# OTHER                    1069
# OFF ROAD                  825
# SHOULDER AREA             773
# ON RAMP                   586
# UNKNOWN                   400
# CROSSOVER AREA            387
# MEDIAN AREA               285
# ACCELERATION LANE         165
# OUTSIDE RIGHT OF WAY       69
# DECELERATION LANE          42
# SEPARATOR                  24
# GORE AREA                   6
# Name: count, dtype: int64
#
# Column: direction
# direction
# North      35160
# East       21452
# South      17363
# Missing    12338
# West       11108
# Unknown       37
# Name: count, dtype: int64
#
# Column: distance
# distance
# 0.0        43919
# Missing    10475
# 100.0       6395
# 50.0        5487
# 10.0        3215
#            ...
# 338.0          1
# 202.0          1
# 0.61           1
# 586.0          1
# 0.98           1
# Name: count, Length: 440, dtype: int64
#
# Column: distance_unit
# distance_unit
# FEET       78880
# Missing    12328
# MILE        5792
# UNKNOWN      458
# Name: count, dtype: int64
#
# Column: road_grade
# road_grade
# LEVEL             64570
# Missing           12967
# GRADE DOWNHILL     9866
# HILL UPHILL        7323
# HILL CREST         2185
# OTHER               190
# UNKNOWN             152
# DIP SAG             131
# ON BRIDGE            74
# Name: count, dtype: int64
#
# Column: road_name
# road_name
# Missing              12328
# GEORGIA AVE           5383
# NEW HAMPSHIRE AVE     3399
# FREDERICK RD          2896
# ROCKVILLE PIKE        2369
#                      ...
# HARDY PL                 1
# MERCER RD                1
# HUTCHINSON LA            1
# SURREYWOOD LA            1
# SLEAFORD RD              1
# Name: count, Length: 3839, dtype: int64
#
# Column: cross_street_type
# cross_street_type
# County                  46832
# Missing                 13016
# Maryland (State)        12847
# Municipality            10507
# Unknown                  7276
# Ramp                     3003
# Other Public Roadway     2160
# US (State)                780
# Government                633
# Interstate (State)        355
# Service Road               49
# Name: count, dtype: int64
#
# Column: cross_street_name
# cross_street_name
# Missing                      12338
# GEORGIA AVE                   1145
# CONNECTICUT AVE                824
# FREDERICK RD                   816
# NEW HAMPSHIRE AVE              692
#                              ...
# YEATMAN TERR                     1
# ANCHORAGE DR                     1
# ALPINE VALLEY CT (ENT TH)        1
# RIFFLE FORD CT                   1
# PELLITA TER                      1
# Name: count, Length: 6725, dtype: int64
#
# Column: off_road_description
# off_road_description
# Missing                                                    85132
# PARKING LOT                                                  100
# UNKNOWN                                                       12
# PARKING LOT OF 1283 SEVEN LOCKS RD                            12
# UNKNOWN LOCATION                                              12
#                                                            ...
# PARKING LOT IN FRONT OF 11405 WOODGLEN DR.                     1
# PARKING LOT BEHIND 4730 BRADLEY BLVD                           1
# PARKING LOT OF BWI AIRPORT                                     1
# PARKING LOT OF 618 CENTER POINT WAY                            1
# ACCESS ROAD BEHIND SOUTH GERMANTOWN INDOOR SWIM CENTER.        1
# Name: count, Length: 11561, dtype: int64
#
# Column: municipality
# municipality
# Missing                86967
# ROCKVILLE               5074
# GAITHERSBURG            3480
# TAKOMA PARK              989
# KENSINGTON               221
# CHEVY CHASE #4           174
# CHEVY CHASE #3            83
# FRIENDSHIP HEIGHTS        80
# POOLESVILLE               77
# CHEVY CHASE VIEW          48
# CHEVY CHASE VILLAGE       46
# CHEVY CHASE #5            36
# SOMERSET                  33
# GARRETT PARK              32
# WASHINGTON GROVE          26
# MATINS ADDITION           21
# NORTH CHEVY CHASE         19
# GLEN ECHO                 18
# LAYTONSVILLE              16
# BROOKEVILLE               13
# DRUMMOND                   5
# Name: count, dtype: int64
#
# Column: related_non_motorist
# related_non_motorist
# Missing                          92077
# PEDESTRIAN                        3813
# BICYCLIST                         1161
# OTHER                              240
# OTHER CONVEYANCE                    80
# MACHINE OPERATOR/RIDER              38
# OTHER PEDALCYCLIST                  26
# OTHER, PEDESTRIAN                    9
# BICYCLIST, PEDESTRIAN                5
# BICYCLIST, OTHER                     4
# OTHER CONVEYANCE, PEDESTRIAN         2
# IN ANIMAL-DRAWN VEH                  1
# MACHINE OPERATOR/RIDER, OTHER        1
# OTHER, OTHER CONVEYANCE              1
# Name: count, dtype: int64
#
# Column: collision_type
# collision_type
# SAME DIR REAR END               25737
# SINGLE VEHICLE                  16092
# STRAIGHT MOVEMENT ANGLE         15239
# OTHER                           13263
# SAME DIRECTION SIDESWIPE         8890
# HEAD ON LEFT TURN                6334
# HEAD ON                          2068
# SAME DIRECTION RIGHT TURN        1985
# SAME DIRECTION LEFT TURN         1836
# OPPOSITE DIRECTION SIDESWIPE     1599
# ANGLE MEETS LEFT TURN             993
# UNKNOWN                           717
# ANGLE MEETS RIGHT TURN            604
# Missing                           504
# SAME DIR REND LEFT TURN           367
# SAME DIR REND RIGHT TURN          366
# SAME DIR BOTH LEFT TURN           356
# ANGLE MEETS LEFT HEAD ON          346
# OPPOSITE DIR BOTH LEFT TURN       162
# Name: count, dtype: int64
#
# Column: weather
# weather
# CLEAR                       65512
# RAINING                     11673
# CLOUDY                       9608
# Missing                      7947
# SNOW                          877
# UNKNOWN                       648
# FOGGY                         429
# WINTRY MIX                    252
# OTHER                         214
# SLEET                         130
# SEVERE WINDS                   93
# BLOWING SNOW                   68
# BLOWING SAND, SOIL, DIRT        7
# Name: count, dtype: int64
#
# Column: surface_condition
# surface_condition
# DRY                       64943
# WET                       15856
# Missing                   14650
# ICE                         682
# SNOW                        602
# UNKNOWN                     407
# SLUSH                       132
# OTHER                        99
# MUD, DIRT, GRAVEL            36
# WATER(STANDING/MOVING)       30
# OIL                          18
# SAND                          3
# Name: count, dtype: int64
#
# Column: light
# light
# DAYLIGHT                    63184
# DARK LIGHTS ON              23736
# DARK NO LIGHTS               3504
# DUSK                         2182
# DAWN                         2004
# DARK -- UNKNOWN LIGHTING     1114
# Missing                       815
# UNKNOWN                       698
# OTHER                         221
# Name: count, dtype: int64
#
# Column: traffic_control
# traffic_control
# NO CONTROLS                41604
# TRAFFIC SIGNAL             29008
# Missing                    16436
# STOP SIGN                   6658
# FLASHING TRAFFIC SIGNAL     1144
# OTHER                       1143
# YIELD SIGN                   912
# UNKNOWN                      234
# PERSON                       164
# WARNING SIGN                 114
# RAILWAY CROSSING DEVICE       27
# SCHOOL ZONE SIGN DEVICE       14
# Name: count, dtype: int64
#
# Column: driver_substance_abuse
# driver_substance_abuse
# NONE DETECTED                                     60770
# Missing                                           15598
# NONE DETECTED, UNKNOWN                             5462
# UNKNOWN                                            5115
# N/A, NONE DETECTED                                 3113
# ALCOHOL PRESENT                                    2140
# ALCOHOL PRESENT, NONE DETECTED                     1456
# N/A, UNKNOWN                                       1154
# ALCOHOL CONTRIBUTED                                 834
# ALCOHOL CONTRIBUTED, NONE DETECTED                  455
# ALCOHOL PRESENT, N/A                                429
# ALCOHOL CONTRIBUTED, N/A                            131
# ILLEGAL DRUG PRESENT                                119
# ILLEGAL DRUG PRESENT, NONE DETECTED                  97
# MEDICATION PRESENT                                   51
# ILLEGAL DRUG CONTRIBUTED                             48
# MEDICATION PRESENT, NONE DETECTED                    47
# COMBINED SUBSTANCE PRESENT                           45
# ILLEGAL DRUG CONTRIBUTED, NONE DETECTED              43
# ILLEGAL DRUG PRESENT, N/A                            39
# OTHER                                                35
# COMBINED SUBSTANCE PRESENT, NONE DETECTED            32
# MEDICATION CONTRIBUTED, NONE DETECTED                29
# MEDICATION CONTRIBUTED                               26
# COMBINATION CONTRIBUTED                              24
# N/A, NONE DETECTED, UNKNOWN                          23
# ALCOHOL PRESENT, N/A, NONE DETECTED                  18
# MEDICATION PRESENT, N/A                              17
# NONE DETECTED, OTHER                                 15
# COMBINATION CONTRIBUTED, NONE DETECTED               15
# COMBINED SUBSTANCE PRESENT, N/A                      13
# ILLEGAL DRUG CONTRIBUTED, N/A                        10
# ALCOHOL PRESENT, UNKNOWN                              9
# MEDICATION CONTRIBUTED, N/A                           7
# N/A, OTHER                                            7
# COMBINATION CONTRIBUTED, N/A                          7
# ALCOHOL CONTRIBUTED, UNKNOWN                          4
# ALCOHOL CONTRIBUTED, ALCOHOL PRESENT                  4
# ALCOHOL PRESENT, NONE DETECTED, UNKNOWN               2
# ALCOHOL PRESENT, N/A, UNKNOWN                         2
# ALCOHOL CONTRIBUTED, N/A, NONE DETECTED               2
# ALCOHOL CONTRIBUTED, NONE DETECTED, UNKNOWN           2
# MEDICATION CONTRIBUTED, NONE DETECTED, UNKNOWN        1
# MEDICATION CONTRIBUTED, UNKNOWN                       1
# ILLEGAL DRUG PRESENT, N/A, NONE DETECTED              1
# COMBINED SUBSTANCE PRESENT, UNKNOWN                   1
# MEDICATION PRESENT, NONE DETECTED, UNKNOWN            1
# COMBINED SUBSTANCE PRESENT, N/A, NONE DETECTED        1
# ILLEGAL DRUG PRESENT, UNKNOWN                         1
# MEDICATION PRESENT, N/A, UNKNOWN                      1
# ALCOHOL PRESENT, ILLEGAL DRUG PRESENT                 1
# Name: count, dtype: int64
#
# Column: non_motorist_substance_abuse
# non_motorist_substance_abuse
# Missing                                 93195
# NONE DETECTED                            3809
# UNKNOWN                                   222
# ALCOHOL PRESENT                           147
# ALCOHOL CONTRIBUTED                        39
# N/A, NONE DETECTED                         25
# MEDICATION PRESENT                          4
# ILLEGAL DRUG PRESENT                        4
# NONE DETECTED, UNKNOWN                      3
# ILLEGAL DRUG CONTRIBUTED                    2
# COMBINATION CONTRIBUTED                     2
# N/A, UNKNOWN                                2
# ALCOHOL CONTRIBUTED, ALCOHOL PRESENT        1
# COMBINED SUBSTANCE PRESENT                  1
# OTHER                                       1
# ALCOHOL PRESENT, NONE DETECTED              1
# Name: count, dtype: int64
#
# Column: first_harmful_event
# first_harmful_event
# OTHER VEHICLE                     66575
# FIXED OBJECT                      11913
# PARKED VEHICLE                     9398
# PEDESTRIAN                         3804
# OFF ROAD                           1139
# ANIMAL                              940
# BICYCLE                             920
# OTHER OBJECT                        721
# Missing                             650
# OTHER                               339
# OVERTURN                            260
# UNKNOWN                             192
# OTHER NON COLLISION                 125
# BACKING                             120
# OTHER CONVEYANCE                    112
# OTHER PEDALCYCLE                     60
# THROWN OR FALLING OBJECT             47
# FELL JUMPED FROM MOTOR VEHICLE       40
# SPILLED CARGO                        24
# DOWNHILL RUNAWAY                     21
# U-TURN                               16
# JACKKNIFE                            10
# RAILWAY TRAIN                         9
# EXPLOSION OR FIRE                     9
# UNITS SEPARATED                       9
# IMMERSION                             5
# Name: count, dtype: int64
#
# Column: second_harmful_event
# second_harmful_event
# Missing                           72948
# OTHER VEHICLE                     12119
# FIXED OBJECT                       7180
# PARKED VEHICLE                     2285
# OFF ROAD                            718
# OVERTURN                            624
# OTHER OBJECT                        624
# PEDESTRIAN                          350
# OTHER                               155
# UNKNOWN                             129
# BICYCLE                              73
# OTHER CONVEYANCE                     49
# ANIMAL                               35
# OTHER NON COLLISION                  33
# BACKING                              29
# FELL JUMPED FROM MOTOR VEHICLE       26
# EXPLOSION OR FIRE                    25
# DOWNHILL RUNAWAY                     16
# U-TURN                               10
# THROWN OR FALLING OBJECT              9
# SPILLED CARGO                         8
# JACKKNIFE                             6
# OTHER PEDALCYCLE                      3
# IMMERSION                             2
# UNITS SEPARATED                       2
# Name: count, dtype: int64
#
# Column: fixed_object_struck
# fixed_object_struck
# Missing                      76863
# CURB                          6142
# TREE SHRUBBERY                2395
# OTHER                         2145
# OTHER POLE                    1890
# GUARDRAIL OR BARRIER          1652
# LIGHT SUPPORT POLE            1572
# SIGN SUPPORT POLE             1042
# BUILDING                       878
# FENCE                          712
# EMBANKMENT                     542
# MAILBOX                        379
# UNKNOWN                        235
# CONCRETE TRAFFIC BARRIER       230
# DITCH                          211
# TRAFFIC SIGNAL SUPPORT         150
# OTHER TRAFFIC BARRIER          116
# GUARDRAIL END                  108
# BRIDGE OR OVERPASS             100
# CULVERT                         33
# CONSTRUCTION BARRIER            30
# CRASH ATTENUATOR                11
# CABLE BARRIER                    8
# BRIDGE OVERHEAD STRUCTURE        7
# BRIDGE RAIL                      4
# BRIDGE PIER SUPPORT              3
# Name: count, dtype: int64
#
# Column: junction
# junction
# INTERSECTION              32163
# Missing                   26099
# NON INTERSECTION          23850
# INTERSECTION RELATED      10957
# COMMERCIAL DRIVEWAY        1162
# INTERCHANGE RELATED        1029
# OTHER                       928
# RESIDENTIAL DRIVEWAY        486
# CROSSOVER RELATED           385
# OTHER DRIVEWAY              271
# UNKNOWN                      79
# ALLEY                        32
# RAILWAY GRADE CROSSING       17
# Name: count, dtype: int64
#
# Column: intersection_type
# intersection_type
# Missing                  49054
# FOUR-WAY INTERSECTION    30612
# T-INTERSECTION           13845
# OTHER                     2581
# Y-INTERSECTION             648
# ROUNDABOUT                 302
# FIVE-POINT OR MORE         202
# TRAFFIC CIRCLE             117
# UNKNOWN                     97
# Name: count, dtype: int64
#
# Column: intersection_area
# intersection_area
# Missing                  71045
# INTERSECTION             15899
# INTERSECTION RELATED      6022
# THRU ROADWAY              1706
# OTHER                     1150
# ON RAMP ENTRANCE AREA      706
# ON RAMP EXIT AREA          690
# ON RAMP MID AREA           161
# UNKNOWN                     79
# Name: count, dtype: int64
#
# Column: road_alignment
# road_alignment
# STRAIGHT       74041
# Missing        12749
# CURVE RIGHT     5186
# CURVE LEFT      4818
# OTHER            533
# UNKNOWN          131
# Name: count, dtype: int64
#
# Column: road_condition
# road_condition
# NO DEFECTS                  80454
# Missing                     15705
# OTHER                         338
# HOLES RUTS ETC                298
# UNKNOWN                       204
# LOOSE SURFACE MATERIAL        158
# FOREIGN MATERIAL              127
# VIEW OBSTRUCTED                76
# SHOULDER DEFECT                71
# OBSTRUCTION NOT LIGHTED        17
# OBSTRUCTION NOT SIGNALED       10
# Name: count, dtype: int64
#
# Column: road_division
# road_division
# TWO-WAY, DIVIDED, POSITIVE MEDIAN BARRIER           39859
# TWO-WAY, NOT DIVIDED                                30623
# Missing                                             13531
# TWO-WAY, DIVIDED, UNPROTECTED PAINTED MIN 4 FEET     9847
# ONE-WAY TRAFFICWAY                                   1979
# OTHER                                                1167
# TWO-WAY, NOT DIVIDED WITH A CONTINUOUS LEFT TURN      367
# UNKNOWN                                                85
# Name: count, dtype: int64

# %% [markdown]
# ### Insights

# %% [raw]
# For hit_run - we have 2 missing values which can be replaced by Yes/No
#
# For route_type - we have 12995 missing values which can be replaced by the mode of 9 different category
# For mile_point - we have 12338 missing values can be filled with mean/median
# For mile_point_direction - we have 12991 missing values and 1 unkown value which can be replaced by Yes/No
# For lane_direction - we have 12327 missing values and 750 unknown which can be replaced by the mode of 9 different category
# For lane_type - we have 87945 missing values can be filled or kept as is where acrs failed to track the lane type
# For distance - we have 10475 missing values which can be replaced by mean/median
#
# For distance_unit - we have 12328 missing values and 458 Unknown values can be filled with mode
#
# For direction - we have 12338 missing values and 37 unknown which can be replaced by 4 other direction- mode
# For road_grade - we have 12967 missing values and 152 unkown value which can be replaced by mode
#
# For road_name - we have 12328 missing values which can be replaced by the mode
# For cross_street_type - we have 13016 missing values and Unknown -7276 can be filled or kept as is where acrs failed to track the lane type
# cross_street_name - 12338 Missing - mode/drop
# off_road_description- 85132 Missing
# municipality- 86967 Missing
# related_non_motorist- 92077 Missing
# collision_type- 13263 Other, 717 Unknown, 504 Missing
# weather- 7947 Missing, 648 Unknown, other 214
# surface_condition- 14650 Missing, 407 Unknown, 99 other
# light- Missing 815, UNKNOWN 698, OTHER 221
# traffic_control- Missing 16436, OTHER 1143, UNKNOWN 234
# driver_substance_abuse- Missing 15598,UNKNOWN 5115, N/A, UNKNOWN 1154, OTHER 35 (need attention) ---Aasim's file
# non_motorist_substance_abuse- Missing 93195, UNKNOWN 222
# first_harmful_event- Missing 650, OTHER 339, UNKNOWN 192
# second_harmful_event- Missing 72948, OTHER 155, UNKNOWN 129
# fixed_object_struck- Missing 76863, UNKNOWN 235
# junction- Missing 26099, UNKNOWN 79
# intersection_type- Missing 49054, UNKNOWN 97
# intersection_area- Missing 71045, OTHER 1150, UNKNOWN 79
# road_alignment- Missing 12749, UNKNOWN 131
# road_condition- Missing 15705, OTHER 338,UNKNOWN 204
# road_division- Missing  13531,OTHER 1167,UNKNOWN 85

# %% [markdown]
# ### hit_run Column

# %%
sql_frame['hit_run'] = sql_frame['hit_run'].replace('Missing', 'unknown')

# %%
# Get the count of repetitions
hit_run_counts = sql_frame['hit_run'].value_counts()

print(hit_run_counts)
# Out:
# hit_run
# No         79476
# Yes        17980
# unknown        2
# Name: count, dtype: int64

# %% [markdown]
# ### Columns with low weightage in analysis/less useful for analysis

# %%
columns_to_drop = ['cross_street_type', 'off_road_description', 'municipality','first_harmful_event','second_harmful_event']
sql_frame.drop(columns=columns_to_drop, inplace=True)

# %%
sql_frame.head()
# Out:
#   report_number local_case_number                agency_name  \
# 0   MCP2686006F         230031339   Montgomery County Police
# 1   MCP3230004G         230031335   Montgomery County Police
# 2   MCP12600013         230031067   Montgomery County Police
# 3    DD55750030         230031365  Rockville Police Departme
# 4   MCP3010008B         230034141   Montgomery County Police
#
#         acrs_report_type         crash_date_time hit_run  \
# 0  Property Damage Crash  06/30/2023 10:55:00 PM      No
# 1  Property Damage Crash  06/30/2023 08:00:00 PM      No
# 2           Injury Crash  06/29/2023 11:53:00 AM      No
# 3  Property Damage Crash  07/01/2023 01:48:00 AM     Yes
# 4  Property Damage Crash  07/01/2023 12:52:00 PM      No
#
#              route_type mile_point mile_point_direction lane_direction  ...  \
# 0               Missing    Missing              Missing        Missing  ...
# 1                County       1.42                 West          North  ...
# 2      Maryland (State)      11.26                North          North  ...
# 3          Municipality       0.07                North          North  ...
# 4  Other Public Roadway        0.0                 West           West  ...
#
#   traffic_control driver_substance_abuse non_motorist_substance_abuse  \
# 0     NO CONTROLS          NONE DETECTED                      Missing
# 1  TRAFFIC SIGNAL          NONE DETECTED                      Missing
# 2       STOP SIGN          NONE DETECTED                      Missing
# 3         Missing                Missing                      Missing
# 4         Missing                Missing                      Missing
#
#   fixed_object_struck          junction      intersection_type  \
# 0               OTHER           Missing                Missing
# 1             Missing      INTERSECTION  FOUR-WAY INTERSECTION
# 2                CURB  NON INTERSECTION                Missing
# 3  LIGHT SUPPORT POLE             OTHER  FOUR-WAY INTERSECTION
# 4             Missing           Missing                Missing
#
#   intersection_area road_alignment road_condition  \
# 0           Missing        Missing        Missing
# 1           Missing       STRAIGHT     NO DEFECTS
# 2      INTERSECTION       STRAIGHT     NO DEFECTS
# 3             OTHER       STRAIGHT     NO DEFECTS
# 4           Missing       STRAIGHT     NO DEFECTS
#
#                                       road_division
# 0                                           Missing
# 1  TWO-WAY, DIVIDED, UNPROTECTED PAINTED MIN 4 FEET
# 2  TWO-WAY, DIVIDED, UNPROTECTED PAINTED MIN 4 FEET
# 3                              TWO-WAY, NOT DIVIDED
# 4                              TWO-WAY, NOT DIVIDED
#
# [5 rows x 36 columns]

# %%
num_rows, num_columns = sql_frame.shape
print("Number of rows:", num_rows)
print("Number of columns:", num_columns)
# Out:
# Number of rows: 97458
# Number of columns: 36

# %%
# Check where "Missing" values occur in each column
missing_mask = sql_frame.eq('Missing')

# Check which columns have at least one "Missing" value
columns_with_missing = missing_mask.any()

# Extract the column names where "Missing" values occur
columns_with_missing_values = columns_with_missing[columns_with_missing].index.tolist()

# Print the columns with "Missing" values
print("Columns with 'Missing' values:", columns_with_missing_values)
# Out:
# Columns with 'Missing' values: ['route_type', 'mile_point', 'mile_point_direction', 'lane_direction', 'lane_type', 'direction', 'distance', 'distance_unit', 'road_grade', 'road_name', 'cross_street_name', 'related_non_motorist', 'collision_type', 'weather', 'surface_condition', 'light', 'traffic_control', 'driver_substance_abuse', 'non_motorist_substance_abuse', 'fixed_object_struck', 'junction', 'intersection_type', 'intersection_area', 'road_alignment', 'road_condition', 'road_division']

# %%
# Iterate through columns with missing values
for column in columns_with_missing_values:
    # Get unique values and their counts
    unique_values_counts = sql_frame[column].value_counts() 
    # Print column name
    print("Column:", column)
    # Print unique values and their counts
    print(unique_values_counts)
    print()
# Out:
# Column: route_type
# route_type
# Maryland (State)        39119
# County                  32674
# Missing                 12995
# Municipality             5777
# US (State)               3732
# Interstate (State)       1647
# Other Public Roadway      707
# Government                414
# Ramp                      357
# Service Road               22
# Unknown                    14
# Name: count, dtype: int64
#
# Column: mile_point
# mile_point
# Missing    12338
# 0.0         7317
# 0.17         487
# 0.18         460
# 0.21         451
#            ...
# 8.32           1
# 2.293          1
# 6.3            1
# 8.79           1
# 0.365          1
# Name: count, Length: 2123, dtype: int64
#
# Column: mile_point_direction
# mile_point_direction
# North      43609
# East       25743
# Missing    12991
# South       8525
# West        6589
# Unknown        1
# Name: count, dtype: int64
#
# Column: lane_direction
# lane_direction
# North      25902
# South      23975
# East       17733
# West       16771
# Missing    12327
# Unknown      750
# Name: count, dtype: int64
#
# Column: lane_type
# lane_type
# Missing                 87945
# LEFT TURN LANE           3182
# RIGHT TURN LANE          1700
# OTHER                    1069
# OFF ROAD                  825
# SHOULDER AREA             773
# ON RAMP                   586
# UNKNOWN                   400
# CROSSOVER AREA            387
# MEDIAN AREA               285
# ACCELERATION LANE         165
# OUTSIDE RIGHT OF WAY       69
# DECELERATION LANE          42
# SEPARATOR                  24
# GORE AREA                   6
# Name: count, dtype: int64
#
# Column: direction
# direction
# North      35160
# East       21452
# South      17363
# Missing    12338
# West       11108
# Unknown       37
# Name: count, dtype: int64
#
# Column: distance
# distance
# 0.0        43919
# Missing    10475
# 100.0       6395
# 50.0        5487
# 10.0        3215
#            ...
# 338.0          1
# 202.0          1
# 0.61           1
# 586.0          1
# 0.98           1
# Name: count, Length: 440, dtype: int64
#
# Column: distance_unit
# distance_unit
# FEET       78880
# Missing    12328
# MILE        5792
# UNKNOWN      458
# Name: count, dtype: int64
#
# Column: road_grade
# road_grade
# LEVEL             64570
# Missing           12967
# GRADE DOWNHILL     9866
# HILL UPHILL        7323
# HILL CREST         2185
# OTHER               190
# UNKNOWN             152
# DIP SAG             131
# ON BRIDGE            74
# Name: count, dtype: int64
#
# Column: road_name
# road_name
# Missing              12328
# GEORGIA AVE           5383
# NEW HAMPSHIRE AVE     3399
# FREDERICK RD          2896
# ROCKVILLE PIKE        2369
#                      ...
# HARDY PL                 1
# MERCER RD                1
# HUTCHINSON LA            1
# SURREYWOOD LA            1
# SLEAFORD RD              1
# Name: count, Length: 3839, dtype: int64
#
# Column: cross_street_name
# cross_street_name
# Missing                      12338
# GEORGIA AVE                   1145
# CONNECTICUT AVE                824
# FREDERICK RD                   816
# NEW HAMPSHIRE AVE              692
#                              ...
# YEATMAN TERR                     1
# ANCHORAGE DR                     1
# ALPINE VALLEY CT (ENT TH)        1
# RIFFLE FORD CT                   1
# PELLITA TER                      1
# Name: count, Length: 6725, dtype: int64
#
# Column: related_non_motorist
# related_non_motorist
# Missing                          92077
# PEDESTRIAN                        3813
# BICYCLIST                         1161
# OTHER                              240
# OTHER CONVEYANCE                    80
# MACHINE OPERATOR/RIDER              38
# OTHER PEDALCYCLIST                  26
# OTHER, PEDESTRIAN                    9
# BICYCLIST, PEDESTRIAN                5
# BICYCLIST, OTHER                     4
# OTHER CONVEYANCE, PEDESTRIAN         2
# IN ANIMAL-DRAWN VEH                  1
# MACHINE OPERATOR/RIDER, OTHER        1
# OTHER, OTHER CONVEYANCE              1
# Name: count, dtype: int64
#
# Column: collision_type
# collision_type
# SAME DIR REAR END               25737
# SINGLE VEHICLE                  16092
# STRAIGHT MOVEMENT ANGLE         15239
# OTHER                           13263
# SAME DIRECTION SIDESWIPE         8890
# HEAD ON LEFT TURN                6334
# HEAD ON                          2068
# SAME DIRECTION RIGHT TURN        1985
# SAME DIRECTION LEFT TURN         1836
# OPPOSITE DIRECTION SIDESWIPE     1599
# ANGLE MEETS LEFT TURN             993
# UNKNOWN                           717
# ANGLE MEETS RIGHT TURN            604
# Missing                           504
# SAME DIR REND LEFT TURN           367
# SAME DIR REND RIGHT TURN          366
# SAME DIR BOTH LEFT TURN           356
# ANGLE MEETS LEFT HEAD ON          346
# OPPOSITE DIR BOTH LEFT TURN       162
# Name: count, dtype: int64
#
# Column: weather
# weather
# CLEAR                       65512
# RAINING                     11673
# CLOUDY                       9608
# Missing                      7947
# SNOW                          877
# UNKNOWN                       648
# FOGGY                         429
# WINTRY MIX                    252
# OTHER                         214
# SLEET                         130
# SEVERE WINDS                   93
# BLOWING SNOW                   68
# BLOWING SAND, SOIL, DIRT        7
# Name: count, dtype: int64
#
# Column: surface_condition
# surface_condition
# DRY                       64943
# WET                       15856
# Missing                   14650
# ICE                         682
# SNOW                        602
# UNKNOWN                     407
# SLUSH                       132
# OTHER                        99
# MUD, DIRT, GRAVEL            36
# WATER(STANDING/MOVING)       30
# OIL                          18
# SAND                          3
# Name: count, dtype: int64
#
# Column: light
# light
# DAYLIGHT                    63184
# DARK LIGHTS ON              23736
# DARK NO LIGHTS               3504
# DUSK                         2182
# DAWN                         2004
# DARK -- UNKNOWN LIGHTING     1114
# Missing                       815
# UNKNOWN                       698
# OTHER                         221
# Name: count, dtype: int64
#
# Column: traffic_control
# traffic_control
# NO CONTROLS                41604
# TRAFFIC SIGNAL             29008
# Missing                    16436
# STOP SIGN                   6658
# FLASHING TRAFFIC SIGNAL     1144
# OTHER                       1143
# YIELD SIGN                   912
# UNKNOWN                      234
# PERSON                       164
# WARNING SIGN                 114
# RAILWAY CROSSING DEVICE       27
# SCHOOL ZONE SIGN DEVICE       14
# Name: count, dtype: int64
#
# Column: driver_substance_abuse
# driver_substance_abuse
# NONE DETECTED                                     60770
# Missing                                           15598
# NONE DETECTED, UNKNOWN                             5462
# UNKNOWN                                            5115
# N/A, NONE DETECTED                                 3113
# ALCOHOL PRESENT                                    2140
# ALCOHOL PRESENT, NONE DETECTED                     1456
# N/A, UNKNOWN                                       1154
# ALCOHOL CONTRIBUTED                                 834
# ALCOHOL CONTRIBUTED, NONE DETECTED                  455
# ALCOHOL PRESENT, N/A                                429
# ALCOHOL CONTRIBUTED, N/A                            131
# ILLEGAL DRUG PRESENT                                119
# ILLEGAL DRUG PRESENT, NONE DETECTED                  97
# MEDICATION PRESENT                                   51
# ILLEGAL DRUG CONTRIBUTED                             48
# MEDICATION PRESENT, NONE DETECTED                    47
# COMBINED SUBSTANCE PRESENT                           45
# ILLEGAL DRUG CONTRIBUTED, NONE DETECTED              43
# ILLEGAL DRUG PRESENT, N/A                            39
# OTHER                                                35
# COMBINED SUBSTANCE PRESENT, NONE DETECTED            32
# MEDICATION CONTRIBUTED, NONE DETECTED                29
# MEDICATION CONTRIBUTED                               26
# COMBINATION CONTRIBUTED                              24
# N/A, NONE DETECTED, UNKNOWN                          23
# ALCOHOL PRESENT, N/A, NONE DETECTED                  18
# MEDICATION PRESENT, N/A                              17
# NONE DETECTED, OTHER                                 15
# COMBINATION CONTRIBUTED, NONE DETECTED               15
# COMBINED SUBSTANCE PRESENT, N/A                      13
# ILLEGAL DRUG CONTRIBUTED, N/A                        10
# ALCOHOL PRESENT, UNKNOWN                              9
# MEDICATION CONTRIBUTED, N/A                           7
# N/A, OTHER                                            7
# COMBINATION CONTRIBUTED, N/A                          7
# ALCOHOL CONTRIBUTED, UNKNOWN                          4
# ALCOHOL CONTRIBUTED, ALCOHOL PRESENT                  4
# ALCOHOL PRESENT, NONE DETECTED, UNKNOWN               2
# ALCOHOL PRESENT, N/A, UNKNOWN                         2
# ALCOHOL CONTRIBUTED, N/A, NONE DETECTED               2
# ALCOHOL CONTRIBUTED, NONE DETECTED, UNKNOWN           2
# MEDICATION CONTRIBUTED, NONE DETECTED, UNKNOWN        1
# MEDICATION CONTRIBUTED, UNKNOWN                       1
# ILLEGAL DRUG PRESENT, N/A, NONE DETECTED              1
# COMBINED SUBSTANCE PRESENT, UNKNOWN                   1
# MEDICATION PRESENT, NONE DETECTED, UNKNOWN            1
# COMBINED SUBSTANCE PRESENT, N/A, NONE DETECTED        1
# ILLEGAL DRUG PRESENT, UNKNOWN                         1
# MEDICATION PRESENT, N/A, UNKNOWN                      1
# ALCOHOL PRESENT, ILLEGAL DRUG PRESENT                 1
# Name: count, dtype: int64
#
# Column: non_motorist_substance_abuse
# non_motorist_substance_abuse
# Missing                                 93195
# NONE DETECTED                            3809
# UNKNOWN                                   222
# ALCOHOL PRESENT                           147
# ALCOHOL CONTRIBUTED                        39
# N/A, NONE DETECTED                         25
# MEDICATION PRESENT                          4
# ILLEGAL DRUG PRESENT                        4
# NONE DETECTED, UNKNOWN                      3
# ILLEGAL DRUG CONTRIBUTED                    2
# COMBINATION CONTRIBUTED                     2
# N/A, UNKNOWN                                2
# ALCOHOL CONTRIBUTED, ALCOHOL PRESENT        1
# COMBINED SUBSTANCE PRESENT                  1
# OTHER                                       1
# ALCOHOL PRESENT, NONE DETECTED              1
# Name: count, dtype: int64
#
# Column: fixed_object_struck
# fixed_object_struck
# Missing                      76863
# CURB                          6142
# TREE SHRUBBERY                2395
# OTHER                         2145
# OTHER POLE                    1890
# GUARDRAIL OR BARRIER          1652
# LIGHT SUPPORT POLE            1572
# SIGN SUPPORT POLE             1042
# BUILDING                       878
# FENCE                          712
# EMBANKMENT                     542
# MAILBOX                        379
# UNKNOWN                        235
# CONCRETE TRAFFIC BARRIER       230
# DITCH                          211
# TRAFFIC SIGNAL SUPPORT         150
# OTHER TRAFFIC BARRIER          116
# GUARDRAIL END                  108
# BRIDGE OR OVERPASS             100
# CULVERT                         33
# CONSTRUCTION BARRIER            30
# CRASH ATTENUATOR                11
# CABLE BARRIER                    8
# BRIDGE OVERHEAD STRUCTURE        7
# BRIDGE RAIL                      4
# BRIDGE PIER SUPPORT              3
# Name: count, dtype: int64
#
# Column: junction
# junction
# INTERSECTION              32163
# Missing                   26099
# NON INTERSECTION          23850
# INTERSECTION RELATED      10957
# COMMERCIAL DRIVEWAY        1162
# INTERCHANGE RELATED        1029
# OTHER                       928
# RESIDENTIAL DRIVEWAY        486
# CROSSOVER RELATED           385
# OTHER DRIVEWAY              271
# UNKNOWN                      79
# ALLEY                        32
# RAILWAY GRADE CROSSING       17
# Name: count, dtype: int64
#
# Column: intersection_type
# intersection_type
# Missing                  49054
# FOUR-WAY INTERSECTION    30612
# T-INTERSECTION           13845
# OTHER                     2581
# Y-INTERSECTION             648
# ROUNDABOUT                 302
# FIVE-POINT OR MORE         202
# TRAFFIC CIRCLE             117
# UNKNOWN                     97
# Name: count, dtype: int64
#
# Column: intersection_area
# intersection_area
# Missing                  71045
# INTERSECTION             15899
# INTERSECTION RELATED      6022
# THRU ROADWAY              1706
# OTHER                     1150
# ON RAMP ENTRANCE AREA      706
# ON RAMP EXIT AREA          690
# ON RAMP MID AREA           161
# UNKNOWN                     79
# Name: count, dtype: int64
#
# Column: road_alignment
# road_alignment
# STRAIGHT       74041
# Missing        12749
# CURVE RIGHT     5186
# CURVE LEFT      4818
# OTHER            533
# UNKNOWN          131
# Name: count, dtype: int64
#
# Column: road_condition
# road_condition
# NO DEFECTS                  80454
# Missing                     15705
# OTHER                         338
# HOLES RUTS ETC                298
# UNKNOWN                       204
# LOOSE SURFACE MATERIAL        158
# FOREIGN MATERIAL              127
# VIEW OBSTRUCTED                76
# SHOULDER DEFECT                71
# OBSTRUCTION NOT LIGHTED        17
# OBSTRUCTION NOT SIGNALED       10
# Name: count, dtype: int64
#
# Column: road_division
# road_division
# TWO-WAY, DIVIDED, POSITIVE MEDIAN BARRIER           39859
# TWO-WAY, NOT DIVIDED                                30623
# Missing                                             13531
# TWO-WAY, DIVIDED, UNPROTECTED PAINTED MIN 4 FEET     9847
# ONE-WAY TRAFFICWAY                                   1979
# OTHER                                                1167
# TWO-WAY, NOT DIVIDED WITH A CONTINUOUS LEFT TURN      367
# UNKNOWN                                                85
# Name: count, dtype: int64

# %% [markdown]
# ### Transformations for columns with moderate or moderate to high weightage in analysis/somewhat useful for analysis

# %%
# road_grade
sql_frame['road_grade'] = sql_frame['road_grade'].replace('Missing', sql_frame['road_grade'].mode()[0])

# %%
sql_frame.head()
# Out:
#   report_number local_case_number                agency_name  \
# 0   MCP2686006F         230031339   Montgomery County Police
# 1   MCP3230004G         230031335   Montgomery County Police
# 2   MCP12600013         230031067   Montgomery County Police
# 3    DD55750030         230031365  Rockville Police Departme
# 4   MCP3010008B         230034141   Montgomery County Police
#
#         acrs_report_type         crash_date_time hit_run  \
# 0  Property Damage Crash  06/30/2023 10:55:00 PM      No
# 1  Property Damage Crash  06/30/2023 08:00:00 PM      No
# 2           Injury Crash  06/29/2023 11:53:00 AM      No
# 3  Property Damage Crash  07/01/2023 01:48:00 AM     Yes
# 4  Property Damage Crash  07/01/2023 12:52:00 PM      No
#
#              route_type mile_point mile_point_direction lane_direction  ...  \
# 0               Missing    Missing              Missing        Missing  ...
# 1                County       1.42                 West          North  ...
# 2      Maryland (State)      11.26                North          North  ...
# 3          Municipality       0.07                North          North  ...
# 4  Other Public Roadway        0.0                 West           West  ...
#
#   traffic_control driver_substance_abuse non_motorist_substance_abuse  \
# 0     NO CONTROLS          NONE DETECTED                      Missing
# 1  TRAFFIC SIGNAL          NONE DETECTED                      Missing
# 2       STOP SIGN          NONE DETECTED                      Missing
# 3         Missing                Missing                      Missing
# 4         Missing                Missing                      Missing
#
#   fixed_object_struck          junction      intersection_type  \
# 0               OTHER           Missing                Missing
# 1             Missing      INTERSECTION  FOUR-WAY INTERSECTION
# 2                CURB  NON INTERSECTION                Missing
# 3  LIGHT SUPPORT POLE             OTHER  FOUR-WAY INTERSECTION
# 4             Missing           Missing                Missing
#
#   intersection_area road_alignment road_condition  \
# 0           Missing        Missing        Missing
# 1           Missing       STRAIGHT     NO DEFECTS
# 2      INTERSECTION       STRAIGHT     NO DEFECTS
# 3             OTHER       STRAIGHT     NO DEFECTS
# 4           Missing       STRAIGHT     NO DEFECTS
#
#                                       road_division
# 0                                           Missing
# 1  TWO-WAY, DIVIDED, UNPROTECTED PAINTED MIN 4 FEET
# 2  TWO-WAY, DIVIDED, UNPROTECTED PAINTED MIN 4 FEET
# 3                              TWO-WAY, NOT DIVIDED
# 4                              TWO-WAY, NOT DIVIDED
#
# [5 rows x 36 columns]

# %%
# Get counts of report numbers for each agency name
road_grade_counts = sql_frame['road_grade'].value_counts()
# Print the counts
print(road_grade_counts)
# Out:
# road_grade
# LEVEL             77537
# GRADE DOWNHILL     9866
# HILL UPHILL        7323
# HILL CREST         2185
# OTHER               190
# UNKNOWN             152
# DIP SAG             131
# ON BRIDGE            74
# Name: count, dtype: int64

# %%
sql_frame['direction'] = sql_frame['direction'].replace('Missing', 'Unknown')

# %%
# Get counts of report numbers for each agency name
direction_counts = sql_frame['direction'].value_counts()
# Print the counts
print(direction_counts)
# Out:
# direction
# North      35160
# East       21452
# South      17363
# Unknown    12375
# West       11108
# Name: count, dtype: int64

# %%
## mile_point
sql_frame['mile_point'] = sql_frame['mile_point'].replace('Missing', np.nan)
sql_frame['mile_point'] = sql_frame['mile_point'].astype(float)
sql_frame['mile_point'].fillna(sql_frame['mile_point'].median())
# Out:
# 0         1.95
# 1         1.42
# 2        11.26
# 3         0.07
# 4         0.00
#          ...
# 97453     1.72
# 97454     7.53
# 97455     1.95
# 97456     2.83
# 97457     3.51
# Name: mile_point, Length: 97458, dtype: float64

# %%
#distance
sql_frame['distance'] = sql_frame['distance'].replace('Missing', np.nan)
sql_frame['distance'] = sql_frame['distance'].astype(float)
sql_frame['distance'].fillna(sql_frame['distance'].median())
# Out:
# 0         0.0
# 1         0.0
# 2        20.0
# 3        20.0
# 4        50.0
#          ...
# 97453    10.0
# 97454    15.0
# 97455     0.0
# 97456     0.0
# 97457    50.0
# Name: distance, Length: 97458, dtype: float64

# %%
# Get counts of report numbers for each agency name
route_type_counts = sql_frame['route_type'].value_counts()
# Print the counts
print(route_type_counts)
# Out:
# route_type
# Maryland (State)        39119
# County                  32674
# Missing                 12995
# Municipality             5777
# US (State)               3732
# Interstate (State)       1647
# Other Public Roadway      707
# Government                414
# Ramp                      357
# Service Road               22
# Unknown                    14
# Name: count, dtype: int64

# %%
# Get counts of report numbers for each agency name
lane_direction_counts = sql_frame['lane_direction'].value_counts()
# Print the counts
print(lane_direction_counts)
# Out:
# lane_direction
# North      25902
# South      23975
# East       17733
# West       16771
# Missing    12327
# Unknown      750
# Name: count, dtype: int64

# %%
# lane_direction
sql_frame['lane_direction'] = sql_frame['lane_direction'].replace('Missing', sql_frame['lane_direction'].mode()[0])

# %%
sql_frame.head()
# Out:
#   report_number local_case_number                agency_name  \
# 0   MCP2686006F         230031339   Montgomery County Police
# 1   MCP3230004G         230031335   Montgomery County Police
# 2   MCP12600013         230031067   Montgomery County Police
# 3    DD55750030         230031365  Rockville Police Departme
# 4   MCP3010008B         230034141   Montgomery County Police
#
#         acrs_report_type         crash_date_time hit_run  \
# 0  Property Damage Crash  06/30/2023 10:55:00 PM      No
# 1  Property Damage Crash  06/30/2023 08:00:00 PM      No
# 2           Injury Crash  06/29/2023 11:53:00 AM      No
# 3  Property Damage Crash  07/01/2023 01:48:00 AM     Yes
# 4  Property Damage Crash  07/01/2023 12:52:00 PM      No
#
#              route_type  mile_point mile_point_direction lane_direction  ...  \
# 0               Missing         NaN              Missing          North  ...
# 1                County        1.42                 West          North  ...
# 2      Maryland (State)       11.26                North          North  ...
# 3          Municipality        0.07                North          North  ...
# 4  Other Public Roadway        0.00                 West           West  ...
#
#   traffic_control driver_substance_abuse non_motorist_substance_abuse  \
# 0     NO CONTROLS          NONE DETECTED                      Missing
# 1  TRAFFIC SIGNAL          NONE DETECTED                      Missing
# 2       STOP SIGN          NONE DETECTED                      Missing
# 3         Missing                Missing                      Missing
# 4         Missing                Missing                      Missing
#
#   fixed_object_struck          junction      intersection_type  \
# 0               OTHER           Missing                Missing
# 1             Missing      INTERSECTION  FOUR-WAY INTERSECTION
# 2                CURB  NON INTERSECTION                Missing
# 3  LIGHT SUPPORT POLE             OTHER  FOUR-WAY INTERSECTION
# 4             Missing           Missing                Missing
#
#   intersection_area road_alignment road_condition  \
# 0           Missing        Missing        Missing
# 1           Missing       STRAIGHT     NO DEFECTS
# 2      INTERSECTION       STRAIGHT     NO DEFECTS
# 3             OTHER       STRAIGHT     NO DEFECTS
# 4           Missing       STRAIGHT     NO DEFECTS
#
#                                       road_division
# 0                                           Missing
# 1  TWO-WAY, DIVIDED, UNPROTECTED PAINTED MIN 4 FEET
# 2  TWO-WAY, DIVIDED, UNPROTECTED PAINTED MIN 4 FEET
# 3                              TWO-WAY, NOT DIVIDED
# 4                              TWO-WAY, NOT DIVIDED
#
# [5 rows x 36 columns]

# %%
# Check where "Missing" values occur in each column
missing_mask = sql_frame.eq('Missing')

# Check which columns have at least one "Missing" value
columns_with_missing = missing_mask.any()

# Extract the column names where "Missing" values occur
columns_with_missing_values = columns_with_missing[columns_with_missing].index.tolist()

# Print the columns with "Missing" values
print("Columns with 'Missing' values:", columns_with_missing_values)
# Out:
# Columns with 'Missing' values: ['route_type', 'mile_point_direction', 'lane_type', 'distance_unit', 'road_name', 'cross_street_name', 'related_non_motorist', 'collision_type', 'weather', 'surface_condition', 'light', 'traffic_control', 'driver_substance_abuse', 'non_motorist_substance_abuse', 'fixed_object_struck', 'junction', 'intersection_type', 'intersection_area', 'road_alignment', 'road_condition', 'road_division']

# %%
# Iterate through columns with missing values
for column in columns_with_missing_values:
    # Get unique values and their counts
    unique_values_counts = sql_frame[column].value_counts() 
    # Print column name
    print("Column:", column)
    # Print unique values and their counts
    print(unique_values_counts)
    print()
# Out:
# Column: route_type
# route_type
# Maryland (State)        39119
# County                  32674
# Missing                 12995
# Municipality             5777
# US (State)               3732
# Interstate (State)       1647
# Other Public Roadway      707
# Government                414
# Ramp                      357
# Service Road               22
# Unknown                    14
# Name: count, dtype: int64
#
# Column: mile_point_direction
# mile_point_direction
# North      43609
# East       25743
# Missing    12991
# South       8525
# West        6589
# Unknown        1
# Name: count, dtype: int64
#
# Column: lane_type
# lane_type
# Missing                 87945
# LEFT TURN LANE           3182
# RIGHT TURN LANE          1700
# OTHER                    1069
# OFF ROAD                  825
# SHOULDER AREA             773
# ON RAMP                   586
# UNKNOWN                   400
# CROSSOVER AREA            387
# MEDIAN AREA               285
# ACCELERATION LANE         165
# OUTSIDE RIGHT OF WAY       69
# DECELERATION LANE          42
# SEPARATOR                  24
# GORE AREA                   6
# Name: count, dtype: int64
#
# Column: distance_unit
# distance_unit
# FEET       78880
# Missing    12328
# MILE        5792
# UNKNOWN      458
# Name: count, dtype: int64
#
# Column: road_name
# road_name
# Missing              12328
# GEORGIA AVE           5383
# NEW HAMPSHIRE AVE     3399
# FREDERICK RD          2896
# ROCKVILLE PIKE        2369
#                      ...
# HARDY PL                 1
# MERCER RD                1
# HUTCHINSON LA            1
# SURREYWOOD LA            1
# SLEAFORD RD              1
# Name: count, Length: 3839, dtype: int64
#
# Column: cross_street_name
# cross_street_name
# Missing                      12338
# GEORGIA AVE                   1145
# CONNECTICUT AVE                824
# FREDERICK RD                   816
# NEW HAMPSHIRE AVE              692
#                              ...
# YEATMAN TERR                     1
# ANCHORAGE DR                     1
# ALPINE VALLEY CT (ENT TH)        1
# RIFFLE FORD CT                   1
# PELLITA TER                      1
# Name: count, Length: 6725, dtype: int64
#
# Column: related_non_motorist
# related_non_motorist
# Missing                          92077
# PEDESTRIAN                        3813
# BICYCLIST                         1161
# OTHER                              240
# OTHER CONVEYANCE                    80
# MACHINE OPERATOR/RIDER              38
# OTHER PEDALCYCLIST                  26
# OTHER, PEDESTRIAN                    9
# BICYCLIST, PEDESTRIAN                5
# BICYCLIST, OTHER                     4
# OTHER CONVEYANCE, PEDESTRIAN         2
# IN ANIMAL-DRAWN VEH                  1
# MACHINE OPERATOR/RIDER, OTHER        1
# OTHER, OTHER CONVEYANCE              1
# Name: count, dtype: int64
#
# Column: collision_type
# collision_type
# SAME DIR REAR END               25737
# SINGLE VEHICLE                  16092
# STRAIGHT MOVEMENT ANGLE         15239
# OTHER                           13263
# SAME DIRECTION SIDESWIPE         8890
# HEAD ON LEFT TURN                6334
# HEAD ON                          2068
# SAME DIRECTION RIGHT TURN        1985
# SAME DIRECTION LEFT TURN         1836
# OPPOSITE DIRECTION SIDESWIPE     1599
# ANGLE MEETS LEFT TURN             993
# UNKNOWN                           717
# ANGLE MEETS RIGHT TURN            604
# Missing                           504
# SAME DIR REND LEFT TURN           367
# SAME DIR REND RIGHT TURN          366
# SAME DIR BOTH LEFT TURN           356
# ANGLE MEETS LEFT HEAD ON          346
# OPPOSITE DIR BOTH LEFT TURN       162
# Name: count, dtype: int64
#
# Column: weather
# weather
# CLEAR                       65512
# RAINING                     11673
# CLOUDY                       9608
# Missing                      7947
# SNOW                          877
# UNKNOWN                       648
# FOGGY                         429
# WINTRY MIX                    252
# OTHER                         214
# SLEET                         130
# SEVERE WINDS                   93
# BLOWING SNOW                   68
# BLOWING SAND, SOIL, DIRT        7
# Name: count, dtype: int64
#
# Column: surface_condition
# surface_condition
# DRY                       64943
# WET                       15856
# Missing                   14650
# ICE                         682
# SNOW                        602
# UNKNOWN                     407
# SLUSH                       132
# OTHER                        99
# MUD, DIRT, GRAVEL            36
# WATER(STANDING/MOVING)       30
# OIL                          18
# SAND                          3
# Name: count, dtype: int64
#
# Column: light
# light
# DAYLIGHT                    63184
# DARK LIGHTS ON              23736
# DARK NO LIGHTS               3504
# DUSK                         2182
# DAWN                         2004
# DARK -- UNKNOWN LIGHTING     1114
# Missing                       815
# UNKNOWN                       698
# OTHER                         221
# Name: count, dtype: int64
#
# Column: traffic_control
# traffic_control
# NO CONTROLS                41604
# TRAFFIC SIGNAL             29008
# Missing                    16436
# STOP SIGN                   6658
# FLASHING TRAFFIC SIGNAL     1144
# OTHER                       1143
# YIELD SIGN                   912
# UNKNOWN                      234
# PERSON                       164
# WARNING SIGN                 114
# RAILWAY CROSSING DEVICE       27
# SCHOOL ZONE SIGN DEVICE       14
# Name: count, dtype: int64
#
# Column: driver_substance_abuse
# driver_substance_abuse
# NONE DETECTED                                     60770
# Missing                                           15598
# NONE DETECTED, UNKNOWN                             5462
# UNKNOWN                                            5115
# N/A, NONE DETECTED                                 3113
# ALCOHOL PRESENT                                    2140
# ALCOHOL PRESENT, NONE DETECTED                     1456
# N/A, UNKNOWN                                       1154
# ALCOHOL CONTRIBUTED                                 834
# ALCOHOL CONTRIBUTED, NONE DETECTED                  455
# ALCOHOL PRESENT, N/A                                429
# ALCOHOL CONTRIBUTED, N/A                            131
# ILLEGAL DRUG PRESENT                                119
# ILLEGAL DRUG PRESENT, NONE DETECTED                  97
# MEDICATION PRESENT                                   51
# ILLEGAL DRUG CONTRIBUTED                             48
# MEDICATION PRESENT, NONE DETECTED                    47
# COMBINED SUBSTANCE PRESENT                           45
# ILLEGAL DRUG CONTRIBUTED, NONE DETECTED              43
# ILLEGAL DRUG PRESENT, N/A                            39
# OTHER                                                35
# COMBINED SUBSTANCE PRESENT, NONE DETECTED            32
# MEDICATION CONTRIBUTED, NONE DETECTED                29
# MEDICATION CONTRIBUTED                               26
# COMBINATION CONTRIBUTED                              24
# N/A, NONE DETECTED, UNKNOWN                          23
# ALCOHOL PRESENT, N/A, NONE DETECTED                  18
# MEDICATION PRESENT, N/A                              17
# NONE DETECTED, OTHER                                 15
# COMBINATION CONTRIBUTED, NONE DETECTED               15
# COMBINED SUBSTANCE PRESENT, N/A                      13
# ILLEGAL DRUG CONTRIBUTED, N/A                        10
# ALCOHOL PRESENT, UNKNOWN                              9
# MEDICATION CONTRIBUTED, N/A                           7
# N/A, OTHER                                            7
# COMBINATION CONTRIBUTED, N/A                          7
# ALCOHOL CONTRIBUTED, UNKNOWN                          4
# ALCOHOL CONTRIBUTED, ALCOHOL PRESENT                  4
# ALCOHOL PRESENT, NONE DETECTED, UNKNOWN               2
# ALCOHOL PRESENT, N/A, UNKNOWN                         2
# ALCOHOL CONTRIBUTED, N/A, NONE DETECTED               2
# ALCOHOL CONTRIBUTED, NONE DETECTED, UNKNOWN           2
# MEDICATION CONTRIBUTED, NONE DETECTED, UNKNOWN        1
# MEDICATION CONTRIBUTED, UNKNOWN                       1
# ILLEGAL DRUG PRESENT, N/A, NONE DETECTED              1
# COMBINED SUBSTANCE PRESENT, UNKNOWN                   1
# MEDICATION PRESENT, NONE DETECTED, UNKNOWN            1
# COMBINED SUBSTANCE PRESENT, N/A, NONE DETECTED        1
# ILLEGAL DRUG PRESENT, UNKNOWN                         1
# MEDICATION PRESENT, N/A, UNKNOWN                      1
# ALCOHOL PRESENT, ILLEGAL DRUG PRESENT                 1
# Name: count, dtype: int64
#
# Column: non_motorist_substance_abuse
# non_motorist_substance_abuse
# Missing                                 93195
# NONE DETECTED                            3809
# UNKNOWN                                   222
# ALCOHOL PRESENT                           147
# ALCOHOL CONTRIBUTED                        39
# N/A, NONE DETECTED                         25
# MEDICATION PRESENT                          4
# ILLEGAL DRUG PRESENT                        4
# NONE DETECTED, UNKNOWN                      3
# ILLEGAL DRUG CONTRIBUTED                    2
# COMBINATION CONTRIBUTED                     2
# N/A, UNKNOWN                                2
# ALCOHOL CONTRIBUTED, ALCOHOL PRESENT        1
# COMBINED SUBSTANCE PRESENT                  1
# OTHER                                       1
# ALCOHOL PRESENT, NONE DETECTED              1
# Name: count, dtype: int64
#
# Column: fixed_object_struck
# fixed_object_struck
# Missing                      76863
# CURB                          6142
# TREE SHRUBBERY                2395
# OTHER                         2145
# OTHER POLE                    1890
# GUARDRAIL OR BARRIER          1652
# LIGHT SUPPORT POLE            1572
# SIGN SUPPORT POLE             1042
# BUILDING                       878
# FENCE                          712
# EMBANKMENT                     542
# MAILBOX                        379
# UNKNOWN                        235
# CONCRETE TRAFFIC BARRIER       230
# DITCH                          211
# TRAFFIC SIGNAL SUPPORT         150
# OTHER TRAFFIC BARRIER          116
# GUARDRAIL END                  108
# BRIDGE OR OVERPASS             100
# CULVERT                         33
# CONSTRUCTION BARRIER            30
# CRASH ATTENUATOR                11
# CABLE BARRIER                    8
# BRIDGE OVERHEAD STRUCTURE        7
# BRIDGE RAIL                      4
# BRIDGE PIER SUPPORT              3
# Name: count, dtype: int64
#
# Column: junction
# junction
# INTERSECTION              32163
# Missing                   26099
# NON INTERSECTION          23850
# INTERSECTION RELATED      10957
# COMMERCIAL DRIVEWAY        1162
# INTERCHANGE RELATED        1029
# OTHER                       928
# RESIDENTIAL DRIVEWAY        486
# CROSSOVER RELATED           385
# OTHER DRIVEWAY              271
# UNKNOWN                      79
# ALLEY                        32
# RAILWAY GRADE CROSSING       17
# Name: count, dtype: int64
#
# Column: intersection_type
# intersection_type
# Missing                  49054
# FOUR-WAY INTERSECTION    30612
# T-INTERSECTION           13845
# OTHER                     2581
# Y-INTERSECTION             648
# ROUNDABOUT                 302
# FIVE-POINT OR MORE         202
# TRAFFIC CIRCLE             117
# UNKNOWN                     97
# Name: count, dtype: int64
#
# Column: intersection_area
# intersection_area
# Missing                  71045
# INTERSECTION             15899
# INTERSECTION RELATED      6022
# THRU ROADWAY              1706
# OTHER                     1150
# ON RAMP ENTRANCE AREA      706
# ON RAMP EXIT AREA          690
# ON RAMP MID AREA           161
# UNKNOWN                     79
# Name: count, dtype: int64
#
# Column: road_alignment
# road_alignment
# STRAIGHT       74041
# Missing        12749
# CURVE RIGHT     5186
# CURVE LEFT      4818
# OTHER            533
# UNKNOWN          131
# Name: count, dtype: int64
#
# Column: road_condition
# road_condition
# NO DEFECTS                  80454
# Missing                     15705
# OTHER                         338
# HOLES RUTS ETC                298
# UNKNOWN                       204
# LOOSE SURFACE MATERIAL        158
# FOREIGN MATERIAL              127
# VIEW OBSTRUCTED                76
# SHOULDER DEFECT                71
# OBSTRUCTION NOT LIGHTED        17
# OBSTRUCTION NOT SIGNALED       10
# Name: count, dtype: int64
#
# Column: road_division
# road_division
# TWO-WAY, DIVIDED, POSITIVE MEDIAN BARRIER           39859
# TWO-WAY, NOT DIVIDED                                30623
# Missing                                             13531
# TWO-WAY, DIVIDED, UNPROTECTED PAINTED MIN 4 FEET     9847
# ONE-WAY TRAFFICWAY                                   1979
# OTHER                                                1167
# TWO-WAY, NOT DIVIDED WITH A CONTINUOUS LEFT TURN      367
# UNKNOWN                                                85
# Name: count, dtype: int64

# %%
column_list = sql_frame.columns.tolist()
print(column_list)
# Out:
# ['report_number', 'local_case_number', 'agency_name', 'acrs_report_type', 'crash_date_time', 'hit_run', 'route_type', 'mile_point', 'mile_point_direction', 'lane_direction', 'lane_number', 'lane_type', 'number_of_lanes', 'direction', 'distance', 'distance_unit', 'road_grade', 'non_traffic', 'road_name', 'cross_street_name', 'related_non_motorist', 'at_fault', 'collision_type', 'weather', 'surface_condition', 'light', 'traffic_control', 'driver_substance_abuse', 'non_motorist_substance_abuse', 'fixed_object_struck', 'junction', 'intersection_type', 'intersection_area', 'road_alignment', 'road_condition', 'road_division']

# %%
columns_to_drop = ['mile_point_direction', 'direction', 'road_grade', 'non_traffic', 'fixed_object_struck', 'intersection_area', 'road_division']
sql_frame.drop(columns=columns_to_drop, inplace=True)

# %%
column_list = sql_frame.columns.tolist()
print(column_list)
# Out:
# ['report_number', 'local_case_number', 'agency_name', 'acrs_report_type', 'crash_date_time', 'hit_run', 'route_type', 'mile_point', 'lane_direction', 'lane_number', 'lane_type', 'number_of_lanes', 'distance', 'distance_unit', 'road_name', 'cross_street_name', 'related_non_motorist', 'at_fault', 'collision_type', 'weather', 'surface_condition', 'light', 'traffic_control', 'driver_substance_abuse', 'non_motorist_substance_abuse', 'junction', 'intersection_type', 'road_alignment', 'road_condition']

# %%
# Count the number of columns containing 'Missing'
missing_columns_count = 0
missing_columns = []

for column in sql_frame.columns:
    if (sql_frame[column] == 'Missing').any():
        missing_count = (sql_frame[column] == 'Missing').sum()
        if missing_count > 0:
            missing_columns_count += 1
            missing_columns.append((column, missing_count))

print("Total number of columns with 'Missing' values:", missing_columns_count)
print("Columns with count of 'Missing' values:")
for column_name, count in missing_columns:
    print(f"{column_name}: {count}")
# Out:
# Total number of columns with 'Missing' values: 17
# Columns with count of 'Missing' values:
# route_type: 12995
# lane_type: 87945
# distance_unit: 12328
# road_name: 12328
# cross_street_name: 12338
# related_non_motorist: 92077
# collision_type: 504
# weather: 7947
# surface_condition: 14650
# light: 815
# traffic_control: 16436
# driver_substance_abuse: 15598
# non_motorist_substance_abuse: 93195
# junction: 26099
# intersection_type: 49054
# road_alignment: 12749
# road_condition: 15705

# %%
# Define threshold for dropping columns
threshold = 50000

# Filter columns with count of 'Missing' values greater than threshold
columns_to_drop = [column for column, count in missing_columns if count > threshold]

# Drop columns from DataFrame
sql_frame.drop(columns=columns_to_drop, inplace=True)

# Print the remaining columns
print("Remaining columns after dropping:")
print(sql_frame.columns.tolist())
# Out:
# Remaining columns after dropping:
# ['report_number', 'local_case_number', 'agency_name', 'acrs_report_type', 'crash_date_time', 'hit_run', 'route_type', 'mile_point', 'lane_direction', 'lane_number', 'number_of_lanes', 'distance', 'distance_unit', 'road_name', 'cross_street_name', 'at_fault', 'collision_type', 'weather', 'surface_condition', 'light', 'traffic_control', 'driver_substance_abuse', 'junction', 'intersection_type', 'road_alignment', 'road_condition']

# %%
sql_frame.head()
# Out:
#   report_number local_case_number                agency_name  \
# 0   MCP2686006F         230031339   Montgomery County Police
# 1   MCP3230004G         230031335   Montgomery County Police
# 2   MCP12600013         230031067   Montgomery County Police
# 3    DD55750030         230031365  Rockville Police Departme
# 4   MCP3010008B         230034141   Montgomery County Police
#
#         acrs_report_type         crash_date_time hit_run  \
# 0  Property Damage Crash  06/30/2023 10:55:00 PM      No
# 1  Property Damage Crash  06/30/2023 08:00:00 PM      No
# 2           Injury Crash  06/29/2023 11:53:00 AM      No
# 3  Property Damage Crash  07/01/2023 01:48:00 AM     Yes
# 4  Property Damage Crash  07/01/2023 12:52:00 PM      No
#
#              route_type  mile_point lane_direction lane_number  ...  \
# 0               Missing         NaN          North           0  ...
# 1                County        1.42          North           1  ...
# 2      Maryland (State)       11.26          North           1  ...
# 3          Municipality        0.07          North           1  ...
# 4  Other Public Roadway        0.00           West           1  ...
#
#             collision_type  weather surface_condition           light  \
# 0           SINGLE VEHICLE    CLEAR           Missing  DARK NO LIGHTS
# 1  STRAIGHT MOVEMENT ANGLE    CLEAR               DRY        DAYLIGHT
# 2           SINGLE VEHICLE    CLEAR               DRY        DAYLIGHT
# 3                    OTHER   CLOUDY               DRY  DARK LIGHTS ON
# 4        SAME DIR REAR END    CLEAR               DRY        DAYLIGHT
#
#   traffic_control driver_substance_abuse          junction  \
# 0     NO CONTROLS          NONE DETECTED           Missing
# 1  TRAFFIC SIGNAL          NONE DETECTED      INTERSECTION
# 2       STOP SIGN          NONE DETECTED  NON INTERSECTION
# 3         Missing                Missing             OTHER
# 4         Missing                Missing           Missing
#
#        intersection_type road_alignment road_condition
# 0                Missing        Missing        Missing
# 1  FOUR-WAY INTERSECTION       STRAIGHT     NO DEFECTS
# 2                Missing       STRAIGHT     NO DEFECTS
# 3  FOUR-WAY INTERSECTION       STRAIGHT     NO DEFECTS
# 4                Missing       STRAIGHT     NO DEFECTS
#
# [5 rows x 26 columns]

# %%
final_transformed_frame=sql_frame

# %%
# Assuming final_transformed_frame is your DataFrame and filename is the name of the output file
filename = "incidents.json"
final_transformed_frame.to_json(filename, orient='records')

# %%
final_df = sql_frame.head(1000)

# %%
# Assuming final_transformed_frame is your DataFrame and filename is the name of the output file
filename = "final.json"
final_df.to_json(filename, orient='records')

# %% [markdown]
# ### MongoDB Cluster connection

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri="mongodb+srv://x22237941:sana123@montgomerycluster.tzxvtsd.mongodb.net/"
#uri = "mongodb+srv://sana:sana123@montgomerycluster.tzxvtsd.mongodb.net/?retryWrites=true&w=majority&appName=montgomerycluster"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

try:
    #client.admin.command('ping')
    client.montgomery.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %% [markdown]
# ### Check server status

# %%
try:
    server_status = client.montgomery.command('serverStatus')
    print("Server is up and running.")
except Exception as e:
    print("Error:", e)
# Out:
# Server is up and running.

# %% [markdown]
# ### List all databases

# %%
databases = client.list_database_names()
print("Databases:")
for db_obj in databases:
    print(db_obj)
# Out:
# Databases:
# montgomery
# admin
# local

# %% [markdown]
# ### List all collections in a specific database

# %%
database_name = "montgomery"
collections = client[database_name].list_collection_names()
print("\nCollections in", database_name, ":")
for col in collections:
    print(col)
# Out:
# Collections in montgomery :
# drivers_dupe
# incident

# %% [markdown]
# ### Create database named montgomery

# %%
database = 'montgomery'
db = client[database]
dblist = client.list_database_names()
if database in dblist:
  print(f"The database {database} exists.")
  colList = db.list_collection_names()
  collection_name = 'incidents_dupe'
  if collection_name in colList:
      print(f"The collection { collection_name} exists.")
  else:
      print(f"The collection { collection_name } does NOT exists.")
      collection = db[ collection_name ]
      print(collection)
      print(f"The collection { collection_name } created")
else:
  print(f"The database {database} does not exists.")
  db = client[database]
# Out:
# The database montgomery exists.
# The collection incidents_dupe does NOT exists.
# Collection(Database(MongoClient(host=['ac-splqn9y-shard-00-02.tzxvtsd.mongodb.net:27017', 'ac-splqn9y-shard-00-00.tzxvtsd.mongodb.net:27017', 'ac-splqn9y-shard-00-01.tzxvtsd.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-t83v95-shard-0', tls=True, server_api=<pymongo.server_api.ServerApi object at 0x0000022D0FD67740>), 'montgomery'), 'incidents_dupe')
# The collection incidents_dupe created

# %%
db = client['montgomery']

# %%
collection = db[ 'incident' ]

# %%
collections = client["montgomery"].list_collection_names()
print("\nCollections in", 'montgomery', ":")
for col in collections:
    print(col)
# Out:
# Collections in montgomery :
# drivers_dupe
# incident

# %% [markdown]
# ### Load JSON file into incidents collection of montgomery database

# %%
# Get the total number of documents in the collection
total_records = collection.count_documents({})
print("Total number of records in the collection:", total_records)
# Out:
# Total number of records in the collection: 1000

# %%
import json
# Load JSON file
filename = "incidents.json"
with open(filename, 'r') as file:
    data = json.load(file)

# %%
# Check if Collection Exists
colList = db.list_collection_names()
colList
collection_name = 'incident'
if collection_name in colList:
  print(f"The collection { collection_name} exists.")
else:
    print(f"The collection { collection_name } does NOT exists.")
# Out:
# The collection incident exists.

# %%
# Insert documents into collection
collection = db['incident']
collection.insert_many(data)
print("JSON data successfully loaded into MongoDB collection 'drivers_dupe' in database 'montgomery'.")
total_records = collection.count_documents({})
print("Total number of records in the collection:", total_records)

# %%
db = client["montgomery"]
collection = db["incident"]
data_dict= final_transformed_frame.to_dict("records")
client["montgomery"].db["incident"].insert_many(data_dict)
# Out:
# ---------------------------------------------------------------------------
# ZeroReturnError                           Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:1020, in Connection.receive_message(self, request_id)
#    1019 try:
# -> 1020     return receive_message(self, request_id, self.max_message_size)
#    1021 except BaseException as error:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\network.py:257, in receive_message(conn, request_id, max_message_size)
#     256 # Ignore the response's request id.
# --> 257 length, _, response_to, op_code = _UNPACK_HEADER(_receive_data_on_socket(conn, 16, deadline))
#     258 # No request_id for exhaust cursor "getMore".
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\network.py:340, in _receive_data_on_socket(conn, length, deadline)
#     339         conn.set_conn_timeout(max(deadline - time.monotonic(), 0))
# --> 340     chunk_length = conn.conn.recv_into(mv[bytes_read:])
#     341 except BLOCKING_IO_ERRORS:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pyopenssl_context.py:155, in _sslConn.recv_into(self, *args, **kwargs)
#     154 try:
# --> 155     return self._call(super().recv_into, *args, **kwargs)
#     156 except _SSL.SysCallError as exc:
#     157     # Suppress ragged EOFs to match the stdlib.
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pyopenssl_context.py:120, in _sslConn._call(self, call, *args, **kwargs)
#     119 try:
# --> 120     return call(*args, **kwargs)
#     121 except BLOCKING_IO_ERRORS as exc:
#     122     # Check for closed socket.
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\OpenSSL\SSL.py:2099, in Connection.recv_into(self, buffer, nbytes, flags)
#    2098     result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 2099 self._raise_ssl_error(self._ssl, result)
#    2101 # This strange line is all to avoid a memory copy. The buffer protocol
#    2102 # should allow us to assign a CFFI buffer to the LHS of this line, but
#    2103 # on CPython 3.3+ that segfaults. As a workaround, we can temporarily
#    2104 # wrap it in a memoryview.
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\OpenSSL\SSL.py:1805, in Connection._raise_ssl_error(self, ssl, result)
#    1804 elif error == _lib.SSL_ERROR_ZERO_RETURN:
# -> 1805     raise ZeroReturnError()
#    1806 elif error == _lib.SSL_ERROR_WANT_X509_LOOKUP:
#    1807     # TODO: This is untested.
#
# ZeroReturnError:
#
# The above exception was the direct cause of the following exception:
#
# AutoReconnect                             Traceback (most recent call last)
# Cell In[107], line 4
#       2 collection = db["incident"]
#       3 data_dict= final_transformed_frame.to_dict("records")
# ----> 4 client["montgomery"].db["incident"].insert_many(data_dict)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\collection.py:755, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     753 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     754 blk.ops = list(gen())
# --> 755 blk.execute(write_concern, session=session)
#     756 return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\bulk.py:576, in _Bulk.execute(self, write_concern, session)
#     574         return None
#     575 else:
# --> 576     return self.execute_command(generator, write_concern, session)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\bulk.py:443, in _Bulk.execute_command(self, generator, write_concern, session)
#     432     self._execute_command(
#     433         generator,
#     434         write_concern,
#    (...)
#     439         full_result,
#     440     )
#     442 client = self.collection.database.client
# --> 443 client._retryable_write(self.is_retryable, retryable_bulk, session, bulk=self)
#     445 if full_result["writeErrors"] or full_result["writeConcernErrors"]:
#     446     _raise_bulk_write_error(full_result)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1523, in MongoClient._retryable_write(self, retryable, func, session, bulk)
#    1509 """Execute an operation with consecutive retries if possible
#    1510
#    1511 Returns func()'s return value on success. On error retries the same
#    (...)
#    1520   - `bulk`: bulk abstraction to execute operations in bulk, defaults to None
#    1521 """
#    1522 with self._tmp_session(session) as s:
# -> 1523     return self._retry_with_session(retryable, func, s, bulk)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1421, in MongoClient._retry_with_session(self, retryable, func, session, bulk)
#    1416 # Ensure that the options supports retry_writes and there is a valid session not in
#    1417 # transaction, otherwise, we will not support retry behavior for this txn.
#    1418 retryable = bool(
#    1419     retryable and self.options.retry_writes and session and not session.in_transaction
#    1420 )
# -> 1421 return self._retry_internal(
#    1422     func=func,
#    1423     session=session,
#    1424     bulk=bulk,
#    1425     retryable=retryable,
#    1426 )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\_csot.py:107, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     105         with _TimeoutContext(timeout):
#     106             return func(self, *args, **kwargs)
# --> 107 return func(self, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:1462, in MongoClient._retry_internal(self, func, session, bulk, is_read, address, read_pref, retryable)
#    1428 @_csot.apply
#    1429 def _retry_internal(
#    1430     self,
#    (...)
#    1437     retryable: bool = False,
#    1438 ) -> T:
#    1439     """Internal retryable helper for all client transactions.
#    1440
#    1441     :Parameters:
#    (...)
#    1451       Output of the calling func()
#    1452     """
#    1453     return _ClientConnectionRetryable(
#    1454         mongo_client=self,
#    1455         func=func,
#    1456         bulk=bulk,
#    1457         is_read=is_read,
#    1458         session=session,
#    1459         read_pref=read_pref,
#    1460         address=address,
#    1461         retryable=retryable,
# -> 1462     ).run()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:2315, in _ClientConnectionRetryable.run(self)
#    2313 self._check_last_error(check_csot=True)
#    2314 try:
# -> 2315     return self._read() if self._is_read else self._write()
#    2316 except ServerSelectionTimeoutError:
#    2317     # The application may think the write was never attempted
#    2318     # if we raise ServerSelectionTimeoutError on the retry
#    2319     # attempt. Raise the original exception instead.
#    2320     self._check_last_error()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\mongo_client.py:2423, in _ClientConnectionRetryable._write(self)
#    2421             self._check_last_error()
#    2422             self._retryable = False
# -> 2423         return self._func(self._session, conn, self._retryable)  # type: ignore
#    2424 except PyMongoError as exc:
#    2425     if not self._retryable:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\bulk.py:432, in _Bulk.execute_command.<locals>.retryable_bulk(session, conn, retryable)
#     429 def retryable_bulk(
#     430     session: Optional[ClientSession], conn: Connection, retryable: bool
#     431 ) -> None:
# --> 432     self._execute_command(
#     433         generator,
#     434         write_concern,
#     435         session,
#     436         conn,
#     437         op_id,
#     438         retryable,
#     439         full_result,
#     440     )
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\bulk.py:378, in _Bulk._execute_command(self, generator, write_concern, session, conn, op_id, retryable, full_result, final_write_concern)
#     376 # Run as many ops as possible in one command.
#     377 if write_concern.acknowledged:
# --> 378     result, to_send = bwc.execute(cmd, ops, client)
#     380     # Retryable writeConcernErrors halt the execution of this run.
#     381     wce = result.get("writeConcernError", {})
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\message.py:964, in _BulkWriteContext.execute(self, cmd, docs, client)
#     960 def execute(
#     961     self, cmd: MutableMapping[str, Any], docs: list[Mapping[str, Any]], client: MongoClient
#     962 ) -> tuple[Mapping[str, Any], list[Mapping[str, Any]]]:
#     963     request_id, msg, to_send = self.__batch_command(cmd, docs)
# --> 964     result = self.write_command(cmd, request_id, msg, to_send)
#     965     client._process_response(result, self.session)
#     966     return result, to_send
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\helpers.py:322, in _handle_reauth.<locals>.inner(*args, **kwargs)
#     319 from pymongo.pool import Connection
#     321 try:
# --> 322     return func(*args, **kwargs)
#     323 except OperationFailure as exc:
#     324     if no_reauth:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\message.py:1058, in _BulkWriteContext.write_command(self, cmd, request_id, msg, docs)
#    1056     start = datetime.datetime.now()
#    1057 try:
# -> 1058     reply = self.conn.write_command(request_id, msg, self.codec)
#    1059     if self.publish:
#    1060         duration = (datetime.datetime.now() - start) + duration
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:1056, in Connection.write_command(self, request_id, msg, codec_options)
#    1047 """Send "insert" etc. command, returning response as a dict.
#    1048
#    1049 Can raise ConnectionFailure or OperationFailure.
#    (...)
#    1053   - `msg`: bytes, the command message.
#    1054 """
#    1055 self.send_message(msg, 0)
# -> 1056 reply = self.receive_message(request_id)
#    1057 result = reply.command_response(codec_options)
#    1059 # Raises NotPrimaryError or OperationFailure.
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:1022, in Connection.receive_message(self, request_id)
#    1020     return receive_message(self, request_id, self.max_message_size)
#    1021 except BaseException as error:
# -> 1022     self._raise_connection_failure(error)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:1171, in Connection._raise_connection_failure(self, error)
#    1169 if isinstance(error, (IOError, OSError, SSLError)):
#    1170     details = _get_timeout_details(self.opts)
# -> 1171     _raise_connection_failure(self.address, error, timeout_details=details)
#    1172 else:
#    1173     raise
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\pool.py:411, in _raise_connection_failure(address, error, msg_prefix, timeout_details)
#     409     raise NetworkTimeout(msg) from error
#     410 else:
# --> 411     raise AutoReconnect(msg) from error
#
# AutoReconnect: ac-splqn9y-shard-00-01.tzxvtsd.mongodb.net:27017:  (configured timeouts: connectTimeoutMS: 20000.0ms)

# %%
import pandas as pd
db = client["montgomery"]
collection = db["incident"]
cursor = collection.find({})
mongo_frame = pd.DataFrame(list(cursor))

# %%
mongo_frame.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
