# %% [markdown]
# # Import Required Librariers:

# %%
import mysql.connector as mysql  
import os
import csv
import matplotlib as mp
import numpy as np
import pandas as pd
from sqlalchemy import create_engine
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Store Data into a variable using the built in CSV.Reader Function:

# %%
data_set=pd.read_csv("Non-Motorists_Data_20240404.csv")

# %% [markdown]
# # Establish a Connection to MySQL

# %%
# MySQL database connection parameters
host = 'localhost'
user = 'root'
password = 'waleed123'
database = 'montgomery'

# Establish connection
connection = mysql.connect(
            host=host,
            user=user,
            password=password,
            database=database
)

if connection.is_connected():
    print("Connected to MySQL database")
# Out:
# Connected to MySQL database

# %%
connection

# %% [markdown]
# # Establishing a cursor

# %%
my_cursor=connection.cursor()

# %% [markdown]
# # DDL/DML Queries

# %%
table_create='''CREATE TABLE non_motorists(
                report_number TEXT,
                local_case_number TEXT,
                agency_name TEXT,
                acrs_report_type TEXT,
                crash_date_time TEXT,
                route_type TEXT,
                road_Name TEXT,
                cross_street_type TEXT,
                cross_street_name TEXT,
                off_road_description TEXT,
                municipality TEXT,
                related_non_motorist TEXT,
                collision_type TEXT,
                weather TEXT,
                surface_condition TEXT,
                light TEXT,
                traffic_control TEXT,
                driver_substance_abuse TEXT,
                non_motorist_substance_abuse TEXT,
                person_id TEXT,
                pedestrian_type TEXT,
                pedestrian_movement TEXT,
                pedestrian_actions TEXT,
                pedestrian_location TEXT,
                pedestrian_obeyed_traffic_signal TEXT,
                pedestrian_visibility TEXT,
                at_fault TEXT,
                injury_severity TEXT,
                safety_equipment TEXT,
                latitude TEXT,
                longitude TEXT,
                location TEXT
                )'''

# %%
show_table="show tables"

# %%
my_cursor.execute(table_create) # executing/creating a table
connection.commit() # Commit the transaction

# %%
my_cursor.execute("SHOW TABLES")
# Fetch all table names
tables = my_cursor.fetchall()

# Print table names
for table in tables:
    print(table[0])
# Out:
# non_motorists

# %%
data_insert='''INSERT INTO non_motorists (report_number,local_case_number,agency_name,acrs_report_type,crash_date_time,route_type, road_Name,cross_street_type,cross_street_name,off_road_description,municipality,related_non_motorist,collision_type,weather,surface_condition,light,traffic_control,driver_substance_abuse,non_motorist_substance_abuse,person_id,pedestrian_type,pedestrian_movement,pedestrian_actions,pedestrian_location,pedestrian_obeyed_traffic_signal,pedestrian_visibility,at_fault,injury_severity,safety_equipment,latitude,longitude,location) VALUES ( %s,%s,%s,%s,%s,%s,%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s,
# %s, %s, %s, %s, %s, %s, %s, %s)'''''

# %%
column_drops='''ALTER TABLE non_motorists
DROP COLUMN Latitude,
DROP COLUMN Longitude,
DROP COLUMN Location'''

# %%
select_query="select * from non_motorists"

# %%
my_cursor = connection.cursor()

# %%
my_cursor.execute("SHOW TABLES")
# Fetch all table names
tables = my_cursor.fetchall()

# Print table names
for table in tables:
    print(table[0])
# Out:
# non_motorists

# %%
illustrate="DESCRIBE non_motorists"

# %%
my_cursor.execute(illustrate)

# %%
# Fetch all the rows
columns = my_cursor.fetchall()
# Print column names and data types
for column in columns:
    print(column[0], "-", column[1])
# Out:
# report_number - text
# local_case_number - text
# agency_name - text
# acrs_report_type - text
# crash_date_time - text
# route_type - text
# road_Name - text
# cross_street_type - text
# cross_street_name - text
# off_road_description - text
# municipality - text
# related_non_motorist - text
# collision_type - text
# weather - text
# surface_condition - text
# light - text
# traffic_control - text
# driver_substance_abuse - text
# non_motorist_substance_abuse - text
# person_id - text
# pedestrian_type - text
# pedestrian_movement - text
# pedestrian_actions - text
# pedestrian_location - text
# pedestrian_obeyed_traffic_signal - text
# pedestrian_visibility - text
# at_fault - text
# injury_severity - text
# safety_equipment - text
# latitude - text
# longitude - text
# location - text

# %%
#select_query="select * from non_motorists_final"

# %%
my_cursor.close()
# Out:
# True

# %%
data_set.head()
# Out:
#   Report Number  Local Case Number               Agency Name  \
# 0   MCP2563001L          230017107  Montgomery County Police
# 1   MCP2771002B          230034003  Montgomery County Police
# 2   MCP2861005Z          230034963  Montgomery County Police
# 3   MCP3299002R          230034733  Montgomery County Police
# 4   MCP3360000L          230046354  Montgomery County Police
#
#         ACRS Report Type         Crash Date/Time        Route Type  \
# 0           Injury Crash  10/04/2023 04:21:00 pm  Maryland (State)
# 1           Injury Crash  07/17/2023 12:53:00 PM            County
# 2           Injury Crash  07/22/2023 06:58:00 PM               NaN
# 3  Property Damage Crash  07/21/2023 11:52:00 AM  Maryland (State)
# 4           Injury Crash  07/25/2023 10:12:00 AM            County
#
#            Road Name Cross-Street Type        Cross-Street Name  \
# 0  MUNCASTER MILL RD           Unknown  STRUC #15015 ROCK CREEK
# 1           PECAN DR            County             BUTTERNUT DR
# 2                NaN               NaN                      NaN
# 3        GEORGIA AVE            County         OLD BALTIMORE RD
# 4    WATKINS MILL RD            County              STEDWICK RD
#
#                  Off-Road Description  ...             Pedestrian Actions  \
# 0                                 NaN  ...  FAILURE TO YIELD RIGHT OF WAY
# 1                                 NaN  ...                          OTHER
# 2  PARKING LOT OF 7101 DEMOCRACY BLVD  ...          IN ROADWAY IMPROPERLY
# 3                                 NaN  ...            NO IMPROPER ACTIONS
# 4                                 NaN  ...            NO IMPROPER ACTIONS
#
#                 Pedestrian Location Pedestrian Obeyed Traffic Signal  \
# 0           ON ROADWAY AT CROSSWALK                   NO PED. SIGNAL
# 1                             OTHER                              NaN
# 2       ON ROADWAY NOT AT CROSSWALK                   NO PED. SIGNAL
# 3           ON ROADWAY AT CROSSWALK               OBEYED PED. SIGNAL
# 4  AT INTERSECTION MARKED CROSSWALK               OBEYED PED. SIGNAL
#
#   Pedestrian Visibility At Fault           Injury Severity Safety Equipment  \
# 0         DARK CLOTHING      Yes  SUSPECTED SERIOUS INJURY             NONE
# 1        LIGHT CLOTHING      Yes    SUSPECTED MINOR INJURY              NaN
# 2        LIGHT CLOTHING       No    SUSPECTED MINOR INJURY             NONE
# 3        LIGHT CLOTHING       No        NO APPARENT INJURY              NaN
# 4               UNKNOWN       No    SUSPECTED MINOR INJURY             NONE
#
#     Latitude  Longitude                     Location
# 0  39.137645 -77.129460  (39.13764511, -77.12946041)
# 1  39.091784 -77.098823  (39.09178359, -77.09882296)
# 2  39.024061 -77.147620  (39.02406091, -77.14761954)
# 3  39.135263 -77.069760     (39.13526333, -77.06976)
# 4  39.170558 -77.208889  (39.17055765, -77.20888876)
#
# [5 rows x 32 columns]

# %% [markdown]
# The dataframe as seen above has "NaN" values which cannot be inserted into the tables created in MySQL DB

# %% [markdown]
# Thus we need to replace those Nan Values with any string like missing/unknown for instance i.e. time being

# %% [markdown]
# # Deep copy of original dataframe:

# %%
dataframe = data_set

# %%
dataframe.describe
# Out:
# <bound method NDFrame.describe of      Report Number  Local Case Number                Agency Name  \
# 0      MCP2563001L          230017107   Montgomery County Police
# 1      MCP2771002B          230034003   Montgomery County Police
# 2      MCP2861005Z          230034963   Montgomery County Police
# 3      MCP3299002R          230034733   Montgomery County Police
# 4      MCP3360000L          230046354   Montgomery County Police
# ...            ...                ...                        ...
# 5645   MCP1151006L          170515099   Montgomery County Police
# 5646   MCP3243000C          200032846   Montgomery County Police
# 5647   MCP15950022          220027156   Montgomery County Police
# 5648    EJ7857001Q          170533688  Gaithersburg Police Depar
# 5649   MCP2964001H           16021317   Montgomery County Police
#
#            ACRS Report Type         Crash Date/Time        Route Type  \
# 0              Injury Crash  10/04/2023 04:21:00 pm  Maryland (State)
# 1              Injury Crash  07/17/2023 12:53:00 PM            County
# 2              Injury Crash  07/22/2023 06:58:00 PM               NaN
# 3     Property Damage Crash  07/21/2023 11:52:00 AM  Maryland (State)
# 4              Injury Crash  07/25/2023 10:12:00 AM            County
# ...                     ...                     ...               ...
# 5645           Injury Crash  06/22/2017 07:41:00 AM               NaN
# 5646           Injury Crash  08/22/2020 05:17:00 PM            County
# 5647           Injury Crash  08/28/2022 03:07:00 AM  Maryland (State)
# 5648           Injury Crash  09/28/2017 06:24:00 PM               NaN
# 5649           Injury Crash  04/30/2016 04:08:00 PM  Maryland (State)
#
#               Road Name Cross-Street Type        Cross-Street Name  \
# 0     MUNCASTER MILL RD           Unknown  STRUC #15015 ROCK CREEK
# 1              PECAN DR            County             BUTTERNUT DR
# 2                   NaN               NaN                      NaN
# 3           GEORGIA AVE            County         OLD BALTIMORE RD
# 4       WATKINS MILL RD            County              STEDWICK RD
# ...                 ...               ...                      ...
# 5645                NaN               NaN                      NaN
# 5646       ROCKLEDGE DR            County           ROCK SPRING DR
# 5647        GEORGIA AVE            County              ENNALLS AVE
# 5648                NaN               NaN                      NaN
# 5649       FREDERICK RD            County           MIDDLEBROOK RD
#
#                                    Off-Road Description  ...  \
# 0                                                   NaN  ...
# 1                                                   NaN  ...
# 2                    PARKING LOT OF 7101 DEMOCRACY BLVD  ...
# 3                                                   NaN  ...
# 4                                                   NaN  ...
# ...                                                 ...  ...
# 5645  PARKING LOT OF CHIC FIL A RESTAURANT  19945 CE...  ...
# 5646                                                NaN  ...
# 5647                                                NaN  ...
# 5648              IN THE PARKING LOT OF CRESTWOOD DRIVE  ...
# 5649                                                NaN  ...
#
#                                     Pedestrian Actions  \
# 0                        FAILURE TO YIELD RIGHT OF WAY
# 1                                                OTHER
# 2                                IN ROADWAY IMPROPERLY
# 3                                  NO IMPROPER ACTIONS
# 4                                  NO IMPROPER ACTIONS
# ...                                                ...
# 5645                               NO IMPROPER ACTIONS
# 5646  FAILURE TO OBEY TRAFFIC SIGNS SIGNALS OR OFFICER
# 5647                               NO IMPROPER ACTIONS
# 5648                             IN ROADWAY IMPROPERLY
# 5649                                       INATTENTIVE
#
#                    Pedestrian Location Pedestrian Obeyed Traffic Signal  \
# 0              ON ROADWAY AT CROSSWALK                   NO PED. SIGNAL
# 1                                OTHER                              NaN
# 2          ON ROADWAY NOT AT CROSSWALK                   NO PED. SIGNAL
# 3              ON ROADWAY AT CROSSWALK               OBEYED PED. SIGNAL
# 4     AT INTERSECTION MARKED CROSSWALK               OBEYED PED. SIGNAL
# ...                                ...                              ...
# 5645                             OTHER                              NaN
# 5646           ON ROADWAY AT CROSSWALK            DISOBEYED PED. SIGNAL
# 5647       ON ROADWAY NOT AT CROSSWALK                   NO PED. SIGNAL
# 5648                               NaN                   NO PED. SIGNAL
# 5649           ON ROADWAY AT CROSSWALK                   NO PED. SIGNAL
#
#      Pedestrian Visibility At Fault           Injury Severity  \
# 0            DARK CLOTHING      Yes  SUSPECTED SERIOUS INJURY
# 1           LIGHT CLOTHING      Yes    SUSPECTED MINOR INJURY
# 2           LIGHT CLOTHING       No    SUSPECTED MINOR INJURY
# 3           LIGHT CLOTHING       No        NO APPARENT INJURY
# 4                  UNKNOWN       No    SUSPECTED MINOR INJURY
# ...                    ...      ...                       ...
# 5645        MIXED CLOTHING       No           POSSIBLE INJURY
# 5646        LIGHT CLOTHING      Yes    SUSPECTED MINOR INJURY
# 5647         DARK CLOTHING      Yes           POSSIBLE INJURY
# 5648         DARK CLOTHING      Yes    SUSPECTED MINOR INJURY
# 5649        MIXED CLOTHING      Yes    SUSPECTED MINOR INJURY
#
#      Safety Equipment   Latitude  Longitude                     Location
# 0                NONE  39.137645 -77.129460  (39.13764511, -77.12946041)
# 1                 NaN  39.091784 -77.098823  (39.09178359, -77.09882296)
# 2                NONE  39.024061 -77.147620  (39.02406091, -77.14761954)
# 3                 NaN  39.135263 -77.069760     (39.13526333, -77.06976)
# 4                NONE  39.170558 -77.208889  (39.17055765, -77.20888876)
# ...               ...        ...        ...                          ...
# 5645              NaN  39.182173 -77.261231      (39.182173, -77.261231)
# 5646             NONE  39.026913 -77.132292  (39.02691291, -77.13229168)
# 5647             NONE  39.039351 -77.054306     (39.0393508, -77.054306)
# 5648             NONE  39.146808 -77.192475    (39.14680833, -77.192475)
# 5649             NONE  39.180768 -77.238629  (39.18076775, -77.23862886)
#
# [5650 rows x 32 columns]>

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5650 entries, 0 to 5649
# Data columns (total 32 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Report Number                     5650 non-null   object
#  1   Local Case Number                 5650 non-null   int64
#  2   Agency Name                       5650 non-null   object
#  3   ACRS Report Type                  5650 non-null   object
#  4   Crash Date/Time                   5650 non-null   object
#  5   Route Type                        4338 non-null   object
#  6   Road Name                         4412 non-null   object
#  7   Cross-Street Type                 4337 non-null   object
#  8   Cross-Street Name                 4411 non-null   object
#  9   Off-Road Description              1238 non-null   object
#  10  Municipality                      624 non-null    object
#  11  Related Non-Motorist              5650 non-null   object
#  12  Collision Type                    5472 non-null   object
#  13  Weather                           5192 non-null   object
#  14  Surface Condition                 4268 non-null   object
#  15  Light                             5604 non-null   object
#  16  Traffic Control                   4839 non-null   object
#  17  Driver Substance Abuse            4568 non-null   object
#  18  Non-Motorist Substance Abuse      4447 non-null   object
#  19  Person ID                         5650 non-null   object
#  20  Pedestrian Type                   5650 non-null   object
#  21  Pedestrian Movement               5494 non-null   object
#  22  Pedestrian Actions                5356 non-null   object
#  23  Pedestrian Location               5497 non-null   object
#  24  Pedestrian Obeyed Traffic Signal  3984 non-null   object
#  25  Pedestrian Visibility             5108 non-null   object
#  26  At Fault                          5363 non-null   object
#  27  Injury Severity                   5650 non-null   object
#  28  Safety Equipment                  3742 non-null   object
#  29  Latitude                          5650 non-null   float64
#  30  Longitude                         5650 non-null   float64
#  31  Location                          5650 non-null   object
# dtypes: float64(2), int64(1), object(29)
# memory usage: 1.4+ MB

# %%
dataframe.dtypes
# Out:
# Report Number                        object
# Local Case Number                     int64
# Agency Name                          object
# ACRS Report Type                     object
# Crash Date/Time                      object
# Route Type                           object
# Road Name                            object
# Cross-Street Type                    object
# Cross-Street Name                    object
# Off-Road Description                 object
# Municipality                         object
# Related Non-Motorist                 object
# Collision Type                       object
# Weather                              object
# Surface Condition                    object
# Light                                object
# Traffic Control                      object
# Driver Substance Abuse               object
# Non-Motorist Substance Abuse         object
# Person ID                            object
# Pedestrian Type                      object
# Pedestrian Movement                  object
# Pedestrian Actions                   object
# Pedestrian Location                  object
# Pedestrian Obeyed Traffic Signal     object
# Pedestrian Visibility                object
# At Fault                             object
# Injury Severity                      object
# Safety Equipment                     object
# Latitude                            float64
# Longitude                           float64
# Location                             object
# dtype: object

# %%
dataframe_fill = dataframe.fillna("Missing")

# %%
dataframe_fill.head()
# Out:
#   Report Number  Local Case Number               Agency Name  \
# 0   MCP2563001L          230017107  Montgomery County Police
# 1   MCP2771002B          230034003  Montgomery County Police
# 2   MCP2861005Z          230034963  Montgomery County Police
# 3   MCP3299002R          230034733  Montgomery County Police
# 4   MCP3360000L          230046354  Montgomery County Police
#
#         ACRS Report Type         Crash Date/Time        Route Type  \
# 0           Injury Crash  10/04/2023 04:21:00 pm  Maryland (State)
# 1           Injury Crash  07/17/2023 12:53:00 PM            County
# 2           Injury Crash  07/22/2023 06:58:00 PM           Missing
# 3  Property Damage Crash  07/21/2023 11:52:00 AM  Maryland (State)
# 4           Injury Crash  07/25/2023 10:12:00 AM            County
#
#            Road Name Cross-Street Type        Cross-Street Name  \
# 0  MUNCASTER MILL RD           Unknown  STRUC #15015 ROCK CREEK
# 1           PECAN DR            County             BUTTERNUT DR
# 2            Missing           Missing                  Missing
# 3        GEORGIA AVE            County         OLD BALTIMORE RD
# 4    WATKINS MILL RD            County              STEDWICK RD
#
#                  Off-Road Description  ...             Pedestrian Actions  \
# 0                             Missing  ...  FAILURE TO YIELD RIGHT OF WAY
# 1                             Missing  ...                          OTHER
# 2  PARKING LOT OF 7101 DEMOCRACY BLVD  ...          IN ROADWAY IMPROPERLY
# 3                             Missing  ...            NO IMPROPER ACTIONS
# 4                             Missing  ...            NO IMPROPER ACTIONS
#
#                 Pedestrian Location Pedestrian Obeyed Traffic Signal  \
# 0           ON ROADWAY AT CROSSWALK                   NO PED. SIGNAL
# 1                             OTHER                          Missing
# 2       ON ROADWAY NOT AT CROSSWALK                   NO PED. SIGNAL
# 3           ON ROADWAY AT CROSSWALK               OBEYED PED. SIGNAL
# 4  AT INTERSECTION MARKED CROSSWALK               OBEYED PED. SIGNAL
#
#   Pedestrian Visibility At Fault           Injury Severity Safety Equipment  \
# 0         DARK CLOTHING      Yes  SUSPECTED SERIOUS INJURY             NONE
# 1        LIGHT CLOTHING      Yes    SUSPECTED MINOR INJURY          Missing
# 2        LIGHT CLOTHING       No    SUSPECTED MINOR INJURY             NONE
# 3        LIGHT CLOTHING       No        NO APPARENT INJURY          Missing
# 4               UNKNOWN       No    SUSPECTED MINOR INJURY             NONE
#
#     Latitude  Longitude                     Location
# 0  39.137645 -77.129460  (39.13764511, -77.12946041)
# 1  39.091784 -77.098823  (39.09178359, -77.09882296)
# 2  39.024061 -77.147620  (39.02406091, -77.14761954)
# 3  39.135263 -77.069760     (39.13526333, -77.06976)
# 4  39.170558 -77.208889  (39.17055765, -77.20888876)
#
# [5 rows x 32 columns]

# %% [markdown]
# # Writing the dataframe to MySQL Table:

# %%
inserted_records_count = 0

# %%
my_cursor = connection.cursor()

# %%
for index, row in dataframe_fill.iterrows():
    my_cursor.execute(data_insert, tuple(row))
    inserted_records_count += 1

# %%
connection.commit()

# %%
print("The number of records placed into the table:", inserted_records_count)
# Out:
# The number of records placed into the table: 5650

# %%
# Execute SELECT COUNT(*) query
my_cursor.execute("SELECT COUNT(*) FROM non_motorists")
count = my_cursor.fetchone()[0]

# %%
#count = my_cursor.fetchone()[0]
print("Number of records in 'non_motorists' table:", count)
# Out:
# Number of records in 'non_motorists' table: 5650

# %%
my_cursor.close()
# Out:
# True

# %%
my_cursor = connection.cursor()

# %%
my_cursor.execute(column_drops)

# %%
# Execute the DESCRIBE query
my_cursor.execute("DESCRIBE non_motorists")

# Fetch and print the column information
columns = my_cursor.fetchall()
for column in columns:
        print(column)
# Out:
# ('report_number', 'text', 'YES', '', None, '')
# ('local_case_number', 'text', 'YES', '', None, '')
# ('agency_name', 'text', 'YES', '', None, '')
# ('acrs_report_type', 'text', 'YES', '', None, '')
# ('crash_date_time', 'text', 'YES', '', None, '')
# ('route_type', 'text', 'YES', '', None, '')
# ('road_Name', 'text', 'YES', '', None, '')
# ('cross_street_type', 'text', 'YES', '', None, '')
# ('cross_street_name', 'text', 'YES', '', None, '')
# ('off_road_description', 'text', 'YES', '', None, '')
# ('municipality', 'text', 'YES', '', None, '')
# ('related_non_motorist', 'text', 'YES', '', None, '')
# ('collision_type', 'text', 'YES', '', None, '')
# ('weather', 'text', 'YES', '', None, '')
# ('surface_condition', 'text', 'YES', '', None, '')
# ('light', 'text', 'YES', '', None, '')
# ('traffic_control', 'text', 'YES', '', None, '')
# ('driver_substance_abuse', 'text', 'YES', '', None, '')
# ('non_motorist_substance_abuse', 'text', 'YES', '', None, '')
# ('person_id', 'text', 'YES', '', None, '')
# ('pedestrian_type', 'text', 'YES', '', None, '')
# ('pedestrian_movement', 'text', 'YES', '', None, '')
# ('pedestrian_actions', 'text', 'YES', '', None, '')
# ('pedestrian_location', 'text', 'YES', '', None, '')
# ('pedestrian_obeyed_traffic_signal', 'text', 'YES', '', None, '')
# ('pedestrian_visibility', 'text', 'YES', '', None, '')
# ('at_fault', 'text', 'YES', '', None, '')
# ('injury_severity', 'text', 'YES', '', None, '')
# ('safety_equipment', 'text', 'YES', '', None, '')
# ('latitude', 'text', 'YES', '', None, '')
# ('longitude', 'text', 'YES', '', None, '')
# ('location', 'text', 'YES', '', None, '')

# %%
read_data = "select * from non_motorists"

# %%
sql_frame = pd.read_sql(read_data, connection)
# Out:
# C:\Users\walee\AppData\Local\Temp\ipykernel_25224\2804283245.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sql_frame = pd.read_sql(read_data, connection)

# %%
sql_frame.head()
# Out:
#   report_number local_case_number               agency_name  \
# 0   MCP2563001L         230017107  Montgomery County Police
# 1   MCP2771002B         230034003  Montgomery County Police
# 2   MCP2861005Z         230034963  Montgomery County Police
# 3   MCP3299002R         230034733  Montgomery County Police
# 4   MCP3360000L         230046354  Montgomery County Police
#
#         acrs_report_type         crash_date_time        route_type  \
# 0           Injury Crash  10/04/2023 04:21:00 pm  Maryland (State)
# 1           Injury Crash  07/17/2023 12:53:00 PM            County
# 2           Injury Crash  07/22/2023 06:58:00 PM           Missing
# 3  Property Damage Crash  07/21/2023 11:52:00 AM  Maryland (State)
# 4           Injury Crash  07/25/2023 10:12:00 AM            County
#
#            road_Name cross_street_type        cross_street_name  \
# 0  MUNCASTER MILL RD           Unknown  STRUC #15015 ROCK CREEK
# 1           PECAN DR            County             BUTTERNUT DR
# 2            Missing           Missing                  Missing
# 3        GEORGIA AVE            County         OLD BALTIMORE RD
# 4    WATKINS MILL RD            County              STEDWICK RD
#
#                  off_road_description  ...             pedestrian_actions  \
# 0                             Missing  ...  FAILURE TO YIELD RIGHT OF WAY
# 1                             Missing  ...                          OTHER
# 2  PARKING LOT OF 7101 DEMOCRACY BLVD  ...          IN ROADWAY IMPROPERLY
# 3                             Missing  ...            NO IMPROPER ACTIONS
# 4                             Missing  ...            NO IMPROPER ACTIONS
#
#                 pedestrian_location pedestrian_obeyed_traffic_signal  \
# 0           ON ROADWAY AT CROSSWALK                   NO PED. SIGNAL
# 1                             OTHER                          Missing
# 2       ON ROADWAY NOT AT CROSSWALK                   NO PED. SIGNAL
# 3           ON ROADWAY AT CROSSWALK               OBEYED PED. SIGNAL
# 4  AT INTERSECTION MARKED CROSSWALK               OBEYED PED. SIGNAL
#
#   pedestrian_visibility at_fault           injury_severity safety_equipment  \
# 0         DARK CLOTHING      Yes  SUSPECTED SERIOUS INJURY             NONE
# 1        LIGHT CLOTHING      Yes    SUSPECTED MINOR INJURY          Missing
# 2        LIGHT CLOTHING       No    SUSPECTED MINOR INJURY             NONE
# 3        LIGHT CLOTHING       No        NO APPARENT INJURY          Missing
# 4               UNKNOWN       No    SUSPECTED MINOR INJURY             NONE
#
#       latitude     longitude                     location
# 0  39.13764511  -77.12946041  (39.13764511, -77.12946041)
# 1  39.09178359  -77.09882296  (39.09178359, -77.09882296)
# 2  39.02406091  -77.14761954  (39.02406091, -77.14761954)
# 3  39.13526333     -77.06976     (39.13526333, -77.06976)
# 4  39.17055765  -77.20888876  (39.17055765, -77.20888876)
#
# [5 rows x 32 columns]

# %% [markdown]
# ### Checking for duplicate records

# %%
duplicate_rows = sql_frame.duplicated()
print("Number of duplicate rows:", duplicate_rows.sum())
# Out:
# Number of duplicate rows: 0

# %%
sql_frame.isnull().sum()
# Out:
# report_number                       0
# local_case_number                   0
# agency_name                         0
# acrs_report_type                    0
# crash_date_time                     0
# route_type                          0
# road_Name                           0
# cross_street_type                   0
# cross_street_name                   0
# off_road_description                0
# municipality                        0
# related_non_motorist                0
# collision_type                      0
# weather                             0
# surface_condition                   0
# light                               0
# traffic_control                     0
# driver_substance_abuse              0
# non_motorist_substance_abuse        0
# person_id                           0
# pedestrian_type                     0
# pedestrian_movement                 0
# pedestrian_actions                  0
# pedestrian_location                 0
# pedestrian_obeyed_traffic_signal    0
# pedestrian_visibility               0
# at_fault                            0
# injury_severity                     0
# safety_equipment                    0
# latitude                            0
# longitude                           0
# location                            0
# dtype: int64

# %%
# Check where "Missing" values occur in each column
missing_mask = sql_frame.eq('Missing')

# Check which columns have at least one "Missing" value
columns_with_missing = missing_mask.any()

# Extract the column names where "Missing" values occur
columns_with_missing_values = columns_with_missing[columns_with_missing].index.tolist()

# Print the columns with "Missing" values
print("Columns with 'Missing' values:", columns_with_missing_values)
# Out:
# Columns with 'Missing' values: ['route_type', 'road_Name', 'cross_street_type', 'cross_street_name', 'off_road_description', 'municipality', 'collision_type', 'weather', 'surface_condition', 'light', 'traffic_control', 'driver_substance_abuse', 'non_motorist_substance_abuse', 'pedestrian_movement', 'pedestrian_actions', 'pedestrian_location', 'pedestrian_obeyed_traffic_signal', 'pedestrian_visibility', 'at_fault', 'safety_equipment']

# %%
# Iterate through columns with missing values
for column in columns_with_missing_values:
    # Get unique values and their counts
    unique_values_counts = sql_frame[column].value_counts() 
    # Print column name
    print("Column:", column)
    # Print unique values and their counts
    print(unique_values_counts)
    print()
# Out:
# Column: route_type
# route_type
# County                  2006
# Maryland (State)        1646
# Missing                 1312
# Municipality             468
# US (State)               119
# Other Public Roadway      43
# Government                41
# Ramp                      10
# Interstate (State)         4
# Service Road               1
# Name: count, dtype: int64
#
# Column: road_Name
# road_Name
# Missing              1238
# GEORGIA AVE           304
# ROCKVILLE PIKE        141
# FREDERICK RD          115
# NEW HAMPSHIRE AVE     115
#                      ...
# PINE PL                 1
# HUNTMASTER RD           1
# BROOKDALE RD            1
# BOWMAN MILL RD          1
# CHELTON RD              1
# Name: count, Length: 953, dtype: int64
#
# Column: cross_street_type
# cross_street_type
# County                  2350
# Missing                 1313
# Maryland (State)         678
# Municipality             625
# Unknown                  378
# Other Public Roadway     132
# Government                64
# US (State)                61
# Ramp                      44
# Interstate (State)         4
# Service Road               1
# Name: count, dtype: int64
#
# Column: cross_street_name
# cross_street_name
# Missing                    1239
# GEORGIA AVE                  99
# FREDERICK RD                 56
# COLESVILLE RD                46
# RANDOLPH RD                  45
#                            ...
# COLLEGE VIEW DR               1
# CONNECTICUT AVE (AHEAD)       1
# E BRADLEY LA                  1
# DAMASCUS MANOR RD             1
# LUZERNE AVE                   1
# Name: count, Length: 1543, dtype: int64
#
# Column: off_road_description
# off_road_description
# Missing                                                                  4412
# PARKING LOT                                                                 8
# PARKING LOT OF 26004 BRIGADIER PLACE                                        4
# 4816 BOILING BROOK PKWY, GOODWILL PARKING LOT                               3
# PARKING LOT OF 6300 NEW HAMPSHIRE AVE, TAKOMA PARK, MD 20912                3
#                                                                          ...
# Parking Garage near Macy's side of Montgomery Mall                          1
# GIANT FOOD PARKING LOT 13781 CONNECTICUT AVE.\nSILVER SPRING MD 20906       1
# PARKING LOT OF PARK MONTGOMERY APARTMENTS 8860 PINEY BRANCH ROAD            1
# IFO 13428 NEW HAMPSHIRE AVE                                                 1
# IN THE PARKING LOT OF CRESTWOOD DRIVE                                       1
# Name: count, Length: 1153, dtype: int64
#
# Column: municipality
# municipality
# Missing                5026
# ROCKVILLE               333
# GAITHERSBURG            176
# TAKOMA PARK              62
# FRIENDSHIP HEIGHTS       13
# KENSINGTON               13
# POOLESVILLE               6
# SOMERSET                  6
# CHEVY CHASE #4            6
# CHEVY CHASE #3            3
# CHEVY CHASE VILLAGE       2
# MATINS ADDITION           2
# GARRETT PARK              1
# GLEN ECHO                 1
# Name: count, dtype: int64
#
# Column: collision_type
# collision_type
# OTHER                           2413
# SINGLE VEHICLE                  1780
# STRAIGHT MOVEMENT ANGLE          690
# Missing                          178
# SAME DIR REAR END                157
# HEAD ON LEFT TURN                147
# SAME DIRECTION SIDESWIPE          87
# SAME DIRECTION RIGHT TURN         46
# HEAD ON                           42
# SAME DIRECTION LEFT TURN          27
# ANGLE MEETS RIGHT TURN            22
# OPPOSITE DIRECTION SIDESWIPE      18
# ANGLE MEETS LEFT TURN             13
# UNKNOWN                           12
# SAME DIR REND LEFT TURN            7
# ANGLE MEETS LEFT HEAD ON           6
# SAME DIR REND RIGHT TURN           3
# OPPOSITE DIR BOTH LEFT TURN        2
# Name: count, dtype: int64
#
# Column: weather
# weather
# CLEAR           3949
# RAINING          601
# CLOUDY           523
# Missing          458
# UNKNOWN           32
# SNOW              29
# FOGGY             22
# OTHER             12
# WINTRY MIX        11
# SEVERE WINDS       7
# BLOWING SNOW       3
# SLEET              3
# Name: count, dtype: int64
#
# Column: surface_condition
# surface_condition
# DRY        3520
# Missing    1382
# WET         687
# UNKNOWN      25
# SNOW         16
# ICE          11
# OTHER         5
# SLUSH         4
# Name: count, dtype: int64
#
# Column: light
# light
# DAYLIGHT                    3604
# DARK LIGHTS ON              1455
# DARK NO LIGHTS               211
# DUSK                         127
# DAWN                         104
# DARK -- UNKNOWN LIGHTING      69
# Missing                       46
# UNKNOWN                       19
# OTHER                         15
# Name: count, dtype: int64
#
# Column: traffic_control
# traffic_control
# NO CONTROLS                2261
# TRAFFIC SIGNAL             1663
# Missing                     811
# STOP SIGN                   580
# OTHER                       167
# PERSON                       57
# YIELD SIGN                   37
# UNKNOWN                      24
# FLASHING TRAFFIC SIGNAL      24
# WARNING SIGN                 18
# SCHOOL ZONE SIGN DEVICE       6
# RAILWAY CROSSING DEVICE       2
# Name: count, dtype: int64
#
# Column: driver_substance_abuse
# driver_substance_abuse
# NONE DETECTED                                3776
# Missing                                      1082
# UNKNOWN                                       687
# ALCOHOL PRESENT                                47
# ALCOHOL CONTRIBUTED                            16
# NONE DETECTED, UNKNOWN                          9
# N/A, NONE DETECTED                              8
# ALCOHOL CONTRIBUTED, NONE DETECTED              4
# ALCOHOL PRESENT, NONE DETECTED                  4
# ILLEGAL DRUG PRESENT                            4
# MEDICATION PRESENT                              2
# ALCOHOL PRESENT, N/A                            2
# ALCOHOL CONTRIBUTED, N/A                        2
# ILLEGAL DRUG CONTRIBUTED                        2
# ALCOHOL PRESENT, UNKNOWN                        1
# COMBINED SUBSTANCE PRESENT                      1
# MEDICATION PRESENT, NONE DETECTED               1
# COMBINED SUBSTANCE PRESENT, NONE DETECTED       1
# OTHER                                           1
# Name: count, dtype: int64
#
# Column: non_motorist_substance_abuse
# non_motorist_substance_abuse
# NONE DETECTED                 4011
# Missing                       1203
# UNKNOWN                        229
# ALCOHOL PRESENT                151
# ALCOHOL CONTRIBUTED             40
# ILLEGAL DRUG PRESENT             6
# MEDICATION PRESENT               4
# ILLEGAL DRUG CONTRIBUTED         2
# COMBINATION CONTRIBUTED          2
# COMBINED SUBSTANCE PRESENT       1
# OTHER                            1
# Name: count, dtype: int64
#
# Column: pedestrian_movement
# pedestrian_movement
# Cross/Enter at Intersection        2522
# Other                               720
# Cross/Enter not at Intersection     677
# Walking/Riding w/Traffic            386
# Standing                            376
# Walking/Cycling on Sidewalk         254
# Missing                             156
# Walking/Riding against Traffic      113
# Unknown                             102
# Other Working                        93
# Getting off/on Vehicle               91
# Playing                              68
# Walking to/from school               53
# Push/Work on Vehicle                 24
# Approach/Leaving Schoolbus           12
# Hitchhiking                           3
# Name: count, dtype: int64
#
# Column: pedestrian_actions
# pedestrian_actions
# NO IMPROPER ACTIONS                                 2881
# UNKNOWN                                              462
# IN ROADWAY IMPROPERLY                                451
# DART DASH                                            429
# Missing                                              294
# OTHER                                                265
# FAILURE TO YIELD RIGHT OF WAY                        264
# INATTENTIVE                                          215
# FAILURE TO OBEY TRAFFIC SIGNS SIGNALS OR OFFICER     162
# NOT VISIBLE                                          118
# ENTERING EXITING PARKED STANDING VEHICLE              37
# WRONG WAY RIDING OR WALKING                           32
# DISABLED VEHICLE RELATED                              17
# IMPROPER PASSING                                      16
# IMPROPER TURN MERGE                                    7
# Name: count, dtype: int64
#
# Column: pedestrian_location
# pedestrian_location
# ON ROADWAY AT CROSSWALK             1502
# ON ROADWAY NOT AT CROSSWALK         1170
# OTHER                                976
# AT INTERSECTION MARKED CROSSWALK     664
# SIDEWALK                             388
# AT INTERSECTION BUT NO CROSSWALK     246
# Missing                              153
# SHOULDER                             143
# OUTSIDE RIGHT OF WAY                  65
# CURB                                  65
# INSIDE BUILDING                       63
# UNKNOWN                               62
# DRIVEWAY ACCESS MARKED CROSSWALK      51
# IN BIKEWAY                            43
# MEDIAN                                27
# MIDBLOCK MARKED CROSSWALK             19
# SHARED USE PATH OR TRAILS              9
# IN SCHOOL BUS ZONE                     3
# ISLAND                                 1
# Name: count, dtype: int64
#
# Column: pedestrian_obeyed_traffic_signal
# pedestrian_obeyed_traffic_signal
# NO PED. SIGNAL             2101
# Missing                    1666
# OBEYED PED. SIGNAL         1043
# DISOBEYED PED. SIGNAL       366
# UNKNOWN                     313
# OTHER                       156
# PED. SIGNAL MALFUNCTION       5
# Name: count, dtype: int64
#
# Column: pedestrian_visibility
# pedestrian_visibility
# MIXED CLOTHING               2149
# DARK CLOTHING                1427
# LIGHT CLOTHING                923
# Missing                       542
# UNKNOWN                       339
# REFLECTIVE MATERIAL           164
# OTHER                          68
# HEAD LIGHT AND REFLECTORS      22
# HEAD LIGHT                     10
# REAR REFLECTOR                  6
# Name: count, dtype: int64
#
# Column: at_fault
# at_fault
# No         3414
# Yes        1509
# Unknown     440
# Missing     287
# Name: count, dtype: int64
#
# Column: safety_equipment
# safety_equipment
# NONE                   2862
# Missing                1908
# MC/BIKE HELMET          615
# UNKNOWN                 125
# REFLECTIVE CLOTHING     104
# OTHER                    22
# LIGHTING                 13
# PROTECTIVE PADS           1
# Name: count, dtype: int64

# %%
columns_to_drop = ['cross_street_type', 'off_road_description', 'municipality']
sql_frame.drop(columns=columns_to_drop, inplace=True)

# %%
sql_frame.head()
# Out:
#   report_number local_case_number               agency_name  \
# 0   MCP2563001L         230017107  Montgomery County Police
# 1   MCP2771002B         230034003  Montgomery County Police
# 2   MCP2861005Z         230034963  Montgomery County Police
# 3   MCP3299002R         230034733  Montgomery County Police
# 4   MCP3360000L         230046354  Montgomery County Police
#
#         acrs_report_type         crash_date_time        route_type  \
# 0           Injury Crash  10/04/2023 04:21:00 pm  Maryland (State)
# 1           Injury Crash  07/17/2023 12:53:00 PM            County
# 2           Injury Crash  07/22/2023 06:58:00 PM           Missing
# 3  Property Damage Crash  07/21/2023 11:52:00 AM  Maryland (State)
# 4           Injury Crash  07/25/2023 10:12:00 AM            County
#
#            road_Name        cross_street_name related_non_motorist  \
# 0  MUNCASTER MILL RD  STRUC #15015 ROCK CREEK           PEDESTRIAN
# 1           PECAN DR             BUTTERNUT DR                OTHER
# 2            Missing                  Missing           PEDESTRIAN
# 3        GEORGIA AVE         OLD BALTIMORE RD           PEDESTRIAN
# 4    WATKINS MILL RD              STEDWICK RD            BICYCLIST
#
#    collision_type  ...             pedestrian_actions  \
# 0  SINGLE VEHICLE  ...  FAILURE TO YIELD RIGHT OF WAY
# 1  SINGLE VEHICLE  ...                          OTHER
# 2  SINGLE VEHICLE  ...          IN ROADWAY IMPROPERLY
# 3           OTHER  ...            NO IMPROPER ACTIONS
# 4  SINGLE VEHICLE  ...            NO IMPROPER ACTIONS
#
#                 pedestrian_location pedestrian_obeyed_traffic_signal  \
# 0           ON ROADWAY AT CROSSWALK                   NO PED. SIGNAL
# 1                             OTHER                          Missing
# 2       ON ROADWAY NOT AT CROSSWALK                   NO PED. SIGNAL
# 3           ON ROADWAY AT CROSSWALK               OBEYED PED. SIGNAL
# 4  AT INTERSECTION MARKED CROSSWALK               OBEYED PED. SIGNAL
#
#   pedestrian_visibility at_fault           injury_severity safety_equipment  \
# 0         DARK CLOTHING      Yes  SUSPECTED SERIOUS INJURY             NONE
# 1        LIGHT CLOTHING      Yes    SUSPECTED MINOR INJURY          Missing
# 2        LIGHT CLOTHING       No    SUSPECTED MINOR INJURY             NONE
# 3        LIGHT CLOTHING       No        NO APPARENT INJURY          Missing
# 4               UNKNOWN       No    SUSPECTED MINOR INJURY             NONE
#
#       latitude     longitude                     location
# 0  39.13764511  -77.12946041  (39.13764511, -77.12946041)
# 1  39.09178359  -77.09882296  (39.09178359, -77.09882296)
# 2  39.02406091  -77.14761954  (39.02406091, -77.14761954)
# 3  39.13526333     -77.06976     (39.13526333, -77.06976)
# 4  39.17055765  -77.20888876  (39.17055765, -77.20888876)
#
# [5 rows x 29 columns]

# %%
num_rows, num_columns = sql_frame.shape
print("Number of rows:", num_rows)
print("Number of columns:", num_columns)
# Out:
# Number of rows: 5650
# Number of columns: 29

# %%
# Check where "Missing" values occur in each column
missing_mask = sql_frame.eq('Missing')

# Check which columns have at least one "Missing" value
columns_with_missing = missing_mask.any()

# Extract the column names where "Missing" values occur
columns_with_missing_values = columns_with_missing[columns_with_missing].index.tolist()

# Print the columns with "Missing" values
print("Columns with 'Missing' values:", columns_with_missing_values)
# Out:
# Columns with 'Missing' values: ['route_type', 'road_Name', 'cross_street_name', 'collision_type', 'weather', 'surface_condition', 'light', 'traffic_control', 'driver_substance_abuse', 'non_motorist_substance_abuse', 'pedestrian_movement', 'pedestrian_actions', 'pedestrian_location', 'pedestrian_obeyed_traffic_signal', 'pedestrian_visibility', 'at_fault', 'safety_equipment']

# %%
# Iterate through columns with missing values
for column in columns_with_missing_values:
    # Get unique values and their counts
    unique_values_counts = sql_frame[column].value_counts() 
    # Print column name
    print("Column:", column)
    # Print unique values and their counts
    print(unique_values_counts)
    print()
# Out:
# Column: route_type
# route_type
# County                  2006
# Maryland (State)        1646
# Missing                 1312
# Municipality             468
# US (State)               119
# Other Public Roadway      43
# Government                41
# Ramp                      10
# Interstate (State)         4
# Service Road               1
# Name: count, dtype: int64
#
# Column: road_Name
# road_Name
# Missing              1238
# GEORGIA AVE           304
# ROCKVILLE PIKE        141
# FREDERICK RD          115
# NEW HAMPSHIRE AVE     115
#                      ...
# PINE PL                 1
# HUNTMASTER RD           1
# BROOKDALE RD            1
# BOWMAN MILL RD          1
# CHELTON RD              1
# Name: count, Length: 953, dtype: int64
#
# Column: cross_street_name
# cross_street_name
# Missing                    1239
# GEORGIA AVE                  99
# FREDERICK RD                 56
# COLESVILLE RD                46
# RANDOLPH RD                  45
#                            ...
# COLLEGE VIEW DR               1
# CONNECTICUT AVE (AHEAD)       1
# E BRADLEY LA                  1
# DAMASCUS MANOR RD             1
# LUZERNE AVE                   1
# Name: count, Length: 1543, dtype: int64
#
# Column: collision_type
# collision_type
# OTHER                           2413
# SINGLE VEHICLE                  1780
# STRAIGHT MOVEMENT ANGLE          690
# Missing                          178
# SAME DIR REAR END                157
# HEAD ON LEFT TURN                147
# SAME DIRECTION SIDESWIPE          87
# SAME DIRECTION RIGHT TURN         46
# HEAD ON                           42
# SAME DIRECTION LEFT TURN          27
# ANGLE MEETS RIGHT TURN            22
# OPPOSITE DIRECTION SIDESWIPE      18
# ANGLE MEETS LEFT TURN             13
# UNKNOWN                           12
# SAME DIR REND LEFT TURN            7
# ANGLE MEETS LEFT HEAD ON           6
# SAME DIR REND RIGHT TURN           3
# OPPOSITE DIR BOTH LEFT TURN        2
# Name: count, dtype: int64
#
# Column: weather
# weather
# CLEAR           3949
# RAINING          601
# CLOUDY           523
# Missing          458
# UNKNOWN           32
# SNOW              29
# FOGGY             22
# OTHER             12
# WINTRY MIX        11
# SEVERE WINDS       7
# BLOWING SNOW       3
# SLEET              3
# Name: count, dtype: int64
#
# Column: surface_condition
# surface_condition
# DRY        3520
# Missing    1382
# WET         687
# UNKNOWN      25
# SNOW         16
# ICE          11
# OTHER         5
# SLUSH         4
# Name: count, dtype: int64
#
# Column: light
# light
# DAYLIGHT                    3604
# DARK LIGHTS ON              1455
# DARK NO LIGHTS               211
# DUSK                         127
# DAWN                         104
# DARK -- UNKNOWN LIGHTING      69
# Missing                       46
# UNKNOWN                       19
# OTHER                         15
# Name: count, dtype: int64
#
# Column: traffic_control
# traffic_control
# NO CONTROLS                2261
# TRAFFIC SIGNAL             1663
# Missing                     811
# STOP SIGN                   580
# OTHER                       167
# PERSON                       57
# YIELD SIGN                   37
# UNKNOWN                      24
# FLASHING TRAFFIC SIGNAL      24
# WARNING SIGN                 18
# SCHOOL ZONE SIGN DEVICE       6
# RAILWAY CROSSING DEVICE       2
# Name: count, dtype: int64
#
# Column: driver_substance_abuse
# driver_substance_abuse
# NONE DETECTED                                3776
# Missing                                      1082
# UNKNOWN                                       687
# ALCOHOL PRESENT                                47
# ALCOHOL CONTRIBUTED                            16
# NONE DETECTED, UNKNOWN                          9
# N/A, NONE DETECTED                              8
# ALCOHOL CONTRIBUTED, NONE DETECTED              4
# ALCOHOL PRESENT, NONE DETECTED                  4
# ILLEGAL DRUG PRESENT                            4
# MEDICATION PRESENT                              2
# ALCOHOL PRESENT, N/A                            2
# ALCOHOL CONTRIBUTED, N/A                        2
# ILLEGAL DRUG CONTRIBUTED                        2
# ALCOHOL PRESENT, UNKNOWN                        1
# COMBINED SUBSTANCE PRESENT                      1
# MEDICATION PRESENT, NONE DETECTED               1
# COMBINED SUBSTANCE PRESENT, NONE DETECTED       1
# OTHER                                           1
# Name: count, dtype: int64
#
# Column: non_motorist_substance_abuse
# non_motorist_substance_abuse
# NONE DETECTED                 4011
# Missing                       1203
# UNKNOWN                        229
# ALCOHOL PRESENT                151
# ALCOHOL CONTRIBUTED             40
# ILLEGAL DRUG PRESENT             6
# MEDICATION PRESENT               4
# ILLEGAL DRUG CONTRIBUTED         2
# COMBINATION CONTRIBUTED          2
# COMBINED SUBSTANCE PRESENT       1
# OTHER                            1
# Name: count, dtype: int64
#
# Column: pedestrian_movement
# pedestrian_movement
# Cross/Enter at Intersection        2522
# Other                               720
# Cross/Enter not at Intersection     677
# Walking/Riding w/Traffic            386
# Standing                            376
# Walking/Cycling on Sidewalk         254
# Missing                             156
# Walking/Riding against Traffic      113
# Unknown                             102
# Other Working                        93
# Getting off/on Vehicle               91
# Playing                              68
# Walking to/from school               53
# Push/Work on Vehicle                 24
# Approach/Leaving Schoolbus           12
# Hitchhiking                           3
# Name: count, dtype: int64
#
# Column: pedestrian_actions
# pedestrian_actions
# NO IMPROPER ACTIONS                                 2881
# UNKNOWN                                              462
# IN ROADWAY IMPROPERLY                                451
# DART DASH                                            429
# Missing                                              294
# OTHER                                                265
# FAILURE TO YIELD RIGHT OF WAY                        264
# INATTENTIVE                                          215
# FAILURE TO OBEY TRAFFIC SIGNS SIGNALS OR OFFICER     162
# NOT VISIBLE                                          118
# ENTERING EXITING PARKED STANDING VEHICLE              37
# WRONG WAY RIDING OR WALKING                           32
# DISABLED VEHICLE RELATED                              17
# IMPROPER PASSING                                      16
# IMPROPER TURN MERGE                                    7
# Name: count, dtype: int64
#
# Column: pedestrian_location
# pedestrian_location
# ON ROADWAY AT CROSSWALK             1502
# ON ROADWAY NOT AT CROSSWALK         1170
# OTHER                                976
# AT INTERSECTION MARKED CROSSWALK     664
# SIDEWALK                             388
# AT INTERSECTION BUT NO CROSSWALK     246
# Missing                              153
# SHOULDER                             143
# OUTSIDE RIGHT OF WAY                  65
# CURB                                  65
# INSIDE BUILDING                       63
# UNKNOWN                               62
# DRIVEWAY ACCESS MARKED CROSSWALK      51
# IN BIKEWAY                            43
# MEDIAN                                27
# MIDBLOCK MARKED CROSSWALK             19
# SHARED USE PATH OR TRAILS              9
# IN SCHOOL BUS ZONE                     3
# ISLAND                                 1
# Name: count, dtype: int64
#
# Column: pedestrian_obeyed_traffic_signal
# pedestrian_obeyed_traffic_signal
# NO PED. SIGNAL             2101
# Missing                    1666
# OBEYED PED. SIGNAL         1043
# DISOBEYED PED. SIGNAL       366
# UNKNOWN                     313
# OTHER                       156
# PED. SIGNAL MALFUNCTION       5
# Name: count, dtype: int64
#
# Column: pedestrian_visibility
# pedestrian_visibility
# MIXED CLOTHING               2149
# DARK CLOTHING                1427
# LIGHT CLOTHING                923
# Missing                       542
# UNKNOWN                       339
# REFLECTIVE MATERIAL           164
# OTHER                          68
# HEAD LIGHT AND REFLECTORS      22
# HEAD LIGHT                     10
# REAR REFLECTOR                  6
# Name: count, dtype: int64
#
# Column: at_fault
# at_fault
# No         3414
# Yes        1509
# Unknown     440
# Missing     287
# Name: count, dtype: int64
#
# Column: safety_equipment
# safety_equipment
# NONE                   2862
# Missing                1908
# MC/BIKE HELMET          615
# UNKNOWN                 125
# REFLECTIVE CLOTHING     104
# OTHER                    22
# LIGHTING                 13
# PROTECTIVE PADS           1
# Name: count, dtype: int64

# %%
# road_grade
sql_frame['route_type'] = sql_frame['route_type'].replace('Missing', sql_frame['route_type'].mode()[0])
sql_frame['driver_substance_abuse'] = sql_frame['driver_substance_abuse'].replace('Missing', sql_frame['driver_substance_abuse'].mode()[0])

# %%
sql_frame.head()
# Out:
#   report_number local_case_number               agency_name  \
# 0   MCP2563001L         230017107  Montgomery County Police
# 1   MCP2771002B         230034003  Montgomery County Police
# 2   MCP2861005Z         230034963  Montgomery County Police
# 3   MCP3299002R         230034733  Montgomery County Police
# 4   MCP3360000L         230046354  Montgomery County Police
#
#         acrs_report_type         crash_date_time        route_type  \
# 0           Injury Crash  10/04/2023 04:21:00 pm  Maryland (State)
# 1           Injury Crash  07/17/2023 12:53:00 PM            County
# 2           Injury Crash  07/22/2023 06:58:00 PM            County
# 3  Property Damage Crash  07/21/2023 11:52:00 AM  Maryland (State)
# 4           Injury Crash  07/25/2023 10:12:00 AM            County
#
#            road_Name        cross_street_name related_non_motorist  \
# 0  MUNCASTER MILL RD  STRUC #15015 ROCK CREEK           PEDESTRIAN
# 1           PECAN DR             BUTTERNUT DR                OTHER
# 2            Missing                  Missing           PEDESTRIAN
# 3        GEORGIA AVE         OLD BALTIMORE RD           PEDESTRIAN
# 4    WATKINS MILL RD              STEDWICK RD            BICYCLIST
#
#    collision_type  ...             pedestrian_actions  \
# 0  SINGLE VEHICLE  ...  FAILURE TO YIELD RIGHT OF WAY
# 1  SINGLE VEHICLE  ...                          OTHER
# 2  SINGLE VEHICLE  ...          IN ROADWAY IMPROPERLY
# 3           OTHER  ...            NO IMPROPER ACTIONS
# 4  SINGLE VEHICLE  ...            NO IMPROPER ACTIONS
#
#                 pedestrian_location pedestrian_obeyed_traffic_signal  \
# 0           ON ROADWAY AT CROSSWALK                   NO PED. SIGNAL
# 1                             OTHER                          Missing
# 2       ON ROADWAY NOT AT CROSSWALK                   NO PED. SIGNAL
# 3           ON ROADWAY AT CROSSWALK               OBEYED PED. SIGNAL
# 4  AT INTERSECTION MARKED CROSSWALK               OBEYED PED. SIGNAL
#
#   pedestrian_visibility at_fault           injury_severity safety_equipment  \
# 0         DARK CLOTHING      Yes  SUSPECTED SERIOUS INJURY             NONE
# 1        LIGHT CLOTHING      Yes    SUSPECTED MINOR INJURY          Missing
# 2        LIGHT CLOTHING       No    SUSPECTED MINOR INJURY             NONE
# 3        LIGHT CLOTHING       No        NO APPARENT INJURY          Missing
# 4               UNKNOWN       No    SUSPECTED MINOR INJURY             NONE
#
#       latitude     longitude                     location
# 0  39.13764511  -77.12946041  (39.13764511, -77.12946041)
# 1  39.09178359  -77.09882296  (39.09178359, -77.09882296)
# 2  39.02406091  -77.14761954  (39.02406091, -77.14761954)
# 3  39.13526333     -77.06976     (39.13526333, -77.06976)
# 4  39.17055765  -77.20888876  (39.17055765, -77.20888876)
#
# [5 rows x 29 columns]

# %%
# Check where "Missing" values occur in each column
missing_mask = sql_frame.eq('Missing')

# Check which columns have at least one "Missing" value
columns_with_missing = missing_mask.any()

# Extract the column names where "Missing" values occur
columns_with_missing_values = columns_with_missing[columns_with_missing].index.tolist()

# Print the columns with "Missing" values
print("Columns with 'Missing' values:", columns_with_missing_values)
# Out:
# Columns with 'Missing' values: ['road_Name', 'cross_street_name', 'collision_type', 'weather', 'surface_condition', 'light', 'traffic_control', 'non_motorist_substance_abuse', 'pedestrian_movement', 'pedestrian_actions', 'pedestrian_location', 'pedestrian_obeyed_traffic_signal', 'pedestrian_visibility', 'at_fault', 'safety_equipment']

# %%
# Iterate through columns with missing values
for column in columns_with_missing_values:
    # Get unique values and their counts
    unique_values_counts = sql_frame[column].value_counts() 
    # Print column name
    print("Column:", column)
    # Print unique values and their counts
    print(unique_values_counts)
    print()
# Out:
# Column: road_Name
# road_Name
# Missing              1238
# GEORGIA AVE           304
# ROCKVILLE PIKE        141
# FREDERICK RD          115
# NEW HAMPSHIRE AVE     115
#                      ...
# PINE PL                 1
# HUNTMASTER RD           1
# BROOKDALE RD            1
# BOWMAN MILL RD          1
# CHELTON RD              1
# Name: count, Length: 953, dtype: int64
#
# Column: cross_street_name
# cross_street_name
# Missing                    1239
# GEORGIA AVE                  99
# FREDERICK RD                 56
# COLESVILLE RD                46
# RANDOLPH RD                  45
#                            ...
# COLLEGE VIEW DR               1
# CONNECTICUT AVE (AHEAD)       1
# E BRADLEY LA                  1
# DAMASCUS MANOR RD             1
# LUZERNE AVE                   1
# Name: count, Length: 1543, dtype: int64
#
# Column: collision_type
# collision_type
# OTHER                           2413
# SINGLE VEHICLE                  1780
# STRAIGHT MOVEMENT ANGLE          690
# Missing                          178
# SAME DIR REAR END                157
# HEAD ON LEFT TURN                147
# SAME DIRECTION SIDESWIPE          87
# SAME DIRECTION RIGHT TURN         46
# HEAD ON                           42
# SAME DIRECTION LEFT TURN          27
# ANGLE MEETS RIGHT TURN            22
# OPPOSITE DIRECTION SIDESWIPE      18
# ANGLE MEETS LEFT TURN             13
# UNKNOWN                           12
# SAME DIR REND LEFT TURN            7
# ANGLE MEETS LEFT HEAD ON           6
# SAME DIR REND RIGHT TURN           3
# OPPOSITE DIR BOTH LEFT TURN        2
# Name: count, dtype: int64
#
# Column: weather
# weather
# CLEAR           3949
# RAINING          601
# CLOUDY           523
# Missing          458
# UNKNOWN           32
# SNOW              29
# FOGGY             22
# OTHER             12
# WINTRY MIX        11
# SEVERE WINDS       7
# BLOWING SNOW       3
# SLEET              3
# Name: count, dtype: int64
#
# Column: surface_condition
# surface_condition
# DRY        3520
# Missing    1382
# WET         687
# UNKNOWN      25
# SNOW         16
# ICE          11
# OTHER         5
# SLUSH         4
# Name: count, dtype: int64
#
# Column: light
# light
# DAYLIGHT                    3604
# DARK LIGHTS ON              1455
# DARK NO LIGHTS               211
# DUSK                         127
# DAWN                         104
# DARK -- UNKNOWN LIGHTING      69
# Missing                       46
# UNKNOWN                       19
# OTHER                         15
# Name: count, dtype: int64
#
# Column: traffic_control
# traffic_control
# NO CONTROLS                2261
# TRAFFIC SIGNAL             1663
# Missing                     811
# STOP SIGN                   580
# OTHER                       167
# PERSON                       57
# YIELD SIGN                   37
# UNKNOWN                      24
# FLASHING TRAFFIC SIGNAL      24
# WARNING SIGN                 18
# SCHOOL ZONE SIGN DEVICE       6
# RAILWAY CROSSING DEVICE       2
# Name: count, dtype: int64
#
# Column: non_motorist_substance_abuse
# non_motorist_substance_abuse
# NONE DETECTED                 4011
# Missing                       1203
# UNKNOWN                        229
# ALCOHOL PRESENT                151
# ALCOHOL CONTRIBUTED             40
# ILLEGAL DRUG PRESENT             6
# MEDICATION PRESENT               4
# ILLEGAL DRUG CONTRIBUTED         2
# COMBINATION CONTRIBUTED          2
# COMBINED SUBSTANCE PRESENT       1
# OTHER                            1
# Name: count, dtype: int64
#
# Column: pedestrian_movement
# pedestrian_movement
# Cross/Enter at Intersection        2522
# Other                               720
# Cross/Enter not at Intersection     677
# Walking/Riding w/Traffic            386
# Standing                            376
# Walking/Cycling on Sidewalk         254
# Missing                             156
# Walking/Riding against Traffic      113
# Unknown                             102
# Other Working                        93
# Getting off/on Vehicle               91
# Playing                              68
# Walking to/from school               53
# Push/Work on Vehicle                 24
# Approach/Leaving Schoolbus           12
# Hitchhiking                           3
# Name: count, dtype: int64
#
# Column: pedestrian_actions
# pedestrian_actions
# NO IMPROPER ACTIONS                                 2881
# UNKNOWN                                              462
# IN ROADWAY IMPROPERLY                                451
# DART DASH                                            429
# Missing                                              294
# OTHER                                                265
# FAILURE TO YIELD RIGHT OF WAY                        264
# INATTENTIVE                                          215
# FAILURE TO OBEY TRAFFIC SIGNS SIGNALS OR OFFICER     162
# NOT VISIBLE                                          118
# ENTERING EXITING PARKED STANDING VEHICLE              37
# WRONG WAY RIDING OR WALKING                           32
# DISABLED VEHICLE RELATED                              17
# IMPROPER PASSING                                      16
# IMPROPER TURN MERGE                                    7
# Name: count, dtype: int64
#
# Column: pedestrian_location
# pedestrian_location
# ON ROADWAY AT CROSSWALK             1502
# ON ROADWAY NOT AT CROSSWALK         1170
# OTHER                                976
# AT INTERSECTION MARKED CROSSWALK     664
# SIDEWALK                             388
# AT INTERSECTION BUT NO CROSSWALK     246
# Missing                              153
# SHOULDER                             143
# OUTSIDE RIGHT OF WAY                  65
# CURB                                  65
# INSIDE BUILDING                       63
# UNKNOWN                               62
# DRIVEWAY ACCESS MARKED CROSSWALK      51
# IN BIKEWAY                            43
# MEDIAN                                27
# MIDBLOCK MARKED CROSSWALK             19
# SHARED USE PATH OR TRAILS              9
# IN SCHOOL BUS ZONE                     3
# ISLAND                                 1
# Name: count, dtype: int64
#
# Column: pedestrian_obeyed_traffic_signal
# pedestrian_obeyed_traffic_signal
# NO PED. SIGNAL             2101
# Missing                    1666
# OBEYED PED. SIGNAL         1043
# DISOBEYED PED. SIGNAL       366
# UNKNOWN                     313
# OTHER                       156
# PED. SIGNAL MALFUNCTION       5
# Name: count, dtype: int64
#
# Column: pedestrian_visibility
# pedestrian_visibility
# MIXED CLOTHING               2149
# DARK CLOTHING                1427
# LIGHT CLOTHING                923
# Missing                       542
# UNKNOWN                       339
# REFLECTIVE MATERIAL           164
# OTHER                          68
# HEAD LIGHT AND REFLECTORS      22
# HEAD LIGHT                     10
# REAR REFLECTOR                  6
# Name: count, dtype: int64
#
# Column: at_fault
# at_fault
# No         3414
# Yes        1509
# Unknown     440
# Missing     287
# Name: count, dtype: int64
#
# Column: safety_equipment
# safety_equipment
# NONE                   2862
# Missing                1908
# MC/BIKE HELMET          615
# UNKNOWN                 125
# REFLECTIVE CLOTHING     104
# OTHER                    22
# LIGHTING                 13
# PROTECTIVE PADS           1
# Name: count, dtype: int64

# %%
column_list = sql_frame.columns.tolist()
print(column_list)
# Out:
# ['report_number', 'local_case_number', 'agency_name', 'acrs_report_type', 'crash_date_time', 'route_type', 'road_Name', 'cross_street_name', 'related_non_motorist', 'collision_type', 'weather', 'surface_condition', 'light', 'traffic_control', 'driver_substance_abuse', 'non_motorist_substance_abuse', 'person_id', 'pedestrian_type', 'pedestrian_movement', 'pedestrian_actions', 'pedestrian_location', 'pedestrian_obeyed_traffic_signal', 'pedestrian_visibility', 'at_fault', 'injury_severity', 'safety_equipment', 'latitude', 'longitude', 'location']

# %%
# Count the number of columns containing 'Missing'
missing_columns_count = 0
missing_columns = []

for column in sql_frame.columns:
    if (sql_frame[column] == 'Missing').any():
        missing_count = (sql_frame[column] == 'Missing').sum()
        if missing_count > 0:
            missing_columns_count += 1
            missing_columns.append((column, missing_count))

print("Total number of columns with 'Missing' values:", missing_columns_count)
print("Columns with count of 'Missing' values:")
for column_name, count in missing_columns:
    print(f"{column_name}: {count}")
# Out:
# Total number of columns with 'Missing' values: 15
# Columns with count of 'Missing' values:
# road_Name: 1238
# cross_street_name: 1239
# collision_type: 178
# weather: 458
# surface_condition: 1382
# light: 46
# traffic_control: 811
# non_motorist_substance_abuse: 1203
# pedestrian_movement: 156
# pedestrian_actions: 294
# pedestrian_location: 153
# pedestrian_obeyed_traffic_signal: 1666
# pedestrian_visibility: 542
# at_fault: 287
# safety_equipment: 1908

# %%
# Define threshold for dropping columns
threshold = 1800

# Filter columns with count of 'Missing' values greater than threshold
columns_to_drop = [column for column, count in missing_columns if count > threshold]

# Drop columns from DataFrame
sql_frame.drop(columns=columns_to_drop, inplace=True)

# Print the remaining columns
print("Remaining columns after dropping:")
print(sql_frame.columns.tolist())
# Out:
# Remaining columns after dropping:
# ['report_number', 'local_case_number', 'agency_name', 'acrs_report_type', 'crash_date_time', 'route_type', 'road_Name', 'cross_street_name', 'related_non_motorist', 'collision_type', 'weather', 'surface_condition', 'light', 'traffic_control', 'driver_substance_abuse', 'non_motorist_substance_abuse', 'person_id', 'pedestrian_type', 'pedestrian_movement', 'pedestrian_actions', 'pedestrian_location', 'pedestrian_obeyed_traffic_signal', 'pedestrian_visibility', 'at_fault', 'injury_severity', 'latitude', 'longitude', 'location']

# %%
sql_frame.head()
# Out:
#   report_number local_case_number               agency_name  \
# 0   MCP2563001L         230017107  Montgomery County Police
# 1   MCP2771002B         230034003  Montgomery County Police
# 2   MCP2861005Z         230034963  Montgomery County Police
# 3   MCP3299002R         230034733  Montgomery County Police
# 4   MCP3360000L         230046354  Montgomery County Police
#
#         acrs_report_type         crash_date_time        route_type  \
# 0           Injury Crash  10/04/2023 04:21:00 pm  Maryland (State)
# 1           Injury Crash  07/17/2023 12:53:00 PM            County
# 2           Injury Crash  07/22/2023 06:58:00 PM            County
# 3  Property Damage Crash  07/21/2023 11:52:00 AM  Maryland (State)
# 4           Injury Crash  07/25/2023 10:12:00 AM            County
#
#            road_Name        cross_street_name related_non_motorist  \
# 0  MUNCASTER MILL RD  STRUC #15015 ROCK CREEK           PEDESTRIAN
# 1           PECAN DR             BUTTERNUT DR                OTHER
# 2            Missing                  Missing           PEDESTRIAN
# 3        GEORGIA AVE         OLD BALTIMORE RD           PEDESTRIAN
# 4    WATKINS MILL RD              STEDWICK RD            BICYCLIST
#
#    collision_type  ...              pedestrian_movement  \
# 0  SINGLE VEHICLE  ...  Cross/Enter not at Intersection
# 1  SINGLE VEHICLE  ...           Getting off/on Vehicle
# 2  SINGLE VEHICLE  ...                            Other
# 3           OTHER  ...      Cross/Enter at Intersection
# 4  SINGLE VEHICLE  ...                          Missing
#
#               pedestrian_actions               pedestrian_location  \
# 0  FAILURE TO YIELD RIGHT OF WAY           ON ROADWAY AT CROSSWALK
# 1                          OTHER                             OTHER
# 2          IN ROADWAY IMPROPERLY       ON ROADWAY NOT AT CROSSWALK
# 3            NO IMPROPER ACTIONS           ON ROADWAY AT CROSSWALK
# 4            NO IMPROPER ACTIONS  AT INTERSECTION MARKED CROSSWALK
#
#   pedestrian_obeyed_traffic_signal pedestrian_visibility at_fault  \
# 0                   NO PED. SIGNAL         DARK CLOTHING      Yes
# 1                          Missing        LIGHT CLOTHING      Yes
# 2                   NO PED. SIGNAL        LIGHT CLOTHING       No
# 3               OBEYED PED. SIGNAL        LIGHT CLOTHING       No
# 4               OBEYED PED. SIGNAL               UNKNOWN       No
#
#             injury_severity     latitude     longitude  \
# 0  SUSPECTED SERIOUS INJURY  39.13764511  -77.12946041
# 1    SUSPECTED MINOR INJURY  39.09178359  -77.09882296
# 2    SUSPECTED MINOR INJURY  39.02406091  -77.14761954
# 3        NO APPARENT INJURY  39.13526333     -77.06976
# 4    SUSPECTED MINOR INJURY  39.17055765  -77.20888876
#
#                       location
# 0  (39.13764511, -77.12946041)
# 1  (39.09178359, -77.09882296)
# 2  (39.02406091, -77.14761954)
# 3     (39.13526333, -77.06976)
# 4  (39.17055765, -77.20888876)
#
# [5 rows x 28 columns]

# %%
final_transformed_frame=sql_frame

# %%
# Assuming final_transformed_frame is your DataFrame and filename is the name of the output file
filename = "non_motorists_APi.json"
final_transformed_frame.to_json(filename, orient='records')

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://x23187956:waleed123@montgomerycluster.tzxvtsd.mongodb.net/?retryWrites=true&w=majority&appName=montgomerycluster"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

try:
    #client.admin.command('ping')
    client.montgomery.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
try:
    server_status = client.montgomery.command('serverStatus')
    print("Server is up and running.")
except Exception as e:
    print("Error:", e)
# Out:
# Server is up and running.

# %%
databases = client.list_database_names()
print("Databases:")
for db_obj in databases:
    print(db_obj)
# Out:
# Databases:
# montgomery
# admin
# local

# %%
database_name = "montgomery"
collections = client[database_name].list_collection_names()
print("\nCollections in", database_name, ":")
for col in collections:
    print(col)
# Out:
# Collections in montgomery :
# non_motorists
# non_motorists_dataset

# %%
# Access the montgomery database (or create it if it doesn't exist)
db = client["montgomery"]
# Create a collection named "incidents"
collection = db["non_motorists_dataset"]
collection
# Out:
# Collection(Database(MongoClient(host=['ac-splqn9y-shard-00-02.tzxvtsd.mongodb.net:27017', 'ac-splqn9y-shard-00-01.tzxvtsd.mongodb.net:27017', 'ac-splqn9y-shard-00-00.tzxvtsd.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='montgomerycluster', authsource='admin', replicaset='atlas-t83v95-shard-0', tls=True, server_api=<pymongo.server_api.ServerApi object at 0x00000253F836AD10>), 'montgomery'), 'non_motorists_dataset')

# %%
# Get the total number of documents in the collection
total_records = collection.count_documents({})
print("Total number of records in the collection:", total_records)
# Out:
# Total number of records in the collection: 5650

# %%
# Select database and collection
db = client['montgomery']
collection_name = 'non_motorists_dataset'

# %%
import json
# Load JSON file
filename = "non_motorists_API.json"
with open(filename, 'r') as file:
    data = json.load(file)

# %%
# Insert documents into collection
collection = db[collection_name]
collection.insert_many(data)
print("JSON data successfully loaded into MongoDB collection 'non_motorists' in database 'montgomery'.")
total_records = collection.count_documents({})
print("Total number of records in the collection:", total_records)
# Out:
# JSON data successfully loaded into MongoDB collection 'non_motorists' in database 'montgomery'.
# Total number of records in the collection: 11300

# %%
collection_data = collection.find({})

# %%
non_motorists_mongo_df = pd.DataFrame(collection_data)

# %%
non_motorists_mongo_df
# Out:
#                             _id report_number local_case_number  \
# 0      662a22d296360083da4c9eaa   MCP2563001L         230017107
# 1      662a22d296360083da4c9eab   MCP2771002B         230034003
# 2      662a22d296360083da4c9eac   MCP2861005Z         230034963
# 3      662a22d296360083da4c9ead   MCP3299002R         230034733
# 4      662a22d296360083da4c9eae   MCP3360000L         230046354
# ...                         ...           ...               ...
# 11295  663103599f725c4ab1661e6b   MCP1151006L         170515099
# 11296  663103599f725c4ab1661e6c   MCP3243000C         200032846
# 11297  663103599f725c4ab1661e6d   MCP15950022         220027156
# 11298  663103599f725c4ab1661e6e    EJ7857001Q         170533688
# 11299  663103599f725c4ab1661e6f   MCP2964001H          16021317
#
#                      agency_name       acrs_report_type  \
# 0       Montgomery County Police           Injury Crash
# 1       Montgomery County Police           Injury Crash
# 2       Montgomery County Police           Injury Crash
# 3       Montgomery County Police  Property Damage Crash
# 4       Montgomery County Police           Injury Crash
# ...                          ...                    ...
# 11295   Montgomery County Police           Injury Crash
# 11296   Montgomery County Police           Injury Crash
# 11297   Montgomery County Police           Injury Crash
# 11298  Gaithersburg Police Depar           Injury Crash
# 11299   Montgomery County Police           Injury Crash
#
#               crash_date_time        route_type          road_Name  \
# 0      10/04/2023 04:21:00 pm  Maryland (State)  MUNCASTER MILL RD
# 1      07/17/2023 12:53:00 PM            County           PECAN DR
# 2      07/22/2023 06:58:00 PM            County            Missing
# 3      07/21/2023 11:52:00 AM  Maryland (State)        GEORGIA AVE
# 4      07/25/2023 10:12:00 AM            County    WATKINS MILL RD
# ...                       ...               ...                ...
# 11295  06/22/2017 07:41:00 AM            County            Missing
# 11296  08/22/2020 05:17:00 PM            County       ROCKLEDGE DR
# 11297  08/28/2022 03:07:00 AM  Maryland (State)        GEORGIA AVE
# 11298  09/28/2017 06:24:00 PM            County            Missing
# 11299  04/30/2016 04:08:00 PM  Maryland (State)       FREDERICK RD
#
#              cross_street_name related_non_motorist  ...  \
# 0      STRUC #15015 ROCK CREEK           PEDESTRIAN  ...
# 1                 BUTTERNUT DR                OTHER  ...
# 2                      Missing           PEDESTRIAN  ...
# 3             OLD BALTIMORE RD           PEDESTRIAN  ...
# 4                  STEDWICK RD            BICYCLIST  ...
# ...                        ...                  ...  ...
# 11295                  Missing           PEDESTRIAN  ...
# 11296           ROCK SPRING DR            BICYCLIST  ...
# 11297              ENNALLS AVE           PEDESTRIAN  ...
# 11298                  Missing                OTHER  ...
# 11299           MIDDLEBROOK RD            BICYCLIST  ...
#
#                    pedestrian_movement  \
# 0      Cross/Enter not at Intersection
# 1               Getting off/on Vehicle
# 2                                Other
# 3          Cross/Enter at Intersection
# 4                              Missing
# ...                                ...
# 11295                            Other
# 11296      Cross/Enter at Intersection
# 11297  Cross/Enter not at Intersection
# 11298                          Playing
# 11299      Cross/Enter at Intersection
#
#                                      pedestrian_actions  \
# 0                         FAILURE TO YIELD RIGHT OF WAY
# 1                                                 OTHER
# 2                                 IN ROADWAY IMPROPERLY
# 3                                   NO IMPROPER ACTIONS
# 4                                   NO IMPROPER ACTIONS
# ...                                                 ...
# 11295                               NO IMPROPER ACTIONS
# 11296  FAILURE TO OBEY TRAFFIC SIGNS SIGNALS OR OFFICER
# 11297                               NO IMPROPER ACTIONS
# 11298                             IN ROADWAY IMPROPERLY
# 11299                                       INATTENTIVE
#
#                     pedestrian_location pedestrian_obeyed_traffic_signal  \
# 0               ON ROADWAY AT CROSSWALK                   NO PED. SIGNAL
# 1                                 OTHER                          Missing
# 2           ON ROADWAY NOT AT CROSSWALK                   NO PED. SIGNAL
# 3               ON ROADWAY AT CROSSWALK               OBEYED PED. SIGNAL
# 4      AT INTERSECTION MARKED CROSSWALK               OBEYED PED. SIGNAL
# ...                                 ...                              ...
# 11295                             OTHER                          Missing
# 11296           ON ROADWAY AT CROSSWALK            DISOBEYED PED. SIGNAL
# 11297       ON ROADWAY NOT AT CROSSWALK                   NO PED. SIGNAL
# 11298                           Missing                   NO PED. SIGNAL
# 11299           ON ROADWAY AT CROSSWALK                   NO PED. SIGNAL
#
#       pedestrian_visibility at_fault           injury_severity     latitude  \
# 0             DARK CLOTHING      Yes  SUSPECTED SERIOUS INJURY          NaN
# 1            LIGHT CLOTHING      Yes    SUSPECTED MINOR INJURY          NaN
# 2            LIGHT CLOTHING       No    SUSPECTED MINOR INJURY          NaN
# 3            LIGHT CLOTHING       No        NO APPARENT INJURY          NaN
# 4                   UNKNOWN       No    SUSPECTED MINOR INJURY          NaN
# ...                     ...      ...                       ...          ...
# 11295        MIXED CLOTHING       No           POSSIBLE INJURY    39.182173
# 11296        LIGHT CLOTHING      Yes    SUSPECTED MINOR INJURY  39.02691291
# 11297         DARK CLOTHING      Yes           POSSIBLE INJURY   39.0393508
# 11298         DARK CLOTHING      Yes    SUSPECTED MINOR INJURY  39.14680833
# 11299        MIXED CLOTHING      Yes    SUSPECTED MINOR INJURY  39.18076775
#
#           longitude                     location
# 0               NaN                          NaN
# 1               NaN                          NaN
# 2               NaN                          NaN
# 3               NaN                          NaN
# 4               NaN                          NaN
# ...             ...                          ...
# 11295    -77.261231      (39.182173, -77.261231)
# 11296  -77.13229168  (39.02691291, -77.13229168)
# 11297    -77.054306     (39.0393508, -77.054306)
# 11298    -77.192475    (39.14680833, -77.192475)
# 11299  -77.23862886  (39.18076775, -77.23862886)
#
# [11300 rows x 29 columns]

# %%
# Function to plot colorful bar plot for Pedestrian Type
def plot_pedestrian_type():
    counts = data['pedestrian_type'].value_counts()
    colors = plt.cm.tab10(np.linspace(0, 1, len(counts)))
    plt.figure(figsize=(10, 5))
    counts.plot(kind='bar', color=colors)
    plt.title('Colorful Bar Plot of Pedestrian Type')
    plt.xlabel('Pedestrian Type')
    plt.ylabel('Frequency')
    plt.xticks(rotation=45, ha='right')
    plt.show()
# Function to plot colorful bar plot for Pedestrian Movement
def plot_pedestrian_movement():
    counts = data['pedestrian_movement'].value_counts()
    colors = plt.cm.tab10(np.linspace(0, 1, len(counts)))
    plt.figure(figsize=(10, 5))
    counts.plot(kind='bar', color=colors)
    plt.title('Colorful Bar Plot of Pedestrian Movement')
    plt.xlabel('Pedestrian Movement')
    plt.ylabel('Frequency')
    plt.xticks(rotation=45, ha='right')
    plt.show()

# Function to plot colorful bar plot for Pedestrian Actions
def plot_pedestrian_actions():
    counts = data['pedestrian_actions'].value_counts()
    colors = plt.cm.tab10(np.linspace(0, 1, len(counts)))
    plt.figure(figsize=(10, 5))
    counts.plot(kind='bar', color=colors)
    plt.title('Colorful Bar Plot of Pedestrian Actions')
    plt.xlabel('Pedestrian Actions')
    plt.ylabel('Frequency')
    plt.xticks(rotation=45, ha='right')
    plt.show()

# Function to plot colorful bar plot for Pedestrian Location
def plot_pedestrian_location():
    counts = data['pedestrian_location'].value_counts()
    colors = plt.cm.tab10(np.linspace(0, 1, len(counts)))
    plt.figure(figsize=(10, 5))
    counts.plot(kind='bar', color=colors)
    plt.title('Colorful Bar Plot of Pedestrian Location')
    plt.xlabel('Pedestrian Location')
    plt.ylabel('Frequency')
    plt.xticks(rotation=45, ha='right')
    plt.show()

# Function to plot colorful bar plot for Pedestrian Visibility
def plot_pedestrian_visibility():
    counts = data['pedestrian_visibility'].value_counts()
    colors = plt.cm.tab10(np.linspace(0, 1, len(counts)))
    plt.figure(figsize=(10, 5))
    counts.plot(kind='bar', color=colors)
    plt.title('Colorful Bar Plot of Pedestrian Visibility')
    plt.xlabel('Pedestrian Visibility')
    plt.ylabel('Frequency')
    plt.xticks(rotation=45, ha='right')
    plt.show()


# Plot colorful bar plots for each column
plot_pedestrian_type()
plot_pedestrian_movement()
plot_pedestrian_actions()
plot_pedestrian_location()
plot_pedestrian_visibility()

# %%
# Calculate counts for each pedestrian movement
pedestrian_movement_counts = data['pedestrian_movement'].value_counts()
# Plot a pie chart
plt.figure(figsize=(8, 8))
pedestrian_movement_counts.plot(kind='pie', autopct='%1.1f%%', colors = ['lime', 'pink', 'skyblue','magenta'])
plt.legend(bbox_to_anchor=(2, 0.5), loc="center left")
plt.title('Pedestrian Movement Distribution')
plt.ylabel('')
plt.show()

# %%
# Calculate counts for each pedestrian obeyed traffic signal
pedestrian_traffic_signal_counts = data['pedestrian_obeyed_traffic_signal'].value_counts()

# Plot a pie chart
plt.figure(figsize=(8, 8))
pedestrian_traffic_signal_counts.plot(kind='pie', autopct='%1.1f%%', colors=['skyblue', 'orange', 'green', 'red'])
plt.legend(bbox_to_anchor=(2, 0.5), loc="center left")
plt.title('Pedestrian Obeyed Traffic Signal Distribution')
plt.ylabel('')
plt.show()

# %%
# Calculate counts for each pedestrian type
pedestrian_type_counts = data['pedestrian_type'].value_counts()
# Plot a pie chart
plt.figure(figsize=(8, 8))
pedestrian_type_counts.plot(kind='pie', autopct='%1.1f%%', colors = [ 'blue', 'purple', 'cyan', 'magenta'])
plt.legend(bbox_to_anchor=(2, 0.5), loc="center left")
plt.title('Pedestrian Type Distribution')
plt.ylabel('')
plt.show()

# %%
# Calculate counts for each pedestrian visibility
pedestrian_visibility_counts = data['pedestrian_visibility'].value_counts()

# Plot a pie chart
plt.figure(figsize=(8, 8))
pedestrian_visibility_counts.plot(kind='pie', autopct='%1.1f%%', colors = ['red', 'orange', 'yellow', 'green']
)
plt.legend(bbox_to_anchor=(2, 0.5), loc="center left")
plt.title('Pedestrian Visibility Distribution')
plt.ylabel('')
plt.show()
