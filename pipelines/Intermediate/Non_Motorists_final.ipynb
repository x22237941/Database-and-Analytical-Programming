# %% [markdown]
# # Import Required Librariers:

# %%
import numpy as np
import pandas as pd
import matplotlib as mp
import matplotlib.pyplot as plt
import seaborn as sns
import csv
import mysql.connector as mysql
from sqlalchemy import create_engine

# %% [markdown]
# # Store Data into a variable using the built in CSV.Reader Function:

# %%
data=pd.read_csv("Non-Motorists_Data_20240404.csv")

# %% [markdown]
# ### Establishing MySQL database connection

# %%
def connect_to_mysql():
    try:
        # MySQL database connection parameters
        host = 'localhost'
        user = 'root'
        password = 'waleed123'
        database = 'montgomery'

        # Establish connection
        connection = mysql.connect(
            host=host,
            user=user,
            password=password,
            database=database
        )

        if connection.is_connected():
            print("Connected to MySQL database")
            return connection
    except mysql.connector.Error as e:
        print("Error connecting to MySQL database:", e)

# %%
conn = connect_to_mysql()
conn
# Out:
# Connected to MySQL database

# %% [markdown]
# ### DDL & DML Queries - Relational DB Reading & Writing Operations

# %%
create_query='''CREATE TABLE non_motorists_finalss (
                report_number TEXT,
                local_case_number TEXT,
                agency_name TEXT,
                acrs_report_type TEXT,
                crash_date_time TEXT,
                route_type TEXT,
                road_Name TEXT,
                cross_street_type TEXT,
                cross_street_name TEXT,
                off_road_description TEXT,
                municipality TEXT,
                related_non_motorist TEXT,
                collision_type TEXT,
                weather TEXT,
                surface_condition TEXT,
                light TEXT,
                traffic_control TEXT,
                driver_substance_abuse TEXT,
                non_motorist_substance_abuse TEXT,
                person_id TEXT,
                pedestrian_type TEXT,
                pedestrian_movement TEXT,
                pedestrian_actions TEXT,
                pedestrian_location TEXT,
                pedestrian_obeyed_traffic_signal TEXT,
                pedestrian_visibility TEXT,
                at_fault TEXT,
                injury_severity TEXT,
                safety_equipment TEXT,
                latitude TEXT,
                longitude TEXT,
                location TEXT
                )'''

# %%
show_table="show tables"

# %%
insert_data='''INSERT INTO non_motorists_finalss (report_number,local_case_number,agency_name,acrs_report_type,crash_date_time,route_type, road_Name,cross_street_type,cross_street_name,off_road_description,municipality,related_non_motorist,collision_type,weather,surface_condition,light,traffic_control,driver_substance_abuse,non_motorist_substance_abuse,person_id,pedestrian_type,pedestrian_movement,pedestrian_actions,pedestrian_location,pedestrian_obeyed_traffic_signal,pedestrian_visibility,at_fault,injury_severity,safety_equipment,latitude,longitude,location) VALUES ( %s,%s,%s,%s,%s,%s,%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s,
# %s, %s, %s, %s, %s, %s, %s, %s)'''''

# %%
drop_columns='''ALTER TABLE non_motorists_finalss
DROP COLUMN Latitude,
DROP COLUMN Longitude,
DROP COLUMN Location'''

# %%
select_query="select * from non_motorists_finalss"

# %% [markdown]
# ### Establishing a cursor

# %%
cursor = conn.cursor()

# %%
cursor.execute(show_table) # gives all the tables in the database
tables = cursor.fetchall()
# Print table names
for table in tables:
    print(table[0])
# Out:
# non_motorists
# non_motorists_1
# non_motorists_2
# non_motorists_3
# non_motorists_4
# non_motorists_5
# non_motorists_6
# non_motorists_final
# non_motorists_final_table
# non_motorists_final_tables
# non_motorists_finals

# %%
cursor.execute(create_query) # executing/creating a table
conn.commit() # Commit the transaction

# %%
cursor.execute(show_table) # gives all the tables in the database
tables = cursor.fetchall()
# Print table names
for table in tables:
    print(table[0])
# Out:
# non_motorists
# non_motorists_1
# non_motorists_2
# non_motorists_3
# non_motorists_4
# non_motorists_5
# non_motorists_6
# non_motorists_final
# non_motorists_final_table
# non_motorists_final_tables
# non_motorists_finals
# non_motorists_finalss

# %%
# Execute the query to get column information
cursor.execute("DESCRIBE non_motorists_finalss")

# %%
# Fetch all the rows
columns = cursor.fetchall()
# Print column names and data types
for column in columns:
    print(column[0], "-", column[1])
# Out:
# report_number - text
# local_case_number - text
# agency_name - text
# acrs_report_type - text
# crash_date_time - text
# route_type - text
# road_Name - text
# cross_street_type - text
# cross_street_name - text
# off_road_description - text
# municipality - text
# related_non_motorist - text
# collision_type - text
# weather - text
# surface_condition - text
# light - text
# traffic_control - text
# driver_substance_abuse - text
# non_motorist_substance_abuse - text
# person_id - text
# pedestrian_type - text
# pedestrian_movement - text
# pedestrian_actions - text
# pedestrian_location - text
# pedestrian_obeyed_traffic_signal - text
# pedestrian_visibility - text
# at_fault - text
# injury_severity - text
# safety_equipment - text
# latitude - text
# longitude - text
# location - text

# %%
cursor.close()
# Out:
# True

# %%
data.head()
# Out:
#   Report Number  Local Case Number               Agency Name  \
# 0   MCP2563001L          230017107  Montgomery County Police
# 1   MCP2771002B          230034003  Montgomery County Police
# 2   MCP2861005Z          230034963  Montgomery County Police
# 3   MCP3299002R          230034733  Montgomery County Police
# 4   MCP3360000L          230046354  Montgomery County Police
#
#         ACRS Report Type         Crash Date/Time        Route Type  \
# 0           Injury Crash  10/04/2023 04:21:00 pm  Maryland (State)
# 1           Injury Crash  07/17/2023 12:53:00 PM            County
# 2           Injury Crash  07/22/2023 06:58:00 PM               NaN
# 3  Property Damage Crash  07/21/2023 11:52:00 AM  Maryland (State)
# 4           Injury Crash  07/25/2023 10:12:00 AM            County
#
#            Road Name Cross-Street Type        Cross-Street Name  \
# 0  MUNCASTER MILL RD           Unknown  STRUC #15015 ROCK CREEK
# 1           PECAN DR            County             BUTTERNUT DR
# 2                NaN               NaN                      NaN
# 3        GEORGIA AVE            County         OLD BALTIMORE RD
# 4    WATKINS MILL RD            County              STEDWICK RD
#
#                  Off-Road Description  ...             Pedestrian Actions  \
# 0                                 NaN  ...  FAILURE TO YIELD RIGHT OF WAY
# 1                                 NaN  ...                          OTHER
# 2  PARKING LOT OF 7101 DEMOCRACY BLVD  ...          IN ROADWAY IMPROPERLY
# 3                                 NaN  ...            NO IMPROPER ACTIONS
# 4                                 NaN  ...            NO IMPROPER ACTIONS
#
#                 Pedestrian Location Pedestrian Obeyed Traffic Signal  \
# 0           ON ROADWAY AT CROSSWALK                   NO PED. SIGNAL
# 1                             OTHER                              NaN
# 2       ON ROADWAY NOT AT CROSSWALK                   NO PED. SIGNAL
# 3           ON ROADWAY AT CROSSWALK               OBEYED PED. SIGNAL
# 4  AT INTERSECTION MARKED CROSSWALK               OBEYED PED. SIGNAL
#
#   Pedestrian Visibility At Fault           Injury Severity Safety Equipment  \
# 0         DARK CLOTHING      Yes  SUSPECTED SERIOUS INJURY             NONE
# 1        LIGHT CLOTHING      Yes    SUSPECTED MINOR INJURY              NaN
# 2        LIGHT CLOTHING       No    SUSPECTED MINOR INJURY             NONE
# 3        LIGHT CLOTHING       No        NO APPARENT INJURY              NaN
# 4               UNKNOWN       No    SUSPECTED MINOR INJURY             NONE
#
#     Latitude  Longitude                     Location
# 0  39.137645 -77.129460  (39.13764511, -77.12946041)
# 1  39.091784 -77.098823  (39.09178359, -77.09882296)
# 2  39.024061 -77.147620  (39.02406091, -77.14761954)
# 3  39.135263 -77.069760     (39.13526333, -77.06976)
# 4  39.170558 -77.208889  (39.17055765, -77.20888876)
#
# [5 rows x 32 columns]

# %% [markdown]
# The dataframe as seen above has "NaN" values which cannot be inserted into the tables created in MySQL DB

# %% [markdown]
# Thus we need to replace those Nan Values with any string like missing/unknown for instance i.e. time being

# %% [markdown]
# ### Creating a copy of original dataframe

# %%
df=data

# %%
print(df.dtypes)
# Out:
# Report Number                        object
# Local Case Number                     int64
# Agency Name                          object
# ACRS Report Type                     object
# Crash Date/Time                      object
# Route Type                           object
# Road Name                            object
# Cross-Street Type                    object
# Cross-Street Name                    object
# Off-Road Description                 object
# Municipality                         object
# Related Non-Motorist                 object
# Collision Type                       object
# Weather                              object
# Surface Condition                    object
# Light                                object
# Traffic Control                      object
# Driver Substance Abuse               object
# Non-Motorist Substance Abuse         object
# Person ID                            object
# Pedestrian Type                      object
# Pedestrian Movement                  object
# Pedestrian Actions                   object
# Pedestrian Location                  object
# Pedestrian Obeyed Traffic Signal     object
# Pedestrian Visibility                object
# At Fault                             object
# Injury Severity                      object
# Safety Equipment                     object
# Latitude                            float64
# Longitude                           float64
# Location                             object
# dtype: object

# %%
df_filled = df.fillna("Missing")

# %%
df_filled.head()
# Out:
#   Report Number  Local Case Number               Agency Name  \
# 0   MCP2563001L          230017107  Montgomery County Police
# 1   MCP2771002B          230034003  Montgomery County Police
# 2   MCP2861005Z          230034963  Montgomery County Police
# 3   MCP3299002R          230034733  Montgomery County Police
# 4   MCP3360000L          230046354  Montgomery County Police
#
#         ACRS Report Type         Crash Date/Time        Route Type  \
# 0           Injury Crash  10/04/2023 04:21:00 pm  Maryland (State)
# 1           Injury Crash  07/17/2023 12:53:00 PM            County
# 2           Injury Crash  07/22/2023 06:58:00 PM           Missing
# 3  Property Damage Crash  07/21/2023 11:52:00 AM  Maryland (State)
# 4           Injury Crash  07/25/2023 10:12:00 AM            County
#
#            Road Name Cross-Street Type        Cross-Street Name  \
# 0  MUNCASTER MILL RD           Unknown  STRUC #15015 ROCK CREEK
# 1           PECAN DR            County             BUTTERNUT DR
# 2            Missing           Missing                  Missing
# 3        GEORGIA AVE            County         OLD BALTIMORE RD
# 4    WATKINS MILL RD            County              STEDWICK RD
#
#                  Off-Road Description  ...             Pedestrian Actions  \
# 0                             Missing  ...  FAILURE TO YIELD RIGHT OF WAY
# 1                             Missing  ...                          OTHER
# 2  PARKING LOT OF 7101 DEMOCRACY BLVD  ...          IN ROADWAY IMPROPERLY
# 3                             Missing  ...            NO IMPROPER ACTIONS
# 4                             Missing  ...            NO IMPROPER ACTIONS
#
#                 Pedestrian Location Pedestrian Obeyed Traffic Signal  \
# 0           ON ROADWAY AT CROSSWALK                   NO PED. SIGNAL
# 1                             OTHER                          Missing
# 2       ON ROADWAY NOT AT CROSSWALK                   NO PED. SIGNAL
# 3           ON ROADWAY AT CROSSWALK               OBEYED PED. SIGNAL
# 4  AT INTERSECTION MARKED CROSSWALK               OBEYED PED. SIGNAL
#
#   Pedestrian Visibility At Fault           Injury Severity Safety Equipment  \
# 0         DARK CLOTHING      Yes  SUSPECTED SERIOUS INJURY             NONE
# 1        LIGHT CLOTHING      Yes    SUSPECTED MINOR INJURY          Missing
# 2        LIGHT CLOTHING       No    SUSPECTED MINOR INJURY             NONE
# 3        LIGHT CLOTHING       No        NO APPARENT INJURY          Missing
# 4               UNKNOWN       No    SUSPECTED MINOR INJURY             NONE
#
#     Latitude  Longitude                     Location
# 0  39.137645 -77.129460  (39.13764511, -77.12946041)
# 1  39.091784 -77.098823  (39.09178359, -77.09882296)
# 2  39.024061 -77.147620  (39.02406091, -77.14761954)
# 3  39.135263 -77.069760     (39.13526333, -77.06976)
# 4  39.170558 -77.208889  (39.17055765, -77.20888876)
#
# [5 rows x 32 columns]

# %% [markdown]
# ### Writing the dataframe to MySQL Table

# %%
inserted_records_count = 0

# %%
cursor = conn.cursor()

# %%
for index, row in df_filled.iterrows():
    cursor.execute(insert_data, tuple(row))
    inserted_records_count += 1

# %%
conn.commit()

# %%
print("Number of records inserted into table:", inserted_records_count)
# Out:
# Number of records inserted into table: 5650

# %%
# Execute SELECT COUNT(*) query
cursor.execute("SELECT COUNT(*) FROM non_motorists_finalss")

# %%
# Fetch the result
count = cursor.fetchone()[0]
print("Number of records in 'non_motorists_finalss' table:", count)
# Out:
# Number of records in 'non_motorists_finalss' table: 5650

# %%
cursor.close()
# Out:
# True

# %% [markdown]
# ### Reading MySQL table to dataframe

# %%
cursor = conn.cursor()

# %%
cursor.execute(drop_columns)

# %%
conn.commit()

# %%
# Execute the DESCRIBE query
cursor.execute("DESCRIBE non_motorists_finalss")

# Fetch and print the column information
columns = cursor.fetchall()
for column in columns:
        print(column)
# Out:
# ('report_number', 'text', 'YES', '', None, '')
# ('local_case_number', 'text', 'YES', '', None, '')
# ('agency_name', 'text', 'YES', '', None, '')
# ('acrs_report_type', 'text', 'YES', '', None, '')
# ('crash_date_time', 'text', 'YES', '', None, '')
# ('route_type', 'text', 'YES', '', None, '')
# ('road_Name', 'text', 'YES', '', None, '')
# ('cross_street_type', 'text', 'YES', '', None, '')
# ('cross_street_name', 'text', 'YES', '', None, '')
# ('off_road_description', 'text', 'YES', '', None, '')
# ('municipality', 'text', 'YES', '', None, '')
# ('related_non_motorist', 'text', 'YES', '', None, '')
# ('collision_type', 'text', 'YES', '', None, '')
# ('weather', 'text', 'YES', '', None, '')
# ('surface_condition', 'text', 'YES', '', None, '')
# ('light', 'text', 'YES', '', None, '')
# ('traffic_control', 'text', 'YES', '', None, '')
# ('driver_substance_abuse', 'text', 'YES', '', None, '')
# ('non_motorist_substance_abuse', 'text', 'YES', '', None, '')
# ('person_id', 'text', 'YES', '', None, '')
# ('pedestrian_type', 'text', 'YES', '', None, '')
# ('pedestrian_movement', 'text', 'YES', '', None, '')
# ('pedestrian_actions', 'text', 'YES', '', None, '')
# ('pedestrian_location', 'text', 'YES', '', None, '')
# ('pedestrian_obeyed_traffic_signal', 'text', 'YES', '', None, '')
# ('pedestrian_visibility', 'text', 'YES', '', None, '')
# ('at_fault', 'text', 'YES', '', None, '')
# ('injury_severity', 'text', 'YES', '', None, '')
# ('safety_equipment', 'text', 'YES', '', None, '')

# %%
read_data = "select * from non_motorists_finalss"

# %%
sql_frame = pd.read_sql(read_data, conn)
# Out:
# C:\Users\walee\AppData\Local\Temp\ipykernel_16880\3075156522.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   sql_frame = pd.read_sql(read_data, conn)

# %%
sql_frame.head()
# Out:
#   report_number local_case_number               agency_name  \
# 0   MCP2563001L         230017107  Montgomery County Police
# 1   MCP2771002B         230034003  Montgomery County Police
# 2   MCP2861005Z         230034963  Montgomery County Police
# 3   MCP3299002R         230034733  Montgomery County Police
# 4   MCP3360000L         230046354  Montgomery County Police
#
#         acrs_report_type         crash_date_time        route_type  \
# 0           Injury Crash  10/04/2023 04:21:00 pm  Maryland (State)
# 1           Injury Crash  07/17/2023 12:53:00 PM            County
# 2           Injury Crash  07/22/2023 06:58:00 PM           Missing
# 3  Property Damage Crash  07/21/2023 11:52:00 AM  Maryland (State)
# 4           Injury Crash  07/25/2023 10:12:00 AM            County
#
#            road_Name cross_street_type        cross_street_name  \
# 0  MUNCASTER MILL RD           Unknown  STRUC #15015 ROCK CREEK
# 1           PECAN DR            County             BUTTERNUT DR
# 2            Missing           Missing                  Missing
# 3        GEORGIA AVE            County         OLD BALTIMORE RD
# 4    WATKINS MILL RD            County              STEDWICK RD
#
#                  off_road_description  ...  \
# 0                             Missing  ...
# 1                             Missing  ...
# 2  PARKING LOT OF 7101 DEMOCRACY BLVD  ...
# 3                             Missing  ...
# 4                             Missing  ...
#
#                               person_id pedestrian_type  \
# 0  2D1655C2-78EB-4552-899C-4C57B12B59E9      PEDESTRIAN
# 1  263E6D27-5F3B-4F27-9D29-B7F2F866CCEB           OTHER
# 2  6EED454B-5A6E-487D-8544-F969F2F21350      PEDESTRIAN
# 3  B056C81B-F1F4-4BA9-83CB-E61F2756C13D      PEDESTRIAN
# 4  390AA256-2353-4FB7-92CB-4F3F61C6ED75       BICYCLIST
#
#                pedestrian_movement             pedestrian_actions  \
# 0  Cross/Enter not at Intersection  FAILURE TO YIELD RIGHT OF WAY
# 1           Getting off/on Vehicle                          OTHER
# 2                            Other          IN ROADWAY IMPROPERLY
# 3      Cross/Enter at Intersection            NO IMPROPER ACTIONS
# 4                          Missing            NO IMPROPER ACTIONS
#
#                 pedestrian_location pedestrian_obeyed_traffic_signal  \
# 0           ON ROADWAY AT CROSSWALK                   NO PED. SIGNAL
# 1                             OTHER                          Missing
# 2       ON ROADWAY NOT AT CROSSWALK                   NO PED. SIGNAL
# 3           ON ROADWAY AT CROSSWALK               OBEYED PED. SIGNAL
# 4  AT INTERSECTION MARKED CROSSWALK               OBEYED PED. SIGNAL
#
#   pedestrian_visibility at_fault           injury_severity safety_equipment
# 0         DARK CLOTHING      Yes  SUSPECTED SERIOUS INJURY             NONE
# 1        LIGHT CLOTHING      Yes    SUSPECTED MINOR INJURY          Missing
# 2        LIGHT CLOTHING       No    SUSPECTED MINOR INJURY             NONE
# 3        LIGHT CLOTHING       No        NO APPARENT INJURY          Missing
# 4               UNKNOWN       No    SUSPECTED MINOR INJURY             NONE
#
# [5 rows x 29 columns]

# %% [markdown]
# ### Checking for duplicate records

# %%
duplicate_rows = sql_frame.duplicated()
print("Number of duplicate rows:", duplicate_rows.sum())
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# There are no Duplicate records in the data

# %% [markdown]
# ### If there were any duplicate records I would have dropped it using below

# %% [markdown]
# sql_frame = sql_frame.drop_duplicates()

# %% [markdown]
# ### Checking Missing Values

# %%
sql_frame.isnull().sum()
# Out:
# report_number                       0
# local_case_number                   0
# agency_name                         0
# acrs_report_type                    0
# crash_date_time                     0
# route_type                          0
# road_Name                           0
# cross_street_type                   0
# cross_street_name                   0
# off_road_description                0
# municipality                        0
# related_non_motorist                0
# collision_type                      0
# weather                             0
# surface_condition                   0
# light                               0
# traffic_control                     0
# driver_substance_abuse              0
# non_motorist_substance_abuse        0
# person_id                           0
# pedestrian_type                     0
# pedestrian_movement                 0
# pedestrian_actions                  0
# pedestrian_location                 0
# pedestrian_obeyed_traffic_signal    0
# pedestrian_visibility               0
# at_fault                            0
# injury_severity                     0
# safety_equipment                    0
# dtype: int64

# %% [markdown]
# As we have replaced 'NaN' has been replaced with 'Missing' we'll search for 'Missing' present in each column.

# %% [markdown]
# ### Where all Missing values are present?

# %%
# Check where "Missing" values occur in each column
missing_mask = sql_frame.eq('Missing')

# Check which columns have at least one "Missing" value
columns_with_missing = missing_mask.any()

# Extract the column names where "Missing" values occur
columns_with_missing_values = columns_with_missing[columns_with_missing].index.tolist()

# Print the columns with "Missing" values
print("Columns with 'Missing' values:", columns_with_missing_values)
# Out:
# Columns with 'Missing' values: ['route_type', 'road_Name', 'cross_street_type', 'cross_street_name', 'off_road_description', 'municipality', 'collision_type', 'weather', 'surface_condition', 'light', 'traffic_control', 'driver_substance_abuse', 'non_motorist_substance_abuse', 'pedestrian_movement', 'pedestrian_actions', 'pedestrian_location', 'pedestrian_obeyed_traffic_signal', 'pedestrian_visibility', 'at_fault', 'safety_equipment']

# %% [markdown]
# These are all the columns where 'Missing' value is found....get the count of 'Missing' value in each of the above columns

# %%
# Iterate through columns with missing values
for column in columns_with_missing_values:
    # Get unique values and their counts
    unique_values_counts = sql_frame[column].value_counts() 
    # Print column name
    print("Column:", column)
    # Print unique values and their counts
    print(unique_values_counts)
    print()
# Out:
# Column: route_type
# route_type
# County                  2006
# Maryland (State)        1646
# Missing                 1312
# Municipality             468
# US (State)               119
# Other Public Roadway      43
# Government                41
# Ramp                      10
# Interstate (State)         4
# Service Road               1
# Name: count, dtype: int64
#
# Column: road_Name
# road_Name
# Missing              1238
# GEORGIA AVE           304
# ROCKVILLE PIKE        141
# FREDERICK RD          115
# NEW HAMPSHIRE AVE     115
#                      ...
# PINE PL                 1
# HUNTMASTER RD           1
# BROOKDALE RD            1
# BOWMAN MILL RD          1
# CHELTON RD              1
# Name: count, Length: 953, dtype: int64
#
# Column: cross_street_type
# cross_street_type
# County                  2350
# Missing                 1313
# Maryland (State)         678
# Municipality             625
# Unknown                  378
# Other Public Roadway     132
# Government                64
# US (State)                61
# Ramp                      44
# Interstate (State)         4
# Service Road               1
# Name: count, dtype: int64
#
# Column: cross_street_name
# cross_street_name
# Missing                    1239
# GEORGIA AVE                  99
# FREDERICK RD                 56
# COLESVILLE RD                46
# RANDOLPH RD                  45
#                            ...
# COLLEGE VIEW DR               1
# CONNECTICUT AVE (AHEAD)       1
# E BRADLEY LA                  1
# DAMASCUS MANOR RD             1
# LUZERNE AVE                   1
# Name: count, Length: 1543, dtype: int64
#
# Column: off_road_description
# off_road_description
# Missing                                                                  4412
# PARKING LOT                                                                 8
# PARKING LOT OF 26004 BRIGADIER PLACE                                        4
# 4816 BOILING BROOK PKWY, GOODWILL PARKING LOT                               3
# PARKING LOT OF 6300 NEW HAMPSHIRE AVE, TAKOMA PARK, MD 20912                3
#                                                                          ...
# Parking Garage near Macy's side of Montgomery Mall                          1
# GIANT FOOD PARKING LOT 13781 CONNECTICUT AVE.\nSILVER SPRING MD 20906       1
# PARKING LOT OF PARK MONTGOMERY APARTMENTS 8860 PINEY BRANCH ROAD            1
# IFO 13428 NEW HAMPSHIRE AVE                                                 1
# IN THE PARKING LOT OF CRESTWOOD DRIVE                                       1
# Name: count, Length: 1153, dtype: int64
#
# Column: municipality
# municipality
# Missing                5026
# ROCKVILLE               333
# GAITHERSBURG            176
# TAKOMA PARK              62
# FRIENDSHIP HEIGHTS       13
# KENSINGTON               13
# POOLESVILLE               6
# SOMERSET                  6
# CHEVY CHASE #4            6
# CHEVY CHASE #3            3
# CHEVY CHASE VILLAGE       2
# MATINS ADDITION           2
# GARRETT PARK              1
# GLEN ECHO                 1
# Name: count, dtype: int64
#
# Column: collision_type
# collision_type
# OTHER                           2413
# SINGLE VEHICLE                  1780
# STRAIGHT MOVEMENT ANGLE          690
# Missing                          178
# SAME DIR REAR END                157
# HEAD ON LEFT TURN                147
# SAME DIRECTION SIDESWIPE          87
# SAME DIRECTION RIGHT TURN         46
# HEAD ON                           42
# SAME DIRECTION LEFT TURN          27
# ANGLE MEETS RIGHT TURN            22
# OPPOSITE DIRECTION SIDESWIPE      18
# ANGLE MEETS LEFT TURN             13
# UNKNOWN                           12
# SAME DIR REND LEFT TURN            7
# ANGLE MEETS LEFT HEAD ON           6
# SAME DIR REND RIGHT TURN           3
# OPPOSITE DIR BOTH LEFT TURN        2
# Name: count, dtype: int64
#
# Column: weather
# weather
# CLEAR           3949
# RAINING          601
# CLOUDY           523
# Missing          458
# UNKNOWN           32
# SNOW              29
# FOGGY             22
# OTHER             12
# WINTRY MIX        11
# SEVERE WINDS       7
# BLOWING SNOW       3
# SLEET              3
# Name: count, dtype: int64
#
# Column: surface_condition
# surface_condition
# DRY        3520
# Missing    1382
# WET         687
# UNKNOWN      25
# SNOW         16
# ICE          11
# OTHER         5
# SLUSH         4
# Name: count, dtype: int64
#
# Column: light
# light
# DAYLIGHT                    3604
# DARK LIGHTS ON              1455
# DARK NO LIGHTS               211
# DUSK                         127
# DAWN                         104
# DARK -- UNKNOWN LIGHTING      69
# Missing                       46
# UNKNOWN                       19
# OTHER                         15
# Name: count, dtype: int64
#
# Column: traffic_control
# traffic_control
# NO CONTROLS                2261
# TRAFFIC SIGNAL             1663
# Missing                     811
# STOP SIGN                   580
# OTHER                       167
# PERSON                       57
# YIELD SIGN                   37
# UNKNOWN                      24
# FLASHING TRAFFIC SIGNAL      24
# WARNING SIGN                 18
# SCHOOL ZONE SIGN DEVICE       6
# RAILWAY CROSSING DEVICE       2
# Name: count, dtype: int64
#
# Column: driver_substance_abuse
# driver_substance_abuse
# NONE DETECTED                                3776
# Missing                                      1082
# UNKNOWN                                       687
# ALCOHOL PRESENT                                47
# ALCOHOL CONTRIBUTED                            16
# NONE DETECTED, UNKNOWN                          9
# N/A, NONE DETECTED                              8
# ALCOHOL CONTRIBUTED, NONE DETECTED              4
# ALCOHOL PRESENT, NONE DETECTED                  4
# ILLEGAL DRUG PRESENT                            4
# MEDICATION PRESENT                              2
# ALCOHOL PRESENT, N/A                            2
# ALCOHOL CONTRIBUTED, N/A                        2
# ILLEGAL DRUG CONTRIBUTED                        2
# ALCOHOL PRESENT, UNKNOWN                        1
# COMBINED SUBSTANCE PRESENT                      1
# MEDICATION PRESENT, NONE DETECTED               1
# COMBINED SUBSTANCE PRESENT, NONE DETECTED       1
# OTHER                                           1
# Name: count, dtype: int64
#
# Column: non_motorist_substance_abuse
# non_motorist_substance_abuse
# NONE DETECTED                 4011
# Missing                       1203
# UNKNOWN                        229
# ALCOHOL PRESENT                151
# ALCOHOL CONTRIBUTED             40
# ILLEGAL DRUG PRESENT             6
# MEDICATION PRESENT               4
# ILLEGAL DRUG CONTRIBUTED         2
# COMBINATION CONTRIBUTED          2
# COMBINED SUBSTANCE PRESENT       1
# OTHER                            1
# Name: count, dtype: int64
#
# Column: pedestrian_movement
# pedestrian_movement
# Cross/Enter at Intersection        2522
# Other                               720
# Cross/Enter not at Intersection     677
# Walking/Riding w/Traffic            386
# Standing                            376
# Walking/Cycling on Sidewalk         254
# Missing                             156
# Walking/Riding against Traffic      113
# Unknown                             102
# Other Working                        93
# Getting off/on Vehicle               91
# Playing                              68
# Walking to/from school               53
# Push/Work on Vehicle                 24
# Approach/Leaving Schoolbus           12
# Hitchhiking                           3
# Name: count, dtype: int64
#
# Column: pedestrian_actions
# pedestrian_actions
# NO IMPROPER ACTIONS                                 2881
# UNKNOWN                                              462
# IN ROADWAY IMPROPERLY                                451
# DART DASH                                            429
# Missing                                              294
# OTHER                                                265
# FAILURE TO YIELD RIGHT OF WAY                        264
# INATTENTIVE                                          215
# FAILURE TO OBEY TRAFFIC SIGNS SIGNALS OR OFFICER     162
# NOT VISIBLE                                          118
# ENTERING EXITING PARKED STANDING VEHICLE              37
# WRONG WAY RIDING OR WALKING                           32
# DISABLED VEHICLE RELATED                              17
# IMPROPER PASSING                                      16
# IMPROPER TURN MERGE                                    7
# Name: count, dtype: int64
#
# Column: pedestrian_location
# pedestrian_location
# ON ROADWAY AT CROSSWALK             1502
# ON ROADWAY NOT AT CROSSWALK         1170
# OTHER                                976
# AT INTERSECTION MARKED CROSSWALK     664
# SIDEWALK                             388
# AT INTERSECTION BUT NO CROSSWALK     246
# Missing                              153
# SHOULDER                             143
# OUTSIDE RIGHT OF WAY                  65
# CURB                                  65
# INSIDE BUILDING                       63
# UNKNOWN                               62
# DRIVEWAY ACCESS MARKED CROSSWALK      51
# IN BIKEWAY                            43
# MEDIAN                                27
# MIDBLOCK MARKED CROSSWALK             19
# SHARED USE PATH OR TRAILS              9
# IN SCHOOL BUS ZONE                     3
# ISLAND                                 1
# Name: count, dtype: int64
#
# Column: pedestrian_obeyed_traffic_signal
# pedestrian_obeyed_traffic_signal
# NO PED. SIGNAL             2101
# Missing                    1666
# OBEYED PED. SIGNAL         1043
# DISOBEYED PED. SIGNAL       366
# UNKNOWN                     313
# OTHER                       156
# PED. SIGNAL MALFUNCTION       5
# Name: count, dtype: int64
#
# Column: pedestrian_visibility
# pedestrian_visibility
# MIXED CLOTHING               2149
# DARK CLOTHING                1427
# LIGHT CLOTHING                923
# Missing                       542
# UNKNOWN                       339
# REFLECTIVE MATERIAL           164
# OTHER                          68
# HEAD LIGHT AND REFLECTORS      22
# HEAD LIGHT                     10
# REAR REFLECTOR                  6
# Name: count, dtype: int64
#
# Column: at_fault
# at_fault
# No         3414
# Yes        1509
# Unknown     440
# Missing     287
# Name: count, dtype: int64
#
# Column: safety_equipment
# safety_equipment
# NONE                   2862
# Missing                1908
# MC/BIKE HELMET          615
# UNKNOWN                 125
# REFLECTIVE CLOTHING     104
# OTHER                    22
# LIGHTING                 13
# PROTECTIVE PADS           1
# Name: count, dtype: int64

# %% [markdown]
# ### Insights

# %% [raw]
# For route_type - we have 1312 missing values
# For road_Name - we have 1238 missing values
# For cross_street_type - we have 1313 missing values
# For cross_street_name - we have 1239 missing values
# For off_road_description - we have 4412 missing values
# For municipality - we have 5026 missing values
# For collision_type - we have 178 missing values
# For weather - we have 458 missing values
# For surface_condition - we have 1382 missing values
# For light - we have 46 missing values
# For traffic_control - we have 811 missing values
# For driver_substance_abuse - we have 1082 missing values
# For non_motorist_substance_abuse - we have 1203 missing values
# For pedestrian_movement - we have 156 missing values
# For pedestrian_actions - we have 294 missing values
# For pedestrian_location - we have 153 missing values
# For pedestrian_obeyed_traffic_signal - we have 1666 missing values
# For pedestrian_visibility - we have 542 missing values
# For at_fault - we have 287 missing values
# For safety_equipment - we have 1908 missing values

# %% [markdown]
# ### Columns with low weightage in analysis/less useful for analysis

# %%
columns_to_drop = ['cross_street_type', 'off_road_description', 'municipality']
sql_frame.drop(columns=columns_to_drop, inplace=True)

# %%
sql_frame.head()
# Out:
#   report_number local_case_number               agency_name  \
# 0   MCP2563001L         230017107  Montgomery County Police
# 1   MCP2771002B         230034003  Montgomery County Police
# 2   MCP2861005Z         230034963  Montgomery County Police
# 3   MCP3299002R         230034733  Montgomery County Police
# 4   MCP3360000L         230046354  Montgomery County Police
#
#         acrs_report_type         crash_date_time        route_type  \
# 0           Injury Crash  10/04/2023 04:21:00 pm  Maryland (State)
# 1           Injury Crash  07/17/2023 12:53:00 PM            County
# 2           Injury Crash  07/22/2023 06:58:00 PM           Missing
# 3  Property Damage Crash  07/21/2023 11:52:00 AM  Maryland (State)
# 4           Injury Crash  07/25/2023 10:12:00 AM            County
#
#            road_Name        cross_street_name related_non_motorist  \
# 0  MUNCASTER MILL RD  STRUC #15015 ROCK CREEK           PEDESTRIAN
# 1           PECAN DR             BUTTERNUT DR                OTHER
# 2            Missing                  Missing           PEDESTRIAN
# 3        GEORGIA AVE         OLD BALTIMORE RD           PEDESTRIAN
# 4    WATKINS MILL RD              STEDWICK RD            BICYCLIST
#
#    collision_type  ...                             person_id pedestrian_type  \
# 0  SINGLE VEHICLE  ...  2D1655C2-78EB-4552-899C-4C57B12B59E9      PEDESTRIAN
# 1  SINGLE VEHICLE  ...  263E6D27-5F3B-4F27-9D29-B7F2F866CCEB           OTHER
# 2  SINGLE VEHICLE  ...  6EED454B-5A6E-487D-8544-F969F2F21350      PEDESTRIAN
# 3           OTHER  ...  B056C81B-F1F4-4BA9-83CB-E61F2756C13D      PEDESTRIAN
# 4  SINGLE VEHICLE  ...  390AA256-2353-4FB7-92CB-4F3F61C6ED75       BICYCLIST
#
#                pedestrian_movement             pedestrian_actions  \
# 0  Cross/Enter not at Intersection  FAILURE TO YIELD RIGHT OF WAY
# 1           Getting off/on Vehicle                          OTHER
# 2                            Other          IN ROADWAY IMPROPERLY
# 3      Cross/Enter at Intersection            NO IMPROPER ACTIONS
# 4                          Missing            NO IMPROPER ACTIONS
#
#                 pedestrian_location pedestrian_obeyed_traffic_signal  \
# 0           ON ROADWAY AT CROSSWALK                   NO PED. SIGNAL
# 1                             OTHER                          Missing
# 2       ON ROADWAY NOT AT CROSSWALK                   NO PED. SIGNAL
# 3           ON ROADWAY AT CROSSWALK               OBEYED PED. SIGNAL
# 4  AT INTERSECTION MARKED CROSSWALK               OBEYED PED. SIGNAL
#
#   pedestrian_visibility at_fault           injury_severity safety_equipment
# 0         DARK CLOTHING      Yes  SUSPECTED SERIOUS INJURY             NONE
# 1        LIGHT CLOTHING      Yes    SUSPECTED MINOR INJURY          Missing
# 2        LIGHT CLOTHING       No    SUSPECTED MINOR INJURY             NONE
# 3        LIGHT CLOTHING       No        NO APPARENT INJURY          Missing
# 4               UNKNOWN       No    SUSPECTED MINOR INJURY             NONE
#
# [5 rows x 26 columns]

# %%
num_rows, num_columns = sql_frame.shape
print("Number of rows:", num_rows)
print("Number of columns:", num_columns)
# Out:
# Number of rows: 5650
# Number of columns: 26

# %%
# Check where "Missing" values occur in each column
missing_mask = sql_frame.eq('Missing')

# Check which columns have at least one "Missing" value
columns_with_missing = missing_mask.any()

# Extract the column names where "Missing" values occur
columns_with_missing_values = columns_with_missing[columns_with_missing].index.tolist()

# Print the columns with "Missing" values
print("Columns with 'Missing' values:", columns_with_missing_values)
# Out:
# Columns with 'Missing' values: ['route_type', 'road_Name', 'cross_street_name', 'collision_type', 'weather', 'surface_condition', 'light', 'traffic_control', 'driver_substance_abuse', 'non_motorist_substance_abuse', 'pedestrian_movement', 'pedestrian_actions', 'pedestrian_location', 'pedestrian_obeyed_traffic_signal', 'pedestrian_visibility', 'at_fault', 'safety_equipment']

# %%
# Iterate through columns with missing values
for column in columns_with_missing_values:
    # Get unique values and their counts
    unique_values_counts = sql_frame[column].value_counts() 
    # Print column name
    print("Column:", column)
    # Print unique values and their counts
    print(unique_values_counts)
    print()
# Out:
# Column: route_type
# route_type
# County                  2006
# Maryland (State)        1646
# Missing                 1312
# Municipality             468
# US (State)               119
# Other Public Roadway      43
# Government                41
# Ramp                      10
# Interstate (State)         4
# Service Road               1
# Name: count, dtype: int64
#
# Column: road_Name
# road_Name
# Missing              1238
# GEORGIA AVE           304
# ROCKVILLE PIKE        141
# FREDERICK RD          115
# NEW HAMPSHIRE AVE     115
#                      ...
# PINE PL                 1
# HUNTMASTER RD           1
# BROOKDALE RD            1
# BOWMAN MILL RD          1
# CHELTON RD              1
# Name: count, Length: 953, dtype: int64
#
# Column: cross_street_name
# cross_street_name
# Missing                    1239
# GEORGIA AVE                  99
# FREDERICK RD                 56
# COLESVILLE RD                46
# RANDOLPH RD                  45
#                            ...
# COLLEGE VIEW DR               1
# CONNECTICUT AVE (AHEAD)       1
# E BRADLEY LA                  1
# DAMASCUS MANOR RD             1
# LUZERNE AVE                   1
# Name: count, Length: 1543, dtype: int64
#
# Column: collision_type
# collision_type
# OTHER                           2413
# SINGLE VEHICLE                  1780
# STRAIGHT MOVEMENT ANGLE          690
# Missing                          178
# SAME DIR REAR END                157
# HEAD ON LEFT TURN                147
# SAME DIRECTION SIDESWIPE          87
# SAME DIRECTION RIGHT TURN         46
# HEAD ON                           42
# SAME DIRECTION LEFT TURN          27
# ANGLE MEETS RIGHT TURN            22
# OPPOSITE DIRECTION SIDESWIPE      18
# ANGLE MEETS LEFT TURN             13
# UNKNOWN                           12
# SAME DIR REND LEFT TURN            7
# ANGLE MEETS LEFT HEAD ON           6
# SAME DIR REND RIGHT TURN           3
# OPPOSITE DIR BOTH LEFT TURN        2
# Name: count, dtype: int64
#
# Column: weather
# weather
# CLEAR           3949
# RAINING          601
# CLOUDY           523
# Missing          458
# UNKNOWN           32
# SNOW              29
# FOGGY             22
# OTHER             12
# WINTRY MIX        11
# SEVERE WINDS       7
# BLOWING SNOW       3
# SLEET              3
# Name: count, dtype: int64
#
# Column: surface_condition
# surface_condition
# DRY        3520
# Missing    1382
# WET         687
# UNKNOWN      25
# SNOW         16
# ICE          11
# OTHER         5
# SLUSH         4
# Name: count, dtype: int64
#
# Column: light
# light
# DAYLIGHT                    3604
# DARK LIGHTS ON              1455
# DARK NO LIGHTS               211
# DUSK                         127
# DAWN                         104
# DARK -- UNKNOWN LIGHTING      69
# Missing                       46
# UNKNOWN                       19
# OTHER                         15
# Name: count, dtype: int64
#
# Column: traffic_control
# traffic_control
# NO CONTROLS                2261
# TRAFFIC SIGNAL             1663
# Missing                     811
# STOP SIGN                   580
# OTHER                       167
# PERSON                       57
# YIELD SIGN                   37
# UNKNOWN                      24
# FLASHING TRAFFIC SIGNAL      24
# WARNING SIGN                 18
# SCHOOL ZONE SIGN DEVICE       6
# RAILWAY CROSSING DEVICE       2
# Name: count, dtype: int64
#
# Column: driver_substance_abuse
# driver_substance_abuse
# NONE DETECTED                                3776
# Missing                                      1082
# UNKNOWN                                       687
# ALCOHOL PRESENT                                47
# ALCOHOL CONTRIBUTED                            16
# NONE DETECTED, UNKNOWN                          9
# N/A, NONE DETECTED                              8
# ALCOHOL CONTRIBUTED, NONE DETECTED              4
# ALCOHOL PRESENT, NONE DETECTED                  4
# ILLEGAL DRUG PRESENT                            4
# MEDICATION PRESENT                              2
# ALCOHOL PRESENT, N/A                            2
# ALCOHOL CONTRIBUTED, N/A                        2
# ILLEGAL DRUG CONTRIBUTED                        2
# ALCOHOL PRESENT, UNKNOWN                        1
# COMBINED SUBSTANCE PRESENT                      1
# MEDICATION PRESENT, NONE DETECTED               1
# COMBINED SUBSTANCE PRESENT, NONE DETECTED       1
# OTHER                                           1
# Name: count, dtype: int64
#
# Column: non_motorist_substance_abuse
# non_motorist_substance_abuse
# NONE DETECTED                 4011
# Missing                       1203
# UNKNOWN                        229
# ALCOHOL PRESENT                151
# ALCOHOL CONTRIBUTED             40
# ILLEGAL DRUG PRESENT             6
# MEDICATION PRESENT               4
# ILLEGAL DRUG CONTRIBUTED         2
# COMBINATION CONTRIBUTED          2
# COMBINED SUBSTANCE PRESENT       1
# OTHER                            1
# Name: count, dtype: int64
#
# Column: pedestrian_movement
# pedestrian_movement
# Cross/Enter at Intersection        2522
# Other                               720
# Cross/Enter not at Intersection     677
# Walking/Riding w/Traffic            386
# Standing                            376
# Walking/Cycling on Sidewalk         254
# Missing                             156
# Walking/Riding against Traffic      113
# Unknown                             102
# Other Working                        93
# Getting off/on Vehicle               91
# Playing                              68
# Walking to/from school               53
# Push/Work on Vehicle                 24
# Approach/Leaving Schoolbus           12
# Hitchhiking                           3
# Name: count, dtype: int64
#
# Column: pedestrian_actions
# pedestrian_actions
# NO IMPROPER ACTIONS                                 2881
# UNKNOWN                                              462
# IN ROADWAY IMPROPERLY                                451
# DART DASH                                            429
# Missing                                              294
# OTHER                                                265
# FAILURE TO YIELD RIGHT OF WAY                        264
# INATTENTIVE                                          215
# FAILURE TO OBEY TRAFFIC SIGNS SIGNALS OR OFFICER     162
# NOT VISIBLE                                          118
# ENTERING EXITING PARKED STANDING VEHICLE              37
# WRONG WAY RIDING OR WALKING                           32
# DISABLED VEHICLE RELATED                              17
# IMPROPER PASSING                                      16
# IMPROPER TURN MERGE                                    7
# Name: count, dtype: int64
#
# Column: pedestrian_location
# pedestrian_location
# ON ROADWAY AT CROSSWALK             1502
# ON ROADWAY NOT AT CROSSWALK         1170
# OTHER                                976
# AT INTERSECTION MARKED CROSSWALK     664
# SIDEWALK                             388
# AT INTERSECTION BUT NO CROSSWALK     246
# Missing                              153
# SHOULDER                             143
# OUTSIDE RIGHT OF WAY                  65
# CURB                                  65
# INSIDE BUILDING                       63
# UNKNOWN                               62
# DRIVEWAY ACCESS MARKED CROSSWALK      51
# IN BIKEWAY                            43
# MEDIAN                                27
# MIDBLOCK MARKED CROSSWALK             19
# SHARED USE PATH OR TRAILS              9
# IN SCHOOL BUS ZONE                     3
# ISLAND                                 1
# Name: count, dtype: int64
#
# Column: pedestrian_obeyed_traffic_signal
# pedestrian_obeyed_traffic_signal
# NO PED. SIGNAL             2101
# Missing                    1666
# OBEYED PED. SIGNAL         1043
# DISOBEYED PED. SIGNAL       366
# UNKNOWN                     313
# OTHER                       156
# PED. SIGNAL MALFUNCTION       5
# Name: count, dtype: int64
#
# Column: pedestrian_visibility
# pedestrian_visibility
# MIXED CLOTHING               2149
# DARK CLOTHING                1427
# LIGHT CLOTHING                923
# Missing                       542
# UNKNOWN                       339
# REFLECTIVE MATERIAL           164
# OTHER                          68
# HEAD LIGHT AND REFLECTORS      22
# HEAD LIGHT                     10
# REAR REFLECTOR                  6
# Name: count, dtype: int64
#
# Column: at_fault
# at_fault
# No         3414
# Yes        1509
# Unknown     440
# Missing     287
# Name: count, dtype: int64
#
# Column: safety_equipment
# safety_equipment
# NONE                   2862
# Missing                1908
# MC/BIKE HELMET          615
# UNKNOWN                 125
# REFLECTIVE CLOTHING     104
# OTHER                    22
# LIGHTING                 13
# PROTECTIVE PADS           1
# Name: count, dtype: int64

# %% [markdown]
# ### Transformations for columns with moderate or moderate to high weightage in analysis/somewhat useful for analysis

# %%
# road_grade
sql_frame['route_type'] = sql_frame['route_type'].replace('Missing', sql_frame['route_type'].mode()[0])
sql_frame['driver_substance_abuse'] = sql_frame['driver_substance_abuse'].replace('Missing', sql_frame['driver_substance_abuse'].mode()[0])

# %%
sql_frame.head()
# Out:
#   report_number local_case_number               agency_name  \
# 0   MCP2563001L         230017107  Montgomery County Police
# 1   MCP2771002B         230034003  Montgomery County Police
# 2   MCP2861005Z         230034963  Montgomery County Police
# 3   MCP3299002R         230034733  Montgomery County Police
# 4   MCP3360000L         230046354  Montgomery County Police
#
#         acrs_report_type         crash_date_time        route_type  \
# 0           Injury Crash  10/04/2023 04:21:00 pm  Maryland (State)
# 1           Injury Crash  07/17/2023 12:53:00 PM            County
# 2           Injury Crash  07/22/2023 06:58:00 PM            County
# 3  Property Damage Crash  07/21/2023 11:52:00 AM  Maryland (State)
# 4           Injury Crash  07/25/2023 10:12:00 AM            County
#
#            road_Name        cross_street_name related_non_motorist  \
# 0  MUNCASTER MILL RD  STRUC #15015 ROCK CREEK           PEDESTRIAN
# 1           PECAN DR             BUTTERNUT DR                OTHER
# 2            Missing                  Missing           PEDESTRIAN
# 3        GEORGIA AVE         OLD BALTIMORE RD           PEDESTRIAN
# 4    WATKINS MILL RD              STEDWICK RD            BICYCLIST
#
#    collision_type  ...                             person_id pedestrian_type  \
# 0  SINGLE VEHICLE  ...  2D1655C2-78EB-4552-899C-4C57B12B59E9      PEDESTRIAN
# 1  SINGLE VEHICLE  ...  263E6D27-5F3B-4F27-9D29-B7F2F866CCEB           OTHER
# 2  SINGLE VEHICLE  ...  6EED454B-5A6E-487D-8544-F969F2F21350      PEDESTRIAN
# 3           OTHER  ...  B056C81B-F1F4-4BA9-83CB-E61F2756C13D      PEDESTRIAN
# 4  SINGLE VEHICLE  ...  390AA256-2353-4FB7-92CB-4F3F61C6ED75       BICYCLIST
#
#                pedestrian_movement             pedestrian_actions  \
# 0  Cross/Enter not at Intersection  FAILURE TO YIELD RIGHT OF WAY
# 1           Getting off/on Vehicle                          OTHER
# 2                            Other          IN ROADWAY IMPROPERLY
# 3      Cross/Enter at Intersection            NO IMPROPER ACTIONS
# 4                          Missing            NO IMPROPER ACTIONS
#
#                 pedestrian_location pedestrian_obeyed_traffic_signal  \
# 0           ON ROADWAY AT CROSSWALK                   NO PED. SIGNAL
# 1                             OTHER                          Missing
# 2       ON ROADWAY NOT AT CROSSWALK                   NO PED. SIGNAL
# 3           ON ROADWAY AT CROSSWALK               OBEYED PED. SIGNAL
# 4  AT INTERSECTION MARKED CROSSWALK               OBEYED PED. SIGNAL
#
#   pedestrian_visibility at_fault           injury_severity safety_equipment
# 0         DARK CLOTHING      Yes  SUSPECTED SERIOUS INJURY             NONE
# 1        LIGHT CLOTHING      Yes    SUSPECTED MINOR INJURY          Missing
# 2        LIGHT CLOTHING       No    SUSPECTED MINOR INJURY             NONE
# 3        LIGHT CLOTHING       No        NO APPARENT INJURY          Missing
# 4               UNKNOWN       No    SUSPECTED MINOR INJURY             NONE
#
# [5 rows x 26 columns]

# %%
# Check where "Missing" values occur in each column
missing_mask = sql_frame.eq('Missing')

# Check which columns have at least one "Missing" value
columns_with_missing = missing_mask.any()

# Extract the column names where "Missing" values occur
columns_with_missing_values = columns_with_missing[columns_with_missing].index.tolist()

# Print the columns with "Missing" values
print("Columns with 'Missing' values:", columns_with_missing_values)
# Out:
# Columns with 'Missing' values: ['road_Name', 'cross_street_name', 'collision_type', 'weather', 'surface_condition', 'light', 'traffic_control', 'non_motorist_substance_abuse', 'pedestrian_movement', 'pedestrian_actions', 'pedestrian_location', 'pedestrian_obeyed_traffic_signal', 'pedestrian_visibility', 'at_fault', 'safety_equipment']

# %%
# Iterate through columns with missing values
for column in columns_with_missing_values:
    # Get unique values and their counts
    unique_values_counts = sql_frame[column].value_counts() 
    # Print column name
    print("Column:", column)
    # Print unique values and their counts
    print(unique_values_counts)
    print()
# Out:
# Column: road_Name
# road_Name
# Missing              1238
# GEORGIA AVE           304
# ROCKVILLE PIKE        141
# FREDERICK RD          115
# NEW HAMPSHIRE AVE     115
#                      ...
# PINE PL                 1
# HUNTMASTER RD           1
# BROOKDALE RD            1
# BOWMAN MILL RD          1
# CHELTON RD              1
# Name: count, Length: 953, dtype: int64
#
# Column: cross_street_name
# cross_street_name
# Missing                    1239
# GEORGIA AVE                  99
# FREDERICK RD                 56
# COLESVILLE RD                46
# RANDOLPH RD                  45
#                            ...
# COLLEGE VIEW DR               1
# CONNECTICUT AVE (AHEAD)       1
# E BRADLEY LA                  1
# DAMASCUS MANOR RD             1
# LUZERNE AVE                   1
# Name: count, Length: 1543, dtype: int64
#
# Column: collision_type
# collision_type
# OTHER                           2413
# SINGLE VEHICLE                  1780
# STRAIGHT MOVEMENT ANGLE          690
# Missing                          178
# SAME DIR REAR END                157
# HEAD ON LEFT TURN                147
# SAME DIRECTION SIDESWIPE          87
# SAME DIRECTION RIGHT TURN         46
# HEAD ON                           42
# SAME DIRECTION LEFT TURN          27
# ANGLE MEETS RIGHT TURN            22
# OPPOSITE DIRECTION SIDESWIPE      18
# ANGLE MEETS LEFT TURN             13
# UNKNOWN                           12
# SAME DIR REND LEFT TURN            7
# ANGLE MEETS LEFT HEAD ON           6
# SAME DIR REND RIGHT TURN           3
# OPPOSITE DIR BOTH LEFT TURN        2
# Name: count, dtype: int64
#
# Column: weather
# weather
# CLEAR           3949
# RAINING          601
# CLOUDY           523
# Missing          458
# UNKNOWN           32
# SNOW              29
# FOGGY             22
# OTHER             12
# WINTRY MIX        11
# SEVERE WINDS       7
# BLOWING SNOW       3
# SLEET              3
# Name: count, dtype: int64
#
# Column: surface_condition
# surface_condition
# DRY        3520
# Missing    1382
# WET         687
# UNKNOWN      25
# SNOW         16
# ICE          11
# OTHER         5
# SLUSH         4
# Name: count, dtype: int64
#
# Column: light
# light
# DAYLIGHT                    3604
# DARK LIGHTS ON              1455
# DARK NO LIGHTS               211
# DUSK                         127
# DAWN                         104
# DARK -- UNKNOWN LIGHTING      69
# Missing                       46
# UNKNOWN                       19
# OTHER                         15
# Name: count, dtype: int64
#
# Column: traffic_control
# traffic_control
# NO CONTROLS                2261
# TRAFFIC SIGNAL             1663
# Missing                     811
# STOP SIGN                   580
# OTHER                       167
# PERSON                       57
# YIELD SIGN                   37
# UNKNOWN                      24
# FLASHING TRAFFIC SIGNAL      24
# WARNING SIGN                 18
# SCHOOL ZONE SIGN DEVICE       6
# RAILWAY CROSSING DEVICE       2
# Name: count, dtype: int64
#
# Column: non_motorist_substance_abuse
# non_motorist_substance_abuse
# NONE DETECTED                 4011
# Missing                       1203
# UNKNOWN                        229
# ALCOHOL PRESENT                151
# ALCOHOL CONTRIBUTED             40
# ILLEGAL DRUG PRESENT             6
# MEDICATION PRESENT               4
# ILLEGAL DRUG CONTRIBUTED         2
# COMBINATION CONTRIBUTED          2
# COMBINED SUBSTANCE PRESENT       1
# OTHER                            1
# Name: count, dtype: int64
#
# Column: pedestrian_movement
# pedestrian_movement
# Cross/Enter at Intersection        2522
# Other                               720
# Cross/Enter not at Intersection     677
# Walking/Riding w/Traffic            386
# Standing                            376
# Walking/Cycling on Sidewalk         254
# Missing                             156
# Walking/Riding against Traffic      113
# Unknown                             102
# Other Working                        93
# Getting off/on Vehicle               91
# Playing                              68
# Walking to/from school               53
# Push/Work on Vehicle                 24
# Approach/Leaving Schoolbus           12
# Hitchhiking                           3
# Name: count, dtype: int64
#
# Column: pedestrian_actions
# pedestrian_actions
# NO IMPROPER ACTIONS                                 2881
# UNKNOWN                                              462
# IN ROADWAY IMPROPERLY                                451
# DART DASH                                            429
# Missing                                              294
# OTHER                                                265
# FAILURE TO YIELD RIGHT OF WAY                        264
# INATTENTIVE                                          215
# FAILURE TO OBEY TRAFFIC SIGNS SIGNALS OR OFFICER     162
# NOT VISIBLE                                          118
# ENTERING EXITING PARKED STANDING VEHICLE              37
# WRONG WAY RIDING OR WALKING                           32
# DISABLED VEHICLE RELATED                              17
# IMPROPER PASSING                                      16
# IMPROPER TURN MERGE                                    7
# Name: count, dtype: int64
#
# Column: pedestrian_location
# pedestrian_location
# ON ROADWAY AT CROSSWALK             1502
# ON ROADWAY NOT AT CROSSWALK         1170
# OTHER                                976
# AT INTERSECTION MARKED CROSSWALK     664
# SIDEWALK                             388
# AT INTERSECTION BUT NO CROSSWALK     246
# Missing                              153
# SHOULDER                             143
# OUTSIDE RIGHT OF WAY                  65
# CURB                                  65
# INSIDE BUILDING                       63
# UNKNOWN                               62
# DRIVEWAY ACCESS MARKED CROSSWALK      51
# IN BIKEWAY                            43
# MEDIAN                                27
# MIDBLOCK MARKED CROSSWALK             19
# SHARED USE PATH OR TRAILS              9
# IN SCHOOL BUS ZONE                     3
# ISLAND                                 1
# Name: count, dtype: int64
#
# Column: pedestrian_obeyed_traffic_signal
# pedestrian_obeyed_traffic_signal
# NO PED. SIGNAL             2101
# Missing                    1666
# OBEYED PED. SIGNAL         1043
# DISOBEYED PED. SIGNAL       366
# UNKNOWN                     313
# OTHER                       156
# PED. SIGNAL MALFUNCTION       5
# Name: count, dtype: int64
#
# Column: pedestrian_visibility
# pedestrian_visibility
# MIXED CLOTHING               2149
# DARK CLOTHING                1427
# LIGHT CLOTHING                923
# Missing                       542
# UNKNOWN                       339
# REFLECTIVE MATERIAL           164
# OTHER                          68
# HEAD LIGHT AND REFLECTORS      22
# HEAD LIGHT                     10
# REAR REFLECTOR                  6
# Name: count, dtype: int64
#
# Column: at_fault
# at_fault
# No         3414
# Yes        1509
# Unknown     440
# Missing     287
# Name: count, dtype: int64
#
# Column: safety_equipment
# safety_equipment
# NONE                   2862
# Missing                1908
# MC/BIKE HELMET          615
# UNKNOWN                 125
# REFLECTIVE CLOTHING     104
# OTHER                    22
# LIGHTING                 13
# PROTECTIVE PADS           1
# Name: count, dtype: int64

# %%
column_list = sql_frame.columns.tolist()
print(column_list)
# Out:
# ['report_number', 'local_case_number', 'agency_name', 'acrs_report_type', 'crash_date_time', 'route_type', 'road_Name', 'cross_street_name', 'related_non_motorist', 'collision_type', 'weather', 'surface_condition', 'light', 'traffic_control', 'driver_substance_abuse', 'non_motorist_substance_abuse', 'person_id', 'pedestrian_type', 'pedestrian_movement', 'pedestrian_actions', 'pedestrian_location', 'pedestrian_obeyed_traffic_signal', 'pedestrian_visibility', 'at_fault', 'injury_severity', 'safety_equipment']

# %%
# Count the number of columns containing 'Missing'
missing_columns_count = 0
missing_columns = []

for column in sql_frame.columns:
    if (sql_frame[column] == 'Missing').any():
        missing_count = (sql_frame[column] == 'Missing').sum()
        if missing_count > 0:
            missing_columns_count += 1
            missing_columns.append((column, missing_count))

print("Total number of columns with 'Missing' values:", missing_columns_count)
print("Columns with count of 'Missing' values:")
for column_name, count in missing_columns:
    print(f"{column_name}: {count}")
# Out:
# Total number of columns with 'Missing' values: 15
# Columns with count of 'Missing' values:
# road_Name: 1238
# cross_street_name: 1239
# collision_type: 178
# weather: 458
# surface_condition: 1382
# light: 46
# traffic_control: 811
# non_motorist_substance_abuse: 1203
# pedestrian_movement: 156
# pedestrian_actions: 294
# pedestrian_location: 153
# pedestrian_obeyed_traffic_signal: 1666
# pedestrian_visibility: 542
# at_fault: 287
# safety_equipment: 1908

# %%
# Define threshold for dropping columns
threshold = 1800

# Filter columns with count of 'Missing' values greater than threshold
columns_to_drop = [column for column, count in missing_columns if count > threshold]

# Drop columns from DataFrame
sql_frame.drop(columns=columns_to_drop, inplace=True)

# Print the remaining columns
print("Remaining columns after dropping:")
print(sql_frame.columns.tolist())
# Out:
# Remaining columns after dropping:
# ['report_number', 'local_case_number', 'agency_name', 'acrs_report_type', 'crash_date_time', 'route_type', 'road_Name', 'cross_street_name', 'related_non_motorist', 'collision_type', 'weather', 'surface_condition', 'light', 'traffic_control', 'driver_substance_abuse', 'non_motorist_substance_abuse', 'person_id', 'pedestrian_type', 'pedestrian_movement', 'pedestrian_actions', 'pedestrian_location', 'pedestrian_obeyed_traffic_signal', 'pedestrian_visibility', 'at_fault', 'injury_severity']

# %%
sql_frame.head()
# Out:
#   report_number local_case_number               agency_name  \
# 0   MCP2563001L         230017107  Montgomery County Police
# 1   MCP2771002B         230034003  Montgomery County Police
# 2   MCP2861005Z         230034963  Montgomery County Police
# 3   MCP3299002R         230034733  Montgomery County Police
# 4   MCP3360000L         230046354  Montgomery County Police
#
#         acrs_report_type         crash_date_time        route_type  \
# 0           Injury Crash  10/04/2023 04:21:00 pm  Maryland (State)
# 1           Injury Crash  07/17/2023 12:53:00 PM            County
# 2           Injury Crash  07/22/2023 06:58:00 PM            County
# 3  Property Damage Crash  07/21/2023 11:52:00 AM  Maryland (State)
# 4           Injury Crash  07/25/2023 10:12:00 AM            County
#
#            road_Name        cross_street_name related_non_motorist  \
# 0  MUNCASTER MILL RD  STRUC #15015 ROCK CREEK           PEDESTRIAN
# 1           PECAN DR             BUTTERNUT DR                OTHER
# 2            Missing                  Missing           PEDESTRIAN
# 3        GEORGIA AVE         OLD BALTIMORE RD           PEDESTRIAN
# 4    WATKINS MILL RD              STEDWICK RD            BICYCLIST
#
#    collision_type  ... non_motorist_substance_abuse  \
# 0  SINGLE VEHICLE  ...                NONE DETECTED
# 1  SINGLE VEHICLE  ...                      Missing
# 2  SINGLE VEHICLE  ...                NONE DETECTED
# 3           OTHER  ...                NONE DETECTED
# 4  SINGLE VEHICLE  ...                      Missing
#
#                               person_id pedestrian_type  \
# 0  2D1655C2-78EB-4552-899C-4C57B12B59E9      PEDESTRIAN
# 1  263E6D27-5F3B-4F27-9D29-B7F2F866CCEB           OTHER
# 2  6EED454B-5A6E-487D-8544-F969F2F21350      PEDESTRIAN
# 3  B056C81B-F1F4-4BA9-83CB-E61F2756C13D      PEDESTRIAN
# 4  390AA256-2353-4FB7-92CB-4F3F61C6ED75       BICYCLIST
#
#                pedestrian_movement             pedestrian_actions  \
# 0  Cross/Enter not at Intersection  FAILURE TO YIELD RIGHT OF WAY
# 1           Getting off/on Vehicle                          OTHER
# 2                            Other          IN ROADWAY IMPROPERLY
# 3      Cross/Enter at Intersection            NO IMPROPER ACTIONS
# 4                          Missing            NO IMPROPER ACTIONS
#
#                 pedestrian_location pedestrian_obeyed_traffic_signal  \
# 0           ON ROADWAY AT CROSSWALK                   NO PED. SIGNAL
# 1                             OTHER                          Missing
# 2       ON ROADWAY NOT AT CROSSWALK                   NO PED. SIGNAL
# 3           ON ROADWAY AT CROSSWALK               OBEYED PED. SIGNAL
# 4  AT INTERSECTION MARKED CROSSWALK               OBEYED PED. SIGNAL
#
#   pedestrian_visibility at_fault           injury_severity
# 0         DARK CLOTHING      Yes  SUSPECTED SERIOUS INJURY
# 1        LIGHT CLOTHING      Yes    SUSPECTED MINOR INJURY
# 2        LIGHT CLOTHING       No    SUSPECTED MINOR INJURY
# 3        LIGHT CLOTHING       No        NO APPARENT INJURY
# 4               UNKNOWN       No    SUSPECTED MINOR INJURY
#
# [5 rows x 25 columns]

# %%
final_transformed_frame=sql_frame

# %%
# Assuming final_transformed_frame is your DataFrame and filename is the name of the output file
filename = "non_motorists.json"
final_transformed_frame.to_json(filename, orient='records')

# %% [markdown]
# ### MongoDB Cluster connection

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://x23187956:waleed123@montgomerycluster.tzxvtsd.mongodb.net/?retryWrites=true&w=majority&appName=montgomerycluster"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

try:
    #client.admin.command('ping')
    client.montgomery.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %% [markdown]
# ### Check server status

# %%
try:
    server_status = client.montgomery.command('serverStatus')
    print("Server is up and running.")
except Exception as e:
    print("Error:", e)
# Out:
# Server is up and running.

# %% [markdown]
# ### List all databases

# %%
databases = client.list_database_names()
print("Databases:")
for db_obj in databases:
    print(db_obj)
# Out:
# Databases:
# montgomery
# admin
# local

# %% [markdown]
# ### List all collections in a specific database

# %%
database_name = "montgomery"
collections = client[database_name].list_collection_names()
print("\nCollections in", database_name, ":")
for col in collections:
    print(col)
# Out:
# Collections in montgomery :
# drivers_dupe
# incident

# %% [markdown]
# ### Create database named montgomery

# %%
# Access the montgomery database (or create it if it doesn't exist)
db = client["montgomery"]
# Create a collection named "incidents"
collection = db["non_motorists"]
collection
# Out:
# Collection(Database(MongoClient(host=['ac-splqn9y-shard-00-02.tzxvtsd.mongodb.net:27017', 'ac-splqn9y-shard-00-01.tzxvtsd.mongodb.net:27017', 'ac-splqn9y-shard-00-00.tzxvtsd.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='montgomerycluster', authsource='admin', replicaset='atlas-t83v95-shard-0', tls=True, server_api=<pymongo.server_api.ServerApi object at 0x0000017CD0A77710>), 'montgomery'), 'non_motorists')

# %% [markdown]
# ### Load JSON file into incidents collection of montgomery database

# %%
# Get the total number of documents in the collection
total_records = collection.count_documents({})
print("Total number of records in the collection:", total_records)
# Out:
# Total number of records in the collection: 0

# %%
# Select database and collection
db = client['montgomery']
collection_name = 'non_motorists'

# %%
import json
# Load JSON file
filename = "non_motorists.json"
with open(filename, 'r') as file:
    data = json.load(file)

# %%
# Insert documents into collection
collection = db[collection_name]
collection.insert_many(data)
print("JSON data successfully loaded into MongoDB collection 'non_motorists' in database 'montgomery'.")
total_records = collection.count_documents({})
print("Total number of records in the collection:", total_records)
# Out:
# JSON data successfully loaded into MongoDB collection 'non_motorists' in database 'montgomery'.
# Total number of records in the collection: 5650

# %%
collection_data = collection.find({})

# %%
non_motorists_mongo_df = pd.DataFrame(collection_data)

# %%
non_motorists_mongo_df
# Out:
#                            _id report_number local_case_number  \
# 0     66269be948466b0ba046b145   MCP2563001L         230017107
# 1     66269be948466b0ba046b146   MCP2771002B         230034003
# 2     66269be948466b0ba046b147   MCP2861005Z         230034963
# 3     66269be948466b0ba046b148   MCP3299002R         230034733
# 4     66269be948466b0ba046b149   MCP3360000L         230046354
# ...                        ...           ...               ...
# 5645  66269be948466b0ba046c752   MCP1151006L         170515099
# 5646  66269be948466b0ba046c753   MCP3243000C         200032846
# 5647  66269be948466b0ba046c754   MCP15950022         220027156
# 5648  66269be948466b0ba046c755    EJ7857001Q         170533688
# 5649  66269be948466b0ba046c756   MCP2964001H          16021317
#
#                     agency_name       acrs_report_type  \
# 0      Montgomery County Police           Injury Crash
# 1      Montgomery County Police           Injury Crash
# 2      Montgomery County Police           Injury Crash
# 3      Montgomery County Police  Property Damage Crash
# 4      Montgomery County Police           Injury Crash
# ...                         ...                    ...
# 5645   Montgomery County Police           Injury Crash
# 5646   Montgomery County Police           Injury Crash
# 5647   Montgomery County Police           Injury Crash
# 5648  Gaithersburg Police Depar           Injury Crash
# 5649   Montgomery County Police           Injury Crash
#
#              crash_date_time        route_type          road_Name  \
# 0     10/04/2023 04:21:00 pm  Maryland (State)  MUNCASTER MILL RD
# 1     07/17/2023 12:53:00 PM            County           PECAN DR
# 2     07/22/2023 06:58:00 PM            County            Missing
# 3     07/21/2023 11:52:00 AM  Maryland (State)        GEORGIA AVE
# 4     07/25/2023 10:12:00 AM            County    WATKINS MILL RD
# ...                      ...               ...                ...
# 5645  06/22/2017 07:41:00 AM            County            Missing
# 5646  08/22/2020 05:17:00 PM            County       ROCKLEDGE DR
# 5647  08/28/2022 03:07:00 AM  Maryland (State)        GEORGIA AVE
# 5648  09/28/2017 06:24:00 PM            County            Missing
# 5649  04/30/2016 04:08:00 PM  Maryland (State)       FREDERICK RD
#
#             cross_street_name related_non_motorist  ...  \
# 0     STRUC #15015 ROCK CREEK           PEDESTRIAN  ...
# 1                BUTTERNUT DR                OTHER  ...
# 2                     Missing           PEDESTRIAN  ...
# 3            OLD BALTIMORE RD           PEDESTRIAN  ...
# 4                 STEDWICK RD            BICYCLIST  ...
# ...                       ...                  ...  ...
# 5645                  Missing           PEDESTRIAN  ...
# 5646           ROCK SPRING DR            BICYCLIST  ...
# 5647              ENNALLS AVE           PEDESTRIAN  ...
# 5648                  Missing                OTHER  ...
# 5649           MIDDLEBROOK RD            BICYCLIST  ...
#
#      non_motorist_substance_abuse                             person_id  \
# 0                   NONE DETECTED  2D1655C2-78EB-4552-899C-4C57B12B59E9
# 1                         Missing  263E6D27-5F3B-4F27-9D29-B7F2F866CCEB
# 2                   NONE DETECTED  6EED454B-5A6E-487D-8544-F969F2F21350
# 3                   NONE DETECTED  B056C81B-F1F4-4BA9-83CB-E61F2756C13D
# 4                         Missing  390AA256-2353-4FB7-92CB-4F3F61C6ED75
# ...                           ...                                   ...
# 5645                NONE DETECTED  BC497ADC-3FF3-498C-9254-602F97B58E77
# 5646                NONE DETECTED  53442B68-0BC2-45DB-BC92-1230D88DEB02
# 5647          ALCOHOL CONTRIBUTED  25EB92E1-A49D-47BA-81F7-8B4496424914
# 5648                NONE DETECTED  4F3583D1-95D0-452F-B95F-AABB40778DA8
# 5649                NONE DETECTED  C9C78F9A-B57D-4AA9-A18A-ADC1BD43341A
#
#      pedestrian_type              pedestrian_movement  \
# 0         PEDESTRIAN  Cross/Enter not at Intersection
# 1              OTHER           Getting off/on Vehicle
# 2         PEDESTRIAN                            Other
# 3         PEDESTRIAN      Cross/Enter at Intersection
# 4          BICYCLIST                          Missing
# ...              ...                              ...
# 5645      PEDESTRIAN                            Other
# 5646       BICYCLIST      Cross/Enter at Intersection
# 5647      PEDESTRIAN  Cross/Enter not at Intersection
# 5648           OTHER                          Playing
# 5649       BICYCLIST      Cross/Enter at Intersection
#
#                                     pedestrian_actions  \
# 0                        FAILURE TO YIELD RIGHT OF WAY
# 1                                                OTHER
# 2                                IN ROADWAY IMPROPERLY
# 3                                  NO IMPROPER ACTIONS
# 4                                  NO IMPROPER ACTIONS
# ...                                                ...
# 5645                               NO IMPROPER ACTIONS
# 5646  FAILURE TO OBEY TRAFFIC SIGNS SIGNALS OR OFFICER
# 5647                               NO IMPROPER ACTIONS
# 5648                             IN ROADWAY IMPROPERLY
# 5649                                       INATTENTIVE
#
#                    pedestrian_location pedestrian_obeyed_traffic_signal  \
# 0              ON ROADWAY AT CROSSWALK                   NO PED. SIGNAL
# 1                                OTHER                          Missing
# 2          ON ROADWAY NOT AT CROSSWALK                   NO PED. SIGNAL
# 3              ON ROADWAY AT CROSSWALK               OBEYED PED. SIGNAL
# 4     AT INTERSECTION MARKED CROSSWALK               OBEYED PED. SIGNAL
# ...                                ...                              ...
# 5645                             OTHER                          Missing
# 5646           ON ROADWAY AT CROSSWALK            DISOBEYED PED. SIGNAL
# 5647       ON ROADWAY NOT AT CROSSWALK                   NO PED. SIGNAL
# 5648                           Missing                   NO PED. SIGNAL
# 5649           ON ROADWAY AT CROSSWALK                   NO PED. SIGNAL
#
#      pedestrian_visibility at_fault           injury_severity
# 0            DARK CLOTHING      Yes  SUSPECTED SERIOUS INJURY
# 1           LIGHT CLOTHING      Yes    SUSPECTED MINOR INJURY
# 2           LIGHT CLOTHING       No    SUSPECTED MINOR INJURY
# 3           LIGHT CLOTHING       No        NO APPARENT INJURY
# 4                  UNKNOWN       No    SUSPECTED MINOR INJURY
# ...                    ...      ...                       ...
# 5645        MIXED CLOTHING       No           POSSIBLE INJURY
# 5646        LIGHT CLOTHING      Yes    SUSPECTED MINOR INJURY
# 5647         DARK CLOTHING      Yes           POSSIBLE INJURY
# 5648         DARK CLOTHING      Yes    SUSPECTED MINOR INJURY
# 5649        MIXED CLOTHING      Yes    SUSPECTED MINOR INJURY
#
# [5650 rows x 26 columns]
